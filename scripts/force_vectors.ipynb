# %% [markdown]
# # Generate Force Vectors

# %% [markdown]
# The goal here is to visualize the force vectors generated by a charged particle moving in a magnetic field.  We'll be looking a much simplier exercise than a full simulation.

# %%
from mu2e.dataframeprod import DataFrameMaker
from mu2e import mu2e_ext_path
import matplotlib.pyplot as plt
from mu2e.tools.axes3d_hack import Axes3D

# %%
 df = DataFrameMaker(mu2e_ext_path+'datafiles/FieldMapsGA05/DSMap', use_pickle=True).data_frame

# %%
xs = range(-500,1,50)
ys = [-100,0]
zs = range(12721, 12900,50)
zs
# Out:
# [12721, 12771, 12821, 12871]

# %%
df_trap = df.query('12600<Z<13000 and -800<X<800 and -800<Y<800', inplace=False)
df_trap = df_trap[(df_trap.X.isin(xs)) & (df_trap.Y.isin(ys)) & (df_trap.Z.isin(zs))]

# %%
df_trap_bx = df_trap[['X','Y','Z','Bx','By','Bz']]

# %%
df_trap_bx.eval('By=0',inplace=True)
df_trap_bx.eval('Bz=0',inplace=True)

# %%
df_trap_bx[['Bx','By','Bz']].values
# Out:
# array([[-0.00297048,  0.        ,  0.        ],
#        [-0.00303274,  0.        ,  0.        ],
#        [-0.00317664,  0.        ,  0.        ],
#        [-0.00344001,  0.        ,  0.        ],
#        [-0.0029798 ,  0.        ,  0.        ],
#        [-0.00306143,  0.        ,  0.        ],
#        [-0.00323003,  0.        ,  0.        ],
#        [-0.00352449,  0.        ,  0.        ],
#        [-0.00291015,  0.        ,  0.        ],
#        [-0.00304199,  0.        ,  0.        ],
#        [-0.00326764,  0.        ,  0.        ],
#        [-0.00362503,  0.        ,  0.        ],
#        [-0.0029107 ,  0.        ,  0.        ],
#        [-0.0030614 ,  0.        ,  0.        ],
#        [-0.00331072,  0.        ,  0.        ],
#        [-0.00369746,  0.        ,  0.        ],
#        [-0.0028158 ,  0.        ,  0.        ],
#        [-0.00299635,  0.        ,  0.        ],
#        [-0.00327631,  0.        ,  0.        ],
#        [-0.00369206,  0.        ,  0.        ],
#        [-0.00280944,  0.        ,  0.        ],
#        [-0.00300784,  0.        ,  0.        ],
#        [-0.00330991,  0.        ,  0.        ],
#        [-0.0037527 ,  0.        ,  0.        ],
#        [-0.00268032,  0.        ,  0.        ],
#        [-0.00288882,  0.        ,  0.        ],
#        [-0.00319636,  0.        ,  0.        ],
#        [-0.0036365 ,  0.        ,  0.        ],
#        [-0.00266811,  0.        ,  0.        ],
#        [-0.00289306,  0.        ,  0.        ],
#        [-0.00322074,  0.        ,  0.        ],
#        [-0.00368522,  0.        ,  0.        ],
#        [-0.00250048,  0.        ,  0.        ],
#        [-0.00271725,  0.        ,  0.        ],
#        [-0.00302748,  0.        ,  0.        ],
#        [-0.00346096,  0.        ,  0.        ],
#        [-0.00248294,  0.        ,  0.        ],
#        [-0.00271447,  0.        ,  0.        ],
#        [-0.00304257,  0.        ,  0.        ],
#        [-0.00349738,  0.        ,  0.        ],
#        [-0.00227664,  0.        ,  0.        ],
#        [-0.00248387,  0.        ,  0.        ],
#        [-0.00277456,  0.        ,  0.        ],
#        [-0.00317405,  0.        ,  0.        ],
#        [-0.00225394,  0.        ,  0.        ],
#        [-0.00247399,  0.        ,  0.        ],
#        [-0.00278005,  0.        ,  0.        ],
#        [-0.00319772,  0.        ,  0.        ],
#        [-0.00201231,  0.        ,  0.        ],
#        [-0.00219457,  0.        ,  0.        ],
#        [-0.00244673,  0.        ,  0.        ],
#        [-0.00278921,  0.        ,  0.        ],
#        [-0.00198441,  0.        ,  0.        ],
#        [-0.00217739,  0.        ,  0.        ],
#        [-0.00244229,  0.        ,  0.        ],
#        [-0.00279967,  0.        ,  0.        ],
#        [-0.00171363,  0.        ,  0.        ],
#        [-0.00185835,  0.        ,  0.        ],
#        [-0.0020566 ,  0.        ,  0.        ],
#        [-0.00232362,  0.        ,  0.        ],
#        [-0.00168039,  0.        ,  0.        ],
#        [-0.00183361,  0.        ,  0.        ],
#        [-0.00204186,  0.        ,  0.        ],
#        [-0.00232047,  0.        ,  0.        ],
#        [-0.00138885,  0.        ,  0.        ],
#        [-0.00148653,  0.        ,  0.        ],
#        [-0.00161938,  0.        ,  0.        ],
#        [-0.00179726,  0.        ,  0.        ],
#        [-0.00135013,  0.        ,  0.        ],
#        [-0.00145401,  0.        ,  0.        ],
#        [-0.00159406,  0.        ,  0.        ],
#        [-0.00178019,  0.        ,  0.        ],
#        [-0.00104777,  0.        ,  0.        ],
#        [-0.00109223,  0.        ,  0.        ],
#        [-0.00115219,  0.        ,  0.        ],
#        [-0.00123207,  0.        ,  0.        ],
#        [-0.00100347,  0.        ,  0.        ],
#        [-0.00105178,  0.        ,  0.        ],
#        [-0.0011161 ,  0.        ,  0.        ],
#        [-0.00120089,  0.        ,  0.        ],
#        [-0.00070124,  0.        ,  0.        ],
#        [-0.00068967,  0.        ,  0.        ],
#        [-0.00067336,  0.        ,  0.        ],
#        [-0.00065123,  0.        ,  0.        ],
#        [-0.00065135,  0.        ,  0.        ],
#        [-0.00064125,  0.        ,  0.        ],
#        [-0.00062646,  0.        ,  0.        ],
#        [-0.00060589,  0.        ,  0.        ]])

# %%
py = [[0,100,0]]*len(df_trap_bx)

# %%
fz = -1*np.cross(py,df_trap_bx[['Bx','By','Bz']].values)[:,2]

# %%
df_trap_bx['Fz']=fz
df_trap_bx.eval('Fx=0',inplace=True)
df_trap_bx.eval('Fy=0',inplace=True)
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df_trap_bx[['X','Y','Z','Fx','Fy','Fz']]
# Out:
#              X      Y        Z  Fx  Fy        Fz
# 1438346 -500.0 -100.0  12721.0   0   0 -0.297048
# 1438348 -500.0 -100.0  12771.0   0   0 -0.303274
# 1438350 -500.0 -100.0  12821.0   0   0 -0.317664
# 1438352 -500.0 -100.0  12871.0   0   0 -0.344001
# 1440430 -500.0    0.0  12721.0   0   0 -0.297980
# 1440432 -500.0    0.0  12771.0   0   0 -0.306143
# 1440434 -500.0    0.0  12821.0   0   0 -0.323003
# 1440436 -500.0    0.0  12871.0   0   0 -0.352449
# 1539420 -450.0 -100.0  12721.0   0   0 -0.291015
# 1539422 -450.0 -100.0  12771.0   0   0 -0.304199
# 1539424 -450.0 -100.0  12821.0   0   0 -0.326764
# 1539426 -450.0 -100.0  12871.0   0   0 -0.362503
# 1541504 -450.0    0.0  12721.0   0   0 -0.291070
# 1541506 -450.0    0.0  12771.0   0   0 -0.306140
# 1541508 -450.0    0.0  12821.0   0   0 -0.331072
# 1541510 -450.0    0.0  12871.0   0   0 -0.369746
# 1640494 -400.0 -100.0  12721.0   0   0 -0.281580
# 1640496 -400.0 -100.0  12771.0   0   0 -0.299635
# 1640498 -400.0 -100.0  12821.0   0   0 -0.327631
# 1640500 -400.0 -100.0  12871.0   0   0 -0.369206
# 1642578 -400.0    0.0  12721.0   0   0 -0.280944
# 1642580 -400.0    0.0  12771.0   0   0 -0.300784
# 1642582 -400.0    0.0  12821.0   0   0 -0.330991
# 1642584 -400.0    0.0  12871.0   0   0 -0.375271
# 1741568 -350.0 -100.0  12721.0   0   0 -0.268032
# 1741570 -350.0 -100.0  12771.0   0   0 -0.288882
# 1741572 -350.0 -100.0  12821.0   0   0 -0.319636
# 1741574 -350.0 -100.0  12871.0   0   0 -0.363650
# 1743652 -350.0    0.0  12721.0   0   0 -0.266811
# 1743654 -350.0    0.0  12771.0   0   0 -0.289306
# ...        ...    ...      ...  ..  ..       ...
# 2145868 -150.0 -100.0  12821.0   0   0 -0.205660
# 2145870 -150.0 -100.0  12871.0   0   0 -0.232362
# 2147948 -150.0    0.0  12721.0   0   0 -0.168039
# 2147950 -150.0    0.0  12771.0   0   0 -0.183361
# 2147952 -150.0    0.0  12821.0   0   0 -0.204186
# 2147954 -150.0    0.0  12871.0   0   0 -0.232047
# 2246938 -100.0 -100.0  12721.0   0   0 -0.138885
# 2246940 -100.0 -100.0  12771.0   0   0 -0.148653
# 2246942 -100.0 -100.0  12821.0   0   0 -0.161938
# 2246944 -100.0 -100.0  12871.0   0   0 -0.179726
# 2249022 -100.0    0.0  12721.0   0   0 -0.135013
# 2249024 -100.0    0.0  12771.0   0   0 -0.145401
# 2249026 -100.0    0.0  12821.0   0   0 -0.159406
# 2249028 -100.0    0.0  12871.0   0   0 -0.178019
# 2348012  -50.0 -100.0  12721.0   0   0 -0.104777
# 2348014  -50.0 -100.0  12771.0   0   0 -0.109223
# 2348016  -50.0 -100.0  12821.0   0   0 -0.115219
# 2348018  -50.0 -100.0  12871.0   0   0 -0.123207
# 2350096  -50.0    0.0  12721.0   0   0 -0.100347
# 2350098  -50.0    0.0  12771.0   0   0 -0.105178
# 2350100  -50.0    0.0  12821.0   0   0 -0.111610
# 2350102  -50.0    0.0  12871.0   0   0 -0.120089
# 2449086    0.0 -100.0  12721.0   0   0 -0.070124
# 2449088    0.0 -100.0  12771.0   0   0 -0.068967
# 2449090    0.0 -100.0  12821.0   0   0 -0.067336
# 2449092    0.0 -100.0  12871.0   0   0 -0.065123
# 2451170    0.0    0.0  12721.0   0   0 -0.065134
# 2451172    0.0    0.0  12771.0   0   0 -0.064125
# 2451174    0.0    0.0  12821.0   0   0 -0.062646
# 2451176    0.0    0.0  12871.0   0   0 -0.060589
#
# [88 rows x 6 columns]

# %%
df_trap_bx.shape[0]**(1./3.)
qxx,qyy,qzz,qfxx,qfyy,qfzz = df_trap_bx[['X','Y','Z','Fx','Fy','Fz']].values.T.reshape(
    6,len(df_trap_bx.X.unique()),len(df_trap_bx.Y.unique()),len(df_trap_bx.Z.unique()))

# %%
plt.close('all')
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.quiver(qzz,qxx,qyy, qfzz*50,qfxx,qfyy, colors='g',linewidth=1.5, arrow_length_ratio=0.5)
plt.show()
ax.set_xlabel('Z (mm)')
ax.set_ylabel('X (mm)')
ax.set_zlabel('Y (mm)')
plt.title('Py and Bx, X50 mag')

# %%
qfzz*1000
# Out:
# array([[[-297.0484, -303.2737, -317.6644, -344.0011],
#         [-297.9804, -306.143 , -323.003 , -352.4488]],
#
#        [[-291.0146, -304.1991, -326.7637, -362.5027],
#         [-291.0704, -306.14  , -331.072 , -369.7457]],
#
#        [[-281.5803, -299.6354, -327.6305, -369.206 ],
#         [-280.9445, -300.7842, -330.9909, -375.2705]],
#
#        [[-268.032 , -288.8819, -319.6355, -363.6503],
#         [-266.8112, -289.3061, -322.0742, -368.5216]],
#
#        [[-250.0477, -271.7253, -302.7485, -346.0962],
#         [-248.2938, -271.4466, -304.2567, -349.7381]],
#
#        [[-227.6637, -248.3865, -277.4559, -317.4052],
#         [-225.3936, -247.3985, -278.0054, -319.7721]],
#
#        [[-201.2307, -219.4575, -244.6734, -278.921 ],
#         [-198.4406, -217.7392, -244.2285, -279.9671]],
#
#        [[-171.363 , -185.8346, -205.6599, -232.362 ],
#         [-168.0394, -183.3609, -204.1857, -232.0471]],
#
#        [[-138.885 , -148.6532, -161.9379, -179.7262],
#         [-135.0133, -145.4012, -159.4056, -178.019 ]],
#
#        [[-104.7774, -109.2229, -115.2189, -123.2071],
#         [-100.3474, -105.1776, -111.6102, -120.0889]],
#
#        [[ -70.1241,  -68.967 ,  -67.336 ,  -65.1229],
#         [ -65.1345,  -64.1252,  -62.6465,  -60.5894]]])
