# %%
import os
from mu2e import mu2e_ext_path
from mu2e.dataframeprod import DataFrameMaker
from mu2e.mu2eplots import mu2e_plot, mu2e_plot3d
import pandas as pd
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12,8)
from skhep.visual import MplPlotter as splt
from copy import deepcopy
from lmfit import Model, Parameters, report_fit
# Out:
# /usr/local/lib/python3.6/site-packages/IPython/html.py:14: ShimWarning:
#
# The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#
# /usr/local/lib/python3.6/site-packages/plotly/widgets/graph_widget.py:13: UserWarning:
#
# IPython.utils.traitlets has moved to a top-level traitlets package.

# %% [markdown]
# # 1 Slice v 1 Slice

# %%
run hallprobesim.py
# Out:
# 0
# (140, 10)
# 375.0
# 1450.0
# 0.002490821
# 2260594    0.002491
# Name: Br, dtype: float64
# fitting with n=20, m=20, cn=0, cm=0
# Elapsed time was 228.503 seconds
# [[Fit Statistics]]
#     # function evals   = 24
#     # data points      = 4200
#     # variables        = 362
#     chi-square         = 0.000
#     reduced chi-square = 0.000
#     Akaike info crit   = -102850.297
#     Bayesian info crit = -100554.189
# [[Variables]]
#     R:         75000 (fixed)
#     ns:        20 (fixed)
#     ms:        20 (fixed)
#     A_0_0:     0 (fixed)
#     B_0_0:     0 (fixed)
#     C_0_0:     0 (fixed)
#     D_0_0:     0 (fixed)
#     A_0_1:     0 (fixed)
#     B_0_1:     0 (fixed)
#     C_0_1:     0 (fixed)
#     D_0_1:     0 (fixed)
#     A_0_2:     0 (fixed)
#     B_0_2:     0 (fixed)
#     C_0_2:     0 (fixed)
#     D_0_2:     0 (fixed)
#     A_0_3:     0 (fixed)
#     B_0_3:     0 (fixed)
#     C_0_3:     0 (fixed)
#     D_0_3:     0 (fixed)
#     A_0_4:     0 (fixed)
#     B_0_4:     0 (fixed)
#     C_0_4:     0 (fixed)
#     D_0_4:     0 (fixed)
#     A_0_5:     0 (fixed)
#     B_0_5:     0 (fixed)
#     C_0_5:     0 (fixed)
#     D_0_5:     0 (fixed)
#     A_0_6:     0 (fixed)
#     B_0_6:     0 (fixed)
#     C_0_6:     0 (fixed)
#     D_0_6:     0 (fixed)
#     A_0_7:     0 (fixed)
#     B_0_7:     0 (fixed)
#     C_0_7:     0 (fixed)
#     D_0_7:     0 (fixed)
#     A_0_8:     0 (fixed)
#     B_0_8:     0 (fixed)
#     C_0_8:     0 (fixed)
#     D_0_8:     0 (fixed)
#     A_0_9:     0 (fixed)
#     B_0_9:     0 (fixed)
#     C_0_9:     0 (fixed)
#     D_0_9:     0 (fixed)
#     A_0_10:    0 (fixed)
#     B_0_10:    0 (fixed)
#     C_0_10:    0 (fixed)
#     D_0_10:    0 (fixed)
#     A_0_11:    0 (fixed)
#     B_0_11:    0 (fixed)
#     C_0_11:    0 (fixed)
#     D_0_11:    0 (fixed)
#     A_0_12:    0 (fixed)
#     B_0_12:    0 (fixed)
#     C_0_12:    0 (fixed)
#     D_0_12:    0 (fixed)
#     A_0_13:    0 (fixed)
#     B_0_13:    0 (fixed)
#     C_0_13:    0 (fixed)
#     D_0_13:    0 (fixed)
#     A_0_14:    0 (fixed)
#     B_0_14:    0 (fixed)
#     C_0_14:    0 (fixed)
#     D_0_14:    0 (fixed)
#     A_0_15:    0 (fixed)
#     B_0_15:    0 (fixed)
#     C_0_15:    0 (fixed)
#     D_0_15:    0 (fixed)
#     A_0_16:    0 (fixed)
#     B_0_16:    0 (fixed)
#     C_0_16:    0 (fixed)
#     D_0_16:    0 (fixed)
#     A_0_17:    0 (fixed)
#     B_0_17:    0 (fixed)
#     C_0_17:    0 (fixed)
#     D_0_17:    0 (fixed)
#     A_0_18:    0 (fixed)
#     B_0_18:    0 (fixed)
#     C_0_18:    0 (fixed)
#     D_0_18:    0 (fixed)
#     A_0_19:    0 (fixed)
#     B_0_19:    0 (fixed)
#     C_0_19:    0 (fixed)
#     D_0_19:    0 (fixed)
#     A_1_0:     0 (fixed)
#     B_1_0:     0 (fixed)
#     C_1_0:     0 (fixed)
#     D_1_0:     0 (fixed)
#     A_1_1:     1293.32323 (init= 1)
#     B_1_1:     32797.1012 (init=-1)
#     C_1_1:     0 (fixed)
#     D_1_1:     0 (fixed)
#     A_1_2:     0 (fixed)
#     B_1_2:     3538.62315 (init=-1)
#     C_1_2:     0 (fixed)
#     D_1_2:     0 (fixed)
#     A_1_3:    -24.5855298 (init= 1)
#     B_1_3:     1803.37333 (init=-1)
#     C_1_3:     0 (fixed)
#     D_1_3:     0 (fixed)
#     A_1_4:     3881.87629 (init= 1)
#     B_1_4:    -431.609112 (init=-1)
#     C_1_4:     0 (fixed)
#     D_1_4:     0 (fixed)
#     A_1_5:    -10861.4833 (init= 1)
#     B_1_5:     1142.42838 (init=-1)
#     C_1_5:     0 (fixed)
#     D_1_5:     0 (fixed)
#     A_1_6:     1.10834081 (init= 1)
#     B_1_6:     6.43461297 (init=-1)
#     C_1_6:     0 (fixed)
#     D_1_6:     0 (fixed)
#     A_1_7:     1.00065177 (init= 1)
#     B_1_7:    -0.99387466 (init=-1)
#     C_1_7:     0 (fixed)
#     D_1_7:     0 (fixed)
#     A_1_8:     1.00218601 (init= 1)
#     B_1_8:    -1.00464655 (init=-1)
#     C_1_8:     0 (fixed)
#     D_1_8:     0 (fixed)
#     A_1_9:     1.00161714 (init= 1)
#     B_1_9:    -0.99607554 (init=-1)
#     C_1_9:     0 (fixed)
#     D_1_9:     0 (fixed)
#     A_1_10:    0.99983696 (init= 1)
#     B_1_10:   -0.99735363 (init=-1)
#     C_1_10:    0 (fixed)
#     D_1_10:    0 (fixed)
#     A_1_11:    1.00832574 (init= 1)
#     B_1_11:   -0.99739980 (init=-1)
#     C_1_11:    0 (fixed)
#     D_1_11:    0 (fixed)
#     A_1_12:    1.00910991 (init= 1)
#     B_1_12:   -0.99884531 (init=-1)
#     C_1_12:    0 (fixed)
#     D_1_12:    0 (fixed)
#     A_1_13:    1.00411391 (init= 1)
#     B_1_13:   -1.00555265 (init=-1)
#     C_1_13:    0 (fixed)
#     D_1_13:    0 (fixed)
#     A_1_14:    0.99593437 (init= 1)
#     B_1_14:   -1.00112117 (init=-1)
#     C_1_14:    0 (fixed)
#     D_1_14:    0 (fixed)
#     A_1_15:    0.99975849 (init= 1)
#     B_1_15:   -0.99438552 (init=-1)
#     C_1_15:    0 (fixed)
#     D_1_15:    0 (fixed)
#     A_1_16:    0.99164869 (init= 1)
#     B_1_16:   -1.00385471 (init=-1)
#     C_1_16:    0 (fixed)
#     D_1_16:    0 (fixed)
#     A_1_17:    0.99600275 (init= 1)
#     B_1_17:   -0.99420122 (init=-1)
#     C_1_17:    0 (fixed)
#     D_1_17:    0 (fixed)
#     A_1_18:    1.00013773 (init= 1)
#     B_1_18:   -1.00120510 (init=-1)
#     C_1_18:    0 (fixed)
#     D_1_18:    0 (fixed)
#     A_1_19:    1.00291462 (init= 1)
#     B_1_19:   -0.99869563 (init=-1)
#     C_1_19:    0 (fixed)
#     D_1_19:    0 (fixed)
#     A_2_0:     0 (fixed)
#     B_2_0:     0 (fixed)
#     C_2_0:     0 (fixed)
#     D_2_0:     0 (fixed)
#     A_2_1:     0 (fixed)
#     B_2_1:     0 (fixed)
#     C_2_1:     0 (fixed)
#     D_2_1:     0 (fixed)
#     A_2_2:    -692.543140 (init= 1)
#     B_2_2:     34055.3199 (init=-1)
#     C_2_2:     0 (fixed)
#     D_2_2:     0 (fixed)
#     A_2_3:     0 (fixed)
#     B_2_3:    -7438.20002 (init=-1)
#     C_2_3:     0 (fixed)
#     D_2_3:     0 (fixed)
#     A_2_4:    -0.75635461 (init= 1)
#     B_2_4:    -16.3588027 (init=-1)
#     C_2_4:     0 (fixed)
#     D_2_4:     0 (fixed)
#     A_2_5:     623.726743 (init= 1)
#     B_2_5:    -86.1447533 (init=-1)
#     C_2_5:     0 (fixed)
#     D_2_5:     0 (fixed)
#     A_2_6:    -4240.41146 (init= 1)
#     B_2_6:     3117.75294 (init=-1)
#     C_2_6:     0 (fixed)
#     D_2_6:     0 (fixed)
#     A_2_7:     14812.9874 (init= 1)
#     B_2_7:    -11916.9594 (init=-1)
#     C_2_7:     0 (fixed)
#     D_2_7:     0 (fixed)
#     A_2_8:     1.00068053 (init= 1)
#     B_2_8:    -1.14401537 (init=-1)
#     C_2_8:     0 (fixed)
#     D_2_8:     0 (fixed)
#     A_2_9:     0.99854131 (init= 1)
#     B_2_9:    -1.00400057 (init=-1)
#     C_2_9:     0 (fixed)
#     D_2_9:     0 (fixed)
#     A_2_10:    1.00111541 (init= 1)
#     B_2_10:   -1.00419290 (init=-1)
#     C_2_10:    0 (fixed)
#     D_2_10:    0 (fixed)
#     A_2_11:    1.00241959 (init= 1)
#     B_2_11:   -0.99933575 (init=-1)
#     C_2_11:    0 (fixed)
#     D_2_11:    0 (fixed)
#     A_2_12:    1.00190215 (init= 1)
#     B_2_12:   -0.99863108 (init=-1)
#     C_2_12:    0 (fixed)
#     D_2_12:    0 (fixed)
#     A_2_13:    1.00140861 (init= 1)
#     B_2_13:   -1.00127871 (init=-1)
#     C_2_13:    0 (fixed)
#     D_2_13:    0 (fixed)
#     A_2_14:    0.99740804 (init= 1)
#     B_2_14:   -0.99931588 (init=-1)
#     C_2_14:    0 (fixed)
#     D_2_14:    0 (fixed)
#     A_2_15:    0.99729271 (init= 1)
#     B_2_15:   -1.00023852 (init=-1)
#     C_2_15:    0 (fixed)
#     D_2_15:    0 (fixed)
#     A_2_16:    1.00021152 (init= 1)
#     B_2_16:   -1.00042719 (init=-1)
#     C_2_16:    0 (fixed)
#     D_2_16:    0 (fixed)
#     A_2_17:    0.99659773 (init= 1)
#     B_2_17:   -0.99598109 (init=-1)
#     C_2_17:    0 (fixed)
#     D_2_17:    0 (fixed)
#     A_2_18:    0.99990433 (init= 1)
#     B_2_18:   -0.99815137 (init=-1)
#     C_2_18:    0 (fixed)
#     D_2_18:    0 (fixed)
#     A_2_19:    0.99972531 (init= 1)
#     B_2_19:   -1.00190233 (init=-1)
#     C_2_19:    0 (fixed)
#     D_2_19:    0 (fixed)
#     A_3_0:     0 (fixed)
#     B_3_0:     0 (fixed)
#     C_3_0:     0 (fixed)
#     D_3_0:     0 (fixed)
#     A_3_1:     0 (fixed)
#     B_3_1:     0 (fixed)
#     C_3_1:     0 (fixed)
#     D_3_1:     0 (fixed)
#     A_3_2:     0 (fixed)
#     B_3_2:     0 (fixed)
#     C_3_2:     0 (fixed)
#     D_3_2:     0 (fixed)
#     A_3_3:    -89.8365368 (init= 1)
#     B_3_3:     2324.32008 (init=-1)
#     C_3_3:     0 (fixed)
#     D_3_3:     0 (fixed)
#     A_3_4:     0 (fixed)
#     B_3_4:     6216.18082 (init=-1)
#     C_3_4:     0 (fixed)
#     D_3_4:     0 (fixed)
#     A_3_5:     8.14598983 (init= 1)
#     B_3_5:    -27.1795826 (init=-1)
#     C_3_5:     0 (fixed)
#     D_3_5:     0 (fixed)
#     A_3_6:    -1193.97782 (init= 1)
#     B_3_6:     408.006739 (init=-1)
#     C_3_6:     0 (fixed)
#     D_3_6:     0 (fixed)
#     A_3_7:    -351.216960 (init= 1)
#     B_3_7:    -5457.07991 (init=-1)
#     C_3_7:     0 (fixed)
#     D_3_7:     0 (fixed)
#     A_3_8:    -8384.96076 (init= 1)
#     B_3_8:     2967.40725 (init=-1)
#     C_3_8:     0 (fixed)
#     D_3_8:     0 (fixed)
#     A_3_9:     13266.9106 (init= 1)
#     B_3_9:    -4254.84103 (init=-1)
#     C_3_9:     0 (fixed)
#     D_3_9:     0 (fixed)
#     A_3_10:    0.99990555 (init= 1)
#     B_3_10:   -1.00094142 (init=-1)
#     C_3_10:    0 (fixed)
#     D_3_10:    0 (fixed)
#     A_3_11:    0.99764408 (init= 1)
#     B_3_11:   -0.99952965 (init=-1)
#     C_3_11:    0 (fixed)
#     D_3_11:    0 (fixed)
#     A_3_12:    1.00006650 (init= 1)
#     B_3_12:   -1.00321952 (init=-1)
#     C_3_12:    0 (fixed)
#     D_3_12:    0 (fixed)
#     A_3_13:    1.00224670 (init= 1)
#     B_3_13:   -0.99920093 (init=-1)
#     C_3_13:    0 (fixed)
#     D_3_13:    0 (fixed)
#     A_3_14:    1.00114188 (init= 1)
#     B_3_14:   -1.00109835 (init=-1)
#     C_3_14:    0 (fixed)
#     D_3_14:    0 (fixed)
#     A_3_15:    0.99914756 (init= 1)
#     B_3_15:   -1.00009259 (init=-1)
#     C_3_15:    0 (fixed)
#     D_3_15:    0 (fixed)
#     A_3_16:    1.00127424 (init= 1)
#     B_3_16:   -1.00103266 (init=-1)
#     C_3_16:    0 (fixed)
#     D_3_16:    0 (fixed)
#     A_3_17:    0.99832772 (init= 1)
#     B_3_17:   -0.99973355 (init=-1)
#     C_3_17:    0 (fixed)
#     D_3_17:    0 (fixed)
#     A_3_18:    0.99946967 (init= 1)
#     B_3_18:   -1.00200480 (init=-1)
#     C_3_18:    0 (fixed)
#     D_3_18:    0 (fixed)
#     A_3_19:    0.99799518 (init= 1)
#     B_3_19:   -0.99961524 (init=-1)
#     C_3_19:    0 (fixed)
#     D_3_19:    0 (fixed)
#     A_4_0:     0 (fixed)
#     B_4_0:     0 (fixed)
#     C_4_0:     0 (fixed)
#     D_4_0:     0 (fixed)
#     A_4_1:     0 (fixed)
#     B_4_1:     0 (fixed)
#     C_4_1:     0 (fixed)
#     D_4_1:     0 (fixed)
#     A_4_2:     0 (fixed)
#     B_4_2:     0 (fixed)
#     C_4_2:     0 (fixed)
#     D_4_2:     0 (fixed)
#     A_4_3:     0 (fixed)
#     B_4_3:     0 (fixed)
#     C_4_3:     0 (fixed)
#     D_4_3:     0 (fixed)
#     A_4_4:     869.124255 (init= 1)
#     B_4_4:    -1884.31397 (init=-1)
#     C_4_4:     0 (fixed)
#     D_4_4:     0 (fixed)
#     A_4_5:     0 (fixed)
#     B_4_5:    -73.2863095 (init=-1)
#     C_4_5:     0 (fixed)
#     D_4_5:     0 (fixed)
#     A_4_6:     46.0659321 (init= 1)
#     B_4_6:    -4249.00945 (init=-1)
#     C_4_6:     0 (fixed)
#     D_4_6:     0 (fixed)
#     A_4_7:    -2.23455892 (init= 1)
#     B_4_7:     123.365346 (init=-1)
#     C_4_7:     0 (fixed)
#     D_4_7:     0 (fixed)
#     A_4_8:     593.878071 (init= 1)
#     B_4_8:    -4283.93850 (init=-1)
#     C_4_8:     0 (fixed)
#     D_4_8:     0 (fixed)
#     A_4_9:    -14808.7149 (init= 1)
#     B_4_9:     1802.98380 (init=-1)
#     C_4_9:     0 (fixed)
#     D_4_9:     0 (fixed)
#     A_4_10:    23191.0642 (init= 1)
#     B_4_10:    10962.3016 (init=-1)
#     C_4_10:    0 (fixed)
#     D_4_10:    0 (fixed)
#     A_4_11:    0.92960066 (init= 1)
#     B_4_11:    85.6930784 (init=-1)
#     C_4_11:    0 (fixed)
#     D_4_11:    0 (fixed)
#     A_4_12:    0.99979640 (init= 1)
#     B_4_12:   -1.00103872 (init=-1)
#     C_4_12:    0 (fixed)
#     D_4_12:    0 (fixed)
#     A_4_13:    0.99920504 (init= 1)
#     B_4_13:   -1.00327300 (init=-1)
#     C_4_13:    0 (fixed)
#     D_4_13:    0 (fixed)
#     A_4_14:    0.99964246 (init= 1)
#     B_4_14:   -1.00046503 (init=-1)
#     C_4_14:    0 (fixed)
#     D_4_14:    0 (fixed)
#     A_4_15:    0.99915556 (init= 1)
#     B_4_15:   -1.00188494 (init=-1)
#     C_4_15:    0 (fixed)
#     D_4_15:    0 (fixed)
#     A_4_16:    1.00062290 (init= 1)
#     B_4_16:   -1.00011409 (init=-1)
#     C_4_16:    0 (fixed)
#     D_4_16:    0 (fixed)
#     A_4_17:    0.99651628 (init= 1)
#     B_4_17:   -0.99990122 (init=-1)
#     C_4_17:    0 (fixed)
#     D_4_17:    0 (fixed)
#     A_4_18:    0.99868755 (init= 1)
#     B_4_18:   -0.99912300 (init=-1)
#     C_4_18:    0 (fixed)
#     D_4_18:    0 (fixed)
#     A_4_19:    0.99938148 (init= 1)
#     B_4_19:   -0.99879594 (init=-1)
#     C_4_19:    0 (fixed)
#     D_4_19:    0 (fixed)
#     A_5_0:     0 (fixed)
#     B_5_0:     0 (fixed)
#     C_5_0:     0 (fixed)
#     D_5_0:     0 (fixed)
#     A_5_1:     0 (fixed)
#     B_5_1:     0 (fixed)
#     C_5_1:     0 (fixed)
#     D_5_1:     0 (fixed)
#     A_5_2:     0 (fixed)
#     B_5_2:     0 (fixed)
#     C_5_2:     0 (fixed)
#     D_5_2:     0 (fixed)
#     A_5_3:     0 (fixed)
#     B_5_3:     0 (fixed)
#     C_5_3:     0 (fixed)
#     D_5_3:     0 (fixed)
#     A_5_4:     0 (fixed)
#     B_5_4:     0 (fixed)
#     C_5_4:     0 (fixed)
#     D_5_4:     0 (fixed)
#     A_5_5:    -90.2470450 (init= 1)
#     B_5_5:    -38540.2788 (init=-1)
#     C_5_5:     0 (fixed)
#     D_5_5:     0 (fixed)
#     A_5_6:     0 (fixed)
#     B_5_6:    -1946.78112 (init=-1)
#     C_5_6:     0 (fixed)
#     D_5_6:     0 (fixed)
#     A_5_7:     51.8491812 (init= 1)
#     B_5_7:     7177.67072 (init=-1)
#     C_5_7:     0 (fixed)
#     D_5_7:     0 (fixed)
#     A_5_8:     452.091461 (init= 1)
#     B_5_8:    -162.825730 (init=-1)
#     C_5_8:     0 (fixed)
#     D_5_8:     0 (fixed)
#     A_5_9:    -71.2711269 (init= 1)
#     B_5_9:     4471.56606 (init=-1)
#     C_5_9:     0 (fixed)
#     D_5_9:     0 (fixed)
#     A_5_10:    5614.11249 (init= 1)
#     B_5_10:    711.830700 (init=-1)
#     C_5_10:    0 (fixed)
#     D_5_10:    0 (fixed)
#     A_5_11:    123.976284 (init= 1)
#     B_5_11:   -14146.8740 (init=-1)
#     C_5_11:    0 (fixed)
#     D_5_11:    0 (fixed)
#     A_5_12:    2180.01130 (init= 1)
#     B_5_12:   -3174.26899 (init=-1)
#     C_5_12:    0 (fixed)
#     D_5_12:    0 (fixed)
#     A_5_13:    0.99876791 (init= 1)
#     B_5_13:   -1.00026187 (init=-1)
#     C_5_13:    0 (fixed)
#     D_5_13:    0 (fixed)
#     A_5_14:    0.99959550 (init= 1)
#     B_5_14:   -0.99828972 (init=-1)
#     C_5_14:    0 (fixed)
#     D_5_14:    0 (fixed)
#     A_5_15:    0.99954241 (init= 1)
#     B_5_15:   -0.99976847 (init=-1)
#     C_5_15:    0 (fixed)
#     D_5_15:    0 (fixed)
#     A_5_16:    0.99733670 (init= 1)
#     B_5_16:   -1.00086362 (init=-1)
#     C_5_16:    0 (fixed)
#     D_5_16:    0 (fixed)
#     A_5_17:    1.00249729 (init= 1)
#     B_5_17:   -1.00166957 (init=-1)
#     C_5_17:    0 (fixed)
#     D_5_17:    0 (fixed)
#     A_5_18:    1.00064014 (init= 1)
#     B_5_18:   -1.00001467 (init=-1)
#     C_5_18:    0 (fixed)
#     D_5_18:    0 (fixed)
#     A_5_19:    0.99978728 (init= 1)
#     B_5_19:   -1.00032183 (init=-1)
#     C_5_19:    0 (fixed)
#     D_5_19:    0 (fixed)
#     A_6_0:     0 (fixed)
#     B_6_0:     0 (fixed)
#     C_6_0:     0 (fixed)
#     D_6_0:     0 (fixed)
#     A_6_1:     0 (fixed)
#     B_6_1:     0 (fixed)
#     C_6_1:     0 (fixed)
#     D_6_1:     0 (fixed)
#     A_6_2:     0 (fixed)
#     B_6_2:     0 (fixed)
#     C_6_2:     0 (fixed)
#     D_6_2:     0 (fixed)
#     A_6_3:     0 (fixed)
#     B_6_3:     0 (fixed)
#     C_6_3:     0 (fixed)
#     D_6_3:     0 (fixed)
#     A_6_4:     0 (fixed)
#     B_6_4:     0 (fixed)
#     C_6_4:     0 (fixed)
#     D_6_4:     0 (fixed)
#     A_6_5:     0 (fixed)
#     B_6_5:     0 (fixed)
#     C_6_5:     0 (fixed)
#     D_6_5:     0 (fixed)
#     A_6_6:    -32.7044399 (init= 1)
#     B_6_6:    -20928.5816 (init=-1)
#     C_6_6:     0 (fixed)
#     D_6_6:     0 (fixed)
#     A_6_7:     0 (fixed)
#     B_6_7:    -170.295866 (init=-1)
#     C_6_7:     0 (fixed)
#     D_6_7:     0 (fixed)
#     A_6_8:    -302.398335 (init= 1)
#     B_6_8:    -3772.43498 (init=-1)
#     C_6_8:     0 (fixed)
#     D_6_8:     0 (fixed)
#     A_6_9:    -45.5260014 (init= 1)
#     B_6_9:    -152.034984 (init=-1)
#     C_6_9:     0 (fixed)
#     D_6_9:     0 (fixed)
#     A_6_10:   -0.33381552 (init= 1)
#     B_6_10:    228.222145 (init=-1)
#     C_6_10:    0 (fixed)
#     D_6_10:    0 (fixed)
#     A_6_11:   -204.695247 (init= 1)
#     B_6_11:    2669.08638 (init=-1)
#     C_6_11:    0 (fixed)
#     D_6_11:    0 (fixed)
#     A_6_12:   -551.049775 (init= 1)
#     B_6_12:   -2959.24491 (init=-1)
#     C_6_12:    0 (fixed)
#     D_6_12:    0 (fixed)
#     A_6_13:   -2230.44360 (init= 1)
#     B_6_13:   -2860.11747 (init=-1)
#     C_6_13:    0 (fixed)
#     D_6_13:    0 (fixed)
#     A_6_14:   -12.7572669 (init= 1)
#     B_6_14:   -1.00064561 (init=-1)
#     C_6_14:    0 (fixed)
#     D_6_14:    0 (fixed)
#     A_6_15:    0.99869430 (init= 1)
#     B_6_15:   -0.99899969 (init=-1)
#     C_6_15:    0 (fixed)
#     D_6_15:    0 (fixed)
#     A_6_16:    1.00163914 (init= 1)
#     B_6_16:   -1.00061153 (init=-1)
#     C_6_16:    0 (fixed)
#     D_6_16:    0 (fixed)
#     A_6_17:    1.00186841 (init= 1)
#     B_6_17:   -1.00109493 (init=-1)
#     C_6_17:    0 (fixed)
#     D_6_17:    0 (fixed)
#     A_6_18:    0.99964939 (init= 1)
#     B_6_18:   -1.00032830 (init=-1)
#     C_6_18:    0 (fixed)
#     D_6_18:    0 (fixed)
#     A_6_19:    0.99996174 (init= 1)
#     B_6_19:   -0.99994501 (init=-1)
#     C_6_19:    0 (fixed)
#     D_6_19:    0 (fixed)
#     A_7_0:     0 (fixed)
#     B_7_0:     0 (fixed)
#     C_7_0:     0 (fixed)
#     D_7_0:     0 (fixed)
#     A_7_1:     0 (fixed)
#     B_7_1:     0 (fixed)
#     C_7_1:     0 (fixed)
#     D_7_1:     0 (fixed)
#     A_7_2:     0 (fixed)
#     B_7_2:     0 (fixed)
#     C_7_2:     0 (fixed)
#     D_7_2:     0 (fixed)
#     A_7_3:     0 (fixed)
#     B_7_3:     0 (fixed)
#     C_7_3:     0 (fixed)
#     D_7_3:     0 (fixed)
#     A_7_4:     0 (fixed)
#     B_7_4:     0 (fixed)
#     C_7_4:     0 (fixed)
#     D_7_4:     0 (fixed)
#     A_7_5:     0 (fixed)
#     B_7_5:     0 (fixed)
#     C_7_5:     0 (fixed)
#     D_7_5:     0 (fixed)
#     A_7_6:     0 (fixed)
#     B_7_6:     0 (fixed)
#     C_7_6:     0 (fixed)
#     D_7_6:     0 (fixed)
#     A_7_7:    -19.8811474 (init= 1)
#     B_7_7:     274.219889 (init=-1)
#     C_7_7:     0 (fixed)
#     D_7_7:     0 (fixed)
#     A_7_8:     0 (fixed)
#     B_7_8:    -809.873449 (init=-1)
#     C_7_8:     0 (fixed)
#     D_7_8:     0 (fixed)
#     A_7_9:     299.407701 (init= 1)
#     B_7_9:    -24.6716316 (init=-1)
#     C_7_9:     0 (fixed)
#     D_7_9:     0 (fixed)
#     A_7_10:    129.962336 (init= 1)
#     B_7_10:    258.605312 (init=-1)
#     C_7_10:    0 (fixed)
#     D_7_10:    0 (fixed)
#     A_7_11:    696.210855 (init= 1)
#     B_7_11:    2672.35151 (init=-1)
#     C_7_11:    0 (fixed)
#     D_7_11:    0 (fixed)
#     A_7_12:    1844.27366 (init= 1)
#     B_7_12:    197.952639 (init=-1)
#     C_7_12:    0 (fixed)
#     D_7_12:    0 (fixed)
#     A_7_13:   -1941.75750 (init= 1)
#     B_7_13:   -722.070470 (init=-1)
#     C_7_13:    0 (fixed)
#     D_7_13:    0 (fixed)
#     A_7_14:    26510.0755 (init= 1)
#     B_7_14:    9294.15711 (init=-1)
#     C_7_14:    0 (fixed)
#     D_7_14:    0 (fixed)
#     A_7_15:   -19297.7588 (init= 1)
#     B_7_15:    40641.6946 (init=-1)
#     C_7_15:    0 (fixed)
#     D_7_15:    0 (fixed)
#     A_7_16:    0.99788789 (init= 1)
#     B_7_16:   -0.99906374 (init=-1)
#     C_7_16:    0 (fixed)
#     D_7_16:    0 (fixed)
#     A_7_17:    0.99891391 (init= 1)
#     B_7_17:   -1.00048882 (init=-1)
#     C_7_17:    0 (fixed)
#     D_7_17:    0 (fixed)
#     A_7_18:    0.99909474 (init= 1)
#     B_7_18:   -1.00045277 (init=-1)
#     C_7_18:    0 (fixed)
#     D_7_18:    0 (fixed)
#     A_7_19:    0.99901379 (init= 1)
#     B_7_19:   -0.99943809 (init=-1)
#     C_7_19:    0 (fixed)
#     D_7_19:    0 (fixed)
#     A_8_0:     0 (fixed)
#     B_8_0:     0 (fixed)
#     C_8_0:     0 (fixed)
#     D_8_0:     0 (fixed)
#     A_8_1:     0 (fixed)
#     B_8_1:     0 (fixed)
#     C_8_1:     0 (fixed)
#     D_8_1:     0 (fixed)
#     A_8_2:     0 (fixed)
#     B_8_2:     0 (fixed)
#     C_8_2:     0 (fixed)
#     D_8_2:     0 (fixed)
#     A_8_3:     0 (fixed)
#     B_8_3:     0 (fixed)
#     C_8_3:     0 (fixed)
#     D_8_3:     0 (fixed)
#     A_8_4:     0 (fixed)
#     B_8_4:     0 (fixed)
#     C_8_4:     0 (fixed)
#     D_8_4:     0 (fixed)
#     A_8_5:     0 (fixed)
#     B_8_5:     0 (fixed)
#     C_8_5:     0 (fixed)
#     D_8_5:     0 (fixed)
#     A_8_6:     0 (fixed)
#     B_8_6:     0 (fixed)
#     C_8_6:     0 (fixed)
#     D_8_6:     0 (fixed)
#     A_8_7:     0 (fixed)
#     B_8_7:     0 (fixed)
#     C_8_7:     0 (fixed)
#     D_8_7:     0 (fixed)
#     A_8_8:    -910.999464 (init= 1)
#     B_8_8:     28122.4288 (init=-1)
#     C_8_8:     0 (fixed)
#     D_8_8:     0 (fixed)
#     A_8_9:     0 (fixed)
#     B_8_9:     1992.89528 (init=-1)
#     C_8_9:     0 (fixed)
#     D_8_9:     0 (fixed)
#     A_8_10:   -2.56022174 (init= 1)
#     B_8_10:    56.8468682 (init=-1)
#     C_8_10:    0 (fixed)
#     D_8_10:    0 (fixed)
#     A_8_11:   -307.540390 (init= 1)
#     B_8_11:   -685.795093 (init=-1)
#     C_8_11:    0 (fixed)
#     D_8_11:    0 (fixed)
#     A_8_12:   -415.593074 (init= 1)
#     B_8_12:   -4121.14343 (init=-1)
#     C_8_12:    0 (fixed)
#     D_8_12:    0 (fixed)
#     A_8_13:    105.099962 (init= 1)
#     B_8_13:   -3525.16899 (init=-1)
#     C_8_13:    0 (fixed)
#     D_8_13:    0 (fixed)
#     A_8_14:    13653.8925 (init= 1)
#     B_8_14:    995.412407 (init=-1)
#     C_8_14:    0 (fixed)
#     D_8_14:    0 (fixed)
#     A_8_15:    567.077446 (init= 1)
#     B_8_15:   -167.028669 (init=-1)
#     C_8_15:    0 (fixed)
#     D_8_15:    0 (fixed)
#     A_8_16:    2481.95681 (init= 1)
#     B_8_16:    1842.30194 (init=-1)
#     C_8_16:    0 (fixed)
#     D_8_16:    0 (fixed)
#     A_8_17:    0.99509427 (init= 1)
#     B_8_17:   -0.85405573 (init=-1)
#     C_8_17:    0 (fixed)
#     D_8_17:    0 (fixed)
#     A_8_18:    0.99831989 (init= 1)
#     B_8_18:   -0.99935145 (init=-1)
#     C_8_18:    0 (fixed)
#     D_8_18:    0 (fixed)
#     A_8_19:    0.99996695 (init= 1)
#     B_8_19:   -0.99985444 (init=-1)
#     C_8_19:    0 (fixed)
#     D_8_19:    0 (fixed)
#     A_9_0:     0 (fixed)
#     B_9_0:     0 (fixed)
#     C_9_0:     0 (fixed)
#     D_9_0:     0 (fixed)
#     A_9_1:     0 (fixed)
#     B_9_1:     0 (fixed)
#     C_9_1:     0 (fixed)
#     D_9_1:     0 (fixed)
#     A_9_2:     0 (fixed)
#     B_9_2:     0 (fixed)
#     C_9_2:     0 (fixed)
#     D_9_2:     0 (fixed)
#     A_9_3:     0 (fixed)
#     B_9_3:     0 (fixed)
#     C_9_3:     0 (fixed)
#     D_9_3:     0 (fixed)
#     A_9_4:     0 (fixed)
#     B_9_4:     0 (fixed)
#     C_9_4:     0 (fixed)
#     D_9_4:     0 (fixed)
#     A_9_5:     0 (fixed)
#     B_9_5:     0 (fixed)
#     C_9_5:     0 (fixed)
#     D_9_5:     0 (fixed)
#     A_9_6:     0 (fixed)
#     B_9_6:     0 (fixed)
#     C_9_6:     0 (fixed)
#     D_9_6:     0 (fixed)
#     A_9_7:     0 (fixed)
#     B_9_7:     0 (fixed)
#     C_9_7:     0 (fixed)
#     D_9_7:     0 (fixed)
#     A_9_8:     0 (fixed)
#     B_9_8:     0 (fixed)
#     C_9_8:     0 (fixed)
#     D_9_8:     0 (fixed)
#     A_9_9:    -142.330333 (init= 1)
#     B_9_9:     46668.1837 (init=-1)
#     C_9_9:     0 (fixed)
#     D_9_9:     0 (fixed)
#     A_9_10:    0 (fixed)
#     B_9_10:   -94.2281868 (init=-1)
#     C_9_10:    0 (fixed)
#     D_9_10:    0 (fixed)
#     A_9_11:   -177.206448 (init= 1)
#     B_9_11:   -3.53889063 (init=-1)
#     C_9_11:    0 (fixed)
#     D_9_11:    0 (fixed)
#     A_9_12:    21.0179308 (init= 1)
#     B_9_12:    71.4136357 (init=-1)
#     C_9_12:    0 (fixed)
#     D_9_12:    0 (fixed)
#     A_9_13:   -32.1988304 (init= 1)
#     B_9_13:   -42.7443473 (init=-1)
#     C_9_13:    0 (fixed)
#     D_9_13:    0 (fixed)
#     A_9_14:   -1473.41339 (init= 1)
#     B_9_14:   -1612.40785 (init=-1)
#     C_9_14:    0 (fixed)
#     D_9_14:    0 (fixed)
#     A_9_15:    599.663978 (init= 1)
#     B_9_15:   -10960.9455 (init=-1)
#     C_9_15:    0 (fixed)
#     D_9_15:    0 (fixed)
#     A_9_16:   -4349.40233 (init= 1)
#     B_9_16:    20619.1813 (init=-1)
#     C_9_16:    0 (fixed)
#     D_9_16:    0 (fixed)
#     A_9_17:    10176.6729 (init= 1)
#     B_9_17:    22509.3106 (init=-1)
#     C_9_17:    0 (fixed)
#     D_9_17:    0 (fixed)
#     A_9_18:    0.99545917 (init= 1)
#     B_9_18:   -0.80809292 (init=-1)
#     C_9_18:    0 (fixed)
#     D_9_18:    0 (fixed)
#     A_9_19:    0.99999801 (init= 1)
#     B_9_19:   -0.99958258 (init=-1)
#     C_9_19:    0 (fixed)
#     D_9_19:    0 (fixed)
#     A_10_0:    0 (fixed)
#     B_10_0:    0 (fixed)
#     C_10_0:    0 (fixed)
#     D_10_0:    0 (fixed)
#     A_10_1:    0 (fixed)
#     B_10_1:    0 (fixed)
#     C_10_1:    0 (fixed)
#     D_10_1:    0 (fixed)
#     A_10_2:    0 (fixed)
#     B_10_2:    0 (fixed)
#     C_10_2:    0 (fixed)
#     D_10_2:    0 (fixed)
#     A_10_3:    0 (fixed)
#     B_10_3:    0 (fixed)
#     C_10_3:    0 (fixed)
#     D_10_3:    0 (fixed)
#     A_10_4:    0 (fixed)
#     B_10_4:    0 (fixed)
#     C_10_4:    0 (fixed)
#     D_10_4:    0 (fixed)
#     A_10_5:    0 (fixed)
#     B_10_5:    0 (fixed)
#     C_10_5:    0 (fixed)
#     D_10_5:    0 (fixed)
#     A_10_6:    0 (fixed)
#     B_10_6:    0 (fixed)
#     C_10_6:    0 (fixed)
#     D_10_6:    0 (fixed)
#     A_10_7:    0 (fixed)
#     B_10_7:    0 (fixed)
#     C_10_7:    0 (fixed)
#     D_10_7:    0 (fixed)
#     A_10_8:    0 (fixed)
#     B_10_8:    0 (fixed)
#     C_10_8:    0 (fixed)
#     D_10_8:    0 (fixed)
#     A_10_9:    0 (fixed)
#     B_10_9:    0 (fixed)
#     C_10_9:    0 (fixed)
#     D_10_9:    0 (fixed)
#     A_10_10:   1739.98567 (init= 1)
#     B_10_10:  -68.2904376 (init=-1)
#     C_10_10:   0 (fixed)
#     D_10_10:   0 (fixed)
#     A_10_11:   0 (fixed)
#     B_10_11:  -127.348585 (init=-1)
#     C_10_11:   0 (fixed)
#     D_10_11:   0 (fixed)
#     A_10_12:   42.4353457 (init= 1)
#     B_10_12:   142.083030 (init=-1)
#     C_10_12:   0 (fixed)
#     D_10_12:   0 (fixed)
#     A_10_13:  -203.189775 (init= 1)
#     B_10_13:   1455.73290 (init=-1)
#     C_10_13:   0 (fixed)
#     D_10_13:   0 (fixed)
#     A_10_14:  -1098.38125 (init= 1)
#     B_10_14:   847.293006 (init=-1)
#     C_10_14:   0 (fixed)
#     D_10_14:   0 (fixed)
#     A_10_15:   581.148059 (init= 1)
#     B_10_15:   4501.69806 (init=-1)
#     C_10_15:   0 (fixed)
#     D_10_15:   0 (fixed)
#     A_10_16:  -100.300557 (init= 1)
#     B_10_16:   257.418523 (init=-1)
#     C_10_16:   0 (fixed)
#     D_10_16:   0 (fixed)
#     A_10_17:  -31312.9980 (init= 1)
#     B_10_17:  -4874.68673 (init=-1)
#     C_10_17:   0 (fixed)
#     D_10_17:   0 (fixed)
#     A_10_18:  -2785.53500 (init= 1)
#     B_10_18:   13591.3651 (init=-1)
#     C_10_18:   0 (fixed)
#     D_10_18:   0 (fixed)
#     A_10_19:   7446.76808 (init= 1)
#     B_10_19:  -0.97756062 (init=-1)
#     C_10_19:   0 (fixed)
#     D_10_19:   0 (fixed)
#     A_11_0:    0 (fixed)
#     B_11_0:    0 (fixed)
#     C_11_0:    0 (fixed)
#     D_11_0:    0 (fixed)
#     A_11_1:    0 (fixed)
#     B_11_1:    0 (fixed)
#     C_11_1:    0 (fixed)
#     D_11_1:    0 (fixed)
#     A_11_2:    0 (fixed)
#     B_11_2:    0 (fixed)
#     C_11_2:    0 (fixed)
#     D_11_2:    0 (fixed)
#     A_11_3:    0 (fixed)
#     B_11_3:    0 (fixed)
#     C_11_3:    0 (fixed)
#     D_11_3:    0 (fixed)
#     A_11_4:    0 (fixed)
#     B_11_4:    0 (fixed)
#     C_11_4:    0 (fixed)
#     D_11_4:    0 (fixed)
#     A_11_5:    0 (fixed)
#     B_11_5:    0 (fixed)
#     C_11_5:    0 (fixed)
#     D_11_5:    0 (fixed)
#     A_11_6:    0 (fixed)
#     B_11_6:    0 (fixed)
#     C_11_6:    0 (fixed)
#     D_11_6:    0 (fixed)
#     A_11_7:    0 (fixed)
#     B_11_7:    0 (fixed)
#     C_11_7:    0 (fixed)
#     D_11_7:    0 (fixed)
#     A_11_8:    0 (fixed)
#     B_11_8:    0 (fixed)
#     C_11_8:    0 (fixed)
#     D_11_8:    0 (fixed)
#     A_11_9:    0 (fixed)
#     B_11_9:    0 (fixed)
#     C_11_9:    0 (fixed)
#     D_11_9:    0 (fixed)
#     A_11_10:   0 (fixed)
#     B_11_10:   0 (fixed)
#     C_11_10:   0 (fixed)
#     D_11_10:   0 (fixed)
#     A_11_11:  -799.221931 (init= 1)
#     B_11_11:  -56596.1874 (init=-1)
#     C_11_11:   0 (fixed)
#     D_11_11:   0 (fixed)
#     A_11_12:   0 (fixed)
#     B_11_12:  -950.656093 (init=-1)
#     C_11_12:   0 (fixed)
#     D_11_12:   0 (fixed)
#     A_11_13:   87.6707577 (init= 1)
#     B_11_13:   597.231282 (init=-1)
#     C_11_13:   0 (fixed)
#     D_11_13:   0 (fixed)
#     A_11_14:   853.494185 (init= 1)
#     B_11_14:  -246.901450 (init=-1)
#     C_11_14:   0 (fixed)
#     D_11_14:   0 (fixed)
#     A_11_15:   1710.41684 (init= 1)
#     B_11_15:   1746.15305 (init=-1)
#     C_11_15:   0 (fixed)
#     D_11_15:   0 (fixed)
#     A_11_16:  -106.360907 (init= 1)
#     B_11_16:  -1676.22762 (init=-1)
#     C_11_16:   0 (fixed)
#     D_11_16:   0 (fixed)
#     A_11_17:  -5250.70344 (init= 1)
#     B_11_17:   1198.34531 (init=-1)
#     C_11_17:   0 (fixed)
#     D_11_17:   0 (fixed)
#     A_11_18:  -1402.18167 (init= 1)
#     B_11_18:   1279.77819 (init=-1)
#     C_11_18:   0 (fixed)
#     D_11_18:   0 (fixed)
#     A_11_19:   8406.85060 (init= 1)
#     B_11_19:  -4596.72572 (init=-1)
#     C_11_19:   0 (fixed)
#     D_11_19:   0 (fixed)
#     A_12_0:    0 (fixed)
#     B_12_0:    0 (fixed)
#     C_12_0:    0 (fixed)
#     D_12_0:    0 (fixed)
#     A_12_1:    0 (fixed)
#     B_12_1:    0 (fixed)
#     C_12_1:    0 (fixed)
#     D_12_1:    0 (fixed)
#     A_12_2:    0 (fixed)
#     B_12_2:    0 (fixed)
#     C_12_2:    0 (fixed)
#     D_12_2:    0 (fixed)
#     A_12_3:    0 (fixed)
#     B_12_3:    0 (fixed)
#     C_12_3:    0 (fixed)
#     D_12_3:    0 (fixed)
#     A_12_4:    0 (fixed)
#     B_12_4:    0 (fixed)
#     C_12_4:    0 (fixed)
#     D_12_4:    0 (fixed)
#     A_12_5:    0 (fixed)
#     B_12_5:    0 (fixed)
#     C_12_5:    0 (fixed)
#     D_12_5:    0 (fixed)
#     A_12_6:    0 (fixed)
#     B_12_6:    0 (fixed)
#     C_12_6:    0 (fixed)
#     D_12_6:    0 (fixed)
#     A_12_7:    0 (fixed)
#     B_12_7:    0 (fixed)
#     C_12_7:    0 (fixed)
#     D_12_7:    0 (fixed)
#     A_12_8:    0 (fixed)
#     B_12_8:    0 (fixed)
#     C_12_8:    0 (fixed)
#     D_12_8:    0 (fixed)
#     A_12_9:    0 (fixed)
#     B_12_9:    0 (fixed)
#     C_12_9:    0 (fixed)
#     D_12_9:    0 (fixed)
#     A_12_10:   0 (fixed)
#     B_12_10:   0 (fixed)
#     C_12_10:   0 (fixed)
#     D_12_10:   0 (fixed)
#     A_12_11:   0 (fixed)
#     B_12_11:   0 (fixed)
#     C_12_11:   0 (fixed)
#     D_12_11:   0 (fixed)
#     A_12_12:  -849.775061 (init= 1)
#     B_12_12:  -13826.6758 (init=-1)
#     C_12_12:   0 (fixed)
#     D_12_12:   0 (fixed)
#     A_12_13:   0 (fixed)
#     B_12_13:   4.85995042 (init=-1)
#     C_12_13:   0 (fixed)
#     D_12_13:   0 (fixed)
#     A_12_14:   96.6570890 (init= 1)
#     B_12_14:   70.3258268 (init=-1)
#     C_12_14:   0 (fixed)
#     D_12_14:   0 (fixed)
#     A_12_15:  -755.887105 (init= 1)
#     B_12_15:  -2999.99695 (init=-1)
#     C_12_15:   0 (fixed)
#     D_12_15:   0 (fixed)
#     A_12_16:  -805.544479 (init= 1)
#     B_12_16:  -1693.24903 (init=-1)
#     C_12_16:   0 (fixed)
#     D_12_16:   0 (fixed)
#     A_12_17:   272.226243 (init= 1)
#     B_12_17:  -138.188571 (init=-1)
#     C_12_17:   0 (fixed)
#     D_12_17:   0 (fixed)
#     A_12_18:   62.0787558 (init= 1)
#     B_12_18:   1613.19977 (init=-1)
#     C_12_18:   0 (fixed)
#     D_12_18:   0 (fixed)
#     A_12_19:   10541.3220 (init= 1)
#     B_12_19:  -4976.38307 (init=-1)
#     C_12_19:   0 (fixed)
#     D_12_19:   0 (fixed)
#     A_13_0:    0 (fixed)
#     B_13_0:    0 (fixed)
#     C_13_0:    0 (fixed)
#     D_13_0:    0 (fixed)
#     A_13_1:    0 (fixed)
#     B_13_1:    0 (fixed)
#     C_13_1:    0 (fixed)
#     D_13_1:    0 (fixed)
#     A_13_2:    0 (fixed)
#     B_13_2:    0 (fixed)
#     C_13_2:    0 (fixed)
#     D_13_2:    0 (fixed)
#     A_13_3:    0 (fixed)
#     B_13_3:    0 (fixed)
#     C_13_3:    0 (fixed)
#     D_13_3:    0 (fixed)
#     A_13_4:    0 (fixed)
#     B_13_4:    0 (fixed)
#     C_13_4:    0 (fixed)
#     D_13_4:    0 (fixed)
#     A_13_5:    0 (fixed)
#     B_13_5:    0 (fixed)
#     C_13_5:    0 (fixed)
#     D_13_5:    0 (fixed)
#     A_13_6:    0 (fixed)
#     B_13_6:    0 (fixed)
#     C_13_6:    0 (fixed)
#     D_13_6:    0 (fixed)
#     A_13_7:    0 (fixed)
#     B_13_7:    0 (fixed)
#     C_13_7:    0 (fixed)
#     D_13_7:    0 (fixed)
#     A_13_8:    0 (fixed)
#     B_13_8:    0 (fixed)
#     C_13_8:    0 (fixed)
#     D_13_8:    0 (fixed)
#     A_13_9:    0 (fixed)
#     B_13_9:    0 (fixed)
#     C_13_9:    0 (fixed)
#     D_13_9:    0 (fixed)
#     A_13_10:   0 (fixed)
#     B_13_10:   0 (fixed)
#     C_13_10:   0 (fixed)
#     D_13_10:   0 (fixed)
#     A_13_11:   0 (fixed)
#     B_13_11:   0 (fixed)
#     C_13_11:   0 (fixed)
#     D_13_11:   0 (fixed)
#     A_13_12:   0 (fixed)
#     B_13_12:   0 (fixed)
#     C_13_12:   0 (fixed)
#     D_13_12:   0 (fixed)
#     A_13_13:   1279.91299 (init= 1)
#     B_13_13:   7315.37539 (init=-1)
#     C_13_13:   0 (fixed)
#     D_13_13:   0 (fixed)
#     A_13_14:   0 (fixed)
#     B_13_14:   691.790076 (init=-1)
#     C_13_14:   0 (fixed)
#     D_13_14:   0 (fixed)
#     A_13_15:  -232.863954 (init= 1)
#     B_13_15:  -1033.29681 (init=-1)
#     C_13_15:   0 (fixed)
#     D_13_15:   0 (fixed)
#     A_13_16:   11.7062373 (init= 1)
#     B_13_16:   3727.84787 (init=-1)
#     C_13_16:   0 (fixed)
#     D_13_16:   0 (fixed)
#     A_13_17:   65.8691926 (init= 1)
#     B_13_17:   10.8800193 (init=-1)
#     C_13_17:   0 (fixed)
#     D_13_17:   0 (fixed)
#     A_13_18:  -198.607683 (init= 1)
#     B_13_18:   33.5677903 (init=-1)
#     C_13_18:   0 (fixed)
#     D_13_18:   0 (fixed)
#     A_13_19:   1234.94038 (init= 1)
#     B_13_19:  -280.205638 (init=-1)
#     C_13_19:   0 (fixed)
#     D_13_19:   0 (fixed)
#     A_14_0:    0 (fixed)
#     B_14_0:    0 (fixed)
#     C_14_0:    0 (fixed)
#     D_14_0:    0 (fixed)
#     A_14_1:    0 (fixed)
#     B_14_1:    0 (fixed)
#     C_14_1:    0 (fixed)
#     D_14_1:    0 (fixed)
#     A_14_2:    0 (fixed)
#     B_14_2:    0 (fixed)
#     C_14_2:    0 (fixed)
#     D_14_2:    0 (fixed)
#     A_14_3:    0 (fixed)
#     B_14_3:    0 (fixed)
#     C_14_3:    0 (fixed)
#     D_14_3:    0 (fixed)
#     A_14_4:    0 (fixed)
#     B_14_4:    0 (fixed)
#     C_14_4:    0 (fixed)
#     D_14_4:    0 (fixed)
#     A_14_5:    0 (fixed)
#     B_14_5:    0 (fixed)
#     C_14_5:    0 (fixed)
#     D_14_5:    0 (fixed)
#     A_14_6:    0 (fixed)
#     B_14_6:    0 (fixed)
#     C_14_6:    0 (fixed)
#     D_14_6:    0 (fixed)
#     A_14_7:    0 (fixed)
#     B_14_7:    0 (fixed)
#     C_14_7:    0 (fixed)
#     D_14_7:    0 (fixed)
#     A_14_8:    0 (fixed)
#     B_14_8:    0 (fixed)
#     C_14_8:    0 (fixed)
#     D_14_8:    0 (fixed)
#     A_14_9:    0 (fixed)
#     B_14_9:    0 (fixed)
#     C_14_9:    0 (fixed)
#     D_14_9:    0 (fixed)
#     A_14_10:   0 (fixed)
#     B_14_10:   0 (fixed)
#     C_14_10:   0 (fixed)
#     D_14_10:   0 (fixed)
#     A_14_11:   0 (fixed)
#     B_14_11:   0 (fixed)
#     C_14_11:   0 (fixed)
#     D_14_11:   0 (fixed)
#     A_14_12:   0 (fixed)
#     B_14_12:   0 (fixed)
#     C_14_12:   0 (fixed)
#     D_14_12:   0 (fixed)
#     A_14_13:   0 (fixed)
#     B_14_13:   0 (fixed)
#     C_14_13:   0 (fixed)
#     D_14_13:   0 (fixed)
#     A_14_14:  -425.763536 (init= 1)
#     B_14_14:   35933.1572 (init=-1)
#     C_14_14:   0 (fixed)
#     D_14_14:   0 (fixed)
#     A_14_15:   0 (fixed)
#     B_14_15:  -189.443390 (init=-1)
#     C_14_15:   0 (fixed)
#     D_14_15:   0 (fixed)
#     A_14_16:   3.28175412 (init= 1)
#     B_14_16:  -56.5646278 (init=-1)
#     C_14_16:   0 (fixed)
#     D_14_16:   0 (fixed)
#     A_14_17:   339.259468 (init= 1)
#     B_14_17:  -1873.84003 (init=-1)
#     C_14_17:   0 (fixed)
#     D_14_17:   0 (fixed)
#     A_14_18:   25.8673445 (init= 1)
#     B_14_18:   413.672320 (init=-1)
#     C_14_18:   0 (fixed)
#     D_14_18:   0 (fixed)
#     A_14_19:   29.9098951 (init= 1)
#     B_14_19:   54.5907739 (init=-1)
#     C_14_19:   0 (fixed)
#     D_14_19:   0 (fixed)
#     A_15_0:    0 (fixed)
#     B_15_0:    0 (fixed)
#     C_15_0:    0 (fixed)
#     D_15_0:    0 (fixed)
#     A_15_1:    0 (fixed)
#     B_15_1:    0 (fixed)
#     C_15_1:    0 (fixed)
#     D_15_1:    0 (fixed)
#     A_15_2:    0 (fixed)
#     B_15_2:    0 (fixed)
#     C_15_2:    0 (fixed)
#     D_15_2:    0 (fixed)
#     A_15_3:    0 (fixed)
#     B_15_3:    0 (fixed)
#     C_15_3:    0 (fixed)
#     D_15_3:    0 (fixed)
#     A_15_4:    0 (fixed)
#     B_15_4:    0 (fixed)
#     C_15_4:    0 (fixed)
#     D_15_4:    0 (fixed)
#     A_15_5:    0 (fixed)
#     B_15_5:    0 (fixed)
#     C_15_5:    0 (fixed)
#     D_15_5:    0 (fixed)
#     A_15_6:    0 (fixed)
#     B_15_6:    0 (fixed)
#     C_15_6:    0 (fixed)
#     D_15_6:    0 (fixed)
#     A_15_7:    0 (fixed)
#     B_15_7:    0 (fixed)
#     C_15_7:    0 (fixed)
#     D_15_7:    0 (fixed)
#     A_15_8:    0 (fixed)
#     B_15_8:    0 (fixed)
#     C_15_8:    0 (fixed)
#     D_15_8:    0 (fixed)
#     A_15_9:    0 (fixed)
#     B_15_9:    0 (fixed)
#     C_15_9:    0 (fixed)
#     D_15_9:    0 (fixed)
#     A_15_10:   0 (fixed)
#     B_15_10:   0 (fixed)
#     C_15_10:   0 (fixed)
#     D_15_10:   0 (fixed)
#     A_15_11:   0 (fixed)
#     B_15_11:   0 (fixed)
#     C_15_11:   0 (fixed)
#     D_15_11:   0 (fixed)
#     A_15_12:   0 (fixed)
#     B_15_12:   0 (fixed)
#     C_15_12:   0 (fixed)
#     D_15_12:   0 (fixed)
#     A_15_13:   0 (fixed)
#     B_15_13:   0 (fixed)
#     C_15_13:   0 (fixed)
#     D_15_13:   0 (fixed)
#     A_15_14:   0 (fixed)
#     B_15_14:   0 (fixed)
#     C_15_14:   0 (fixed)
#     D_15_14:   0 (fixed)
#     A_15_15:  -720.704669 (init= 1)
#     B_15_15:   4357.74274 (init=-1)
#     C_15_15:   0 (fixed)
#     D_15_15:   0 (fixed)
#     A_15_16:   0 (fixed)
#     B_15_16:   377.330098 (init=-1)
#     C_15_16:   0 (fixed)
#     D_15_16:   0 (fixed)
#     A_15_17:   205.583285 (init= 1)
#     B_15_17:   1199.29514 (init=-1)
#     C_15_17:   0 (fixed)
#     D_15_17:   0 (fixed)
#     A_15_18:  -193.924946 (init= 1)
#     B_15_18:   395.526489 (init=-1)
#     C_15_18:   0 (fixed)
#     D_15_18:   0 (fixed)
#     A_15_19:  -0.48835619 (init= 1)
#     B_15_19:  -118.142459 (init=-1)
#     C_15_19:   0 (fixed)
#     D_15_19:   0 (fixed)
#     A_16_0:    0 (fixed)
#     B_16_0:    0 (fixed)
#     C_16_0:    0 (fixed)
#     D_16_0:    0 (fixed)
#     A_16_1:    0 (fixed)
#     B_16_1:    0 (fixed)
#     C_16_1:    0 (fixed)
#     D_16_1:    0 (fixed)
#     A_16_2:    0 (fixed)
#     B_16_2:    0 (fixed)
#     C_16_2:    0 (fixed)
#     D_16_2:    0 (fixed)
#     A_16_3:    0 (fixed)
#     B_16_3:    0 (fixed)
#     C_16_3:    0 (fixed)
#     D_16_3:    0 (fixed)
#     A_16_4:    0 (fixed)
#     B_16_4:    0 (fixed)
#     C_16_4:    0 (fixed)
#     D_16_4:    0 (fixed)
#     A_16_5:    0 (fixed)
#     B_16_5:    0 (fixed)
#     C_16_5:    0 (fixed)
#     D_16_5:    0 (fixed)
#     A_16_6:    0 (fixed)
#     B_16_6:    0 (fixed)
#     C_16_6:    0 (fixed)
#     D_16_6:    0 (fixed)
#     A_16_7:    0 (fixed)
#     B_16_7:    0 (fixed)
#     C_16_7:    0 (fixed)
#     D_16_7:    0 (fixed)
#     A_16_8:    0 (fixed)
#     B_16_8:    0 (fixed)
#     C_16_8:    0 (fixed)
#     D_16_8:    0 (fixed)
#     A_16_9:    0 (fixed)
#     B_16_9:    0 (fixed)
#     C_16_9:    0 (fixed)
#     D_16_9:    0 (fixed)
#     A_16_10:   0 (fixed)
#     B_16_10:   0 (fixed)
#     C_16_10:   0 (fixed)
#     D_16_10:   0 (fixed)
#     A_16_11:   0 (fixed)
#     B_16_11:   0 (fixed)
#     C_16_11:   0 (fixed)
#     D_16_11:   0 (fixed)
#     A_16_12:   0 (fixed)
#     B_16_12:   0 (fixed)
#     C_16_12:   0 (fixed)
#     D_16_12:   0 (fixed)
#     A_16_13:   0 (fixed)
#     B_16_13:   0 (fixed)
#     C_16_13:   0 (fixed)
#     D_16_13:   0 (fixed)
#     A_16_14:   0 (fixed)
#     B_16_14:   0 (fixed)
#     C_16_14:   0 (fixed)
#     D_16_14:   0 (fixed)
#     A_16_15:   0 (fixed)
#     B_16_15:   0 (fixed)
#     C_16_15:   0 (fixed)
#     D_16_15:   0 (fixed)
#     A_16_16:   754.829159 (init= 1)
#     B_16_16:  -17352.3935 (init=-1)
#     C_16_16:   0 (fixed)
#     D_16_16:   0 (fixed)
#     A_16_17:   0 (fixed)
#     B_16_17:  -776.945085 (init=-1)
#     C_16_17:   0 (fixed)
#     D_16_17:   0 (fixed)
#     A_16_18:  -142.095372 (init= 1)
#     B_16_18:  -820.900106 (init=-1)
#     C_16_18:   0 (fixed)
#     D_16_18:   0 (fixed)
#     A_16_19:   35.5677936 (init= 1)
#     B_16_19:  -19.6953553 (init=-1)
#     C_16_19:   0 (fixed)
#     D_16_19:   0 (fixed)
#     A_17_0:    0 (fixed)
#     B_17_0:    0 (fixed)
#     C_17_0:    0 (fixed)
#     D_17_0:    0 (fixed)
#     A_17_1:    0 (fixed)
#     B_17_1:    0 (fixed)
#     C_17_1:    0 (fixed)
#     D_17_1:    0 (fixed)
#     A_17_2:    0 (fixed)
#     B_17_2:    0 (fixed)
#     C_17_2:    0 (fixed)
#     D_17_2:    0 (fixed)
#     A_17_3:    0 (fixed)
#     B_17_3:    0 (fixed)
#     C_17_3:    0 (fixed)
#     D_17_3:    0 (fixed)
#     A_17_4:    0 (fixed)
#     B_17_4:    0 (fixed)
#     C_17_4:    0 (fixed)
#     D_17_4:    0 (fixed)
#     A_17_5:    0 (fixed)
#     B_17_5:    0 (fixed)
#     C_17_5:    0 (fixed)
#     D_17_5:    0 (fixed)
#     A_17_6:    0 (fixed)
#     B_17_6:    0 (fixed)
#     C_17_6:    0 (fixed)
#     D_17_6:    0 (fixed)
#     A_17_7:    0 (fixed)
#     B_17_7:    0 (fixed)
#     C_17_7:    0 (fixed)
#     D_17_7:    0 (fixed)
#     A_17_8:    0 (fixed)
#     B_17_8:    0 (fixed)
#     C_17_8:    0 (fixed)
#     D_17_8:    0 (fixed)
#     A_17_9:    0 (fixed)
#     B_17_9:    0 (fixed)
#     C_17_9:    0 (fixed)
#     D_17_9:    0 (fixed)
#     A_17_10:   0 (fixed)
#     B_17_10:   0 (fixed)
#     C_17_10:   0 (fixed)
#     D_17_10:   0 (fixed)
#     A_17_11:   0 (fixed)
#     B_17_11:   0 (fixed)
#     C_17_11:   0 (fixed)
#     D_17_11:   0 (fixed)
#     A_17_12:   0 (fixed)
#     B_17_12:   0 (fixed)
#     C_17_12:   0 (fixed)
#     D_17_12:   0 (fixed)
#     A_17_13:   0 (fixed)
#     B_17_13:   0 (fixed)
#     C_17_13:   0 (fixed)
#     D_17_13:   0 (fixed)
#     A_17_14:   0 (fixed)
#     B_17_14:   0 (fixed)
#     C_17_14:   0 (fixed)
#     D_17_14:   0 (fixed)
#     A_17_15:   0 (fixed)
#     B_17_15:   0 (fixed)
#     C_17_15:   0 (fixed)
#     D_17_15:   0 (fixed)
#     A_17_16:   0 (fixed)
#     B_17_16:   0 (fixed)
#     C_17_16:   0 (fixed)
#     D_17_16:   0 (fixed)
#     A_17_17:  -92.2275005 (init= 1)
#     B_17_17:  -16007.7107 (init=-1)
#     C_17_17:   0 (fixed)
#     D_17_17:   0 (fixed)
#     A_17_18:   0 (fixed)
#     B_17_18:   481.368715 (init=-1)
#     C_17_18:   0 (fixed)
#     D_17_18:   0 (fixed)
#     A_17_19:   30.1593150 (init= 1)
#     B_17_19:   173.472536 (init=-1)
#     C_17_19:   0 (fixed)
#     D_17_19:   0 (fixed)
#     A_18_0:    0 (fixed)
#     B_18_0:    0 (fixed)
#     C_18_0:    0 (fixed)
#     D_18_0:    0 (fixed)
#     A_18_1:    0 (fixed)
#     B_18_1:    0 (fixed)
#     C_18_1:    0 (fixed)
#     D_18_1:    0 (fixed)
#     A_18_2:    0 (fixed)
#     B_18_2:    0 (fixed)
#     C_18_2:    0 (fixed)
#     D_18_2:    0 (fixed)
#     A_18_3:    0 (fixed)
#     B_18_3:    0 (fixed)
#     C_18_3:    0 (fixed)
#     D_18_3:    0 (fixed)
#     A_18_4:    0 (fixed)
#     B_18_4:    0 (fixed)
#     C_18_4:    0 (fixed)
#     D_18_4:    0 (fixed)
#     A_18_5:    0 (fixed)
#     B_18_5:    0 (fixed)
#     C_18_5:    0 (fixed)
#     D_18_5:    0 (fixed)
#     A_18_6:    0 (fixed)
#     B_18_6:    0 (fixed)
#     C_18_6:    0 (fixed)
#     D_18_6:    0 (fixed)
#     A_18_7:    0 (fixed)
#     B_18_7:    0 (fixed)
#     C_18_7:    0 (fixed)
#     D_18_7:    0 (fixed)
#     A_18_8:    0 (fixed)
#     B_18_8:    0 (fixed)
#     C_18_8:    0 (fixed)
#     D_18_8:    0 (fixed)
#     A_18_9:    0 (fixed)
#     B_18_9:    0 (fixed)
#     C_18_9:    0 (fixed)
#     D_18_9:    0 (fixed)
#     A_18_10:   0 (fixed)
#     B_18_10:   0 (fixed)
#     C_18_10:   0 (fixed)
#     D_18_10:   0 (fixed)
#     A_18_11:   0 (fixed)
#     B_18_11:   0 (fixed)
#     C_18_11:   0 (fixed)
#     D_18_11:   0 (fixed)
#     A_18_12:   0 (fixed)
#     B_18_12:   0 (fixed)
#     C_18_12:   0 (fixed)
#     D_18_12:   0 (fixed)
#     A_18_13:   0 (fixed)
#     B_18_13:   0 (fixed)
#     C_18_13:   0 (fixed)
#     D_18_13:   0 (fixed)
#     A_18_14:   0 (fixed)
#     B_18_14:   0 (fixed)
#     C_18_14:   0 (fixed)
#     D_18_14:   0 (fixed)
#     A_18_15:   0 (fixed)
#     B_18_15:   0 (fixed)
#     C_18_15:   0 (fixed)
#     D_18_15:   0 (fixed)
#     A_18_16:   0 (fixed)
#     B_18_16:   0 (fixed)
#     C_18_16:   0 (fixed)
#     D_18_16:   0 (fixed)
#     A_18_17:   0 (fixed)
#     B_18_17:   0 (fixed)
#     C_18_17:   0 (fixed)
#     D_18_17:   0 (fixed)
#     A_18_18:  -144.264231 (init= 1)
#     B_18_18:   19576.4192 (init=-1)
#     C_18_18:   0 (fixed)
#     D_18_18:   0 (fixed)
#     A_18_19:   0 (fixed)
#     B_18_19:  -98.2154991 (init=-1)
#     C_18_19:   0 (fixed)
#     D_18_19:   0 (fixed)
#     A_19_0:    0 (fixed)
#     B_19_0:    0 (fixed)
#     C_19_0:    0 (fixed)
#     D_19_0:    0 (fixed)
#     A_19_1:    0 (fixed)
#     B_19_1:    0 (fixed)
#     C_19_1:    0 (fixed)
#     D_19_1:    0 (fixed)
#     A_19_2:    0 (fixed)
#     B_19_2:    0 (fixed)
#     C_19_2:    0 (fixed)
#     D_19_2:    0 (fixed)
#     A_19_3:    0 (fixed)
#     B_19_3:    0 (fixed)
#     C_19_3:    0 (fixed)
#     D_19_3:    0 (fixed)
#     A_19_4:    0 (fixed)
#     B_19_4:    0 (fixed)
#     C_19_4:    0 (fixed)
#     D_19_4:    0 (fixed)
#     A_19_5:    0 (fixed)
#     B_19_5:    0 (fixed)
#     C_19_5:    0 (fixed)
#     D_19_5:    0 (fixed)
#     A_19_6:    0 (fixed)
#     B_19_6:    0 (fixed)
#     C_19_6:    0 (fixed)
#     D_19_6:    0 (fixed)
#     A_19_7:    0 (fixed)
#     B_19_7:    0 (fixed)
#     C_19_7:    0 (fixed)
#     D_19_7:    0 (fixed)
#     A_19_8:    0 (fixed)
#     B_19_8:    0 (fixed)
#     C_19_8:    0 (fixed)
#     D_19_8:    0 (fixed)
#     A_19_9:    0 (fixed)
#     B_19_9:    0 (fixed)
#     C_19_9:    0 (fixed)
#     D_19_9:    0 (fixed)
#     A_19_10:   0 (fixed)
#     B_19_10:   0 (fixed)
#     C_19_10:   0 (fixed)
#     D_19_10:   0 (fixed)
#     A_19_11:   0 (fixed)
#     B_19_11:   0 (fixed)
#     C_19_11:   0 (fixed)
#     D_19_11:   0 (fixed)
#     A_19_12:   0 (fixed)
#     B_19_12:   0 (fixed)
#     C_19_12:   0 (fixed)
#     D_19_12:   0 (fixed)
#     A_19_13:   0 (fixed)
#     B_19_13:   0 (fixed)
#     C_19_13:   0 (fixed)
#     D_19_13:   0 (fixed)
#     A_19_14:   0 (fixed)
#     B_19_14:   0 (fixed)
#     C_19_14:   0 (fixed)
#     D_19_14:   0 (fixed)
#     A_19_15:   0 (fixed)
#     B_19_15:   0 (fixed)
#     C_19_15:   0 (fixed)
#     D_19_15:   0 (fixed)
#     A_19_16:   0 (fixed)
#     B_19_16:   0 (fixed)
#     C_19_16:   0 (fixed)
#     D_19_16:   0 (fixed)
#     A_19_17:   0 (fixed)
#     B_19_17:   0 (fixed)
#     C_19_17:   0 (fixed)
#     D_19_17:   0 (fixed)
#     A_19_18:   0 (fixed)
#     B_19_18:   0 (fixed)
#     C_19_18:   0 (fixed)
#     D_19_18:   0 (fixed)
#     A_19_19:   47.5277003 (init= 1)
#     B_19_19:  -4949.60311 (init=-1)
#     C_19_19:   0 (fixed)
#     D_19_19:   0 (fixed)

# %%
ff1 = deepcopy(ff)

# %%
run hallprobesim.py
# Out:
# 1.5707963267948966
# (140, 10)
# 375.0
# 1450.0
# 0.002531942
# 1732114    0.002532
# Name: Br, dtype: float64
# fitting with n=20, m=20, cn=0, cm=0
# Elapsed time was 104.597 seconds
# [[Fit Statistics]]
#     # function evals   = 11
#     # data points      = 4200
#     # variables        = 362
#     chi-square         = 0.000
#     reduced chi-square = 0.000
#     Akaike info crit   = -98717.007
#     Bayesian info crit = -96420.899
# [[Variables]]
#     R:         50000 (fixed)
#     ns:        20 (fixed)
#     ms:        20 (fixed)
#     A_0_0:     0 (fixed)
#     B_0_0:     0 (fixed)
#     C_0_0:     0 (fixed)
#     D_0_0:     0 (fixed)
#     A_0_1:     0 (fixed)
#     B_0_1:     0 (fixed)
#     C_0_1:     0 (fixed)
#     D_0_1:     0 (fixed)
#     A_0_2:     0 (fixed)
#     B_0_2:     0 (fixed)
#     C_0_2:     0 (fixed)
#     D_0_2:     0 (fixed)
#     A_0_3:     0 (fixed)
#     B_0_3:     0 (fixed)
#     C_0_3:     0 (fixed)
#     D_0_3:     0 (fixed)
#     A_0_4:     0 (fixed)
#     B_0_4:     0 (fixed)
#     C_0_4:     0 (fixed)
#     D_0_4:     0 (fixed)
#     A_0_5:     0 (fixed)
#     B_0_5:     0 (fixed)
#     C_0_5:     0 (fixed)
#     D_0_5:     0 (fixed)
#     A_0_6:     0 (fixed)
#     B_0_6:     0 (fixed)
#     C_0_6:     0 (fixed)
#     D_0_6:     0 (fixed)
#     A_0_7:     0 (fixed)
#     B_0_7:     0 (fixed)
#     C_0_7:     0 (fixed)
#     D_0_7:     0 (fixed)
#     A_0_8:     0 (fixed)
#     B_0_8:     0 (fixed)
#     C_0_8:     0 (fixed)
#     D_0_8:     0 (fixed)
#     A_0_9:     0 (fixed)
#     B_0_9:     0 (fixed)
#     C_0_9:     0 (fixed)
#     D_0_9:     0 (fixed)
#     A_0_10:    0 (fixed)
#     B_0_10:    0 (fixed)
#     C_0_10:    0 (fixed)
#     D_0_10:    0 (fixed)
#     A_0_11:    0 (fixed)
#     B_0_11:    0 (fixed)
#     C_0_11:    0 (fixed)
#     D_0_11:    0 (fixed)
#     A_0_12:    0 (fixed)
#     B_0_12:    0 (fixed)
#     C_0_12:    0 (fixed)
#     D_0_12:    0 (fixed)
#     A_0_13:    0 (fixed)
#     B_0_13:    0 (fixed)
#     C_0_13:    0 (fixed)
#     D_0_13:    0 (fixed)
#     A_0_14:    0 (fixed)
#     B_0_14:    0 (fixed)
#     C_0_14:    0 (fixed)
#     D_0_14:    0 (fixed)
#     A_0_15:    0 (fixed)
#     B_0_15:    0 (fixed)
#     C_0_15:    0 (fixed)
#     D_0_15:    0 (fixed)
#     A_0_16:    0 (fixed)
#     B_0_16:    0 (fixed)
#     C_0_16:    0 (fixed)
#     D_0_16:    0 (fixed)
#     A_0_17:    0 (fixed)
#     B_0_17:    0 (fixed)
#     C_0_17:    0 (fixed)
#     D_0_17:    0 (fixed)
#     A_0_18:    0 (fixed)
#     B_0_18:    0 (fixed)
#     C_0_18:    0 (fixed)
#     D_0_18:    0 (fixed)
#     A_0_19:    0 (fixed)
#     B_0_19:    0 (fixed)
#     C_0_19:    0 (fixed)
#     D_0_19:    0 (fixed)
#     A_1_0:     0 (fixed)
#     B_1_0:     0 (fixed)
#     C_1_0:     0 (fixed)
#     D_1_0:     0 (fixed)
#     A_1_1:     2.04425549 (init= 1)
#     B_1_1:     706.321092 (init=-1)
#     C_1_1:     0 (fixed)
#     D_1_1:     0 (fixed)
#     A_1_2:     0 (fixed)
#     B_1_2:    -3.30123003 (init=-1)
#     C_1_2:     0 (fixed)
#     D_1_2:     0 (fixed)
#     A_1_3:     0.37307046 (init= 1)
#     B_1_3:     9.67273071 (init=-1)
#     C_1_3:     0 (fixed)
#     D_1_3:     0 (fixed)
#     A_1_4:     0.94701203 (init= 1)
#     B_1_4:    -0.81488926 (init=-1)
#     C_1_4:     0 (fixed)
#     D_1_4:     0 (fixed)
#     A_1_5:     1.02597323 (init= 1)
#     B_1_5:    -1.04187708 (init=-1)
#     C_1_5:     0 (fixed)
#     D_1_5:     0 (fixed)
#     A_1_6:     0.99939501 (init= 1)
#     B_1_6:    -0.99786376 (init=-1)
#     C_1_6:     0 (fixed)
#     D_1_6:     0 (fixed)
#     A_1_7:     1.00001954 (init= 1)
#     B_1_7:    -0.99999999 (init=-1)
#     C_1_7:     0 (fixed)
#     D_1_7:     0 (fixed)
#     A_1_8:     1          (init= 1)
#     B_1_8:    -1          (init=-1)
#     C_1_8:     0 (fixed)
#     D_1_8:     0 (fixed)
#     A_1_9:     1          (init= 1)
#     B_1_9:    -1          (init=-1)
#     C_1_9:     0 (fixed)
#     D_1_9:     0 (fixed)
#     A_1_10:    1          (init= 1)
#     B_1_10:   -1          (init=-1)
#     C_1_10:    0 (fixed)
#     D_1_10:    0 (fixed)
#     A_1_11:    1          (init= 1)
#     B_1_11:   -1          (init=-1)
#     C_1_11:    0 (fixed)
#     D_1_11:    0 (fixed)
#     A_1_12:    1          (init= 1)
#     B_1_12:   -1          (init=-1)
#     C_1_12:    0 (fixed)
#     D_1_12:    0 (fixed)
#     A_1_13:    1          (init= 1)
#     B_1_13:   -1          (init=-1)
#     C_1_13:    0 (fixed)
#     D_1_13:    0 (fixed)
#     A_1_14:    1          (init= 1)
#     B_1_14:   -1          (init=-1)
#     C_1_14:    0 (fixed)
#     D_1_14:    0 (fixed)
#     A_1_15:    1          (init= 1)
#     B_1_15:   -1          (init=-1)
#     C_1_15:    0 (fixed)
#     D_1_15:    0 (fixed)
#     A_1_16:    1          (init= 1)
#     B_1_16:   -1          (init=-1)
#     C_1_16:    0 (fixed)
#     D_1_16:    0 (fixed)
#     A_1_17:    1          (init= 1)
#     B_1_17:   -1          (init=-1)
#     C_1_17:    0 (fixed)
#     D_1_17:    0 (fixed)
#     A_1_18:    1          (init= 1)
#     B_1_18:   -1          (init=-1)
#     C_1_18:    0 (fixed)
#     D_1_18:    0 (fixed)
#     A_1_19:    1          (init= 1)
#     B_1_19:   -1          (init=-1)
#     C_1_19:    0 (fixed)
#     D_1_19:    0 (fixed)
#     A_2_0:     0 (fixed)
#     B_2_0:     0 (fixed)
#     C_2_0:     0 (fixed)
#     D_2_0:     0 (fixed)
#     A_2_1:     0 (fixed)
#     B_2_1:     0 (fixed)
#     C_2_1:     0 (fixed)
#     D_2_1:     0 (fixed)
#     A_2_2:     4.12755594 (init= 1)
#     B_2_2:     1168.01661 (init=-1)
#     C_2_2:     0 (fixed)
#     D_2_2:     0 (fixed)
#     A_2_3:     0 (fixed)
#     B_2_3:     1.11017696 (init=-1)
#     C_2_3:     0 (fixed)
#     D_2_3:     0 (fixed)
#     A_2_4:    -0.26990552 (init= 1)
#     B_2_4:     16.2298542 (init=-1)
#     C_2_4:     0 (fixed)
#     D_2_4:     0 (fixed)
#     A_2_5:     0.86616706 (init= 1)
#     B_2_5:    -0.52797525 (init=-1)
#     C_2_5:     0 (fixed)
#     D_2_5:     0 (fixed)
#     A_2_6:     0.91438220 (init= 1)
#     B_2_6:    -1.35696313 (init=-1)
#     C_2_6:     0 (fixed)
#     D_2_6:     0 (fixed)
#     A_2_7:     0.99714527 (init= 1)
#     B_2_7:    -1.00447069 (init=-1)
#     C_2_7:     0 (fixed)
#     D_2_7:     0 (fixed)
#     A_2_8:     0.99902996 (init= 1)
#     B_2_8:    -0.99915099 (init=-1)
#     C_2_8:     0 (fixed)
#     D_2_8:     0 (fixed)
#     A_2_9:     1          (init= 1)
#     B_2_9:    -0.99999999 (init=-1)
#     C_2_9:     0 (fixed)
#     D_2_9:     0 (fixed)
#     A_2_10:    1          (init= 1)
#     B_2_10:   -1          (init=-1)
#     C_2_10:    0 (fixed)
#     D_2_10:    0 (fixed)
#     A_2_11:    1          (init= 1)
#     B_2_11:   -1          (init=-1)
#     C_2_11:    0 (fixed)
#     D_2_11:    0 (fixed)
#     A_2_12:    1          (init= 1)
#     B_2_12:   -1          (init=-1)
#     C_2_12:    0 (fixed)
#     D_2_12:    0 (fixed)
#     A_2_13:    1          (init= 1)
#     B_2_13:   -1          (init=-1)
#     C_2_13:    0 (fixed)
#     D_2_13:    0 (fixed)
#     A_2_14:    1          (init= 1)
#     B_2_14:   -1          (init=-1)
#     C_2_14:    0 (fixed)
#     D_2_14:    0 (fixed)
#     A_2_15:    1          (init= 1)
#     B_2_15:   -1          (init=-1)
#     C_2_15:    0 (fixed)
#     D_2_15:    0 (fixed)
#     A_2_16:    1          (init= 1)
#     B_2_16:   -1          (init=-1)
#     C_2_16:    0 (fixed)
#     D_2_16:    0 (fixed)
#     A_2_17:    1          (init= 1)
#     B_2_17:   -1          (init=-1)
#     C_2_17:    0 (fixed)
#     D_2_17:    0 (fixed)
#     A_2_18:    1          (init= 1)
#     B_2_18:   -1          (init=-1)
#     C_2_18:    0 (fixed)
#     D_2_18:    0 (fixed)
#     A_2_19:    1          (init= 1)
#     B_2_19:   -1          (init=-1)
#     C_2_19:    0 (fixed)
#     D_2_19:    0 (fixed)
#     A_3_0:     0 (fixed)
#     B_3_0:     0 (fixed)
#     C_3_0:     0 (fixed)
#     D_3_0:     0 (fixed)
#     A_3_1:     0 (fixed)
#     B_3_1:     0 (fixed)
#     C_3_1:     0 (fixed)
#     D_3_1:     0 (fixed)
#     A_3_2:     0 (fixed)
#     B_3_2:     0 (fixed)
#     C_3_2:     0 (fixed)
#     D_3_2:     0 (fixed)
#     A_3_3:     5.59448383 (init= 1)
#     B_3_3:     1238.48805 (init=-1)
#     C_3_3:     0 (fixed)
#     D_3_3:     0 (fixed)
#     A_3_4:     0 (fixed)
#     B_3_4:     2.47250213 (init=-1)
#     C_3_4:     0 (fixed)
#     D_3_4:     0 (fixed)
#     A_3_5:     0.00197605 (init= 1)
#     B_3_5:     6.91918929 (init=-1)
#     C_3_5:     0 (fixed)
#     D_3_5:     0 (fixed)
#     A_3_6:     0.52281444 (init= 1)
#     B_3_6:     0.09803302 (init=-1)
#     C_3_6:     0 (fixed)
#     D_3_6:     0 (fixed)
#     A_3_7:     1.01311965 (init= 1)
#     B_3_7:    -2.39585856 (init=-1)
#     C_3_7:     0 (fixed)
#     D_3_7:     0 (fixed)
#     A_3_8:     1.01739426 (init= 1)
#     B_3_8:    -1.00477290 (init=-1)
#     C_3_8:     0 (fixed)
#     D_3_8:     0 (fixed)
#     A_3_9:     0.99675438 (init= 1)
#     B_3_9:    -0.98967678 (init=-1)
#     C_3_9:     0 (fixed)
#     D_3_9:     0 (fixed)
#     A_3_10:    0.99991525 (init= 1)
#     B_3_10:   -0.99992280 (init=-1)
#     C_3_10:    0 (fixed)
#     D_3_10:    0 (fixed)
#     A_3_11:    1          (init= 1)
#     B_3_11:   -1          (init=-1)
#     C_3_11:    0 (fixed)
#     D_3_11:    0 (fixed)
#     A_3_12:    1          (init= 1)
#     B_3_12:   -1          (init=-1)
#     C_3_12:    0 (fixed)
#     D_3_12:    0 (fixed)
#     A_3_13:    1          (init= 1)
#     B_3_13:   -1          (init=-1)
#     C_3_13:    0 (fixed)
#     D_3_13:    0 (fixed)
#     A_3_14:    1          (init= 1)
#     B_3_14:   -1          (init=-1)
#     C_3_14:    0 (fixed)
#     D_3_14:    0 (fixed)
#     A_3_15:    1          (init= 1)
#     B_3_15:   -1          (init=-1)
#     C_3_15:    0 (fixed)
#     D_3_15:    0 (fixed)
#     A_3_16:    1          (init= 1)
#     B_3_16:   -1          (init=-1)
#     C_3_16:    0 (fixed)
#     D_3_16:    0 (fixed)
#     A_3_17:    1          (init= 1)
#     B_3_17:   -1          (init=-1)
#     C_3_17:    0 (fixed)
#     D_3_17:    0 (fixed)
#     A_3_18:    1          (init= 1)
#     B_3_18:   -1          (init=-1)
#     C_3_18:    0 (fixed)
#     D_3_18:    0 (fixed)
#     A_3_19:    1          (init= 1)
#     B_3_19:   -1          (init=-1)
#     C_3_19:    0 (fixed)
#     D_3_19:    0 (fixed)
#     A_4_0:     0 (fixed)
#     B_4_0:     0 (fixed)
#     C_4_0:     0 (fixed)
#     D_4_0:     0 (fixed)
#     A_4_1:     0 (fixed)
#     B_4_1:     0 (fixed)
#     C_4_1:     0 (fixed)
#     D_4_1:     0 (fixed)
#     A_4_2:     0 (fixed)
#     B_4_2:     0 (fixed)
#     C_4_2:     0 (fixed)
#     D_4_2:     0 (fixed)
#     A_4_3:     0 (fixed)
#     B_4_3:     0 (fixed)
#     C_4_3:     0 (fixed)
#     D_4_3:     0 (fixed)
#     A_4_4:     4.81385679 (init= 1)
#     B_4_4:     929.757951 (init=-1)
#     C_4_4:     0 (fixed)
#     D_4_4:     0 (fixed)
#     A_4_5:     0 (fixed)
#     B_4_5:     0.84559543 (init=-1)
#     C_4_5:     0 (fixed)
#     D_4_5:     0 (fixed)
#     A_4_6:     0.69100610 (init= 1)
#     B_4_6:    -7.15015954 (init=-1)
#     C_4_6:     0 (fixed)
#     D_4_6:     0 (fixed)
#     A_4_7:     0.10370816 (init= 1)
#     B_4_7:     0.37284854 (init=-1)
#     C_4_7:     0 (fixed)
#     D_4_7:     0 (fixed)
#     A_4_8:     1.14587500 (init= 1)
#     B_4_8:    -2.61913421 (init=-1)
#     C_4_8:     0 (fixed)
#     D_4_8:     0 (fixed)
#     A_4_9:     1.04887077 (init= 1)
#     B_4_9:    -0.99851387 (init=-1)
#     C_4_9:     0 (fixed)
#     D_4_9:     0 (fixed)
#     A_4_10:    1.00417937 (init= 1)
#     B_4_10:   -0.98394529 (init=-1)
#     C_4_10:    0 (fixed)
#     D_4_10:    0 (fixed)
#     A_4_11:    1.02020306 (init= 1)
#     B_4_11:   -1.00124963 (init=-1)
#     C_4_11:    0 (fixed)
#     D_4_11:    0 (fixed)
#     A_4_12:    1.00033135 (init= 1)
#     B_4_12:   -1.00033779 (init=-1)
#     C_4_12:    0 (fixed)
#     D_4_12:    0 (fixed)
#     A_4_13:    1          (init= 1)
#     B_4_13:   -1          (init=-1)
#     C_4_13:    0 (fixed)
#     D_4_13:    0 (fixed)
#     A_4_14:    1          (init= 1)
#     B_4_14:   -1          (init=-1)
#     C_4_14:    0 (fixed)
#     D_4_14:    0 (fixed)
#     A_4_15:    1          (init= 1)
#     B_4_15:   -1          (init=-1)
#     C_4_15:    0 (fixed)
#     D_4_15:    0 (fixed)
#     A_4_16:    1          (init= 1)
#     B_4_16:   -1          (init=-1)
#     C_4_16:    0 (fixed)
#     D_4_16:    0 (fixed)
#     A_4_17:    1          (init= 1)
#     B_4_17:   -1          (init=-1)
#     C_4_17:    0 (fixed)
#     D_4_17:    0 (fixed)
#     A_4_18:    1          (init= 1)
#     B_4_18:   -1          (init=-1)
#     C_4_18:    0 (fixed)
#     D_4_18:    0 (fixed)
#     A_4_19:    1          (init= 1)
#     B_4_19:   -1          (init=-1)
#     C_4_19:    0 (fixed)
#     D_4_19:    0 (fixed)
#     A_5_0:     0 (fixed)
#     B_5_0:     0 (fixed)
#     C_5_0:     0 (fixed)
#     D_5_0:     0 (fixed)
#     A_5_1:     0 (fixed)
#     B_5_1:     0 (fixed)
#     C_5_1:     0 (fixed)
#     D_5_1:     0 (fixed)
#     A_5_2:     0 (fixed)
#     B_5_2:     0 (fixed)
#     C_5_2:     0 (fixed)
#     D_5_2:     0 (fixed)
#     A_5_3:     0 (fixed)
#     B_5_3:     0 (fixed)
#     C_5_3:     0 (fixed)
#     D_5_3:     0 (fixed)
#     A_5_4:     0 (fixed)
#     B_5_4:     0 (fixed)
#     C_5_4:     0 (fixed)
#     D_5_4:     0 (fixed)
#     A_5_5:     1.60615510 (init= 1)
#     B_5_5:     401.808364 (init=-1)
#     C_5_5:     0 (fixed)
#     D_5_5:     0 (fixed)
#     A_5_6:     0 (fixed)
#     B_5_6:    -1.37828789 (init=-1)
#     C_5_6:     0 (fixed)
#     D_5_6:     0 (fixed)
#     A_5_7:     0.82150364 (init= 1)
#     B_5_7:    -11.8836817 (init=-1)
#     C_5_7:     0 (fixed)
#     D_5_7:     0 (fixed)
#     A_5_8:    -0.16652431 (init= 1)
#     B_5_8:     0.16070412 (init=-1)
#     C_5_8:     0 (fixed)
#     D_5_8:     0 (fixed)
#     A_5_9:     1.46912800 (init= 1)
#     B_5_9:    -1.56277985 (init=-1)
#     C_5_9:     0 (fixed)
#     D_5_9:     0 (fixed)
#     A_5_10:    0.81353569 (init= 1)
#     B_5_10:   -0.97286274 (init=-1)
#     C_5_10:    0 (fixed)
#     D_5_10:    0 (fixed)
#     A_5_11:    1.02512027 (init= 1)
#     B_5_11:   -1.04616443 (init=-1)
#     C_5_11:    0 (fixed)
#     D_5_11:    0 (fixed)
#     A_5_12:    1.00426492 (init= 1)
#     B_5_12:   -0.99488883 (init=-1)
#     C_5_12:    0 (fixed)
#     D_5_12:    0 (fixed)
#     A_5_13:    0.99999366 (init= 1)
#     B_5_13:   -1.00356739 (init=-1)
#     C_5_13:    0 (fixed)
#     D_5_13:    0 (fixed)
#     A_5_14:    1          (init= 1)
#     B_5_14:   -0.99999999 (init=-1)
#     C_5_14:    0 (fixed)
#     D_5_14:    0 (fixed)
#     A_5_15:    1          (init= 1)
#     B_5_15:   -1          (init=-1)
#     C_5_15:    0 (fixed)
#     D_5_15:    0 (fixed)
#     A_5_16:    1          (init= 1)
#     B_5_16:   -1          (init=-1)
#     C_5_16:    0 (fixed)
#     D_5_16:    0 (fixed)
#     A_5_17:    1          (init= 1)
#     B_5_17:   -1          (init=-1)
#     C_5_17:    0 (fixed)
#     D_5_17:    0 (fixed)
#     A_5_18:    1          (init= 1)
#     B_5_18:   -1          (init=-1)
#     C_5_18:    0 (fixed)
#     D_5_18:    0 (fixed)
#     A_5_19:    1          (init= 1)
#     B_5_19:   -1          (init=-1)
#     C_5_19:    0 (fixed)
#     D_5_19:    0 (fixed)
#     A_6_0:     0 (fixed)
#     B_6_0:     0 (fixed)
#     C_6_0:     0 (fixed)
#     D_6_0:     0 (fixed)
#     A_6_1:     0 (fixed)
#     B_6_1:     0 (fixed)
#     C_6_1:     0 (fixed)
#     D_6_1:     0 (fixed)
#     A_6_2:     0 (fixed)
#     B_6_2:     0 (fixed)
#     C_6_2:     0 (fixed)
#     D_6_2:     0 (fixed)
#     A_6_3:     0 (fixed)
#     B_6_3:     0 (fixed)
#     C_6_3:     0 (fixed)
#     D_6_3:     0 (fixed)
#     A_6_4:     0 (fixed)
#     B_6_4:     0 (fixed)
#     C_6_4:     0 (fixed)
#     D_6_4:     0 (fixed)
#     A_6_5:     0 (fixed)
#     B_6_5:     0 (fixed)
#     C_6_5:     0 (fixed)
#     D_6_5:     0 (fixed)
#     A_6_6:    -2.53094531 (init= 1)
#     B_6_6:    -110.806840 (init=-1)
#     C_6_6:     0 (fixed)
#     D_6_6:     0 (fixed)
#     A_6_7:     0 (fixed)
#     B_6_7:    -1.83567575 (init=-1)
#     C_6_7:     0 (fixed)
#     D_6_7:     0 (fixed)
#     A_6_8:     0.35537302 (init= 1)
#     B_6_8:    -4.19959797 (init=-1)
#     C_6_8:     0 (fixed)
#     D_6_8:     0 (fixed)
#     A_6_9:    -0.28535080 (init= 1)
#     B_6_9:    -0.38667618 (init=-1)
#     C_6_9:     0 (fixed)
#     D_6_9:     0 (fixed)
#     A_6_10:    1.41592628 (init= 1)
#     B_6_10:    1.84223129 (init=-1)
#     C_6_10:    0 (fixed)
#     D_6_10:    0 (fixed)
#     A_6_11:    1.19242750 (init= 1)
#     B_6_11:   -1.11315815 (init=-1)
#     C_6_11:    0 (fixed)
#     D_6_11:    0 (fixed)
#     A_6_12:    1.00381270 (init= 1)
#     B_6_12:   -0.96053868 (init=-1)
#     C_6_12:    0 (fixed)
#     D_6_12:    0 (fixed)
#     A_6_13:    0.97010502 (init= 1)
#     B_6_13:   -1.00582231 (init=-1)
#     C_6_13:    0 (fixed)
#     D_6_13:    0 (fixed)
#     A_6_14:    1.00016321 (init= 1)
#     B_6_14:   -0.99890008 (init=-1)
#     C_6_14:    0 (fixed)
#     D_6_14:    0 (fixed)
#     A_6_15:    1          (init= 1)
#     B_6_15:   -1.00000101 (init=-1)
#     C_6_15:    0 (fixed)
#     D_6_15:    0 (fixed)
#     A_6_16:    1          (init= 1)
#     B_6_16:   -1          (init=-1)
#     C_6_16:    0 (fixed)
#     D_6_16:    0 (fixed)
#     A_6_17:    1          (init= 1)
#     B_6_17:   -1          (init=-1)
#     C_6_17:    0 (fixed)
#     D_6_17:    0 (fixed)
#     A_6_18:    1          (init= 1)
#     B_6_18:   -1          (init=-1)
#     C_6_18:    0 (fixed)
#     D_6_18:    0 (fixed)
#     A_6_19:    1          (init= 1)
#     B_6_19:   -1          (init=-1)
#     C_6_19:    0 (fixed)
#     D_6_19:    0 (fixed)
#     A_7_0:     0 (fixed)
#     B_7_0:     0 (fixed)
#     C_7_0:     0 (fixed)
#     D_7_0:     0 (fixed)
#     A_7_1:     0 (fixed)
#     B_7_1:     0 (fixed)
#     C_7_1:     0 (fixed)
#     D_7_1:     0 (fixed)
#     A_7_2:     0 (fixed)
#     B_7_2:     0 (fixed)
#     C_7_2:     0 (fixed)
#     D_7_2:     0 (fixed)
#     A_7_3:     0 (fixed)
#     B_7_3:     0 (fixed)
#     C_7_3:     0 (fixed)
#     D_7_3:     0 (fixed)
#     A_7_4:     0 (fixed)
#     B_7_4:     0 (fixed)
#     C_7_4:     0 (fixed)
#     D_7_4:     0 (fixed)
#     A_7_5:     0 (fixed)
#     B_7_5:     0 (fixed)
#     C_7_5:     0 (fixed)
#     D_7_5:     0 (fixed)
#     A_7_6:     0 (fixed)
#     B_7_6:     0 (fixed)
#     C_7_6:     0 (fixed)
#     D_7_6:     0 (fixed)
#     A_7_7:    -5.41816977 (init= 1)
#     B_7_7:    -404.730282 (init=-1)
#     C_7_7:     0 (fixed)
#     D_7_7:     0 (fixed)
#     A_7_8:     0 (fixed)
#     B_7_8:    -0.60979971 (init=-1)
#     C_7_8:     0 (fixed)
#     D_7_8:     0 (fixed)
#     A_7_9:    -0.63699357 (init= 1)
#     B_7_9:     7.09330472 (init=-1)
#     C_7_9:     0 (fixed)
#     D_7_9:     0 (fixed)
#     A_7_10:   -0.15087619 (init= 1)
#     B_7_10:   -0.58510114 (init=-1)
#     C_7_10:    0 (fixed)
#     D_7_10:    0 (fixed)
#     A_7_11:    1.17329488 (init= 1)
#     B_7_11:    6.36322726 (init=-1)
#     C_7_11:    0 (fixed)
#     D_7_11:    0 (fixed)
#     A_7_12:    0.99062317 (init= 1)
#     B_7_12:   -0.98567414 (init=-1)
#     C_7_12:    0 (fixed)
#     D_7_12:    0 (fixed)
#     A_7_13:    1.11868866 (init= 1)
#     B_7_13:   -1.05628659 (init=-1)
#     C_7_13:    0 (fixed)
#     D_7_13:    0 (fixed)
#     A_7_14:    0.94084037 (init= 1)
#     B_7_14:   -0.98941160 (init=-1)
#     C_7_14:    0 (fixed)
#     D_7_14:    0 (fixed)
#     A_7_15:    0.99622503 (init= 1)
#     B_7_15:   -0.99957470 (init=-1)
#     C_7_15:    0 (fixed)
#     D_7_15:    0 (fixed)
#     A_7_16:    1.00350409 (init= 1)
#     B_7_16:   -0.99991706 (init=-1)
#     C_7_16:    0 (fixed)
#     D_7_16:    0 (fixed)
#     A_7_17:    0.99994882 (init= 1)
#     B_7_17:   -1.00000004 (init=-1)
#     C_7_17:    0 (fixed)
#     D_7_17:    0 (fixed)
#     A_7_18:    1          (init= 1)
#     B_7_18:   -1          (init=-1)
#     C_7_18:    0 (fixed)
#     D_7_18:    0 (fixed)
#     A_7_19:    1          (init= 1)
#     B_7_19:   -1          (init=-1)
#     C_7_19:    0 (fixed)
#     D_7_19:    0 (fixed)
#     A_8_0:     0 (fixed)
#     B_8_0:     0 (fixed)
#     C_8_0:     0 (fixed)
#     D_8_0:     0 (fixed)
#     A_8_1:     0 (fixed)
#     B_8_1:     0 (fixed)
#     C_8_1:     0 (fixed)
#     D_8_1:     0 (fixed)
#     A_8_2:     0 (fixed)
#     B_8_2:     0 (fixed)
#     C_8_2:     0 (fixed)
#     D_8_2:     0 (fixed)
#     A_8_3:     0 (fixed)
#     B_8_3:     0 (fixed)
#     C_8_3:     0 (fixed)
#     D_8_3:     0 (fixed)
#     A_8_4:     0 (fixed)
#     B_8_4:     0 (fixed)
#     C_8_4:     0 (fixed)
#     D_8_4:     0 (fixed)
#     A_8_5:     0 (fixed)
#     B_8_5:     0 (fixed)
#     C_8_5:     0 (fixed)
#     D_8_5:     0 (fixed)
#     A_8_6:     0 (fixed)
#     B_8_6:     0 (fixed)
#     C_8_6:     0 (fixed)
#     D_8_6:     0 (fixed)
#     A_8_7:     0 (fixed)
#     B_8_7:     0 (fixed)
#     C_8_7:     0 (fixed)
#     D_8_7:     0 (fixed)
#     A_8_8:    -4.38081265 (init= 1)
#     B_8_8:    -397.875941 (init=-1)
#     C_8_8:     0 (fixed)
#     D_8_8:     0 (fixed)
#     A_8_9:     0 (fixed)
#     B_8_9:     1.05027420 (init=-1)
#     C_8_9:     0 (fixed)
#     D_8_9:     0 (fixed)
#     A_8_10:   -0.99834684 (init= 1)
#     B_8_10:    10.6249287 (init=-1)
#     C_8_10:    0 (fixed)
#     D_8_10:    0 (fixed)
#     A_8_11:    0.03896001 (init= 1)
#     B_8_11:   -0.31889474 (init=-1)
#     C_8_11:    0 (fixed)
#     D_8_11:    0 (fixed)
#     A_8_12:    0.59152789 (init= 1)
#     B_8_12:    8.86321642 (init=-1)
#     C_8_12:    0 (fixed)
#     D_8_12:    0 (fixed)
#     A_8_13:    0.90017435 (init= 1)
#     B_8_13:   -0.67261314 (init=-1)
#     C_8_13:    0 (fixed)
#     D_8_13:    0 (fixed)
#     A_8_14:    0.89342734 (init= 1)
#     B_8_14:   -1.14280215 (init=-1)
#     C_8_14:    0 (fixed)
#     D_8_14:    0 (fixed)
#     A_8_15:    1.03591068 (init= 1)
#     B_8_15:   -1.04608119 (init=-1)
#     C_8_15:    0 (fixed)
#     D_8_15:    0 (fixed)
#     A_8_16:    0.98786798 (init= 1)
#     B_8_16:   -0.99295595 (init=-1)
#     C_8_16:    0 (fixed)
#     D_8_16:    0 (fixed)
#     A_8_17:    1.00117353 (init= 1)
#     B_8_17:   -1.00319087 (init=-1)
#     C_8_17:    0 (fixed)
#     D_8_17:    0 (fixed)
#     A_8_18:    1.00004193 (init= 1)
#     B_8_18:   -1.00005866 (init=-1)
#     C_8_18:    0 (fixed)
#     D_8_18:    0 (fixed)
#     A_8_19:    1          (init= 1)
#     B_8_19:   -1          (init=-1)
#     C_8_19:    0 (fixed)
#     D_8_19:    0 (fixed)
#     A_9_0:     0 (fixed)
#     B_9_0:     0 (fixed)
#     C_9_0:     0 (fixed)
#     D_9_0:     0 (fixed)
#     A_9_1:     0 (fixed)
#     B_9_1:     0 (fixed)
#     C_9_1:     0 (fixed)
#     D_9_1:     0 (fixed)
#     A_9_2:     0 (fixed)
#     B_9_2:     0 (fixed)
#     C_9_2:     0 (fixed)
#     D_9_2:     0 (fixed)
#     A_9_3:     0 (fixed)
#     B_9_3:     0 (fixed)
#     C_9_3:     0 (fixed)
#     D_9_3:     0 (fixed)
#     A_9_4:     0 (fixed)
#     B_9_4:     0 (fixed)
#     C_9_4:     0 (fixed)
#     D_9_4:     0 (fixed)
#     A_9_5:     0 (fixed)
#     B_9_5:     0 (fixed)
#     C_9_5:     0 (fixed)
#     D_9_5:     0 (fixed)
#     A_9_6:     0 (fixed)
#     B_9_6:     0 (fixed)
#     C_9_6:     0 (fixed)
#     D_9_6:     0 (fixed)
#     A_9_7:     0 (fixed)
#     B_9_7:     0 (fixed)
#     C_9_7:     0 (fixed)
#     D_9_7:     0 (fixed)
#     A_9_8:     0 (fixed)
#     B_9_8:     0 (fixed)
#     C_9_8:     0 (fixed)
#     D_9_8:     0 (fixed)
#     A_9_9:    -0.42243083 (init= 1)
#     B_9_9:    -162.949203 (init=-1)
#     C_9_9:     0 (fixed)
#     D_9_9:     0 (fixed)
#     A_9_10:    0 (fixed)
#     B_9_10:    1.63190084 (init=-1)
#     C_9_10:    0 (fixed)
#     D_9_10:    0 (fixed)
#     A_9_11:   -0.68986603 (init= 1)
#     B_9_11:    3.17298925 (init=-1)
#     C_9_11:    0 (fixed)
#     D_9_11:    0 (fixed)
#     A_9_12:    0.23918078 (init= 1)
#     B_9_12:    0.17426343 (init=-1)
#     C_9_12:    0 (fixed)
#     D_9_12:    0 (fixed)
#     A_9_13:   -0.13169646 (init= 1)
#     B_9_13:    6.52448825 (init=-1)
#     C_9_13:    0 (fixed)
#     D_9_13:    0 (fixed)
#     A_9_14:    0.55574533 (init= 1)
#     B_9_14:   -0.47804456 (init=-1)
#     C_9_14:    0 (fixed)
#     D_9_14:    0 (fixed)
#     A_9_15:    1.06234111 (init= 1)
#     B_9_15:   -1.43591829 (init=-1)
#     C_9_15:    0 (fixed)
#     D_9_15:    0 (fixed)
#     A_9_16:    0.98561838 (init= 1)
#     B_9_16:   -0.99464839 (init=-1)
#     C_9_16:    0 (fixed)
#     D_9_16:    0 (fixed)
#     A_9_17:    1.00977639 (init= 1)
#     B_9_17:   -0.99670915 (init=-1)
#     C_9_17:    0 (fixed)
#     D_9_17:    0 (fixed)
#     A_9_18:    0.99940763 (init= 1)
#     B_9_18:   -0.99953906 (init=-1)
#     C_9_18:    0 (fixed)
#     D_9_18:    0 (fixed)
#     A_9_19:    1.00000402 (init= 1)
#     B_9_19:   -1.00000057 (init=-1)
#     C_9_19:    0 (fixed)
#     D_9_19:    0 (fixed)
#     A_10_0:    0 (fixed)
#     B_10_0:    0 (fixed)
#     C_10_0:    0 (fixed)
#     D_10_0:    0 (fixed)
#     A_10_1:    0 (fixed)
#     B_10_1:    0 (fixed)
#     C_10_1:    0 (fixed)
#     D_10_1:    0 (fixed)
#     A_10_2:    0 (fixed)
#     B_10_2:    0 (fixed)
#     C_10_2:    0 (fixed)
#     D_10_2:    0 (fixed)
#     A_10_3:    0 (fixed)
#     B_10_3:    0 (fixed)
#     C_10_3:    0 (fixed)
#     D_10_3:    0 (fixed)
#     A_10_4:    0 (fixed)
#     B_10_4:    0 (fixed)
#     C_10_4:    0 (fixed)
#     D_10_4:    0 (fixed)
#     A_10_5:    0 (fixed)
#     B_10_5:    0 (fixed)
#     C_10_5:    0 (fixed)
#     D_10_5:    0 (fixed)
#     A_10_6:    0 (fixed)
#     B_10_6:    0 (fixed)
#     C_10_6:    0 (fixed)
#     D_10_6:    0 (fixed)
#     A_10_7:    0 (fixed)
#     B_10_7:    0 (fixed)
#     C_10_7:    0 (fixed)
#     D_10_7:    0 (fixed)
#     A_10_8:    0 (fixed)
#     B_10_8:    0 (fixed)
#     C_10_8:    0 (fixed)
#     D_10_8:    0 (fixed)
#     A_10_9:    0 (fixed)
#     B_10_9:    0 (fixed)
#     C_10_9:    0 (fixed)
#     D_10_9:    0 (fixed)
#     A_10_10:   4.03912361 (init= 1)
#     B_10_10:   118.439279 (init=-1)
#     C_10_10:   0 (fixed)
#     D_10_10:   0 (fixed)
#     A_10_11:   0 (fixed)
#     B_10_11:   0.38454431 (init=-1)
#     C_10_11:   0 (fixed)
#     D_10_11:   0 (fixed)
#     A_10_12:   0.18677810 (init= 1)
#     B_10_12:  -7.31938578 (init=-1)
#     C_10_12:   0 (fixed)
#     D_10_12:   0 (fixed)
#     A_10_13:   0.04337274 (init= 1)
#     B_10_13:   0.69373868 (init=-1)
#     C_10_13:   0 (fixed)
#     D_10_13:   0 (fixed)
#     A_10_14:  -0.66009232 (init= 1)
#     B_10_14:  -1.08339452 (init=-1)
#     C_10_14:   0 (fixed)
#     D_10_14:   0 (fixed)
#     A_10_15:   0.25735062 (init= 1)
#     B_10_15:  -0.30289014 (init=-1)
#     C_10_15:   0 (fixed)
#     D_10_15:   0 (fixed)
#     A_10_16:   1.16213691 (init= 1)
#     B_10_16:  -1.43421346 (init=-1)
#     C_10_16:   0 (fixed)
#     D_10_16:   0 (fixed)
#     A_10_17:   0.95474348 (init= 1)
#     B_10_17:  -0.92122621 (init=-1)
#     C_10_17:   0 (fixed)
#     D_10_17:   0 (fixed)
#     A_10_18:   1.01945057 (init= 1)
#     B_10_18:  -1.03163829 (init=-1)
#     C_10_18:   0 (fixed)
#     D_10_18:   0 (fixed)
#     A_10_19:   0.99192877 (init= 1)
#     B_10_19:  -0.99634954 (init=-1)
#     C_10_19:   0 (fixed)
#     D_10_19:   0 (fixed)
#     A_11_0:    0 (fixed)
#     B_11_0:    0 (fixed)
#     C_11_0:    0 (fixed)
#     D_11_0:    0 (fixed)
#     A_11_1:    0 (fixed)
#     B_11_1:    0 (fixed)
#     C_11_1:    0 (fixed)
#     D_11_1:    0 (fixed)
#     A_11_2:    0 (fixed)
#     B_11_2:    0 (fixed)
#     C_11_2:    0 (fixed)
#     D_11_2:    0 (fixed)
#     A_11_3:    0 (fixed)
#     B_11_3:    0 (fixed)
#     C_11_3:    0 (fixed)
#     D_11_3:    0 (fixed)
#     A_11_4:    0 (fixed)
#     B_11_4:    0 (fixed)
#     C_11_4:    0 (fixed)
#     D_11_4:    0 (fixed)
#     A_11_5:    0 (fixed)
#     B_11_5:    0 (fixed)
#     C_11_5:    0 (fixed)
#     D_11_5:    0 (fixed)
#     A_11_6:    0 (fixed)
#     B_11_6:    0 (fixed)
#     C_11_6:    0 (fixed)
#     D_11_6:    0 (fixed)
#     A_11_7:    0 (fixed)
#     B_11_7:    0 (fixed)
#     C_11_7:    0 (fixed)
#     D_11_7:    0 (fixed)
#     A_11_8:    0 (fixed)
#     B_11_8:    0 (fixed)
#     C_11_8:    0 (fixed)
#     D_11_8:    0 (fixed)
#     A_11_9:    0 (fixed)
#     B_11_9:    0 (fixed)
#     C_11_9:    0 (fixed)
#     D_11_9:    0 (fixed)
#     A_11_10:   0 (fixed)
#     B_11_10:   0 (fixed)
#     C_11_10:   0 (fixed)
#     D_11_10:   0 (fixed)
#     A_11_11:   5.51325989 (init= 1)
#     B_11_11:   259.737909 (init=-1)
#     C_11_11:   0 (fixed)
#     D_11_11:   0 (fixed)
#     A_11_12:   0 (fixed)
#     B_11_12:  -0.63328701 (init=-1)
#     C_11_12:   0 (fixed)
#     D_11_12:   0 (fixed)
#     A_11_13:   1.06033407 (init= 1)
#     B_11_13:  -9.32323853 (init=-1)
#     C_11_13:   0 (fixed)
#     D_11_13:   0 (fixed)
#     A_11_14:   0.08787238 (init= 1)
#     B_11_14:   0.53911513 (init=-1)
#     C_11_14:   0 (fixed)
#     D_11_14:   0 (fixed)
#     A_11_15:  -1.40948877 (init= 1)
#     B_11_15:  -9.23514389 (init=-1)
#     C_11_15:   0 (fixed)
#     D_11_15:   0 (fixed)
#     A_11_16:  -0.18049291 (init= 1)
#     B_11_16:   0.02672359 (init=-1)
#     C_11_16:   0 (fixed)
#     D_11_16:   0 (fixed)
#     A_11_17:   1.06878043 (init= 1)
#     B_11_17:  -0.92296035 (init=-1)
#     C_11_17:   0 (fixed)
#     D_11_17:   0 (fixed)
#     A_11_18:   1.03628367 (init= 1)
#     B_11_18:  -0.94887953 (init=-1)
#     C_11_18:   0 (fixed)
#     D_11_18:   0 (fixed)
#     A_11_19:   0.97651954 (init= 1)
#     B_11_19:  -0.96851629 (init=-1)
#     C_11_19:   0 (fixed)
#     D_11_19:   0 (fixed)
#     A_12_0:    0 (fixed)
#     B_12_0:    0 (fixed)
#     C_12_0:    0 (fixed)
#     D_12_0:    0 (fixed)
#     A_12_1:    0 (fixed)
#     B_12_1:    0 (fixed)
#     C_12_1:    0 (fixed)
#     D_12_1:    0 (fixed)
#     A_12_2:    0 (fixed)
#     B_12_2:    0 (fixed)
#     C_12_2:    0 (fixed)
#     D_12_2:    0 (fixed)
#     A_12_3:    0 (fixed)
#     B_12_3:    0 (fixed)
#     C_12_3:    0 (fixed)
#     D_12_3:    0 (fixed)
#     A_12_4:    0 (fixed)
#     B_12_4:    0 (fixed)
#     C_12_4:    0 (fixed)
#     D_12_4:    0 (fixed)
#     A_12_5:    0 (fixed)
#     B_12_5:    0 (fixed)
#     C_12_5:    0 (fixed)
#     D_12_5:    0 (fixed)
#     A_12_6:    0 (fixed)
#     B_12_6:    0 (fixed)
#     C_12_6:    0 (fixed)
#     D_12_6:    0 (fixed)
#     A_12_7:    0 (fixed)
#     B_12_7:    0 (fixed)
#     C_12_7:    0 (fixed)
#     D_12_7:    0 (fixed)
#     A_12_8:    0 (fixed)
#     B_12_8:    0 (fixed)
#     C_12_8:    0 (fixed)
#     D_12_8:    0 (fixed)
#     A_12_9:    0 (fixed)
#     B_12_9:    0 (fixed)
#     C_12_9:    0 (fixed)
#     D_12_9:    0 (fixed)
#     A_12_10:   0 (fixed)
#     B_12_10:   0 (fixed)
#     C_12_10:   0 (fixed)
#     D_12_10:   0 (fixed)
#     A_12_11:   0 (fixed)
#     B_12_11:   0 (fixed)
#     C_12_11:   0 (fixed)
#     D_12_11:   0 (fixed)
#     A_12_12:   2.47466652 (init= 1)
#     B_12_12:   182.220980 (init=-1)
#     C_12_12:   0 (fixed)
#     D_12_12:   0 (fixed)
#     A_12_13:   0 (fixed)
#     B_12_13:  -1.40732757 (init=-1)
#     C_12_13:   0 (fixed)
#     D_12_13:   0 (fixed)
#     A_12_14:   0.95026943 (init= 1)
#     B_12_14:  -0.24567263 (init=-1)
#     C_12_14:   0 (fixed)
#     D_12_14:   0 (fixed)
#     A_12_15:  -0.15421515 (init= 1)
#     B_12_15:  -0.23372927 (init=-1)
#     C_12_15:   0 (fixed)
#     D_12_15:   0 (fixed)
#     A_12_16:  -0.50527979 (init= 1)
#     B_12_16:  -9.85270608 (init=-1)
#     C_12_16:   0 (fixed)
#     D_12_16:   0 (fixed)
#     A_12_17:  -0.31116097 (init= 1)
#     B_12_17:   0.10612407 (init=-1)
#     C_12_17:   0 (fixed)
#     D_12_17:   0 (fixed)
#     A_12_18:   1.05491529 (init= 1)
#     B_12_18:  -1.07295505 (init=-1)
#     C_12_18:   0 (fixed)
#     D_12_18:   0 (fixed)
#     A_12_19:   1.07963412 (init= 1)
#     B_12_19:  -1.01601906 (init=-1)
#     C_12_19:   0 (fixed)
#     D_12_19:   0 (fixed)
#     A_13_0:    0 (fixed)
#     B_13_0:    0 (fixed)
#     C_13_0:    0 (fixed)
#     D_13_0:    0 (fixed)
#     A_13_1:    0 (fixed)
#     B_13_1:    0 (fixed)
#     C_13_1:    0 (fixed)
#     D_13_1:    0 (fixed)
#     A_13_2:    0 (fixed)
#     B_13_2:    0 (fixed)
#     C_13_2:    0 (fixed)
#     D_13_2:    0 (fixed)
#     A_13_3:    0 (fixed)
#     B_13_3:    0 (fixed)
#     C_13_3:    0 (fixed)
#     D_13_3:    0 (fixed)
#     A_13_4:    0 (fixed)
#     B_13_4:    0 (fixed)
#     C_13_4:    0 (fixed)
#     D_13_4:    0 (fixed)
#     A_13_5:    0 (fixed)
#     B_13_5:    0 (fixed)
#     C_13_5:    0 (fixed)
#     D_13_5:    0 (fixed)
#     A_13_6:    0 (fixed)
#     B_13_6:    0 (fixed)
#     C_13_6:    0 (fixed)
#     D_13_6:    0 (fixed)
#     A_13_7:    0 (fixed)
#     B_13_7:    0 (fixed)
#     C_13_7:    0 (fixed)
#     D_13_7:    0 (fixed)
#     A_13_8:    0 (fixed)
#     B_13_8:    0 (fixed)
#     C_13_8:    0 (fixed)
#     D_13_8:    0 (fixed)
#     A_13_9:    0 (fixed)
#     B_13_9:    0 (fixed)
#     C_13_9:    0 (fixed)
#     D_13_9:    0 (fixed)
#     A_13_10:   0 (fixed)
#     B_13_10:   0 (fixed)
#     C_13_10:   0 (fixed)
#     D_13_10:   0 (fixed)
#     A_13_11:   0 (fixed)
#     B_13_11:   0 (fixed)
#     C_13_11:   0 (fixed)
#     D_13_11:   0 (fixed)
#     A_13_12:   0 (fixed)
#     B_13_12:   0 (fixed)
#     C_13_12:   0 (fixed)
#     D_13_12:   0 (fixed)
#     A_13_13:  -3.29723517 (init= 1)
#     B_13_13:  -30.2833552 (init=-1)
#     C_13_13:   0 (fixed)
#     D_13_13:   0 (fixed)
#     A_13_14:   0 (fixed)
#     B_13_14:  -0.31658415 (init=-1)
#     C_13_14:   0 (fixed)
#     D_13_14:   0 (fixed)
#     A_13_15:   0.01946680 (init= 1)
#     B_13_15:   8.77142045 (init=-1)
#     C_13_15:   0 (fixed)
#     D_13_15:   0 (fixed)
#     A_13_16:  -0.10373203 (init= 1)
#     B_13_16:  -0.99124098 (init=-1)
#     C_13_16:   0 (fixed)
#     D_13_16:   0 (fixed)
#     A_13_17:   0.84568076 (init= 1)
#     B_13_17:   2.28781792 (init=-1)
#     C_13_17:   0 (fixed)
#     D_13_17:   0 (fixed)
#     A_13_18:  -0.48072360 (init= 1)
#     B_13_18:  -0.01248792 (init=-1)
#     C_13_18:   0 (fixed)
#     D_13_18:   0 (fixed)
#     A_13_19:   1.12703501 (init= 1)
#     B_13_19:  -1.21030184 (init=-1)
#     C_13_19:   0 (fixed)
#     D_13_19:   0 (fixed)
#     A_14_0:    0 (fixed)
#     B_14_0:    0 (fixed)
#     C_14_0:    0 (fixed)
#     D_14_0:    0 (fixed)
#     A_14_1:    0 (fixed)
#     B_14_1:    0 (fixed)
#     C_14_1:    0 (fixed)
#     D_14_1:    0 (fixed)
#     A_14_2:    0 (fixed)
#     B_14_2:    0 (fixed)
#     C_14_2:    0 (fixed)
#     D_14_2:    0 (fixed)
#     A_14_3:    0 (fixed)
#     B_14_3:    0 (fixed)
#     C_14_3:    0 (fixed)
#     D_14_3:    0 (fixed)
#     A_14_4:    0 (fixed)
#     B_14_4:    0 (fixed)
#     C_14_4:    0 (fixed)
#     D_14_4:    0 (fixed)
#     A_14_5:    0 (fixed)
#     B_14_5:    0 (fixed)
#     C_14_5:    0 (fixed)
#     D_14_5:    0 (fixed)
#     A_14_6:    0 (fixed)
#     B_14_6:    0 (fixed)
#     C_14_6:    0 (fixed)
#     D_14_6:    0 (fixed)
#     A_14_7:    0 (fixed)
#     B_14_7:    0 (fixed)
#     C_14_7:    0 (fixed)
#     D_14_7:    0 (fixed)
#     A_14_8:    0 (fixed)
#     B_14_8:    0 (fixed)
#     C_14_8:    0 (fixed)
#     D_14_8:    0 (fixed)
#     A_14_9:    0 (fixed)
#     B_14_9:    0 (fixed)
#     C_14_9:    0 (fixed)
#     D_14_9:    0 (fixed)
#     A_14_10:   0 (fixed)
#     B_14_10:   0 (fixed)
#     C_14_10:   0 (fixed)
#     D_14_10:   0 (fixed)
#     A_14_11:   0 (fixed)
#     B_14_11:   0 (fixed)
#     C_14_11:   0 (fixed)
#     D_14_11:   0 (fixed)
#     A_14_12:   0 (fixed)
#     B_14_12:   0 (fixed)
#     C_14_12:   0 (fixed)
#     D_14_12:   0 (fixed)
#     A_14_13:   0 (fixed)
#     B_14_13:   0 (fixed)
#     C_14_13:   0 (fixed)
#     D_14_13:   0 (fixed)
#     A_14_14:  -6.12866518 (init= 1)
#     B_14_14:  -183.104343 (init=-1)
#     C_14_14:   0 (fixed)
#     D_14_14:   0 (fixed)
#     A_14_15:   0 (fixed)
#     B_14_15:   0.84451875 (init=-1)
#     C_14_15:   0 (fixed)
#     D_14_15:   0 (fixed)
#     A_14_16:  -1.44837996 (init= 1)
#     B_14_16:   4.21170170 (init=-1)
#     C_14_16:   0 (fixed)
#     D_14_16:   0 (fixed)
#     A_14_17:  -0.03156920 (init= 1)
#     B_14_17:  -0.21418465 (init=-1)
#     C_14_17:   0 (fixed)
#     D_14_17:   0 (fixed)
#     A_14_18:   1.71894048 (init= 1)
#     B_14_18:   16.3588667 (init=-1)
#     C_14_18:   0 (fixed)
#     D_14_18:   0 (fixed)
#     A_14_19:   0.13944052 (init= 1)
#     B_14_19:  -0.50926210 (init=-1)
#     C_14_19:   0 (fixed)
#     D_14_19:   0 (fixed)
#     A_15_0:    0 (fixed)
#     B_15_0:    0 (fixed)
#     C_15_0:    0 (fixed)
#     D_15_0:    0 (fixed)
#     A_15_1:    0 (fixed)
#     B_15_1:    0 (fixed)
#     C_15_1:    0 (fixed)
#     D_15_1:    0 (fixed)
#     A_15_2:    0 (fixed)
#     B_15_2:    0 (fixed)
#     C_15_2:    0 (fixed)
#     D_15_2:    0 (fixed)
#     A_15_3:    0 (fixed)
#     B_15_3:    0 (fixed)
#     C_15_3:    0 (fixed)
#     D_15_3:    0 (fixed)
#     A_15_4:    0 (fixed)
#     B_15_4:    0 (fixed)
#     C_15_4:    0 (fixed)
#     D_15_4:    0 (fixed)
#     A_15_5:    0 (fixed)
#     B_15_5:    0 (fixed)
#     C_15_5:    0 (fixed)
#     D_15_5:    0 (fixed)
#     A_15_6:    0 (fixed)
#     B_15_6:    0 (fixed)
#     C_15_6:    0 (fixed)
#     D_15_6:    0 (fixed)
#     A_15_7:    0 (fixed)
#     B_15_7:    0 (fixed)
#     C_15_7:    0 (fixed)
#     D_15_7:    0 (fixed)
#     A_15_8:    0 (fixed)
#     B_15_8:    0 (fixed)
#     C_15_8:    0 (fixed)
#     D_15_8:    0 (fixed)
#     A_15_9:    0 (fixed)
#     B_15_9:    0 (fixed)
#     C_15_9:    0 (fixed)
#     D_15_9:    0 (fixed)
#     A_15_10:   0 (fixed)
#     B_15_10:   0 (fixed)
#     C_15_10:   0 (fixed)
#     D_15_10:   0 (fixed)
#     A_15_11:   0 (fixed)
#     B_15_11:   0 (fixed)
#     C_15_11:   0 (fixed)
#     D_15_11:   0 (fixed)
#     A_15_12:   0 (fixed)
#     B_15_12:   0 (fixed)
#     C_15_12:   0 (fixed)
#     D_15_12:   0 (fixed)
#     A_15_13:   0 (fixed)
#     B_15_13:   0 (fixed)
#     C_15_13:   0 (fixed)
#     D_15_13:   0 (fixed)
#     A_15_14:   0 (fixed)
#     B_15_14:   0 (fixed)
#     C_15_14:   0 (fixed)
#     D_15_14:   0 (fixed)
#     A_15_15:  -2.21193311 (init= 1)
#     B_15_15:  -123.818428 (init=-1)
#     C_15_15:   0 (fixed)
#     D_15_15:   0 (fixed)
#     A_15_16:   0 (fixed)
#     B_15_16:   0.80530741 (init=-1)
#     C_15_16:   0 (fixed)
#     D_15_16:   0 (fixed)
#     A_15_17:  -1.01523874 (init= 1)
#     B_15_17:  -7.60513693 (init=-1)
#     C_15_17:   0 (fixed)
#     D_15_17:   0 (fixed)
#     A_15_18:   0.18702531 (init= 1)
#     B_15_18:   1.09824568 (init=-1)
#     C_15_18:   0 (fixed)
#     D_15_18:   0 (fixed)
#     A_15_19:  -1.17537781 (init= 1)
#     B_15_19:  -8.76331430 (init=-1)
#     C_15_19:   0 (fixed)
#     D_15_19:   0 (fixed)
#     A_16_0:    0 (fixed)
#     B_16_0:    0 (fixed)
#     C_16_0:    0 (fixed)
#     D_16_0:    0 (fixed)
#     A_16_1:    0 (fixed)
#     B_16_1:    0 (fixed)
#     C_16_1:    0 (fixed)
#     D_16_1:    0 (fixed)
#     A_16_2:    0 (fixed)
#     B_16_2:    0 (fixed)
#     C_16_2:    0 (fixed)
#     D_16_2:    0 (fixed)
#     A_16_3:    0 (fixed)
#     B_16_3:    0 (fixed)
#     C_16_3:    0 (fixed)
#     D_16_3:    0 (fixed)
#     A_16_4:    0 (fixed)
#     B_16_4:    0 (fixed)
#     C_16_4:    0 (fixed)
#     D_16_4:    0 (fixed)
#     A_16_5:    0 (fixed)
#     B_16_5:    0 (fixed)
#     C_16_5:    0 (fixed)
#     D_16_5:    0 (fixed)
#     A_16_6:    0 (fixed)
#     B_16_6:    0 (fixed)
#     C_16_6:    0 (fixed)
#     D_16_6:    0 (fixed)
#     A_16_7:    0 (fixed)
#     B_16_7:    0 (fixed)
#     C_16_7:    0 (fixed)
#     D_16_7:    0 (fixed)
#     A_16_8:    0 (fixed)
#     B_16_8:    0 (fixed)
#     C_16_8:    0 (fixed)
#     D_16_8:    0 (fixed)
#     A_16_9:    0 (fixed)
#     B_16_9:    0 (fixed)
#     C_16_9:    0 (fixed)
#     D_16_9:    0 (fixed)
#     A_16_10:   0 (fixed)
#     B_16_10:   0 (fixed)
#     C_16_10:   0 (fixed)
#     D_16_10:   0 (fixed)
#     A_16_11:   0 (fixed)
#     B_16_11:   0 (fixed)
#     C_16_11:   0 (fixed)
#     D_16_11:   0 (fixed)
#     A_16_12:   0 (fixed)
#     B_16_12:   0 (fixed)
#     C_16_12:   0 (fixed)
#     D_16_12:   0 (fixed)
#     A_16_13:   0 (fixed)
#     B_16_13:   0 (fixed)
#     C_16_13:   0 (fixed)
#     D_16_13:   0 (fixed)
#     A_16_14:   0 (fixed)
#     B_16_14:   0 (fixed)
#     C_16_14:   0 (fixed)
#     D_16_14:   0 (fixed)
#     A_16_15:   0 (fixed)
#     B_16_15:   0 (fixed)
#     C_16_15:   0 (fixed)
#     D_16_15:   0 (fixed)
#     A_16_16:   5.42321361 (init= 1)
#     B_16_16:   87.1657994 (init=-1)
#     C_16_16:   0 (fixed)
#     D_16_16:   0 (fixed)
#     A_16_17:   0 (fixed)
#     B_16_17:  -0.24012061 (init=-1)
#     C_16_17:   0 (fixed)
#     D_16_17:   0 (fixed)
#     A_16_18:   2.13548214 (init= 1)
#     B_16_18:   1.12466338 (init=-1)
#     C_16_18:   0 (fixed)
#     D_16_18:   0 (fixed)
#     A_16_19:  -0.07833830 (init= 1)
#     B_16_19:  -0.42909571 (init=-1)
#     C_16_19:   0 (fixed)
#     D_16_19:   0 (fixed)
#     A_17_0:    0 (fixed)
#     B_17_0:    0 (fixed)
#     C_17_0:    0 (fixed)
#     D_17_0:    0 (fixed)
#     A_17_1:    0 (fixed)
#     B_17_1:    0 (fixed)
#     C_17_1:    0 (fixed)
#     D_17_1:    0 (fixed)
#     A_17_2:    0 (fixed)
#     B_17_2:    0 (fixed)
#     C_17_2:    0 (fixed)
#     D_17_2:    0 (fixed)
#     A_17_3:    0 (fixed)
#     B_17_3:    0 (fixed)
#     C_17_3:    0 (fixed)
#     D_17_3:    0 (fixed)
#     A_17_4:    0 (fixed)
#     B_17_4:    0 (fixed)
#     C_17_4:    0 (fixed)
#     D_17_4:    0 (fixed)
#     A_17_5:    0 (fixed)
#     B_17_5:    0 (fixed)
#     C_17_5:    0 (fixed)
#     D_17_5:    0 (fixed)
#     A_17_6:    0 (fixed)
#     B_17_6:    0 (fixed)
#     C_17_6:    0 (fixed)
#     D_17_6:    0 (fixed)
#     A_17_7:    0 (fixed)
#     B_17_7:    0 (fixed)
#     C_17_7:    0 (fixed)
#     D_17_7:    0 (fixed)
#     A_17_8:    0 (fixed)
#     B_17_8:    0 (fixed)
#     C_17_8:    0 (fixed)
#     D_17_8:    0 (fixed)
#     A_17_9:    0 (fixed)
#     B_17_9:    0 (fixed)
#     C_17_9:    0 (fixed)
#     D_17_9:    0 (fixed)
#     A_17_10:   0 (fixed)
#     B_17_10:   0 (fixed)
#     C_17_10:   0 (fixed)
#     D_17_10:   0 (fixed)
#     A_17_11:   0 (fixed)
#     B_17_11:   0 (fixed)
#     C_17_11:   0 (fixed)
#     D_17_11:   0 (fixed)
#     A_17_12:   0 (fixed)
#     B_17_12:   0 (fixed)
#     C_17_12:   0 (fixed)
#     D_17_12:   0 (fixed)
#     A_17_13:   0 (fixed)
#     B_17_13:   0 (fixed)
#     C_17_13:   0 (fixed)
#     D_17_13:   0 (fixed)
#     A_17_14:   0 (fixed)
#     B_17_14:   0 (fixed)
#     C_17_14:   0 (fixed)
#     D_17_14:   0 (fixed)
#     A_17_15:   0 (fixed)
#     B_17_15:   0 (fixed)
#     C_17_15:   0 (fixed)
#     D_17_15:   0 (fixed)
#     A_17_16:   0 (fixed)
#     B_17_16:   0 (fixed)
#     C_17_16:   0 (fixed)
#     D_17_16:   0 (fixed)
#     A_17_17:   5.74082370 (init= 1)
#     B_17_17:   152.542116 (init=-1)
#     C_17_17:   0 (fixed)
#     D_17_17:   0 (fixed)
#     A_17_18:   0 (fixed)
#     B_17_18:  -0.68021636 (init=-1)
#     C_17_18:   0 (fixed)
#     D_17_18:   0 (fixed)
#     A_17_19:  -0.74217865 (init= 1)
#     B_17_19:   0.54026050 (init=-1)
#     C_17_19:   0 (fixed)
#     D_17_19:   0 (fixed)
#     A_18_0:    0 (fixed)
#     B_18_0:    0 (fixed)
#     C_18_0:    0 (fixed)
#     D_18_0:    0 (fixed)
#     A_18_1:    0 (fixed)
#     B_18_1:    0 (fixed)
#     C_18_1:    0 (fixed)
#     D_18_1:    0 (fixed)
#     A_18_2:    0 (fixed)
#     B_18_2:    0 (fixed)
#     C_18_2:    0 (fixed)
#     D_18_2:    0 (fixed)
#     A_18_3:    0 (fixed)
#     B_18_3:    0 (fixed)
#     C_18_3:    0 (fixed)
#     D_18_3:    0 (fixed)
#     A_18_4:    0 (fixed)
#     B_18_4:    0 (fixed)
#     C_18_4:    0 (fixed)
#     D_18_4:    0 (fixed)
#     A_18_5:    0 (fixed)
#     B_18_5:    0 (fixed)
#     C_18_5:    0 (fixed)
#     D_18_5:    0 (fixed)
#     A_18_6:    0 (fixed)
#     B_18_6:    0 (fixed)
#     C_18_6:    0 (fixed)
#     D_18_6:    0 (fixed)
#     A_18_7:    0 (fixed)
#     B_18_7:    0 (fixed)
#     C_18_7:    0 (fixed)
#     D_18_7:    0 (fixed)
#     A_18_8:    0 (fixed)
#     B_18_8:    0 (fixed)
#     C_18_8:    0 (fixed)
#     D_18_8:    0 (fixed)
#     A_18_9:    0 (fixed)
#     B_18_9:    0 (fixed)
#     C_18_9:    0 (fixed)
#     D_18_9:    0 (fixed)
#     A_18_10:   0 (fixed)
#     B_18_10:   0 (fixed)
#     C_18_10:   0 (fixed)
#     D_18_10:   0 (fixed)
#     A_18_11:   0 (fixed)
#     B_18_11:   0 (fixed)
#     C_18_11:   0 (fixed)
#     D_18_11:   0 (fixed)
#     A_18_12:   0 (fixed)
#     B_18_12:   0 (fixed)
#     C_18_12:   0 (fixed)
#     D_18_12:   0 (fixed)
#     A_18_13:   0 (fixed)
#     B_18_13:   0 (fixed)
#     C_18_13:   0 (fixed)
#     D_18_13:   0 (fixed)
#     A_18_14:   0 (fixed)
#     B_18_14:   0 (fixed)
#     C_18_14:   0 (fixed)
#     D_18_14:   0 (fixed)
#     A_18_15:   0 (fixed)
#     B_18_15:   0 (fixed)
#     C_18_15:   0 (fixed)
#     D_18_15:   0 (fixed)
#     A_18_16:   0 (fixed)
#     B_18_16:   0 (fixed)
#     C_18_16:   0 (fixed)
#     D_18_16:   0 (fixed)
#     A_18_17:   0 (fixed)
#     B_18_17:   0 (fixed)
#     C_18_17:   0 (fixed)
#     D_18_17:   0 (fixed)
#     A_18_18:  -7.86505268 (init= 1)
#     B_18_18:  -127.967322 (init=-1)
#     C_18_18:   0 (fixed)
#     D_18_18:   0 (fixed)
#     A_18_19:   0 (fixed)
#     B_18_19:   0.30778984 (init=-1)
#     C_18_19:   0 (fixed)
#     D_18_19:   0 (fixed)
#     A_19_0:    0 (fixed)
#     B_19_0:    0 (fixed)
#     C_19_0:    0 (fixed)
#     D_19_0:    0 (fixed)
#     A_19_1:    0 (fixed)
#     B_19_1:    0 (fixed)
#     C_19_1:    0 (fixed)
#     D_19_1:    0 (fixed)
#     A_19_2:    0 (fixed)
#     B_19_2:    0 (fixed)
#     C_19_2:    0 (fixed)
#     D_19_2:    0 (fixed)
#     A_19_3:    0 (fixed)
#     B_19_3:    0 (fixed)
#     C_19_3:    0 (fixed)
#     D_19_3:    0 (fixed)
#     A_19_4:    0 (fixed)
#     B_19_4:    0 (fixed)
#     C_19_4:    0 (fixed)
#     D_19_4:    0 (fixed)
#     A_19_5:    0 (fixed)
#     B_19_5:    0 (fixed)
#     C_19_5:    0 (fixed)
#     D_19_5:    0 (fixed)
#     A_19_6:    0 (fixed)
#     B_19_6:    0 (fixed)
#     C_19_6:    0 (fixed)
#     D_19_6:    0 (fixed)
#     A_19_7:    0 (fixed)
#     B_19_7:    0 (fixed)
#     C_19_7:    0 (fixed)
#     D_19_7:    0 (fixed)
#     A_19_8:    0 (fixed)
#     B_19_8:    0 (fixed)
#     C_19_8:    0 (fixed)
#     D_19_8:    0 (fixed)
#     A_19_9:    0 (fixed)
#     B_19_9:    0 (fixed)
#     C_19_9:    0 (fixed)
#     D_19_9:    0 (fixed)
#     A_19_10:   0 (fixed)
#     B_19_10:   0 (fixed)
#     C_19_10:   0 (fixed)
#     D_19_10:   0 (fixed)
#     A_19_11:   0 (fixed)
#     B_19_11:   0 (fixed)
#     C_19_11:   0 (fixed)
#     D_19_11:   0 (fixed)
#     A_19_12:   0 (fixed)
#     B_19_12:   0 (fixed)
#     C_19_12:   0 (fixed)
#     D_19_12:   0 (fixed)
#     A_19_13:   0 (fixed)
#     B_19_13:   0 (fixed)
#     C_19_13:   0 (fixed)
#     D_19_13:   0 (fixed)
#     A_19_14:   0 (fixed)
#     B_19_14:   0 (fixed)
#     C_19_14:   0 (fixed)
#     D_19_14:   0 (fixed)
#     A_19_15:   0 (fixed)
#     B_19_15:   0 (fixed)
#     C_19_15:   0 (fixed)
#     D_19_15:   0 (fixed)
#     A_19_16:   0 (fixed)
#     B_19_16:   0 (fixed)
#     C_19_16:   0 (fixed)
#     D_19_16:   0 (fixed)
#     A_19_17:   0 (fixed)
#     B_19_17:   0 (fixed)
#     C_19_17:   0 (fixed)
#     D_19_17:   0 (fixed)
#     A_19_18:   0 (fixed)
#     B_19_18:   0 (fixed)
#     C_19_18:   0 (fixed)
#     D_19_18:   0 (fixed)
#     A_19_19:   2.25791192 (init= 1)
#     B_19_19:   26.7066958 (init=-1)
#     C_19_19:   0 (fixed)
#     D_19_19:   0 (fixed)

# %%
ff2 = deepcopy(ff)

# %%
labs=[i[2:] for i in ff1.params if ('A' in i and ff1.params[i].vary==True and i.split('_')[1] != '0')]

As_1=[ff1.params[i].value for i in ff1.params if ('A' in i and ff1.params[i].vary==True and i.split('_')[1] != '0')]
As_2=[ff2.params[i].value for i in ff2.params if ('A' in i and ff2.params[i].vary==True and i.split('_')[1] != '0')]
#As_3=[ff3.params[i].value for i in ff3.params if ('A' in i and ff3.params[i].vary==True and i.split('_')[1] != '0')]


Bs_1=[ff1.params[i].value for i in ff1.params if ('B' in i and ff1.params[i].vary==True and i.split('_')[1] != '0')]
Bs_2=[ff2.params[i].value for i in ff2.params if ('B' in i and ff2.params[i].vary==True and i.split('_')[1] != '0')]
#Bs_3=[ff3.params[i].value for i in ff3.params if ('B' in i and ff3.params[i].vary==True and i.split('_')[1] != '0')]

# %%
_ = plt.plot(range(len(As_1)),As_1, 'o-', label='As, phi=0')
_ = plt.plot(range(len(As_1)),As_2, 'o-', label='As, phi=pi/2')
#_ = plt.plot(range(len(As_1)),As_3, 'o-', label='As, phi=pi/8')
_ = plt.axhline(0,0, 1, linestyle='--', color='k')

_ = plt.xticks(range(len(As_1)), labs, rotation='vertical')
plt.yscale('symlog')
plt.legend()
plt.title('Free param values for A')

# %%
_ = plt.plot(range(len(Bs_1)),Bs_1, 'o-', label='Bs, phi=0')
_ = plt.plot(range(len(Bs_1)),Bs_2, 'o-', label='Bs, phi=pi/2')
#_ = plt.plot(range(len(Bs_1)),Bs_3, 'o-', label='Bs, phi=pi/8')
_ = plt.axhline(0,0, 1, linestyle='--', color='k')


_ = plt.xticks(range(len(Bs_1)), labs, rotation='vertical')
plt.yscale('symlog')
plt.legend()
plt.title('Free param values for B')

# %%
_ = plt.plot(As_1,As_2, 'o', label='As')
_ = plt.plot(Bs_1,Bs_2, 's', label='Bs')
plt.ylim(-10e7, 10e7)
plt.xlim(-10e7, 10e7)
_ =plt.plot(plt.gca().get_xlim(), plt.gca().get_ylim(), 'k--', zorder=0)
_ =plt.plot(plt.gca().get_xlim(), plt.gca().get_ylim()[::-1], 'k--', zorder=0)

#_ = plt.plot(range(len(Bs_1)),Bs_2, 'o-', label='Bs, 2 slices')
#_ = plt.xticks(range(len(Bs_1)), labs, rotation='vertical')
plt.xscale('symlog')
plt.yscale('symlog')
plt.legend()
plt.title('Free param values, phi=0 vs phi=pi/2')
plt.xlabel('1 slice phi=0')
plt.ylabel('1 slice phi=pi/2')

# %%
_ = plt.plot(range(len(Bs_1)),[Bs_1[i]/Bs_2[i] for i in range(len(Bs_2))], 'o-', label='B(phi 0)/B(phi pi/2)')
#_ = plt.plot(range(len(Bs_1)),Bs_1b, 'o-', label='Bs, 1 slice phi=pi/2')
_ = plt.xticks(range(len(Bs_1)), labs, rotation='vertical')
plt.yscale('symlog')
plt.legend()
plt.title('Ratio of B values')

# %%
_ = plt.plot(range(len(As_1)),[As_1[i]/As_2[i] for i in range(len(As_2))], 'o-', label='A(phi 0)/A(phi pi/2)')
#_ = plt.plot(range(len(Bs_1)),Bs_1b, 'o-', label='Bs, 1 slice phi=pi/2')
_ = plt.xticks(range(len(As_1)), labs, rotation='vertical')
plt.yscale('symlog')
plt.legend()
plt.title('Ratio of A values')

# %%
n,m = np.meshgrid(range(21),range(21))
Anm1 = np.asarray([ff1.params[i] for i in ff1.params if 'A' in i]).reshape(20,20)
Bnm1 = np.asarray([ff1.params[i] for i in ff1.params if 'B' in i]).reshape(20,20)
Anm2 = np.asarray([ff2.params[i] for i in ff1.params if 'A' in i]).reshape(20,20)
Bnm2 = np.asarray([ff2.params[i] for i in ff1.params if 'B' in i]).reshape(20,20)
Anm_rat = np.nan_to_num(Anm1/Anm2)
Bnm_rat = np.nan_to_num(Bnm1/Bnm2)
AB_comb1 = Anm1**2+Bnm1**2
AB_comb2 = Anm2**2+Bnm2**2

# %%
import matplotlib.colors as colors
plt.pcolor(n,m, Anm1,
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=Anm.min(), vmax=Anm.max()))
plt.colorbar()
plt.title('Amn for Phi=0')
plt.xlabel('m')
plt.ylabel('n')
plt.figure()
plt.pcolor(n,m, Bnm1,
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=Bnm.min(), vmax=Bnm.max()))
plt.colorbar()
plt.title('Bmn for Phi=0')
plt.xlabel('m')
plt.ylabel('n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-4e4abc4bb7a9> in <module>()
#       1 import matplotlib.colors as colors
#       2 plt.pcolor(n,m, Anm1,
# ----> 3           norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=Anm.min(), vmax=Anm.max()))
#       4 plt.colorbar()
#       5 plt.title('Amn for Phi=0')
#
# NameError: name 'Anm' is not defined

# %%
import matplotlib.colors as colors
plt.pcolor(n,m, abs(Anm),
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=0, vmax=Anm.max()))
plt.colorbar()
plt.title('abs(Amn) for Phi=0')
plt.xlabel('m')
plt.ylabel('n')
plt.figure()
plt.pcolor(n,m, abs(Bnm),
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=0, vmax=Bnm.max()))
plt.colorbar()
plt.title('abs(Bmn) for Phi=0')
plt.xlabel('m')
plt.ylabel('n')

# %%
import matplotlib.colors as colors
plt.pcolor(n,m, abs(Anm_rat),
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=0, vmax=Anm_rat.max()))
plt.colorbar()
plt.title('abs(Amn (phi=0)/Amn (phi=pi/2))')
plt.xlabel('m')
plt.ylabel('n')
plt.figure()
plt.pcolor(n,m, abs(Bnm_rat),
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=0, vmax=Bnm_rat.max()))
plt.colorbar()
plt.title('abs(Bmn (phi=0)/Bmn (phi=pi/2))')
plt.xlabel('m')
plt.ylabel('n')

# %%
import matplotlib.colors as colors
plt.pcolor(n,m, AB_comb1,
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=AB_comb1.min(), vmax=AB_comb1.max()))
plt.colorbar()
plt.title('Anm^2+Bnm^2, phi=0')
plt.xlabel('m')
plt.ylabel('n')
plt.figure()

plt.pcolor(n,m, AB_comb2,
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=AB_comb2.min(), vmax=AB_comb2.max()))
plt.colorbar()
plt.title('Anm^2+Bnm^2, phi=pi/2')
plt.xlabel('m')
plt.ylabel('n')
