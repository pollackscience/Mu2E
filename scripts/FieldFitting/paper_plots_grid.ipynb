# %%
import os
from mu2e import mu2e_ext_path
from mu2e.dataframeprod import DataFrameMaker
from mu2e.mu2eplots import mu2e_plot, mu2e_plot3d
from matplotlib import gridspec
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12,8)
import pandas as pd
from time import sleep
import plotly.io as pio
from plotly.offline import init_notebook_mode
from skhep.visual import MplPlotter as splt
from copy import deepcopy
from lmfit import Model, Parameters, report_fit
from hallprobesim_redux import *
from tqdm import tnrange, tqdm_notebook
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Combo Fit

# %%
cfg_pickle_Opt = cfg_pickle(use_pickle=False, save_pickle=True,
                             load_name='solC_val', save_name='solC_grid_gz9', recreate=False)
cfg_params_Opt  = cfg_params(pitch1=0.1, ms_h1=2, ns_h1=3,
                                 pitch2=0, ms_h2=0, ns_h2=0,
                                 length1=9.2, ms_c1=5, ns_c1=3,
                                 length2=0, ms_c2=0, ns_c2=0,
                                 ks_dict={'k3':768},
                                 bs_tuples=((0.25, 0, -4.6),
                                            (0.25, 0, 4.6)),
                                 bs_bounds=(1e-3, 1e-3, 4),
                                 version=1000)
hmd, ff = field_map_analysis('fma_opt_test', cfg_data_Cole_250mm_short_cyl,
                                  cfg_geom_Cole_250mm_cyl_gz9, cfg_params_Opt,
                                  cfg_pickle_Opt, cfg_plot_none)
# Out:
# starting
# hpg
# init hpg
# interpolate?
# no
#                R     Phi       Z          Br       Bphi          Bz        X  \
# 0        0.25625  3.1416 -4.5750  -603.78530   16.05317   143.06790 -0.25625
# 1        0.25625  3.1416 -4.5625  -993.72460   24.71853    12.93478 -0.25625
# 2        0.25625  3.1416 -4.5500 -1868.80800  247.42810 -3563.03400 -0.25625
# 3        0.25625  3.1416 -4.5375   740.74890   30.11225   -55.30098 -0.25625
# 4        0.25625  3.1416 -4.5250   238.84690   17.44254   157.87970 -0.25625
# ...          ...     ...     ...         ...        ...         ...      ...
# 3846779  0.25625  0.0000  4.5250   570.49000   37.84981   158.31830  0.25625
# 3846780  0.25625  0.0000  4.5375   369.48470   36.16776   185.15020  0.25625
# 3846781  0.25625  0.0000  4.5500   245.62180   36.04599   186.65750  0.25625
# 3846782  0.25625  0.0000  4.5625   141.69000   36.43867   179.38050  0.25625
# 3846783  0.25625  0.0000  4.5750    19.79245   37.45928   160.36320  0.25625
#
#                 Y
# 0       -0.000002
# 1       -0.000002
# 2       -0.000002
# 3       -0.000002
# 4       -0.000002
# ...           ...
# 3846779  0.000000
# 3846780  0.000000
# 3846781  0.000000
# 3846782  0.000000
# 3846783  0.000000
#
# [3846784 rows x 8 columns]
# sorting sparse field
# hpg done
# [False, False, False]
# ff gen
# fitting with func_version=1000,
# cfg_params(pitch1=0.1, ms_h1=2, ns_h1=3, pitch2=0, ms_h2=0, ns_h2=0, length1=9.2, ms_c1=5, ns_c1=3, length2=0, ms_c2=0, ns_c2=0, ks_dict={'k3': 768}, bs_tuples=((0.25, 0, -4.6), (0.25, 0, 4.6)), bs_bounds=(0.001, 0.001, 4), version=1000)
# `xtol` termination condition is satisfied.
# Function evaluations 15, initial cost 3.1951e+06, final cost 9.4918e-04, first-order optimality 1.53e+06.
# Elapsed time was 13.0229 seconds
# [[Fit Statistics]]
#     # fitting method   = least_squares
#     # function evals   = 15
#     # data points      = 2016
#     # variables        = 58
#     chi-square         = 0.00189837
#     reduced chi-square = 9.6955e-07
#     Akaike info crit   = -27857.2711
#     Bayesian info crit = -27531.9566
# [[Variables]]
#     pitch1:   0.1 (fixed)
#     ms_h1:    2 (fixed)
#     ns_h1:    3 (fixed)
#     pitch2:   0 (fixed)
#     ms_h2:    0 (fixed)
#     ns_h2:    0 (fixed)
#     length1:  9.2 (fixed)
#     ms_c1:    5 (fixed)
#     ns_c1:    3 (fixed)
#     length2:  0 (fixed)
#     ms_c2:    0 (fixed)
#     ns_c2:    0 (fixed)
#     Ah1_0_0:  0 (fixed)
#     Bh1_0_0:  0 (fixed)
#     Ch1_0_0: -2.7961e-10 (init = 8.680988e-09)
#     Dh1_0_0: -3.9365e-10 (init = -4.432612e-08)
#     Ah1_0_1:  0 (fixed)
#     Bh1_0_1:  0 (fixed)
#     Ch1_0_1: -1.2204e-06 (init = -1.509648e-08)
#     Dh1_0_1: -1.6515e-05 (init = 6.895523e-08)
#     Ah1_0_2:  0 (fixed)
#     Bh1_0_2:  0 (fixed)
#     Ch1_0_2: -1.2870e-10 (init = -9.905623e-08)
#     Dh1_0_2: -1.7940e-10 (init = -7.568618e-08)
#     Ah1_1_0:  0 (fixed)
#     Bh1_1_0:  0 (fixed)
#     Ch1_1_0: -7.8676e-15 (init = 3.414982e-08)
#     Dh1_1_0: -8.0663e-14 (init = 6.517055e-08)
#     Ah1_1_1:  0 (fixed)
#     Bh1_1_1:  0 (fixed)
#     Ch1_1_1:  1.7267e-13 (init = -7.265868e-08)
#     Dh1_1_1: -1.4978e-13 (init = 1.501867e-08)
#     Ah1_1_2:  0 (fixed)
#     Bh1_1_2:  0 (fixed)
#     Ch1_1_2: -3.0703e-13 (init = 7.826439e-08)
#     Dh1_1_2: -1.5432e-12 (init = -5.815958e-08)
#     Ac1_0_0: -8444.58068 (init = 8.680988e-09)
#     Bc1_0_0:  2931.32408 (init = -4.432612e-08)
#     Dc1_0:    0.99986088 (init = 1)
#     Ac1_0_1:  1.22797924 (init = -1.509648e-08)
#     Bc1_0_1: -22.1521636 (init = 6.895523e-08)
#     Dc1_1:    0.77732386 (init = 0.5)
#     Ac1_0_2: -2172.95354 (init = -9.905623e-08)
#     Bc1_0_2:  472.618496 (init = -7.568618e-08)
#     Dc1_2:    0.36841990 (init = 0)
#     Ac1_1_0:  4442.50782 (init = 3.414982e-08)
#     Bc1_1_0:  14485.0124 (init = 6.517055e-08)
#     Ac1_1_1:  0.91377132 (init = -7.265868e-08)
#     Bc1_1_1:  17.1814044 (init = 1.501867e-08)
#     Ac1_1_2:  1261.85733 (init = 7.826439e-08)
#     Bc1_1_2: -265.358342 (init = -5.815958e-08)
#     Ac1_2_0: -1475.13898 (init = -6.293436e-08)
#     Bc1_2_0:  10381.5751 (init = -7.832462e-08)
#     Ac1_2_1: -1.63854470 (init = -5.60605e-08)
#     Bc1_2_1: -9.46343958 (init = 9.572476e-08)
#     Ac1_2_2: -486.070477 (init = 6.233663e-08)
#     Bc1_2_2:  123.751790 (init = -6.56118e-08)
#     Ac1_3_0:  299.938809 (init = 6.324495e-08)
#     Bc1_3_0: -8867.74298 (init = -4.518525e-08)
#     Ac1_3_1:  0.85027438 (init = -1.365916e-08)
#     Bc1_3_1:  3.12352261 (init = 8.800596e-08)
#     Ac1_3_2:  112.172574 (init = 6.352988e-08)
#     Bc1_3_2: -35.1836606 (init = -3.277761e-08)
#     Ac1_4_0: -33.2030050 (init = -6.491791e-08)
#     Bc1_4_0:  1820.61677 (init = -2.543359e-08)
#     Ac1_4_1: -0.16140603 (init = -9.88623e-08)
#     Bc1_4_1: -0.45810285 (init = -4.951473e-08)
#     Ac1_4_2: -11.7816935 (init = 5.91325e-08)
#     Bc1_4_2:  4.48718931 (init = -9.694901e-08)
#     k1:       0 (fixed)
#     k2:       0 (fixed)
#     k3:       765.409849 (init = 768)
#     k4:       0 (fixed)
#     k5:       0 (fixed)
#     k6:       0 (fixed)
#     k7:       0 (fixed)
#     k8:       0 (fixed)
#     k9:       0 (fixed)
#     k10:      0 (fixed)
#     x1:       0.25099999 (init = 0.25)
#     y1:       9.9378e-04 (init = 0)
#     z1:      -4.59954418 (init = -4.6)
#     vx1:      0.08785056 (init = 0)
#     vy1:     -0.08909098 (init = 0)
#     vz1:     -3.06326711 (init = 0)
#     x2:       0.25099951 (init = 0.25)
#     y2:       6.3274e-04 (init = 0)
#     z2:       4.59977601 (init = 4.6)
#     vx2:     -0.02185191 (init = 0)
#     vy2:      0.04806421 (init = 0)
#     vz2:     -3.06315829 (init = 0)
# ff fit
# ff merge
# done

# %%
phi=0
fig = mu2e_plot3d(ff.input_data, 'R', 'Z', 'Bz', f'R<=0.15 and Phi=={phi} and -2<Z<2',
            title_simp = r'$B_{z}$, Fit to Solenoid C', df_fit=True, mode='mpl', ptype='3d', units='m', aspect='rect2', do2pi=True)
#plt.savefig('/Users/brianpollack/Documents/Notes_Papers/Helix/figs/bz_C_fit.png', bbox_inches='tight')

# %%
phi=0
fig = mu2e_plot3d(ff.input_data, 'R', 'Z', 'Br', f'R<=0.15 and Phi=={phi} and -2<Z<2',
            title_simp = r'$B_{r}$, Fit to Solenoid C', df_fit=True, mode='mpl', ptype='3d', units='m', aspect='rect2', do2pi=True)
#plt.savefig('/Users/brianpollack/Documents/Notes_Papers/Helix/figs/br_C_fit.png', bbox_inches='tight')

# %%
phi=0
fig = mu2e_plot3d(ff.input_data, 'R', 'Z', 'Bphi', f'R<=0.15 and Phi=={phi} and -2<Z<2',
            title_simp = r'$B_{\theta}$, Fit to Solenoid C', df_fit=True, mode='mpl', ptype='3d', units='m', aspect='rect2', do2pi=True)
#plt.savefig('/Users/brianpollack/Documents/Notes_Papers/Helix/figs/bt_C_fit.png', bbox_inches='tight')

# %% [markdown]
# # Validation

# %%
grid_list = ['gz9', 'gz3', 'g8', 'nom']
df_dict = {}
for i, grid in enumerate(grid_list):
    if grid == 'nom':
        cfg_pickle_fs = cfg_pickle(use_pickle=False, save_pickle=False,
                                     load_name=f'solC_val', save_name=f'solC_grid_val_{grid}', recreate=True)
        _, ff_fullsim = field_map_analysis(f'fma_fit_solC_syst_{grid}', cfg_data_Cole_250mm_short_cyl,
                                          cfg_geom_Cole_250mm_cyl_hg, cfg_params_Opt,
                                          cfg_pickle_fs, cfg_plot_none)
    else:
        cfg_geom_hg = cfg_geom_Cole_250mm_cyl_hg
        if i == 0:
            cfg_geom_hg._replace(z_steps=z_steps_cole_hg_gz9)
        elif i == 1:
            cfg_geom_hg._replace(z_steps=z_steps_cole_hg_gz3)
        elif i == 2:
            cfg_geom_hg._replace(z_steps=z_steps_cole_hg_g8)
        cfg_pickle_fs = cfg_pickle(use_pickle=False, save_pickle=False,
                                     load_name=f'solC_grid_{grid}', save_name=f'solC_grid_val_{grid}', recreate=True)
        _, ff_fullsim = field_map_analysis(f'fma_fit_solC_syst_{grid}', cfg_data_Cole_250mm_short_cyl,
                                          cfg_geom_hg, cfg_params_Opt,
                                          cfg_pickle_fs, cfg_plot_none)
    df_dict[grid] = ff_fullsim.input_data
    df_dict[grid].eval('Bmag = (Bz**2+Br**2+Bphi**2)**(1/2)', inplace=True)
    df_dict[grid].eval('Bmag_fit = (Bz_fit**2+Br_fit**2+Bphi_fit**2)**(1/2)', inplace=True)
# Out:
# starting
# hpg
# init hpg
# interpolate?
# no
#                R     Phi       Z          Br       Bphi          Bz        X  \
# 0        0.25625  3.1416 -4.5750  -603.78530   16.05317   143.06790 -0.25625
# 1        0.25625  3.1416 -4.5625  -993.72460   24.71853    12.93478 -0.25625
# 2        0.25625  3.1416 -4.5500 -1868.80800  247.42810 -3563.03400 -0.25625
# 3        0.25625  3.1416 -4.5375   740.74890   30.11225   -55.30098 -0.25625
# 4        0.25625  3.1416 -4.5250   238.84690   17.44254   157.87970 -0.25625
# ...          ...     ...     ...         ...        ...         ...      ...
# 3846779  0.25625  0.0000  4.5250   570.49000   37.84981   158.31830  0.25625
# 3846780  0.25625  0.0000  4.5375   369.48470   36.16776   185.15020  0.25625
# 3846781  0.25625  0.0000  4.5500   245.62180   36.04599   186.65750  0.25625
# 3846782  0.25625  0.0000  4.5625   141.69000   36.43867   179.38050  0.25625
# 3846783  0.25625  0.0000  4.5750    19.79245   37.45928   160.36320  0.25625
#
#                 Y
# 0       -0.000002
# 1       -0.000002
# 2       -0.000002
# 3       -0.000002
# 4       -0.000002
# ...           ...
# 3846779  0.000000
# 3846780  0.000000
# 3846781  0.000000
# 3846782  0.000000
# 3846783  0.000000
#
# [3846784 rows x 8 columns]
# sorting sparse field
# hpg done
# [False, False, False]
# ff gen
# recreating fit with func_version=1000,
# cfg_params(pitch1=0.1, ms_h1=2, ns_h1=3, pitch2=0, ms_h2=0, ns_h2=0, length1=9.2, ms_c1=5, ns_c1=3, length2=0, ms_c2=0, ns_c2=0, ks_dict={'k3': 768}, bs_tuples=((0.25, 0, -4.6), (0.25, 0, 4.6)), bs_bounds=(0.001, 0.001, 4), version=1000)
# Elapsed time was 12.9705 seconds
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 0
#     # data points      = 1088640
#     # variables        = 0
#     chi-square         = 1.17037461
#     reduced chi-square = 1.0751e-06
#     Akaike info crit   = -14961305.7
#     Bayesian info crit = -14961305.7
# [[Variables]]
#     pitch1:   0.1 (fixed)
#     ms_h1:    2 (fixed)
#     ns_h1:    3 (fixed)
#     pitch2:   0 (fixed)
#     ms_h2:    0 (fixed)
#     ns_h2:    0 (fixed)
#     length1:  9.2 (fixed)
#     ms_c1:    5 (fixed)
#     ns_c1:    3 (fixed)
#     length2:  0 (fixed)
#     ms_c2:    0 (fixed)
#     ns_c2:    0 (fixed)
#     Ah1_0_0:  0 (fixed)
#     Bh1_0_0:  0 (fixed)
#     Ch1_0_0: -2.796071e-10 (fixed)
#     Dh1_0_0: -3.936502e-10 (fixed)
#     Ah1_0_1:  0 (fixed)
#     Bh1_0_1:  0 (fixed)
#     Ch1_0_1: -1.220372e-06 (fixed)
#     Dh1_0_1: -1.651458e-05 (fixed)
#     Ah1_0_2:  0 (fixed)
#     Bh1_0_2:  0 (fixed)
#     Ch1_0_2: -1.287047e-10 (fixed)
#     Dh1_0_2: -1.793965e-10 (fixed)
#     Ah1_1_0:  0 (fixed)
#     Bh1_1_0:  0 (fixed)
#     Ch1_1_0: -7.86756e-15 (fixed)
#     Dh1_1_0: -8.066306e-14 (fixed)
#     Ah1_1_1:  0 (fixed)
#     Bh1_1_1:  0 (fixed)
#     Ch1_1_1:  1.726655e-13 (fixed)
#     Dh1_1_1: -1.497833e-13 (fixed)
#     Ah1_1_2:  0 (fixed)
#     Bh1_1_2:  0 (fixed)
#     Ch1_1_2: -3.070263e-13 (fixed)
#     Dh1_1_2: -1.543187e-12 (fixed)
#     Ac1_0_0: -8444.581 (fixed)
#     Bc1_0_0:  2931.324 (fixed)
#     Dc1_0:    0.9998609 (fixed)
#     Ac1_0_1:  1.227979 (fixed)
#     Bc1_0_1: -22.15216 (fixed)
#     Dc1_1:    0.7773239 (fixed)
#     Ac1_0_2: -2172.954 (fixed)
#     Bc1_0_2:  472.6185 (fixed)
#     Dc1_2:    0.3684199 (fixed)
#     Ac1_1_0:  4442.508 (fixed)
#     Bc1_1_0:  14485.01 (fixed)
#     Ac1_1_1:  0.9137713 (fixed)
#     Bc1_1_1:  17.1814 (fixed)
#     Ac1_1_2:  1261.857 (fixed)
#     Bc1_1_2: -265.3583 (fixed)
#     Ac1_2_0: -1475.139 (fixed)
#     Bc1_2_0:  10381.58 (fixed)
#     Ac1_2_1: -1.638545 (fixed)
#     Bc1_2_1: -9.46344 (fixed)
#     Ac1_2_2: -486.0705 (fixed)
#     Bc1_2_2:  123.7518 (fixed)
#     Ac1_3_0:  299.9388 (fixed)
#     Bc1_3_0: -8867.743 (fixed)
#     Ac1_3_1:  0.8502744 (fixed)
#     Bc1_3_1:  3.123523 (fixed)
#     Ac1_3_2:  112.1726 (fixed)
#     Bc1_3_2: -35.18366 (fixed)
#     Ac1_4_0: -33.203 (fixed)
#     Bc1_4_0:  1820.617 (fixed)
#     Ac1_4_1: -0.161406 (fixed)
#     Bc1_4_1: -0.4581028 (fixed)
#     Ac1_4_2: -11.78169 (fixed)
#     Bc1_4_2:  4.487189 (fixed)
#     k1:       0 (fixed)
#     k2:       0 (fixed)
#     k3:       765.4098 (fixed)
#     k4:       0 (fixed)
#     k5:       0 (fixed)
#     k6:       0 (fixed)
#     k7:       0 (fixed)
#     k8:       0 (fixed)
#     k9:       0 (fixed)
#     k10:      0 (fixed)
#     x1:       0.251 (fixed)
#     y1:       0.0009937772 (fixed)
#     z1:      -4.599544 (fixed)
#     vx1:      0.08785056 (fixed)
#     vy1:     -0.08909098 (fixed)
#     vz1:     -3.063267 (fixed)
#     x2:       0.2509995 (fixed)
#     y2:       0.0006327411 (fixed)
#     z2:       4.599776 (fixed)
#     vx2:     -0.02185191 (fixed)
#     vy2:      0.04806421 (fixed)
#     vz2:     -3.063158 (fixed)
# ff fit
# ff merge
# done
# starting
# hpg
# init hpg
# interpolate?
# no
#                R     Phi       Z          Br       Bphi          Bz        X  \
# 0        0.25625  3.1416 -4.5750  -603.78530   16.05317   143.06790 -0.25625
# 1        0.25625  3.1416 -4.5625  -993.72460   24.71853    12.93478 -0.25625
# 2        0.25625  3.1416 -4.5500 -1868.80800  247.42810 -3563.03400 -0.25625
# 3        0.25625  3.1416 -4.5375   740.74890   30.11225   -55.30098 -0.25625
# 4        0.25625  3.1416 -4.5250   238.84690   17.44254   157.87970 -0.25625
# ...          ...     ...     ...         ...        ...         ...      ...
# 3846779  0.25625  0.0000  4.5250   570.49000   37.84981   158.31830  0.25625
# 3846780  0.25625  0.0000  4.5375   369.48470   36.16776   185.15020  0.25625
# 3846781  0.25625  0.0000  4.5500   245.62180   36.04599   186.65750  0.25625
# 3846782  0.25625  0.0000  4.5625   141.69000   36.43867   179.38050  0.25625
# 3846783  0.25625  0.0000  4.5750    19.79245   37.45928   160.36320  0.25625
#
#                 Y
# 0       -0.000002
# 1       -0.000002
# 2       -0.000002
# 3       -0.000002
# 4       -0.000002
# ...           ...
# 3846779  0.000000
# 3846780  0.000000
# 3846781  0.000000
# 3846782  0.000000
# 3846783  0.000000
#
# [3846784 rows x 8 columns]
# sorting sparse field
# hpg done
# [False, False, False]
# ff gen
# recreating fit with func_version=1000,
# cfg_params(pitch1=0.1, ms_h1=2, ns_h1=3, pitch2=0, ms_h2=0, ns_h2=0, length1=9.2, ms_c1=5, ns_c1=3, length2=0, ms_c2=0, ns_c2=0, ks_dict={'k3': 768}, bs_tuples=((0.25, 0, -4.6), (0.25, 0, 4.6)), bs_bounds=(0.001, 0.001, 4), version=1000)
# Elapsed time was 12.7896 seconds
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 0
#     # data points      = 1088640
#     # variables        = 0
#     chi-square         = 0.00272776
#     reduced chi-square = 2.5057e-09
#     Akaike info crit   = -21560203.0
#     Bayesian info crit = -21560203.0
# [[Variables]]
#     pitch1:   0.1 (fixed)
#     ms_h1:    2 (fixed)
#     ns_h1:    3 (fixed)
#     pitch2:   0 (fixed)
#     ms_h2:    0 (fixed)
#     ns_h2:    0 (fixed)
#     length1:  9.2 (fixed)
#     ms_c1:    5 (fixed)
#     ns_c1:    3 (fixed)
#     length2:  0 (fixed)
#     ms_c2:    0 (fixed)
#     ns_c2:    0 (fixed)
#     Ah1_0_0:  0 (fixed)
#     Bh1_0_0:  0 (fixed)
#     Ch1_0_0: -1.184568e-10 (fixed)
#     Dh1_0_0:  3.34155e-11 (fixed)
#     Ah1_0_1:  0 (fixed)
#     Bh1_0_1:  0 (fixed)
#     Ch1_0_1: -1.216242e-06 (fixed)
#     Dh1_0_1: -1.65154e-05 (fixed)
#     Ah1_0_2:  0 (fixed)
#     Bh1_0_2:  0 (fixed)
#     Ch1_0_2:  2.484878e-11 (fixed)
#     Dh1_0_2: -8.191294e-11 (fixed)
#     Ah1_1_0:  0 (fixed)
#     Bh1_1_0:  0 (fixed)
#     Ch1_1_0: -6.19748e-16 (fixed)
#     Dh1_1_0: -6.512525e-15 (fixed)
#     Ah1_1_1:  0 (fixed)
#     Bh1_1_1:  0 (fixed)
#     Ch1_1_1:  1.20534e-15 (fixed)
#     Dh1_1_1: -8.353178e-15 (fixed)
#     Ah1_1_2:  0 (fixed)
#     Bh1_1_2:  0 (fixed)
#     Ch1_1_2: -2.263888e-13 (fixed)
#     Dh1_1_2: -1.529172e-12 (fixed)
#     Ac1_0_0: -91.16098 (fixed)
#     Bc1_0_0:  27.00587 (fixed)
#     Dc1_0:    0.9907719 (fixed)
#     Ac1_0_1: -12.85941 (fixed)
#     Bc1_0_1: -184.0339 (fixed)
#     Dc1_1:    0.9999995 (fixed)
#     Ac1_0_2:  473.8834 (fixed)
#     Bc1_0_2: -38.25547 (fixed)
#     Dc1_2:    0.9937641 (fixed)
#     Ac1_1_0: -25.60509 (fixed)
#     Bc1_1_0:  356.1324 (fixed)
#     Ac1_1_1:  17.24076 (fixed)
#     Bc1_1_1:  106.7781 (fixed)
#     Ac1_1_2: -278.3829 (fixed)
#     Bc1_1_2: -1.697195 (fixed)
#     Ac1_2_0:  61.00819 (fixed)
#     Bc1_2_0:  59.0787 (fixed)
#     Ac1_2_1: -10.78114 (fixed)
#     Bc1_2_1: -41.10494 (fixed)
#     Ac1_2_2:  109.3905 (fixed)
#     Bc1_2_2:  6.123824 (fixed)
#     Ac1_3_0: -31.06578 (fixed)
#     Bc1_3_0: -99.68056 (fixed)
#     Ac1_3_1:  3.524723 (fixed)
#     Bc1_3_1:  9.479331 (fixed)
#     Ac1_3_2: -25.97694 (fixed)
#     Bc1_3_2: -2.519411 (fixed)
#     Ac1_4_0:  5.650657 (fixed)
#     Bc1_4_0:  22.39081 (fixed)
#     Ac1_4_1: -0.488141 (fixed)
#     Bc1_4_1: -0.9944343 (fixed)
#     Ac1_4_2:  2.832786 (fixed)
#     Bc1_4_2:  0.3821377 (fixed)
#     k1:       0 (fixed)
#     k2:       0 (fixed)
#     k3:       765.1675 (fixed)
#     k4:       0 (fixed)
#     k5:       0 (fixed)
#     k6:       0 (fixed)
#     k7:       0 (fixed)
#     k8:       0 (fixed)
#     k9:       0 (fixed)
#     k10:      0 (fixed)
#     x1:       0.2509988 (fixed)
#     y1:       0.001 (fixed)
#     z1:      -4.599078 (fixed)
#     vx1:      0.2354823 (fixed)
#     vy1:     -0.002793356 (fixed)
#     vz1:     -3.049328 (fixed)
#     x2:       0.2508783 (fixed)
#     y2:      -0.000425242 (fixed)
#     z2:       4.599143 (fixed)
#     vx2:     -0.1649417 (fixed)
#     vy2:     -0.003182685 (fixed)
#     vz2:     -3.050442 (fixed)
# ff fit
# ff merge
# done
# starting
# hpg
# init hpg
# interpolate?
# no
#                R     Phi       Z          Br       Bphi          Bz        X  \
# 0        0.25625  3.1416 -4.5750  -603.78530   16.05317   143.06790 -0.25625
# 1        0.25625  3.1416 -4.5625  -993.72460   24.71853    12.93478 -0.25625
# 2        0.25625  3.1416 -4.5500 -1868.80800  247.42810 -3563.03400 -0.25625
# 3        0.25625  3.1416 -4.5375   740.74890   30.11225   -55.30098 -0.25625
# 4        0.25625  3.1416 -4.5250   238.84690   17.44254   157.87970 -0.25625
# ...          ...     ...     ...         ...        ...         ...      ...
# 3846779  0.25625  0.0000  4.5250   570.49000   37.84981   158.31830  0.25625
# 3846780  0.25625  0.0000  4.5375   369.48470   36.16776   185.15020  0.25625
# 3846781  0.25625  0.0000  4.5500   245.62180   36.04599   186.65750  0.25625
# 3846782  0.25625  0.0000  4.5625   141.69000   36.43867   179.38050  0.25625
# 3846783  0.25625  0.0000  4.5750    19.79245   37.45928   160.36320  0.25625
#
#                 Y
# 0       -0.000002
# 1       -0.000002
# 2       -0.000002
# 3       -0.000002
# 4       -0.000002
# ...           ...
# 3846779  0.000000
# 3846780  0.000000
# 3846781  0.000000
# 3846782  0.000000
# 3846783  0.000000
#
# [3846784 rows x 8 columns]
# sorting sparse field
# hpg done
# [False, False, False]
# ff gen
# recreating fit with func_version=1000,
# cfg_params(pitch1=0.1, ms_h1=2, ns_h1=3, pitch2=0, ms_h2=0, ns_h2=0, length1=9.2, ms_c1=5, ns_c1=3, length2=0, ms_c2=0, ns_c2=0, ks_dict={'k3': 768}, bs_tuples=((0.25, 0, -4.6), (0.25, 0, 4.6)), bs_bounds=(0.001, 0.001, 4), version=1000)
# Elapsed time was 12.6209 seconds
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 0
#     # data points      = 1088640
#     # variables        = 0
#     chi-square         = 0.09551818
#     reduced chi-square = 8.7741e-08
#     Akaike info crit   = -17689179.0
#     Bayesian info crit = -17689179.0
# [[Variables]]
#     pitch1:   0.1 (fixed)
#     ms_h1:    2 (fixed)
#     ns_h1:    3 (fixed)
#     pitch2:   0 (fixed)
#     ms_h2:    0 (fixed)
#     ns_h2:    0 (fixed)
#     length1:  9.2 (fixed)
#     ms_c1:    5 (fixed)
#     ns_c1:    3 (fixed)
#     length2:  0 (fixed)
#     ms_c2:    0 (fixed)
#     ns_c2:    0 (fixed)
#     Ah1_0_0:  0 (fixed)
#     Bh1_0_0:  0 (fixed)
#     Ch1_0_0: -4.703197e-10 (fixed)
#     Dh1_0_0: -1.176746e-09 (fixed)
#     Ah1_0_1:  0 (fixed)
#     Bh1_0_1:  0 (fixed)
#     Ch1_0_1: -1.216006e-06 (fixed)
#     Dh1_0_1: -1.650075e-05 (fixed)
#     Ah1_0_2:  0 (fixed)
#     Bh1_0_2:  0 (fixed)
#     Ch1_0_2:  4.081138e-10 (fixed)
#     Dh1_0_2:  2.972031e-11 (fixed)
#     Ah1_1_0:  0 (fixed)
#     Bh1_1_0:  0 (fixed)
#     Ch1_1_0:  2.482076e-14 (fixed)
#     Dh1_1_0:  6.368142e-14 (fixed)
#     Ah1_1_1:  0 (fixed)
#     Bh1_1_1:  0 (fixed)
#     Ch1_1_1: -9.113185e-15 (fixed)
#     Dh1_1_1: -8.011181e-13 (fixed)
#     Ah1_1_2:  0 (fixed)
#     Bh1_1_2:  0 (fixed)
#     Ch1_1_2: -2.474937e-13 (fixed)
#     Dh1_1_2: -1.533174e-12 (fixed)
#     Ac1_0_0: -97.37728 (fixed)
#     Bc1_0_0:  122.6655 (fixed)
#     Dc1_0:    0.9941023 (fixed)
#     Ac1_0_1:  0.5827932 (fixed)
#     Bc1_0_1:  46.08784 (fixed)
#     Dc1_1:    0.9995581 (fixed)
#     Ac1_0_2:  189.5956 (fixed)
#     Bc1_0_2:  134.1278 (fixed)
#     Dc1_2:    0.8883196 (fixed)
#     Ac1_1_0:  1.566762 (fixed)
#     Bc1_1_0:  506.6779 (fixed)
#     Ac1_1_1: -0.05882989 (fixed)
#     Bc1_1_1: -27.16041 (fixed)
#     Ac1_1_2: -110.8482 (fixed)
#     Bc1_1_2: -32.70731 (fixed)
#     Ac1_2_0:  34.69686 (fixed)
#     Bc1_2_0:  121.4673 (fixed)
#     Ac1_2_1: -0.2912606 (fixed)
#     Bc1_2_1:  10.68143 (fixed)
#     Ac1_2_2:  43.19101 (fixed)
#     Bc1_2_2:  5.641703 (fixed)
#     Ac1_3_0: -19.56504 (fixed)
#     Bc1_3_0: -166.5869 (fixed)
#     Ac1_3_1:  0.1657 (fixed)
#     Bc1_3_1: -2.532916 (fixed)
#     Ac1_3_2: -10.13152 (fixed)
#     Bc1_3_2: -0.2753261 (fixed)
#     Ac1_4_0:  3.653529 (fixed)
#     Bc1_4_0:  36.7998 (fixed)
#     Ac1_4_1: -0.02894355 (fixed)
#     Bc1_4_1:  0.275106 (fixed)
#     Ac1_4_2:  1.087 (fixed)
#     Bc1_4_2: -0.05766088 (fixed)
#     k1:       0 (fixed)
#     k2:       0 (fixed)
#     k3:       765.1017 (fixed)
#     k4:       0 (fixed)
#     k5:       0 (fixed)
#     k6:       0 (fixed)
#     k7:       0 (fixed)
#     k8:       0 (fixed)
#     k9:       0 (fixed)
#     k10:      0 (fixed)
#     x1:       0.251 (fixed)
#     y1:      -0.0004122441 (fixed)
#     z1:      -4.599044 (fixed)
#     vx1:     -0.081512 (fixed)
#     vy1:     -0.004876252 (fixed)
#     vz1:     -3.069417 (fixed)
#     x2:       0.250884 (fixed)
#     y2:       0.0009996917 (fixed)
#     z2:       4.599 (fixed)
#     vx2:      0.1677426 (fixed)
#     vy2:     -0.005222961 (fixed)
#     vz2:     -3.070317 (fixed)
# ff fit
# ff merge
# done
# starting
# hpg
# init hpg
# interpolate?
# no
#                R     Phi       Z          Br       Bphi          Bz        X  \
# 0        0.25625  3.1416 -4.5750  -603.78530   16.05317   143.06790 -0.25625
# 1        0.25625  3.1416 -4.5625  -993.72460   24.71853    12.93478 -0.25625
# 2        0.25625  3.1416 -4.5500 -1868.80800  247.42810 -3563.03400 -0.25625
# 3        0.25625  3.1416 -4.5375   740.74890   30.11225   -55.30098 -0.25625
# 4        0.25625  3.1416 -4.5250   238.84690   17.44254   157.87970 -0.25625
# ...          ...     ...     ...         ...        ...         ...      ...
# 3846779  0.25625  0.0000  4.5250   570.49000   37.84981   158.31830  0.25625
# 3846780  0.25625  0.0000  4.5375   369.48470   36.16776   185.15020  0.25625
# 3846781  0.25625  0.0000  4.5500   245.62180   36.04599   186.65750  0.25625
# 3846782  0.25625  0.0000  4.5625   141.69000   36.43867   179.38050  0.25625
# 3846783  0.25625  0.0000  4.5750    19.79245   37.45928   160.36320  0.25625
#
#                 Y
# 0       -0.000002
# 1       -0.000002
# 2       -0.000002
# 3       -0.000002
# 4       -0.000002
# ...           ...
# 3846779  0.000000
# 3846780  0.000000
# 3846781  0.000000
# 3846782  0.000000
# 3846783  0.000000
#
# [3846784 rows x 8 columns]
# sorting sparse field
# hpg done
# [False, False, False]
# ff gen
# recreating fit with func_version=1000,
# cfg_params(pitch1=0.1, ms_h1=2, ns_h1=3, pitch2=0, ms_h2=0, ns_h2=0, length1=9.2, ms_c1=5, ns_c1=3, length2=0, ms_c2=0, ns_c2=0, ks_dict={'k3': 768}, bs_tuples=((0.25, 0, -4.6), (0.25, 0, 4.6)), bs_bounds=(0.001, 0.001, 4), version=1000)
# Elapsed time was 19.9945 seconds
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 0
#     # data points      = 1088640
#     # variables        = 0
#     chi-square         = 5.9614e-04
#     reduced chi-square = 5.4760e-10
#     Akaike info crit   = -23215762.3
#     Bayesian info crit = -23215762.3
# [[Variables]]
#     pitch1:   0.1 (fixed)
#     ms_h1:    2 (fixed)
#     ns_h1:    3 (fixed)
#     pitch2:   0 (fixed)
#     ms_h2:    0 (fixed)
#     ns_h2:    0 (fixed)
#     length1:  9.2 (fixed)
#     ms_c1:    5 (fixed)
#     ns_c1:    3 (fixed)
#     length2:  0 (fixed)
#     ms_c2:    0 (fixed)
#     ns_c2:    0 (fixed)
#     Ah1_0_0:  0 (fixed)
#     Bh1_0_0:  0 (fixed)
#     Ch1_0_0: -5.583648e-12 (fixed)
#     Dh1_0_0:  3.523915e-15 (fixed)
#     Ah1_0_1:  0 (fixed)
#     Bh1_0_1:  0 (fixed)
#     Ch1_0_1: -1.216194e-06 (fixed)
#     Dh1_0_1: -1.651543e-05 (fixed)
#     Ah1_0_2:  0 (fixed)
#     Bh1_0_2:  0 (fixed)
#     Ch1_0_2: -1.330184e-11 (fixed)
#     Dh1_0_2: -4.760284e-11 (fixed)
#     Ah1_1_0:  0 (fixed)
#     Bh1_1_0:  0 (fixed)
#     Ch1_1_0:  4.663003e-17 (fixed)
#     Dh1_1_0:  4.483861e-16 (fixed)
#     Ah1_1_1:  0 (fixed)
#     Bh1_1_1:  0 (fixed)
#     Ch1_1_1:  5.200118e-17 (fixed)
#     Dh1_1_1: -7.257074e-15 (fixed)
#     Ah1_1_2:  0 (fixed)
#     Bh1_1_2:  0 (fixed)
#     Ch1_1_2: -2.271185e-13 (fixed)
#     Dh1_1_2: -1.53004e-12 (fixed)
#     Ac1_0_0: -1.360389 (fixed)
#     Bc1_0_0: -7.332599 (fixed)
#     Dc1_0:    0.7697827 (fixed)
#     Ac1_0_1:  4.551593 (fixed)
#     Bc1_0_1:  6.904601 (fixed)
#     Dc1_1:    0.9999826 (fixed)
#     Ac1_0_2: -11.82854 (fixed)
#     Bc1_0_2: -152.0879 (fixed)
#     Dc1_2:    0.9986379 (fixed)
#     Ac1_1_0:  0.728443 (fixed)
#     Bc1_1_0:  90.95857 (fixed)
#     Ac1_1_1: -3.129079 (fixed)
#     Bc1_1_1: -4.068687 (fixed)
#     Ac1_1_2:  7.140333 (fixed)
#     Bc1_1_2:  44.48049 (fixed)
#     Ac1_2_0: -0.2555801 (fixed)
#     Bc1_2_0: -49.82785 (fixed)
#     Ac1_2_1:  1.143224 (fixed)
#     Bc1_2_1:  1.603681 (fixed)
#     Ac1_2_2: -2.886547 (fixed)
#     Bc1_2_2: -11.56449 (fixed)
#     Ac1_3_0:  0.05418532 (fixed)
#     Bc1_3_0:  13.19086 (fixed)
#     Ac1_3_1: -0.2137486 (fixed)
#     Bc1_3_1: -0.3819044 (fixed)
#     Ac1_3_2:  0.7038993 (fixed)
#     Bc1_3_2:  2.037174 (fixed)
#     Ac1_4_0: -0.005374707 (fixed)
#     Bc1_4_0: -1.469084 (fixed)
#     Ac1_4_1:  0.01484241 (fixed)
#     Bc1_4_1:  0.04174665 (fixed)
#     Ac1_4_2: -0.07861885 (fixed)
#     Bc1_4_2: -0.1751627 (fixed)
#     k1:       0 (fixed)
#     k2:       0 (fixed)
#     k3:       761.6081 (fixed)
#     k4:       0 (fixed)
#     k5:       0 (fixed)
#     k6:       0 (fixed)
#     k7:       0 (fixed)
#     k8:       0 (fixed)
#     k9:       0 (fixed)
#     k10:      0 (fixed)
#     x1:       0.2509999 (fixed)
#     y1:       0.0008918325 (fixed)
#     z1:      -4.599004 (fixed)
#     vx1:      0.2045156 (fixed)
#     vy1:     -0.002833357 (fixed)
#     vz1:     -3.052018 (fixed)
#     x2:       0.251 (fixed)
#     y2:      -0.0006693265 (fixed)
#     z2:       4.599005 (fixed)
#     vx2:     -0.2001746 (fixed)
#     vy2:     -0.002968382 (fixed)
#     vz2:     -3.047234 (fixed)
# ff fit
# ff merge
# done

# %%
mag_means = []
mag_std = []
grid_list = ['gz9', 'g8', 'gz3', 'nom']
alphas = [0.2, 0.5, 1, 1]
labels = [r'1/9 Density',
          r'1/8 Density',
          r'1/3 Density',
          r'Nominal']
cs = ['C0', 'C1', 'C2', 'k']
          
          
fig, axs = plt.subplots(2, 2, figsize=(12,10), constrained_layout=True)
for i, grid in enumerate(grid_list):
    if i == 3:
        c_comp = 'k'
        c_mag = 'k'
        bins=100
    else:
        c_comp = 'C0'
        c_mag = 'C3'
        bins=100
        
    #fig.text(0.5,0.01, "Data-Fit (G)", ha="center", va="center", fontsize=18)
    #ax = fig.add_subplot(2, 2, 1)
    _ = splt.hist((df_dict[grid].Bz-df_dict[grid].Bz_fit), ax=axs[0][0], bins=bins, log=True, alpha=alphas[i], label=labels[i], color=c_comp, range=(-5e-3, 5e-3))
    axs[0][0].set_title(r'$B_z$', fontsize=24)
    #axs[0][0].set_ylabel('Counts')
    axs[0][0].set_xlabel('Data-Fit (G)')
    axs[0][0].ticklabel_format(style='sci', axis='x', scilimits=(0,0), useOffset=False)
    _ = splt.hist((df_dict[grid].Br-df_dict[grid].Br_fit), ax=axs[0][1], bins=bins, log=True, color=c_comp, alpha=alphas[i], range=(-5e-3, 5e-3))
    axs[0][1].set_title(r'$B_r$', fontsize=24)
    axs[0][1].set_xlabel('Data-Fit (G)')
    axs[0][1].ticklabel_format(style='sci', axis='x', scilimits=(0,0), useOffset=False)
    _ = splt.hist((df_dict[grid].Bphi-df_dict[grid].Bphi_fit), ax=axs[1][0], bins=bins, log=True, color=c_comp, alpha=alphas[i], range=(-5e-3, 5e-3))
    axs[1][0].set_title(r'$B_{\theta}$', fontsize=24)
    axs[1][0].set_xlabel('Data-Fit (G)')
    axs[1][0].ticklabel_format(style='sci', axis='x', scilimits=(0,0), useOffset=False)
    _ = splt.hist((df_dict[grid].Bmag-df_dict[grid].Bmag_fit)/df_dict[grid].Bmag, ax=axs[1][1], bins=bins, log=True,
                  color=c_mag, alpha=alphas[i], label=labels[i], range=(-5e-6,5e-6))
    mag_means.append(np.mean((df_dict[grid].Bmag-df_dict[grid].Bmag_fit)))
    mag_std.append(np.std((df_dict[grid].Bmag-df_dict[grid].Bmag_fit)))
    axs[1][1].set_title(r'$B_{mag}$', fontsize=24)
    axs[1][1].set_xlabel(r'Relative Residual $\left(\frac{Data-Fit}{Data}\right)$')
    axs[1][1].ticklabel_format(style='sci', axis='x', scilimits=(0,0), useOffset=False)
ylim = axs[0][0].get_ylim()
axs[0][0].set_ylim(ylim[0], ylim[1]*10)
ylim = axs[0][1].get_ylim()
axs[0][1].set_ylim(ylim[0], ylim[1]*20)
ylim = axs[1][0].get_ylim()
axs[1][0].set_ylim(ylim[0], ylim[1]*20)
ylim = axs[1][1].get_ylim()
axs[1][1].set_ylim(ylim[0], ylim[1]*10)
axs[0][0].legend(loc='upper left')
axs[1][1].legend(loc='upper left')

fig.suptitle('Residuals (Grid Spacing)', verticalalignment='bottom', fontsize=28)
fig.text(-0.015,0.5, "Counts (Validation Data)", ha="center", va="center", rotation=90, fontsize=25)
#plt.savefig('/Users/brianpollack/Documents/Notes_Papers/Helix/figs/res_solC.pdf', bbox_inches='tight')
#plt.savefig('/Users/brianpollack/Documents/Notes_Papers/Helix/figs/res_solA_cyl.pdf', bbox_inches='tight')

# fig = plt.figure(figsize=plt.figaspect(0.3), constrained_layout=False)
# fig.text(0.5,0.01, "Data-Fit (G)", ha="center", va="center", fontsize=18)
# ax = fig.add_subplot(1, 3, 1)
# ax.ticklabel_format(style='sci', axis='x', scilimits=(0,0), useOffset=False)
# _ = splt.hist((df_fs.Bz-df_fs.Bz_fit), ax=ax, bins=100, log=True, color='r')
# ax.set_title(r'$B_{z}$')
# ax.set_ylabel('Counts')
# ax = fig.add_subplot(1, 3, 2)
# ax.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
# _ = splt.hist((df_fs.Br-df_fs.Br_fit), ax=ax, bins=100, log=True, color='r')
# ax.set_title(r'$B_r$')
# ax = fig.add_subplot(1, 3, 3)
# ax.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
# _ = splt.hist((df_fs.Bphi-df_fs.Bphi_fit), ax=ax, bins=100, log=True, color='r')
# ax.set_title(r'$B_{\theta}$')
# fig.suptitle('B Component Residuals', verticalalignment='bottom')
plt.savefig('/Users/brianpollack/Documents/Notes_Papers/Helix/figs/res_solC_grid.pdf', bbox_inches='tight')

# %%
np.mean(df_dict[grid].Bmag-df_dict[grid].Bmag_fit)
np.std(df_dict[grid].Bmag-df_dict[grid].Bmag_fit)
# Out:
# 3.359130816780836e-05

# %%
z_steps_cole_hg = [i/1000 for i in range(-1500, 1500, 25)]

# %%
z_steps_cole_hg[-1]
# Out:
# 1.475

# %%
z_steps_cole_small[::2][-1]
# Out:
# 1.4

# %%
z_steps_cole_small[::9][-1]
# Out:
# 1.2

# %%
plt.plot(grid_list,mag_means, 'o')
plt.plot(grid_list,mag_std, 'o')
