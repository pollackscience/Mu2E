# %%
import os
from mu2e import mu2e_ext_path
from mu2e.dataframeprod import DataFrameMaker
from mu2e.mu2eplots import mu2e_plot, mu2e_plot3d
import pandas as pd
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12,8)
from skhep.visual import MplPlotter as splt
from copy import deepcopy
from lmfit import Model, Parameters, report_fit
# Out:
# /usr/local/lib/python3.6/site-packages/IPython/html.py:14: ShimWarning:
#
# The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#
# /usr/local/lib/python3.6/site-packages/plotly/widgets/graph_widget.py:13: UserWarning:
#
# IPython.utils.traitlets has moved to a top-level traitlets package.

# %% [markdown]
# # 1 Slice v 1 Slice

# %%
run hallprobesim.py
# Out:
# 0
# (140, 10)
# 375.0
# 1450.0
# 0.002490821
# 2260594    0.002491
# Name: Br, dtype: float64
# fitting with n=10, m=10, cn=0, cm=0
# Elapsed time was 7.63448 seconds
# [[Fit Statistics]]
#     # function evals   = 1017
#     # data points      = 4200
#     # variables        = 110
#     chi-square         = 0.000
#     reduced chi-square = 0.000
#     Akaike info crit   = -109156.026
#     Bayesian info crit = -108458.313
# [[Variables]]
#     R:       25000 (fixed)
#     ns:      10 (fixed)
#     ms:      10 (fixed)
#     A_0_0:   1          +/- 0        (0.00%) (init= 1)
#     B_0_0:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_0:   0 (fixed)
#     D_0_0:   0 (fixed)
#     A_0_1:   1          +/- 0        (0.00%) (init= 1)
#     B_0_1:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_1:   0 (fixed)
#     D_0_1:   0 (fixed)
#     A_0_2:   1          +/- 0        (0.00%) (init= 1)
#     B_0_2:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_2:   0 (fixed)
#     D_0_2:   0 (fixed)
#     A_0_3:   1          +/- 0        (0.00%) (init= 1)
#     B_0_3:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_3:   0 (fixed)
#     D_0_3:   0 (fixed)
#     A_0_4:   1          +/- 0        (0.00%) (init= 1)
#     B_0_4:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_4:   0 (fixed)
#     D_0_4:   0 (fixed)
#     A_0_5:   1          +/- 0        (0.00%) (init= 1)
#     B_0_5:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_5:   0 (fixed)
#     D_0_5:   0 (fixed)
#     A_0_6:   1          +/- 0        (0.00%) (init= 1)
#     B_0_6:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_6:   0 (fixed)
#     D_0_6:   0 (fixed)
#     A_0_7:   1          +/- 0        (0.00%) (init= 1)
#     B_0_7:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_7:   0 (fixed)
#     D_0_7:   0 (fixed)
#     A_0_8:   1          +/- 0        (0.00%) (init= 1)
#     B_0_8:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_8:   0 (fixed)
#     D_0_8:   0 (fixed)
#     A_0_9:   1          +/- 0        (0.00%) (init= 1)
#     B_0_9:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_9:   0 (fixed)
#     D_0_9:   0 (fixed)
#     A_1_0:   0 (fixed)
#     B_1_0:   0 (fixed)
#     C_1_0:   0 (fixed)
#     D_1_0:   0 (fixed)
#     A_1_1:   718.403667 +/- 0        (0.00%) (init= 1)
#     B_1_1:   1.0026e+05 +/- 0        (0.00%) (init=-1)
#     C_1_1:   0 (fixed)
#     D_1_1:   0 (fixed)
#     A_1_2:  -0.01733240 +/- 0        (0.00%) (init= 1)
#     B_1_2:  -4.53981845 +/- 0        (0.00%) (init=-1)
#     C_1_2:   0 (fixed)
#     D_1_2:   0 (fixed)
#     A_1_3:   24.8117382 +/- 0        (0.00%) (init= 1)
#     B_1_3:   0.68198607 +/- 0        (0.00%) (init=-1)
#     C_1_3:   0 (fixed)
#     D_1_3:   0 (fixed)
#     A_1_4:  -21.7833426 +/- 0        (0.00%) (init= 1)
#     B_1_4:  -299.439321 +/- 0        (0.00%) (init=-1)
#     C_1_4:   0 (fixed)
#     D_1_4:   0 (fixed)
#     A_1_5:   107.345749 +/- 0        (0.00%) (init= 1)
#     B_1_5:  -7449.77434 +/- 0        (0.00%) (init=-1)
#     C_1_5:   0 (fixed)
#     D_1_5:   0 (fixed)
#     A_1_6:   24103.9447 +/- 0        (0.00%) (init= 1)
#     B_1_6:  -12675.9285 +/- 0        (0.00%) (init=-1)
#     C_1_6:   0 (fixed)
#     D_1_6:   0 (fixed)
#     A_1_7:  -23567.9300 +/- 0        (0.00%) (init= 1)
#     B_1_7:   8.2456e+06 +/- 0        (0.00%) (init=-1)
#     C_1_7:   0 (fixed)
#     D_1_7:   0 (fixed)
#     A_1_8:   5.9571e+06 +/- 0        (0.00%) (init= 1)
#     B_1_8:   9.8336e+06 +/- 0        (0.00%) (init=-1)
#     C_1_8:   0 (fixed)
#     D_1_8:   0 (fixed)
#     A_1_9:   1          +/- 0        (0.00%) (init= 1)
#     B_1_9:  -1          +/- 0        (0.00%) (init=-1)
#     C_1_9:   0 (fixed)
#     D_1_9:   0 (fixed)
#     A_2_0:   0 (fixed)
#     B_2_0:   0 (fixed)
#     C_2_0:   0 (fixed)
#     D_2_0:   0 (fixed)
#     A_2_1:   0 (fixed)
#     B_2_1:   0 (fixed)
#     C_2_1:   0 (fixed)
#     D_2_1:   0 (fixed)
#     A_2_2:  -111.614359 +/- 0        (0.00%) (init= 1)
#     B_2_2:  -1.4699e+05 +/- 0        (0.00%) (init=-1)
#     C_2_2:   0 (fixed)
#     D_2_2:   0 (fixed)
#     A_2_3:   0.07737818 +/- 0        (0.00%) (init= 1)
#     B_2_3:   13.4824891 +/- 0        (0.00%) (init=-1)
#     C_2_3:   0 (fixed)
#     D_2_3:   0 (fixed)
#     A_2_4:  -34.1062871 +/- 0        (0.00%) (init= 1)
#     B_2_4:  -1.30936995 +/- 0        (0.00%) (init=-1)
#     C_2_4:   0 (fixed)
#     D_2_4:   0 (fixed)
#     A_2_5:   5.50197781 +/- 0        (0.00%) (init= 1)
#     B_2_5:   153.273059 +/- 0        (0.00%) (init=-1)
#     C_2_5:   0 (fixed)
#     D_2_5:   0 (fixed)
#     A_2_6:  -29.6181232 +/- 0        (0.00%) (init= 1)
#     B_2_6:   1197.34524 +/- 0        (0.00%) (init=-1)
#     C_2_6:   0 (fixed)
#     D_2_6:   0 (fixed)
#     A_2_7:  -1454.81282 +/- 0        (0.00%) (init= 1)
#     B_2_7:   573.870366 +/- 0        (0.00%) (init=-1)
#     C_2_7:   0 (fixed)
#     D_2_7:   0 (fixed)
#     A_2_8:   14997.8816 +/- 0        (0.00%) (init= 1)
#     B_2_8:  -2.4473e+05 +/- 0        (0.00%) (init=-1)
#     C_2_8:   0 (fixed)
#     D_2_8:   0 (fixed)
#     A_2_9:  -2.9549e+05 +/- 0        (0.00%) (init= 1)
#     B_2_9:  -87003.8855 +/- 0        (0.00%) (init=-1)
#     C_2_9:   0 (fixed)
#     D_2_9:   0 (fixed)
#     A_3_0:   0 (fixed)
#     B_3_0:   0 (fixed)
#     C_3_0:   0 (fixed)
#     D_3_0:   0 (fixed)
#     A_3_1:   0 (fixed)
#     B_3_1:   0 (fixed)
#     C_3_1:   0 (fixed)
#     D_3_1:   0 (fixed)
#     A_3_2:   0 (fixed)
#     B_3_2:   0 (fixed)
#     C_3_2:   0 (fixed)
#     D_3_2:   0 (fixed)
#     A_3_3:  -376.016292 +/- 0        (0.00%) (init= 1)
#     B_3_3:   1.4007e+05 +/- 0        (0.00%) (init=-1)
#     C_3_3:   0 (fixed)
#     D_3_3:   0 (fixed)
#     A_3_4:  -0.13978796 +/- 0        (0.00%) (init= 1)
#     B_3_4:  -21.6910881 +/- 0        (0.00%) (init=-1)
#     C_3_4:   0 (fixed)
#     D_3_4:   0 (fixed)
#     A_3_5:   33.6419332 +/- 0        (0.00%) (init= 1)
#     B_3_5:   1.48538524 +/- 0        (0.00%) (init=-1)
#     C_3_5:   0 (fixed)
#     D_3_5:   0 (fixed)
#     A_3_6:  -1.31020374 +/- 0        (0.00%) (init= 1)
#     B_3_6:  -79.1434336 +/- 0        (0.00%) (init=-1)
#     C_3_6:   0 (fixed)
#     D_3_6:   0 (fixed)
#     A_3_7:  -0.23466766 +/- 0        (0.00%) (init= 1)
#     B_3_7:  -251.705741 +/- 0        (0.00%) (init=-1)
#     C_3_7:   0 (fixed)
#     D_3_7:   0 (fixed)
#     A_3_8:   250.112007 +/- 0        (0.00%) (init= 1)
#     B_3_8:  -15.4420594 +/- 0        (0.00%) (init=-1)
#     C_3_8:   0 (fixed)
#     D_3_8:   0 (fixed)
#     A_3_9:  -1509.63346 +/- 0        (0.00%) (init= 1)
#     B_3_9:   12030.0710 +/- 0        (0.00%) (init=-1)
#     C_3_9:   0 (fixed)
#     D_3_9:   0 (fixed)
#     A_4_0:   0 (fixed)
#     B_4_0:   0 (fixed)
#     C_4_0:   0 (fixed)
#     D_4_0:   0 (fixed)
#     A_4_1:   0 (fixed)
#     B_4_1:   0 (fixed)
#     C_4_1:   0 (fixed)
#     D_4_1:   0 (fixed)
#     A_4_2:   0 (fixed)
#     B_4_2:   0 (fixed)
#     C_4_2:   0 (fixed)
#     D_4_2:   0 (fixed)
#     A_4_3:   0 (fixed)
#     B_4_3:   0 (fixed)
#     C_4_3:   0 (fixed)
#     D_4_3:   0 (fixed)
#     A_4_4:   504.461448 +/- 0        (0.00%) (init= 1)
#     B_4_4:  -96797.7452 +/- 0        (0.00%) (init=-1)
#     C_4_4:   0 (fixed)
#     D_4_4:   0 (fixed)
#     A_4_5:   0.14607369 +/- 0        (0.00%) (init= 1)
#     B_4_5:   22.6867789 +/- 0        (0.00%) (init=-1)
#     C_4_5:   0 (fixed)
#     D_4_5:   0 (fixed)
#     A_4_6:  -22.3539785 +/- 0        (0.00%) (init= 1)
#     B_4_6:  -1.19485557 +/- 0        (0.00%) (init=-1)
#     C_4_6:   0 (fixed)
#     D_4_6:   0 (fixed)
#     A_4_7:  -0.00141035 +/- 0        (0.00%) (init= 1)
#     B_4_7:   30.8889567 +/- 0        (0.00%) (init=-1)
#     C_4_7:   0 (fixed)
#     D_4_7:   0 (fixed)
#     A_4_8:   2.89314874 +/- 0        (0.00%) (init= 1)
#     B_4_8:   44.0352221 +/- 0        (0.00%) (init=-1)
#     C_4_8:   0 (fixed)
#     D_4_8:   0 (fixed)
#     A_4_9:  -21.6179394 +/- 0        (0.00%) (init= 1)
#     B_4_9:  -2.65463200 +/- 0        (0.00%) (init=-1)
#     C_4_9:   0 (fixed)
#     D_4_9:   0 (fixed)
#     A_5_0:   0 (fixed)
#     B_5_0:   0 (fixed)
#     C_5_0:   0 (fixed)
#     D_5_0:   0 (fixed)
#     A_5_1:   0 (fixed)
#     B_5_1:   0 (fixed)
#     C_5_1:   0 (fixed)
#     D_5_1:   0 (fixed)
#     A_5_2:   0 (fixed)
#     B_5_2:   0 (fixed)
#     C_5_2:   0 (fixed)
#     D_5_2:   0 (fixed)
#     A_5_3:   0 (fixed)
#     B_5_3:   0 (fixed)
#     C_5_3:   0 (fixed)
#     D_5_3:   0 (fixed)
#     A_5_4:   0 (fixed)
#     B_5_4:   0 (fixed)
#     C_5_4:   0 (fixed)
#     D_5_4:   0 (fixed)
#     A_5_5:  -365.405212 +/- 0        (0.00%) (init= 1)
#     B_5_5:   49565.8344 +/- 0        (0.00%) (init=-1)
#     C_5_5:   0 (fixed)
#     D_5_5:   0 (fixed)
#     A_5_6:  -0.09336682 +/- 0        (0.00%) (init= 1)
#     B_5_6:  -16.0014826 +/- 0        (0.00%) (init=-1)
#     C_5_6:   0 (fixed)
#     D_5_6:   0 (fixed)
#     A_5_7:   9.69971282 +/- 0        (0.00%) (init= 1)
#     B_5_7:   0.64307352 +/- 0        (0.00%) (init=-1)
#     C_5_7:   0 (fixed)
#     D_5_7:   0 (fixed)
#     A_5_8:   0.08655646 +/- 0        (0.00%) (init= 1)
#     B_5_8:  -7.78424806 +/- 0        (0.00%) (init=-1)
#     C_5_8:   0 (fixed)
#     D_5_8:   0 (fixed)
#     A_5_9:  -0.38328653 +/- 0        (0.00%) (init= 1)
#     B_5_9:  -5.54986164 +/- 0        (0.00%) (init=-1)
#     C_5_9:   0 (fixed)
#     D_5_9:   0 (fixed)
#     A_6_0:   0 (fixed)
#     B_6_0:   0 (fixed)
#     C_6_0:   0 (fixed)
#     D_6_0:   0 (fixed)
#     A_6_1:   0 (fixed)
#     B_6_1:   0 (fixed)
#     C_6_1:   0 (fixed)
#     D_6_1:   0 (fixed)
#     A_6_2:   0 (fixed)
#     B_6_2:   0 (fixed)
#     C_6_2:   0 (fixed)
#     D_6_2:   0 (fixed)
#     A_6_3:   0 (fixed)
#     B_6_3:   0 (fixed)
#     C_6_3:   0 (fixed)
#     D_6_3:   0 (fixed)
#     A_6_4:   0 (fixed)
#     B_6_4:   0 (fixed)
#     C_6_4:   0 (fixed)
#     D_6_4:   0 (fixed)
#     A_6_5:   0 (fixed)
#     B_6_5:   0 (fixed)
#     C_6_5:   0 (fixed)
#     D_6_5:   0 (fixed)
#     A_6_6:   174.603427 +/- 0        (0.00%) (init= 1)
#     B_6_6:  -18523.3997 +/- 0        (0.00%) (init=-1)
#     C_6_6:   0 (fixed)
#     D_6_6:   0 (fixed)
#     A_6_7:   0.03489645 +/- 0        (0.00%) (init= 1)
#     B_6_7:   7.42335398 +/- 0        (0.00%) (init=-1)
#     C_6_7:   0 (fixed)
#     D_6_7:   0 (fixed)
#     A_6_8:  -2.52529980 +/- 0        (0.00%) (init= 1)
#     B_6_8:  -0.20995703 +/- 0        (0.00%) (init=-1)
#     C_6_8:   0 (fixed)
#     D_6_8:   0 (fixed)
#     A_6_9:  -0.01179862 +/- 0        (0.00%) (init= 1)
#     B_6_9:   0.95241872 +/- 0        (0.00%) (init=-1)
#     C_6_9:   0 (fixed)
#     D_6_9:   0 (fixed)
#     A_7_0:   0 (fixed)
#     B_7_0:   0 (fixed)
#     C_7_0:   0 (fixed)
#     D_7_0:   0 (fixed)
#     A_7_1:   0 (fixed)
#     B_7_1:   0 (fixed)
#     C_7_1:   0 (fixed)
#     D_7_1:   0 (fixed)
#     A_7_2:   0 (fixed)
#     B_7_2:   0 (fixed)
#     C_7_2:   0 (fixed)
#     D_7_2:   0 (fixed)
#     A_7_3:   0 (fixed)
#     B_7_3:   0 (fixed)
#     C_7_3:   0 (fixed)
#     D_7_3:   0 (fixed)
#     A_7_4:   0 (fixed)
#     B_7_4:   0 (fixed)
#     C_7_4:   0 (fixed)
#     D_7_4:   0 (fixed)
#     A_7_5:   0 (fixed)
#     B_7_5:   0 (fixed)
#     C_7_5:   0 (fixed)
#     D_7_5:   0 (fixed)
#     A_7_6:   0 (fixed)
#     B_7_6:   0 (fixed)
#     C_7_6:   0 (fixed)
#     D_7_6:   0 (fixed)
#     A_7_7:  -55.6205697 +/- 0        (0.00%) (init= 1)
#     B_7_7:   4816.26773 +/- 0        (0.00%) (init=-1)
#     C_7_7:   0 (fixed)
#     D_7_7:   0 (fixed)
#     A_7_8:  -0.00625024 +/- 0        (0.00%) (init= 1)
#     B_7_8:  -2.06775648 +/- 0        (0.00%) (init=-1)
#     C_7_8:   0 (fixed)
#     D_7_8:   0 (fixed)
#     A_7_9:   0.30391611 +/- 0        (0.00%) (init= 1)
#     B_7_9:   0.03688918 +/- 0        (0.00%) (init=-1)
#     C_7_9:   0 (fixed)
#     D_7_9:   0 (fixed)
#     A_8_0:   0 (fixed)
#     B_8_0:   0 (fixed)
#     C_8_0:   0 (fixed)
#     D_8_0:   0 (fixed)
#     A_8_1:   0 (fixed)
#     B_8_1:   0 (fixed)
#     C_8_1:   0 (fixed)
#     D_8_1:   0 (fixed)
#     A_8_2:   0 (fixed)
#     B_8_2:   0 (fixed)
#     C_8_2:   0 (fixed)
#     D_8_2:   0 (fixed)
#     A_8_3:   0 (fixed)
#     B_8_3:   0 (fixed)
#     C_8_3:   0 (fixed)
#     D_8_3:   0 (fixed)
#     A_8_4:   0 (fixed)
#     B_8_4:   0 (fixed)
#     C_8_4:   0 (fixed)
#     D_8_4:   0 (fixed)
#     A_8_5:   0 (fixed)
#     B_8_5:   0 (fixed)
#     C_8_5:   0 (fixed)
#     D_8_5:   0 (fixed)
#     A_8_6:   0 (fixed)
#     B_8_6:   0 (fixed)
#     C_8_6:   0 (fixed)
#     D_8_6:   0 (fixed)
#     A_8_7:   0 (fixed)
#     B_8_7:   0 (fixed)
#     C_8_7:   0 (fixed)
#     D_8_7:   0 (fixed)
#     A_8_8:   10.8964041 +/- 0        (0.00%) (init= 1)
#     B_8_8:  -784.325221 +/- 0        (0.00%) (init=-1)
#     C_8_8:   0 (fixed)
#     D_8_8:   0 (fixed)
#     A_8_9:   0.00012754 +/- 0        (0.00%) (init= 1)
#     B_8_9:   0.26488795 +/- 0        (0.00%) (init=-1)
#     C_8_9:   0 (fixed)
#     D_8_9:   0 (fixed)
#     A_9_0:   0 (fixed)
#     B_9_0:   0 (fixed)
#     C_9_0:   0 (fixed)
#     D_9_0:   0 (fixed)
#     A_9_1:   0 (fixed)
#     B_9_1:   0 (fixed)
#     C_9_1:   0 (fixed)
#     D_9_1:   0 (fixed)
#     A_9_2:   0 (fixed)
#     B_9_2:   0 (fixed)
#     C_9_2:   0 (fixed)
#     D_9_2:   0 (fixed)
#     A_9_3:   0 (fixed)
#     B_9_3:   0 (fixed)
#     C_9_3:   0 (fixed)
#     D_9_3:   0 (fixed)
#     A_9_4:   0 (fixed)
#     B_9_4:   0 (fixed)
#     C_9_4:   0 (fixed)
#     D_9_4:   0 (fixed)
#     A_9_5:   0 (fixed)
#     B_9_5:   0 (fixed)
#     C_9_5:   0 (fixed)
#     D_9_5:   0 (fixed)
#     A_9_6:   0 (fixed)
#     B_9_6:   0 (fixed)
#     C_9_6:   0 (fixed)
#     D_9_6:   0 (fixed)
#     A_9_7:   0 (fixed)
#     B_9_7:   0 (fixed)
#     C_9_7:   0 (fixed)
#     D_9_7:   0 (fixed)
#     A_9_8:   0 (fixed)
#     B_9_8:   0 (fixed)
#     C_9_8:   0 (fixed)
#     D_9_8:   0 (fixed)
#     A_9_9:  -1.00827959 +/- 0        (0.00%) (init= 1)
#     B_9_9:   60.6352395 +/- 0        (0.00%) (init=-1)
#     C_9_9:   0 (fixed)
#     D_9_9:   0 (fixed)

# %%
ff1 = deepcopy(ff)

# %%
run hallprobesim.py
# Out:
# 1.5707963267948966
# (140, 10)
# 375.0
# 1450.0
# 0.002531942
# 1732114    0.002532
# Name: Br, dtype: float64
# fitting with n=10, m=10, cn=0, cm=0
# Elapsed time was 9.86875 seconds
# [[Fit Statistics]]
#     # function evals   = 1239
#     # data points      = 4200
#     # variables        = 110
#     chi-square         = 0.000
#     reduced chi-square = 0.000
#     Akaike info crit   = -108978.905
#     Bayesian info crit = -108281.192
# [[Variables]]
#     R:       25000 (fixed)
#     ns:      10 (fixed)
#     ms:      10 (fixed)
#     A_0_0:   1          +/- 0        (0.00%) (init= 1)
#     B_0_0:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_0:   0 (fixed)
#     D_0_0:   0 (fixed)
#     A_0_1:   1          +/- 0        (0.00%) (init= 1)
#     B_0_1:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_1:   0 (fixed)
#     D_0_1:   0 (fixed)
#     A_0_2:   1          +/- 0        (0.00%) (init= 1)
#     B_0_2:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_2:   0 (fixed)
#     D_0_2:   0 (fixed)
#     A_0_3:   1          +/- 0        (0.00%) (init= 1)
#     B_0_3:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_3:   0 (fixed)
#     D_0_3:   0 (fixed)
#     A_0_4:   1          +/- 0        (0.00%) (init= 1)
#     B_0_4:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_4:   0 (fixed)
#     D_0_4:   0 (fixed)
#     A_0_5:   1          +/- 0        (0.00%) (init= 1)
#     B_0_5:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_5:   0 (fixed)
#     D_0_5:   0 (fixed)
#     A_0_6:   1          +/- 0        (0.00%) (init= 1)
#     B_0_6:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_6:   0 (fixed)
#     D_0_6:   0 (fixed)
#     A_0_7:   1          +/- 0        (0.00%) (init= 1)
#     B_0_7:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_7:   0 (fixed)
#     D_0_7:   0 (fixed)
#     A_0_8:   1          +/- 0        (0.00%) (init= 1)
#     B_0_8:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_8:   0 (fixed)
#     D_0_8:   0 (fixed)
#     A_0_9:   1          +/- 0        (0.00%) (init= 1)
#     B_0_9:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_9:   0 (fixed)
#     D_0_9:   0 (fixed)
#     A_1_0:   0 (fixed)
#     B_1_0:   0 (fixed)
#     C_1_0:   0 (fixed)
#     D_1_0:   0 (fixed)
#     A_1_1:   1506.17715 +/- 0        (0.00%) (init= 1)
#     B_1_1:   99980.6154 +/- 0        (0.00%) (init=-1)
#     C_1_1:   0 (fixed)
#     D_1_1:   0 (fixed)
#     A_1_2:  -0.14471966 +/- 0        (0.00%) (init= 1)
#     B_1_2:  -5.61249835 +/- 0        (0.00%) (init=-1)
#     C_1_2:   0 (fixed)
#     D_1_2:   0 (fixed)
#     A_1_3:  -24.2936910 +/- 0        (0.00%) (init= 1)
#     B_1_3:  -6.99026134 +/- 0        (0.00%) (init=-1)
#     C_1_3:   0 (fixed)
#     D_1_3:   0 (fixed)
#     A_1_4:  -18.5768130 +/- 0        (0.00%) (init= 1)
#     B_1_4:   213.125149 +/- 0        (0.00%) (init=-1)
#     C_1_4:   0 (fixed)
#     D_1_4:   0 (fixed)
#     A_1_5:  -5.72334331 +/- 0        (0.00%) (init= 1)
#     B_1_5:  -6285.23000 +/- 0        (0.00%) (init=-1)
#     C_1_5:   0 (fixed)
#     D_1_5:   0 (fixed)
#     A_1_6:  -2299.07628 +/- 0        (0.00%) (init= 1)
#     B_1_6:   72187.3178 +/- 0        (0.00%) (init=-1)
#     C_1_6:   0 (fixed)
#     D_1_6:   0 (fixed)
#     A_1_7:  -5.8606e+05 +/- 0        (0.00%) (init= 1)
#     B_1_7:  -8.2105e+06 +/- 0        (0.00%) (init=-1)
#     C_1_7:   0 (fixed)
#     D_1_7:   0 (fixed)
#     A_1_8:  -157.064519 +/- 0        (0.00%) (init= 1)
#     B_1_8:  -0.99581149 +/- 0        (0.00%) (init=-1)
#     C_1_8:   0 (fixed)
#     D_1_8:   0 (fixed)
#     A_1_9:   1          +/- 0        (0.00%) (init= 1)
#     B_1_9:  -1          +/- 0        (0.00%) (init=-1)
#     C_1_9:   0 (fixed)
#     D_1_9:   0 (fixed)
#     A_2_0:   0 (fixed)
#     B_2_0:   0 (fixed)
#     C_2_0:   0 (fixed)
#     D_2_0:   0 (fixed)
#     A_2_1:   0 (fixed)
#     B_2_1:   0 (fixed)
#     C_2_1:   0 (fixed)
#     D_2_1:   0 (fixed)
#     A_2_2:  -695.355479 +/- 0        (0.00%) (init= 1)
#     B_2_2:  -1.4656e+05 +/- 0        (0.00%) (init=-1)
#     C_2_2:   0 (fixed)
#     D_2_2:   0 (fixed)
#     A_2_3:   0.38429438 +/- 0        (0.00%) (init= 1)
#     B_2_3:   16.5781248 +/- 0        (0.00%) (init=-1)
#     C_2_3:   0 (fixed)
#     D_2_3:   0 (fixed)
#     A_2_4:   33.5016651 +/- 0        (0.00%) (init= 1)
#     B_2_4:   7.40445320 +/- 0        (0.00%) (init=-1)
#     C_2_4:   0 (fixed)
#     D_2_4:   0 (fixed)
#     A_2_5:   9.67469364 +/- 0        (0.00%) (init= 1)
#     B_2_5:  -96.3336194 +/- 0        (0.00%) (init=-1)
#     C_2_5:   0 (fixed)
#     D_2_5:   0 (fixed)
#     A_2_6:  -14.5949307 +/- 0        (0.00%) (init= 1)
#     B_2_6:   946.591202 +/- 0        (0.00%) (init=-1)
#     C_2_6:   0 (fixed)
#     D_2_6:   0 (fixed)
#     A_2_7:   33.7746023 +/- 0        (0.00%) (init= 1)
#     B_2_7:  -6995.47293 +/- 0        (0.00%) (init=-1)
#     C_2_7:   0 (fixed)
#     D_2_7:   0 (fixed)
#     A_2_8:   8720.89668 +/- 0        (0.00%) (init= 1)
#     B_2_8:   2.4929e+05 +/- 0        (0.00%) (init=-1)
#     C_2_8:   0 (fixed)
#     D_2_8:   0 (fixed)
#     A_2_9:  -701.679624 +/- 0        (0.00%) (init= 1)
#     B_2_9:  -55686.3257 +/- 0        (0.00%) (init=-1)
#     C_2_9:   0 (fixed)
#     D_2_9:   0 (fixed)
#     A_3_0:   0 (fixed)
#     B_3_0:   0 (fixed)
#     C_3_0:   0 (fixed)
#     D_3_0:   0 (fixed)
#     A_3_1:   0 (fixed)
#     B_3_1:   0 (fixed)
#     C_3_1:   0 (fixed)
#     D_3_1:   0 (fixed)
#     A_3_2:   0 (fixed)
#     B_3_2:   0 (fixed)
#     C_3_2:   0 (fixed)
#     D_3_2:   0 (fixed)
#     A_3_3:  -24.7685263 +/- 0        (0.00%) (init= 1)
#     B_3_3:   1.3966e+05 +/- 0        (0.00%) (init=-1)
#     C_3_3:   0 (fixed)
#     D_3_3:   0 (fixed)
#     A_3_4:  -0.61342614 +/- 0        (0.00%) (init= 1)
#     B_3_4:  -27.0649366 +/- 0        (0.00%) (init=-1)
#     C_3_4:   0 (fixed)
#     D_3_4:   0 (fixed)
#     A_3_5:  -33.0267418 +/- 0        (0.00%) (init= 1)
#     B_3_5:  -5.58410578 +/- 0        (0.00%) (init=-1)
#     C_3_5:   0 (fixed)
#     D_3_5:   0 (fixed)
#     A_3_6:  -5.55195723 +/- 0        (0.00%) (init= 1)
#     B_3_6:   43.4061941 +/- 0        (0.00%) (init=-1)
#     C_3_6:   0 (fixed)
#     D_3_6:   0 (fixed)
#     A_3_7:   0.12995126 +/- 0        (0.00%) (init= 1)
#     B_3_7:  -183.132147 +/- 0        (0.00%) (init=-1)
#     C_3_7:   0 (fixed)
#     D_3_7:   0 (fixed)
#     A_3_8:  -5.00308386 +/- 0        (0.00%) (init= 1)
#     B_3_8:   1011.95142 +/- 0        (0.00%) (init=-1)
#     C_3_8:   0 (fixed)
#     D_3_8:   0 (fixed)
#     A_3_9:  -14.8375490 +/- 0        (0.00%) (init= 1)
#     B_3_9:  -12344.4216 +/- 0        (0.00%) (init=-1)
#     C_3_9:   0 (fixed)
#     D_3_9:   0 (fixed)
#     A_4_0:   0 (fixed)
#     B_4_0:   0 (fixed)
#     C_4_0:   0 (fixed)
#     D_4_0:   0 (fixed)
#     A_4_1:   0 (fixed)
#     B_4_1:   0 (fixed)
#     C_4_1:   0 (fixed)
#     D_4_1:   0 (fixed)
#     A_4_2:   0 (fixed)
#     B_4_2:   0 (fixed)
#     C_4_2:   0 (fixed)
#     D_4_2:   0 (fixed)
#     A_4_3:   0 (fixed)
#     B_4_3:   0 (fixed)
#     C_4_3:   0 (fixed)
#     D_4_3:   0 (fixed)
#     A_4_4:   335.195888 +/- 0        (0.00%) (init= 1)
#     B_4_4:  -96521.1467 +/- 0        (0.00%) (init=-1)
#     C_4_4:   0 (fixed)
#     D_4_4:   0 (fixed)
#     A_4_5:   0.64431907 +/- 0        (0.00%) (init= 1)
#     B_4_5:   28.8149749 +/- 0        (0.00%) (init=-1)
#     C_4_5:   0 (fixed)
#     D_4_5:   0 (fixed)
#     A_4_6:   21.8858467 +/- 0        (0.00%) (init= 1)
#     B_4_6:   2.99137850 +/- 0        (0.00%) (init=-1)
#     C_4_6:   0 (fixed)
#     D_4_6:   0 (fixed)
#     A_4_7:   2.45284719 +/- 0        (0.00%) (init= 1)
#     B_4_7:  -14.5609933 +/- 0        (0.00%) (init=-1)
#     C_4_7:   0 (fixed)
#     D_4_7:   0 (fixed)
#     A_4_8:   1.67447917 +/- 0        (0.00%) (init= 1)
#     B_4_8:   29.9167673 +/- 0        (0.00%) (init=-1)
#     C_4_8:   0 (fixed)
#     D_4_8:   0 (fixed)
#     A_4_9:   2.87440678 +/- 0        (0.00%) (init= 1)
#     B_4_9:  -100.132267 +/- 0        (0.00%) (init=-1)
#     C_4_9:   0 (fixed)
#     D_4_9:   0 (fixed)
#     A_5_0:   0 (fixed)
#     B_5_0:   0 (fixed)
#     C_5_0:   0 (fixed)
#     D_5_0:   0 (fixed)
#     A_5_1:   0 (fixed)
#     B_5_1:   0 (fixed)
#     C_5_1:   0 (fixed)
#     D_5_1:   0 (fixed)
#     A_5_2:   0 (fixed)
#     B_5_2:   0 (fixed)
#     C_5_2:   0 (fixed)
#     D_5_2:   0 (fixed)
#     A_5_3:   0 (fixed)
#     B_5_3:   0 (fixed)
#     C_5_3:   0 (fixed)
#     D_5_3:   0 (fixed)
#     A_5_4:   0 (fixed)
#     B_5_4:   0 (fixed)
#     C_5_4:   0 (fixed)
#     D_5_4:   0 (fixed)
#     A_5_5:  -301.529251 +/- 0        (0.00%) (init= 1)
#     B_5_5:   49424.1906 +/- 0        (0.00%) (init=-1)
#     C_5_5:   0 (fixed)
#     D_5_5:   0 (fixed)
#     A_5_6:  -0.45568478 +/- 0        (0.00%) (init= 1)
#     B_5_6:  -20.6970512 +/- 0        (0.00%) (init=-1)
#     C_5_6:   0 (fixed)
#     D_5_6:   0 (fixed)
#     A_5_7:  -9.45485413 +/- 0        (0.00%) (init= 1)
#     B_5_7:  -1.12583486 +/- 0        (0.00%) (init=-1)
#     C_5_7:   0 (fixed)
#     D_5_7:   0 (fixed)
#     A_5_8:  -0.68716655 +/- 0        (0.00%) (init= 1)
#     B_5_8:   3.10282963 +/- 0        (0.00%) (init=-1)
#     C_5_8:   0 (fixed)
#     D_5_8:   0 (fixed)
#     A_5_9:  -0.34265459 +/- 0        (0.00%) (init= 1)
#     B_5_9:  -4.09967553 +/- 0        (0.00%) (init=-1)
#     C_5_9:   0 (fixed)
#     D_5_9:   0 (fixed)
#     A_6_0:   0 (fixed)
#     B_6_0:   0 (fixed)
#     C_6_0:   0 (fixed)
#     D_6_0:   0 (fixed)
#     A_6_1:   0 (fixed)
#     B_6_1:   0 (fixed)
#     C_6_1:   0 (fixed)
#     D_6_1:   0 (fixed)
#     A_6_2:   0 (fixed)
#     B_6_2:   0 (fixed)
#     C_6_2:   0 (fixed)
#     D_6_2:   0 (fixed)
#     A_6_3:   0 (fixed)
#     B_6_3:   0 (fixed)
#     C_6_3:   0 (fixed)
#     D_6_3:   0 (fixed)
#     A_6_4:   0 (fixed)
#     B_6_4:   0 (fixed)
#     C_6_4:   0 (fixed)
#     D_6_4:   0 (fixed)
#     A_6_5:   0 (fixed)
#     B_6_5:   0 (fixed)
#     C_6_5:   0 (fixed)
#     D_6_5:   0 (fixed)
#     A_6_6:   156.389592 +/- 0        (0.00%) (init= 1)
#     B_6_6:  -18469.7010 +/- 0        (0.00%) (init=-1)
#     C_6_6:   0 (fixed)
#     D_6_6:   0 (fixed)
#     A_6_7:   0.21235056 +/- 0        (0.00%) (init= 1)
#     B_6_7:   9.78366659 +/- 0        (0.00%) (init=-1)
#     C_6_7:   0 (fixed)
#     D_6_7:   0 (fixed)
#     A_6_8:   2.44383919 +/- 0        (0.00%) (init= 1)
#     B_6_8:   0.27442522 +/- 0        (0.00%) (init=-1)
#     C_6_8:   0 (fixed)
#     D_6_8:   0 (fixed)
#     A_6_9:   0.09560123 +/- 0        (0.00%) (init= 1)
#     B_6_9:  -0.33786110 +/- 0        (0.00%) (init=-1)
#     C_6_9:   0 (fixed)
#     D_6_9:   0 (fixed)
#     A_7_0:   0 (fixed)
#     B_7_0:   0 (fixed)
#     C_7_0:   0 (fixed)
#     D_7_0:   0 (fixed)
#     A_7_1:   0 (fixed)
#     B_7_1:   0 (fixed)
#     C_7_1:   0 (fixed)
#     D_7_1:   0 (fixed)
#     A_7_2:   0 (fixed)
#     B_7_2:   0 (fixed)
#     C_7_2:   0 (fixed)
#     D_7_2:   0 (fixed)
#     A_7_3:   0 (fixed)
#     B_7_3:   0 (fixed)
#     C_7_3:   0 (fixed)
#     D_7_3:   0 (fixed)
#     A_7_4:   0 (fixed)
#     B_7_4:   0 (fixed)
#     C_7_4:   0 (fixed)
#     D_7_4:   0 (fixed)
#     A_7_5:   0 (fixed)
#     B_7_5:   0 (fixed)
#     C_7_5:   0 (fixed)
#     D_7_5:   0 (fixed)
#     A_7_6:   0 (fixed)
#     B_7_6:   0 (fixed)
#     C_7_6:   0 (fixed)
#     D_7_6:   0 (fixed)
#     A_7_7:  -51.9222606 +/- 0        (0.00%) (init= 1)
#     B_7_7:   4801.88409 +/- 0        (0.00%) (init=-1)
#     C_7_7:   0 (fixed)
#     D_7_7:   0 (fixed)
#     A_7_8:  -0.05987702 +/- 0        (0.00%) (init= 1)
#     B_7_8:  -2.78040786 +/- 0        (0.00%) (init=-1)
#     C_7_8:   0 (fixed)
#     D_7_8:   0 (fixed)
#     A_7_9:  -0.29115288 +/- 0        (0.00%) (init= 1)
#     B_7_9:  -0.03779746 +/- 0        (0.00%) (init=-1)
#     C_7_9:   0 (fixed)
#     D_7_9:   0 (fixed)
#     A_8_0:   0 (fixed)
#     B_8_0:   0 (fixed)
#     C_8_0:   0 (fixed)
#     D_8_0:   0 (fixed)
#     A_8_1:   0 (fixed)
#     B_8_1:   0 (fixed)
#     C_8_1:   0 (fixed)
#     D_8_1:   0 (fixed)
#     A_8_2:   0 (fixed)
#     B_8_2:   0 (fixed)
#     C_8_2:   0 (fixed)
#     D_8_2:   0 (fixed)
#     A_8_3:   0 (fixed)
#     B_8_3:   0 (fixed)
#     C_8_3:   0 (fixed)
#     D_8_3:   0 (fixed)
#     A_8_4:   0 (fixed)
#     B_8_4:   0 (fixed)
#     C_8_4:   0 (fixed)
#     D_8_4:   0 (fixed)
#     A_8_5:   0 (fixed)
#     B_8_5:   0 (fixed)
#     C_8_5:   0 (fixed)
#     D_8_5:   0 (fixed)
#     A_8_6:   0 (fixed)
#     B_8_6:   0 (fixed)
#     C_8_6:   0 (fixed)
#     D_8_6:   0 (fixed)
#     A_8_7:   0 (fixed)
#     B_8_7:   0 (fixed)
#     C_8_7:   0 (fixed)
#     D_8_7:   0 (fixed)
#     A_8_8:   10.4175459 +/- 0        (0.00%) (init= 1)
#     B_8_8:  -781.876136 +/- 0        (0.00%) (init=-1)
#     C_8_8:   0 (fixed)
#     D_8_8:   0 (fixed)
#     A_8_9:   0.00793396 +/- 0        (0.00%) (init= 1)
#     B_8_9:   0.36440625 +/- 0        (0.00%) (init=-1)
#     C_8_9:   0 (fixed)
#     D_8_9:   0 (fixed)
#     A_9_0:   0 (fixed)
#     B_9_0:   0 (fixed)
#     C_9_0:   0 (fixed)
#     D_9_0:   0 (fixed)
#     A_9_1:   0 (fixed)
#     B_9_1:   0 (fixed)
#     C_9_1:   0 (fixed)
#     D_9_1:   0 (fixed)
#     A_9_2:   0 (fixed)
#     B_9_2:   0 (fixed)
#     C_9_2:   0 (fixed)
#     D_9_2:   0 (fixed)
#     A_9_3:   0 (fixed)
#     B_9_3:   0 (fixed)
#     C_9_3:   0 (fixed)
#     D_9_3:   0 (fixed)
#     A_9_4:   0 (fixed)
#     B_9_4:   0 (fixed)
#     C_9_4:   0 (fixed)
#     D_9_4:   0 (fixed)
#     A_9_5:   0 (fixed)
#     B_9_5:   0 (fixed)
#     C_9_5:   0 (fixed)
#     D_9_5:   0 (fixed)
#     A_9_6:   0 (fixed)
#     B_9_6:   0 (fixed)
#     C_9_6:   0 (fixed)
#     D_9_6:   0 (fixed)
#     A_9_7:   0 (fixed)
#     B_9_7:   0 (fixed)
#     C_9_7:   0 (fixed)
#     D_9_7:   0 (fixed)
#     A_9_8:   0 (fixed)
#     B_9_8:   0 (fixed)
#     C_9_8:   0 (fixed)
#     D_9_8:   0 (fixed)
#     A_9_9:  -0.97816311 +/- 0        (0.00%) (init= 1)
#     B_9_9:   60.4347157 +/- 0        (0.00%) (init=-1)
#     C_9_9:   0 (fixed)
#     D_9_9:   0 (fixed)

# %%
ff2 = deepcopy(ff)

# %%
run hallprobesim.py
# Out:
# 0.463648
# (140, 10)
# 335.410196625
# 1450.0
# 0.002255389
# 2155999    0.002255
# Name: Br, dtype: float64
# fitting with n=10, m=10, cn=0, cm=0
# Elapsed time was 13.3655 seconds
# [[Fit Statistics]]
#     # function evals   = 1793
#     # data points      = 4200
#     # variables        = 110
#     chi-square         = 0.000
#     reduced chi-square = 0.000
#     Akaike info crit   = -93469.508
#     Bayesian info crit = -92771.796
# [[Variables]]
#     R:       25000 (fixed)
#     ns:      10 (fixed)
#     ms:      10 (fixed)
#     A_0_0:   1          +/- 0        (0.00%) (init= 1)
#     B_0_0:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_0:   0 (fixed)
#     D_0_0:   0 (fixed)
#     A_0_1:   1          +/- 0        (0.00%) (init= 1)
#     B_0_1:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_1:   0 (fixed)
#     D_0_1:   0 (fixed)
#     A_0_2:   1          +/- 0        (0.00%) (init= 1)
#     B_0_2:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_2:   0 (fixed)
#     D_0_2:   0 (fixed)
#     A_0_3:   1          +/- 0        (0.00%) (init= 1)
#     B_0_3:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_3:   0 (fixed)
#     D_0_3:   0 (fixed)
#     A_0_4:   1          +/- 0        (0.00%) (init= 1)
#     B_0_4:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_4:   0 (fixed)
#     D_0_4:   0 (fixed)
#     A_0_5:   1          +/- 0        (0.00%) (init= 1)
#     B_0_5:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_5:   0 (fixed)
#     D_0_5:   0 (fixed)
#     A_0_6:   1          +/- 0        (0.00%) (init= 1)
#     B_0_6:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_6:   0 (fixed)
#     D_0_6:   0 (fixed)
#     A_0_7:   1          +/- 0        (0.00%) (init= 1)
#     B_0_7:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_7:   0 (fixed)
#     D_0_7:   0 (fixed)
#     A_0_8:   1          +/- 0        (0.00%) (init= 1)
#     B_0_8:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_8:   0 (fixed)
#     D_0_8:   0 (fixed)
#     A_0_9:   1          +/- 0        (0.00%) (init= 1)
#     B_0_9:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_9:   0 (fixed)
#     D_0_9:   0 (fixed)
#     A_1_0:   0 (fixed)
#     B_1_0:   0 (fixed)
#     C_1_0:   0 (fixed)
#     D_1_0:   0 (fixed)
#     A_1_1:   15932.1812 +/- 0        (0.00%) (init= 1)
#     B_1_1:   30694.2264 +/- 0        (0.00%) (init=-1)
#     C_1_1:   0 (fixed)
#     D_1_1:   0 (fixed)
#     A_1_2:  -0.53469644 +/- 0        (0.00%) (init= 1)
#     B_1_2:  -4.90617577 +/- 0        (0.00%) (init=-1)
#     C_1_2:   0 (fixed)
#     D_1_2:   0 (fixed)
#     A_1_3:   16.1914838 +/- 0        (0.00%) (init= 1)
#     B_1_3:   7.23829585 +/- 0        (0.00%) (init=-1)
#     C_1_3:   0 (fixed)
#     D_1_3:   0 (fixed)
#     A_1_4:   237.499464 +/- 0        (0.00%) (init= 1)
#     B_1_4:  -78.9518165 +/- 0        (0.00%) (init=-1)
#     C_1_4:   0 (fixed)
#     D_1_4:   0 (fixed)
#     A_1_5:  -769.820980 +/- 0        (0.00%) (init= 1)
#     B_1_5:   878.068666 +/- 0        (0.00%) (init=-1)
#     C_1_5:   0 (fixed)
#     D_1_5:   0 (fixed)
#     A_1_6:  -50696.2992 +/- 0        (0.00%) (init= 1)
#     B_1_6:   99898.5008 +/- 0        (0.00%) (init=-1)
#     C_1_6:   0 (fixed)
#     D_1_6:   0 (fixed)
#     A_1_7:   2.2462e+06 +/- 0        (0.00%) (init= 1)
#     B_1_7:   2.1658e+05 +/- 0        (0.00%) (init=-1)
#     C_1_7:   0 (fixed)
#     D_1_7:   0 (fixed)
#     A_1_8:   1.5246e+08 +/- 0        (0.00%) (init= 1)
#     B_1_8:   341.389198 +/- 0        (0.00%) (init=-1)
#     C_1_8:   0 (fixed)
#     D_1_8:   0 (fixed)
#     A_1_9:   1          +/- 0        (0.00%) (init= 1)
#     B_1_9:  -1          +/- 0        (0.00%) (init=-1)
#     C_1_9:   0 (fixed)
#     D_1_9:   0 (fixed)
#     A_2_0:   0 (fixed)
#     B_2_0:   0 (fixed)
#     C_2_0:   0 (fixed)
#     D_2_0:   0 (fixed)
#     A_2_1:   0 (fixed)
#     B_2_1:   0 (fixed)
#     C_2_1:   0 (fixed)
#     D_2_1:   0 (fixed)
#     A_2_2:  -11087.4089 +/- 0        (0.00%) (init= 1)
#     B_2_2:  -42037.2002 +/- 0        (0.00%) (init=-1)
#     C_2_2:   0 (fixed)
#     D_2_2:   0 (fixed)
#     A_2_3:   1.46267075 +/- 0        (0.00%) (init= 1)
#     B_2_3:   14.4665283 +/- 0        (0.00%) (init=-1)
#     C_2_3:   0 (fixed)
#     D_2_3:   0 (fixed)
#     A_2_4:  -21.4609387 +/- 0        (0.00%) (init= 1)
#     B_2_4:  -13.4606821 +/- 0        (0.00%) (init=-1)
#     C_2_4:   0 (fixed)
#     D_2_4:   0 (fixed)
#     A_2_5:  -131.004314 +/- 0        (0.00%) (init= 1)
#     B_2_5:   22.2958940 +/- 0        (0.00%) (init=-1)
#     C_2_5:   0 (fixed)
#     D_2_5:   0 (fixed)
#     A_2_6:   41.0277793 +/- 0        (0.00%) (init= 1)
#     B_2_6:  -59.7311573 +/- 0        (0.00%) (init=-1)
#     C_2_6:   0 (fixed)
#     D_2_6:   0 (fixed)
#     A_2_7:   1668.96846 +/- 0        (0.00%) (init= 1)
#     B_2_7:  -5291.67617 +/- 0        (0.00%) (init=-1)
#     C_2_7:   0 (fixed)
#     D_2_7:   0 (fixed)
#     A_2_8:  -59052.4849 +/- 0        (0.00%) (init= 1)
#     B_2_8:   25015.1764 +/- 0        (0.00%) (init=-1)
#     C_2_8:   0 (fixed)
#     D_2_8:   0 (fixed)
#     A_2_9:  -8.7447e+05 +/- 0        (0.00%) (init= 1)
#     B_2_9:   4.0301e+05 +/- 0        (0.00%) (init=-1)
#     C_2_9:   0 (fixed)
#     D_2_9:   0 (fixed)
#     A_3_0:   0 (fixed)
#     B_3_0:   0 (fixed)
#     C_3_0:   0 (fixed)
#     D_3_0:   0 (fixed)
#     A_3_1:   0 (fixed)
#     B_3_1:   0 (fixed)
#     C_3_1:   0 (fixed)
#     D_3_1:   0 (fixed)
#     A_3_2:   0 (fixed)
#     B_3_2:   0 (fixed)
#     C_3_2:   0 (fixed)
#     D_3_2:   0 (fixed)
#     A_3_3:   5914.67219 +/- 0        (0.00%) (init= 1)
#     B_3_3:   42442.8757 +/- 0        (0.00%) (init=-1)
#     C_3_3:   0 (fixed)
#     D_3_3:   0 (fixed)
#     A_3_4:  -2.40343312 +/- 0        (0.00%) (init= 1)
#     B_3_4:  -23.3051463 +/- 0        (0.00%) (init=-1)
#     C_3_4:   0 (fixed)
#     D_3_4:   0 (fixed)
#     A_3_5:   20.9051529 +/- 0        (0.00%) (init= 1)
#     B_3_5:   14.5462107 +/- 0        (0.00%) (init=-1)
#     C_3_5:   0 (fixed)
#     D_3_5:   0 (fixed)
#     A_3_6:   72.0527526 +/- 0        (0.00%) (init= 1)
#     B_3_6:  -4.67726977 +/- 0        (0.00%) (init=-1)
#     C_3_6:   0 (fixed)
#     D_3_6:   0 (fixed)
#     A_3_7:  -5.99173830 +/- 0        (0.00%) (init= 1)
#     B_3_7:  -21.3283765 +/- 0        (0.00%) (init=-1)
#     C_3_7:   0 (fixed)
#     D_3_7:   0 (fixed)
#     A_3_8:  -245.490818 +/- 0        (0.00%) (init= 1)
#     B_3_8:   471.017838 +/- 0        (0.00%) (init=-1)
#     C_3_8:   0 (fixed)
#     D_3_8:   0 (fixed)
#     A_3_9:   2615.58326 +/- 0        (0.00%) (init= 1)
#     B_3_9:  -2993.11544 +/- 0        (0.00%) (init=-1)
#     C_3_9:   0 (fixed)
#     D_3_9:   0 (fixed)
#     A_4_0:   0 (fixed)
#     B_4_0:   0 (fixed)
#     C_4_0:   0 (fixed)
#     D_4_0:   0 (fixed)
#     A_4_1:   0 (fixed)
#     B_4_1:   0 (fixed)
#     C_4_1:   0 (fixed)
#     D_4_1:   0 (fixed)
#     A_4_2:   0 (fixed)
#     B_4_2:   0 (fixed)
#     C_4_2:   0 (fixed)
#     D_4_2:   0 (fixed)
#     A_4_3:   0 (fixed)
#     B_4_3:   0 (fixed)
#     C_4_3:   0 (fixed)
#     D_4_3:   0 (fixed)
#     A_4_4:  -2298.84604 +/- 0        (0.00%) (init= 1)
#     B_4_4:  -31305.8513 +/- 0        (0.00%) (init=-1)
#     C_4_4:   0 (fixed)
#     D_4_4:   0 (fixed)
#     A_4_5:   2.60429431 +/- 0        (0.00%) (init= 1)
#     B_4_5:   24.4461297 +/- 0        (0.00%) (init=-1)
#     C_4_5:   0 (fixed)
#     D_4_5:   0 (fixed)
#     A_4_6:  -13.6438641 +/- 0        (0.00%) (init= 1)
#     B_4_6:  -9.82734457 +/- 0        (0.00%) (init=-1)
#     C_4_6:   0 (fixed)
#     D_4_6:   0 (fixed)
#     A_4_7:  -29.6181092 +/- 0        (0.00%) (init= 1)
#     B_4_7:  -0.87671982 +/- 0        (0.00%) (init=-1)
#     C_4_7:   0 (fixed)
#     D_4_7:   0 (fixed)
#     A_4_8:   4.20397226 +/- 0        (0.00%) (init= 1)
#     B_4_8:   12.5846772 +/- 0        (0.00%) (init=-1)
#     C_4_8:   0 (fixed)
#     D_4_8:   0 (fixed)
#     A_4_9:   29.3976010 +/- 0        (0.00%) (init= 1)
#     B_4_9:  -43.3463608 +/- 0        (0.00%) (init=-1)
#     C_4_9:   0 (fixed)
#     D_4_9:   0 (fixed)
#     A_5_0:   0 (fixed)
#     B_5_0:   0 (fixed)
#     C_5_0:   0 (fixed)
#     D_5_0:   0 (fixed)
#     A_5_1:   0 (fixed)
#     B_5_1:   0 (fixed)
#     C_5_1:   0 (fixed)
#     D_5_1:   0 (fixed)
#     A_5_2:   0 (fixed)
#     B_5_2:   0 (fixed)
#     C_5_2:   0 (fixed)
#     D_5_2:   0 (fixed)
#     A_5_3:   0 (fixed)
#     B_5_3:   0 (fixed)
#     C_5_3:   0 (fixed)
#     D_5_3:   0 (fixed)
#     A_5_4:   0 (fixed)
#     B_5_4:   0 (fixed)
#     C_5_4:   0 (fixed)
#     D_5_4:   0 (fixed)
#     A_5_5:   569.855196 +/- 0        (0.00%) (init= 1)
#     B_5_5:   16859.8359 +/- 0        (0.00%) (init=-1)
#     C_5_5:   0 (fixed)
#     D_5_5:   0 (fixed)
#     A_5_6:  -1.90805765 +/- 0        (0.00%) (init= 1)
#     B_5_6:  -17.3010916 +/- 0        (0.00%) (init=-1)
#     C_5_6:   0 (fixed)
#     D_5_6:   0 (fixed)
#     A_5_7:   5.75469395 +/- 0        (0.00%) (init= 1)
#     B_5_7:   4.14936212 +/- 0        (0.00%) (init=-1)
#     C_5_7:   0 (fixed)
#     D_5_7:   0 (fixed)
#     A_5_8:   7.85372017 +/- 0        (0.00%) (init= 1)
#     B_5_8:   0.98728249 +/- 0        (0.00%) (init=-1)
#     C_5_8:   0 (fixed)
#     D_5_8:   0 (fixed)
#     A_5_9:  -0.69086859 +/- 0        (0.00%) (init= 1)
#     B_5_9:  -1.82403031 +/- 0        (0.00%) (init=-1)
#     C_5_9:   0 (fixed)
#     D_5_9:   0 (fixed)
#     A_6_0:   0 (fixed)
#     B_6_0:   0 (fixed)
#     C_6_0:   0 (fixed)
#     D_6_0:   0 (fixed)
#     A_6_1:   0 (fixed)
#     B_6_1:   0 (fixed)
#     C_6_1:   0 (fixed)
#     D_6_1:   0 (fixed)
#     A_6_2:   0 (fixed)
#     B_6_2:   0 (fixed)
#     C_6_2:   0 (fixed)
#     D_6_2:   0 (fixed)
#     A_6_3:   0 (fixed)
#     B_6_3:   0 (fixed)
#     C_6_3:   0 (fixed)
#     D_6_3:   0 (fixed)
#     A_6_4:   0 (fixed)
#     B_6_4:   0 (fixed)
#     C_6_4:   0 (fixed)
#     D_6_4:   0 (fixed)
#     A_6_5:   0 (fixed)
#     B_6_5:   0 (fixed)
#     C_6_5:   0 (fixed)
#     D_6_5:   0 (fixed)
#     A_6_6:  -43.3842556 +/- 0        (0.00%) (init= 1)
#     B_6_6:  -6498.03281 +/- 0        (0.00%) (init=-1)
#     C_6_6:   0 (fixed)
#     D_6_6:   0 (fixed)
#     A_6_7:   0.92591272 +/- 0        (0.00%) (init= 1)
#     B_6_7:   8.05774620 +/- 0        (0.00%) (init=-1)
#     C_6_7:   0 (fixed)
#     D_6_7:   0 (fixed)
#     A_6_8:  -1.44744352 +/- 0        (0.00%) (init= 1)
#     B_6_8:  -1.00963948 +/- 0        (0.00%) (init=-1)
#     C_6_8:   0 (fixed)
#     D_6_8:   0 (fixed)
#     A_6_9:  -1.00744198 +/- 0        (0.00%) (init= 1)
#     B_6_9:  -0.21366111 +/- 0        (0.00%) (init=-1)
#     C_6_9:   0 (fixed)
#     D_6_9:   0 (fixed)
#     A_7_0:   0 (fixed)
#     B_7_0:   0 (fixed)
#     C_7_0:   0 (fixed)
#     D_7_0:   0 (fixed)
#     A_7_1:   0 (fixed)
#     B_7_1:   0 (fixed)
#     C_7_1:   0 (fixed)
#     D_7_1:   0 (fixed)
#     A_7_2:   0 (fixed)
#     B_7_2:   0 (fixed)
#     C_7_2:   0 (fixed)
#     D_7_2:   0 (fixed)
#     A_7_3:   0 (fixed)
#     B_7_3:   0 (fixed)
#     C_7_3:   0 (fixed)
#     D_7_3:   0 (fixed)
#     A_7_4:   0 (fixed)
#     B_7_4:   0 (fixed)
#     C_7_4:   0 (fixed)
#     D_7_4:   0 (fixed)
#     A_7_5:   0 (fixed)
#     B_7_5:   0 (fixed)
#     C_7_5:   0 (fixed)
#     D_7_5:   0 (fixed)
#     A_7_6:   0 (fixed)
#     B_7_6:   0 (fixed)
#     C_7_6:   0 (fixed)
#     D_7_6:   0 (fixed)
#     A_7_7:  -25.0554847 +/- 0        (0.00%) (init= 1)
#     B_7_7:   1707.70728 +/- 0        (0.00%) (init=-1)
#     C_7_7:   0 (fixed)
#     D_7_7:   0 (fixed)
#     A_7_8:  -0.27447224 +/- 0        (0.00%) (init= 1)
#     B_7_8:  -2.25513177 +/- 0        (0.00%) (init=-1)
#     C_7_8:   0 (fixed)
#     D_7_8:   0 (fixed)
#     A_7_9:   0.16922154 +/- 0        (0.00%) (init= 1)
#     B_7_9:   0.10835430 +/- 0        (0.00%) (init=-1)
#     C_7_9:   0 (fixed)
#     D_7_9:   0 (fixed)
#     A_8_0:   0 (fixed)
#     B_8_0:   0 (fixed)
#     C_8_0:   0 (fixed)
#     D_8_0:   0 (fixed)
#     A_8_1:   0 (fixed)
#     B_8_1:   0 (fixed)
#     C_8_1:   0 (fixed)
#     D_8_1:   0 (fixed)
#     A_8_2:   0 (fixed)
#     B_8_2:   0 (fixed)
#     C_8_2:   0 (fixed)
#     D_8_2:   0 (fixed)
#     A_8_3:   0 (fixed)
#     B_8_3:   0 (fixed)
#     C_8_3:   0 (fixed)
#     D_8_3:   0 (fixed)
#     A_8_4:   0 (fixed)
#     B_8_4:   0 (fixed)
#     C_8_4:   0 (fixed)
#     D_8_4:   0 (fixed)
#     A_8_5:   0 (fixed)
#     B_8_5:   0 (fixed)
#     C_8_5:   0 (fixed)
#     D_8_5:   0 (fixed)
#     A_8_6:   0 (fixed)
#     B_8_6:   0 (fixed)
#     C_8_6:   0 (fixed)
#     D_8_6:   0 (fixed)
#     A_8_7:   0 (fixed)
#     B_8_7:   0 (fixed)
#     C_8_7:   0 (fixed)
#     D_8_7:   0 (fixed)
#     A_8_8:   9.39405098 +/- 0        (0.00%) (init= 1)
#     B_8_8:  -275.494173 +/- 0        (0.00%) (init=-1)
#     C_8_8:   0 (fixed)
#     D_8_8:   0 (fixed)
#     A_8_9:   0.03891282 +/- 0        (0.00%) (init= 1)
#     B_8_9:   0.29074344 +/- 0        (0.00%) (init=-1)
#     C_8_9:   0 (fixed)
#     D_8_9:   0 (fixed)
#     A_9_0:   0 (fixed)
#     B_9_0:   0 (fixed)
#     C_9_0:   0 (fixed)
#     D_9_0:   0 (fixed)
#     A_9_1:   0 (fixed)
#     B_9_1:   0 (fixed)
#     C_9_1:   0 (fixed)
#     D_9_1:   0 (fixed)
#     A_9_2:   0 (fixed)
#     B_9_2:   0 (fixed)
#     C_9_2:   0 (fixed)
#     D_9_2:   0 (fixed)
#     A_9_3:   0 (fixed)
#     B_9_3:   0 (fixed)
#     C_9_3:   0 (fixed)
#     D_9_3:   0 (fixed)
#     A_9_4:   0 (fixed)
#     B_9_4:   0 (fixed)
#     C_9_4:   0 (fixed)
#     D_9_4:   0 (fixed)
#     A_9_5:   0 (fixed)
#     B_9_5:   0 (fixed)
#     C_9_5:   0 (fixed)
#     D_9_5:   0 (fixed)
#     A_9_6:   0 (fixed)
#     B_9_6:   0 (fixed)
#     C_9_6:   0 (fixed)
#     D_9_6:   0 (fixed)
#     A_9_7:   0 (fixed)
#     B_9_7:   0 (fixed)
#     C_9_7:   0 (fixed)
#     D_9_7:   0 (fixed)
#     A_9_8:   0 (fixed)
#     B_9_8:   0 (fixed)
#     C_9_8:   0 (fixed)
#     D_9_8:   0 (fixed)
#     A_9_9:  -1.12387635 +/- 0        (0.00%) (init= 1)
#     B_9_9:   20.6599110 +/- 0        (0.00%) (init=-1)
#     C_9_9:   0 (fixed)
#     D_9_9:   0 (fixed)

# %%
ff3 = deepcopy(ff)

# %%
labs=[i[2:] for i in ff1.params if ('A' in i and ff1.params[i].vary==True and i.split('_')[1] != '0')]

As_1=[ff1.params[i].value for i in ff1.params if ('A' in i and ff1.params[i].vary==True and i.split('_')[1] != '0')]
As_2=[ff2.params[i].value for i in ff2.params if ('A' in i and ff2.params[i].vary==True and i.split('_')[1] != '0')]
As_3=[ff3.params[i].value for i in ff3.params if ('A' in i and ff3.params[i].vary==True and i.split('_')[1] != '0')]


Bs_1=[ff1.params[i].value for i in ff1.params if ('B' in i and ff1.params[i].vary==True and i.split('_')[1] != '0')]
Bs_2=[ff2.params[i].value for i in ff2.params if ('B' in i and ff2.params[i].vary==True and i.split('_')[1] != '0')]
Bs_3=[ff3.params[i].value for i in ff3.params if ('B' in i and ff3.params[i].vary==True and i.split('_')[1] != '0')]

# %%
_ = plt.plot(range(len(As_1)),As_1, 'o-', label='As, phi=0')
_ = plt.plot(range(len(As_1)),As_2, 'o-', label='As, phi=pi/2')
_ = plt.plot(range(len(As_1)),As_3, 'o-', label='As, phi=pi/8')
_ = plt.axhline(0,0, 1, linestyle='--', color='k')

_ = plt.xticks(range(len(As_1)), labs, rotation='vertical')
plt.yscale('symlog')
plt.legend()
plt.title('Free param values for A')

# %%
_ = plt.plot(range(len(Bs_1)),Bs_1, 'o-', label='Bs, phi=0')
_ = plt.plot(range(len(Bs_1)),Bs_2, 'o-', label='Bs, phi=pi/2')
_ = plt.plot(range(len(Bs_1)),Bs_3, 'o-', label='Bs, phi=pi/8')
_ = plt.axhline(0,0, 1, linestyle='--', color='k')


_ = plt.xticks(range(len(Bs_1)), labs, rotation='vertical')
plt.yscale('symlog')
plt.legend()
plt.title('Free param values for B')

# %%
_ = plt.plot(As_1,As_2, 'o', label='As')
_ = plt.plot(Bs_1,Bs_2, 's', label='Bs')
plt.ylim(-10e7, 10e7)
plt.xlim(-10e7, 10e7)
_ =plt.plot(plt.gca().get_xlim(), plt.gca().get_ylim(), 'k--', zorder=0)
_ =plt.plot(plt.gca().get_xlim(), plt.gca().get_ylim()[::-1], 'k--', zorder=0)

#_ = plt.plot(range(len(Bs_1)),Bs_2, 'o-', label='Bs, 2 slices')
#_ = plt.xticks(range(len(Bs_1)), labs, rotation='vertical')
plt.xscale('symlog')
plt.yscale('symlog')
plt.legend()
plt.title('Free param values, phi=0 vs phi=pi/2')
plt.xlabel('1 slice phi=0')
plt.ylabel('1 slice phi=pi/2')

# %%
_ = plt.plot(As_1,As_3, 'o', color='C2', label='As')
_ = plt.plot(Bs_1,Bs_3, 's', color='C4', label='Bs')
plt.ylim(-10e7, 10e7)
plt.xlim(-10e7, 10e7)
_ =plt.plot(plt.gca().get_xlim(), plt.gca().get_ylim(), 'k--', zorder=0)
_ =plt.plot(plt.gca().get_xlim(), plt.gca().get_ylim()[::-1], 'k--', zorder=0)

#_ = plt.plot(range(len(Bs_1)),Bs_2, 'o-', label='Bs, 2 slices')
#_ = plt.xticks(range(len(Bs_1)), labs, rotation='vertical')
plt.xscale('symlog')
plt.yscale('symlog')
plt.legend()
plt.title('Free param values, phi=0 vs phi=pi/8')
plt.xlabel('1 slice phi=0')
plt.ylabel('1 slice phi=pi/8')

# %%
_ = plt.plot(range(len(Bs_1)),[Bs_1[i]/Bs_2[i] for i in range(len(Bs_2))], 'o-', label='B(phi 0)/B(phi pi/2)')
#_ = plt.plot(range(len(Bs_1)),Bs_1b, 'o-', label='Bs, 1 slice phi=pi/2')
_ = plt.xticks(range(len(Bs_1)), labs, rotation='vertical')
plt.yscale('symlog')
plt.legend()
plt.title('Ratio of B values')

# %%
_ = plt.plot(range(len(As_1)),[As_1[i]/As_2[i] for i in range(len(As_2))], 'o-', label='A(phi 0)/A(phi pi/2)')
#_ = plt.plot(range(len(Bs_1)),Bs_1b, 'o-', label='Bs, 1 slice phi=pi/2')
_ = plt.xticks(range(len(As_1)), labs, rotation='vertical')
plt.yscale('symlog')
plt.legend()
plt.title('Ratio of A values')

# %%
n,m = np.meshgrid(range(11),range(11))
Anm = np.asarray([ff1.params[i] for i in ff1.params if 'A' in i]).reshape(10,10)
Bnm = np.asarray([ff1.params[i] for i in ff1.params if 'B' in i]).reshape(10,10)
Anmb = np.asarray([ff2.params[i] for i in ff1.params if 'A' in i]).reshape(10,10)
Bnmb = np.asarray([ff2.params[i] for i in ff1.params if 'B' in i]).reshape(10,10)
Anm_rat = np.nan_to_num(Anm/Anmb)
Bnm_rat = np.nan_to_num(Bnm/Bnmb)
AB_comb = Anm**2+Bnm**2

# %%
import matplotlib.colors as colors
plt.pcolor(n,m, Anm,
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=Anm.min(), vmax=Anm.max()))
plt.colorbar()
plt.title('Amn for Phi=0')
plt.xlabel('m')
plt.ylabel('n')
plt.figure()
plt.pcolor(n,m, Bnm,
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=Bnm.min(), vmax=Bnm.max()))
plt.colorbar()
plt.title('Bmn for Phi=0')
plt.xlabel('m')
plt.ylabel('n')

# %%
import matplotlib.colors as colors
plt.pcolor(n,m, abs(Anm),
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=0, vmax=Anm.max()))
plt.colorbar()
plt.title('abs(Amn) for Phi=0')
plt.xlabel('m')
plt.ylabel('n')
plt.figure()
plt.pcolor(n,m, abs(Bnm),
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=0, vmax=Bnm.max()))
plt.colorbar()
plt.title('abs(Bmn) for Phi=0')
plt.xlabel('m')
plt.ylabel('n')

# %%
import matplotlib.colors as colors
plt.pcolor(n,m, Anm_rat,
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=Anm_rat.min(), vmax=Anm_rat.max()))
plt.colorbar()
plt.title('Amn (phi=0)/Amn (phi=pi/2)')
plt.xlabel('m')
plt.ylabel('n')
plt.figure()
plt.pcolor(n,m, Bnm_rat,
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=Bnm_rat.min(), vmax=Bnm_rat.max()))
plt.colorbar()
plt.title('Bmn (phi=0)/Bmn (phi=pi/2)')
plt.xlabel('m')
plt.ylabel('n')

# %%
import matplotlib.colors as colors
plt.pcolor(n,m, AB_comb,
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=AB_comb.min(), vmax=AB_comb.max()))
plt.colorbar()
plt.title('Anm^2+Bnm^2, phi=0')
plt.xlabel('m')
plt.ylabel('n')
