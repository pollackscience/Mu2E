# %%
import os
from mu2e import mu2e_ext_path
from mu2e.dataframeprod import DataFrameMaker
from mu2e.mu2eplots import mu2e_plot, mu2e_plot3d
import pandas as pd
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12,8)
from skhep.visual import MplPlotter as splt
from copy import deepcopy
from lmfit import Model, Parameters, report_fit
# Out:
# /usr/local/lib/python3.6/site-packages/IPython/html.py:14: ShimWarning:
#
# The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#
# /usr/local/lib/python3.6/site-packages/plotly/widgets/graph_widget.py:13: UserWarning:
#
# IPython.utils.traitlets has moved to a top-level traitlets package.

# %% [markdown]
# # 1 Slice v 2 Slice

# %%
run hallprobesim.py
# Out:
# 0
# (140, 10)
# 375.0
# 1450.0
# 0.002490821
# 2260594    0.002491
# Name: Br, dtype: float64
# fitting with n=10, m=10, cn=0, cm=0
# Elapsed time was 9.58121 seconds
# [[Fit Statistics]]
#     # function evals   = 1342
#     # data points      = 4200
#     # variables        = 101
#     chi-square         = 0.000
#     reduced chi-square = 0.000
#     Akaike info crit   = -109176.459
#     Bayesian info crit = -108535.832
# [[Variables]]
#     R:       25000 (fixed)
#     ns:      10 (fixed)
#     ms:      10 (fixed)
#     A_0_0:   1          +/- 0        (0.00%) (init= 1)
#     B_0_0:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_0:   0 (fixed)
#     D_0_0:   0 (fixed)
#     A_0_1:   0 (fixed)
#     B_0_1:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_1:   0 (fixed)
#     D_0_1:   0 (fixed)
#     A_0_2:   1          +/- 0        (0.00%) (init= 1)
#     B_0_2:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_2:   0 (fixed)
#     D_0_2:   0 (fixed)
#     A_0_3:   1          +/- 0        (0.00%) (init= 1)
#     B_0_3:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_3:   0 (fixed)
#     D_0_3:   0 (fixed)
#     A_0_4:   1          +/- 0        (0.00%) (init= 1)
#     B_0_4:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_4:   0 (fixed)
#     D_0_4:   0 (fixed)
#     A_0_5:   1          +/- 0        (0.00%) (init= 1)
#     B_0_5:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_5:   0 (fixed)
#     D_0_5:   0 (fixed)
#     A_0_6:   1          +/- 0        (0.00%) (init= 1)
#     B_0_6:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_6:   0 (fixed)
#     D_0_6:   0 (fixed)
#     A_0_7:   1          +/- 0        (0.00%) (init= 1)
#     B_0_7:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_7:   0 (fixed)
#     D_0_7:   0 (fixed)
#     A_0_8:   1          +/- 0        (0.00%) (init= 1)
#     B_0_8:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_8:   0 (fixed)
#     D_0_8:   0 (fixed)
#     A_0_9:   1          +/- 0        (0.00%) (init= 1)
#     B_0_9:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_9:   0 (fixed)
#     D_0_9:   0 (fixed)
#     A_1_0:   0 (fixed)
#     B_1_0:   0 (fixed)
#     C_1_0:   0 (fixed)
#     D_1_0:   0 (fixed)
#     A_1_1:   2254.78594 +/- 0        (0.00%) (init= 1)
#     B_1_1:   99994.3138 +/- 0        (0.00%) (init=-1)
#     C_1_1:   0 (fixed)
#     D_1_1:   0 (fixed)
#     A_1_2:   0 (fixed)
#     B_1_2:  -4.50292679 +/- 0        (0.00%) (init=-1)
#     C_1_2:   0 (fixed)
#     D_1_2:   0 (fixed)
#     A_1_3:   22.8917553 +/- 0        (0.00%) (init= 1)
#     B_1_3:   1.56365603 +/- 0        (0.00%) (init=-1)
#     C_1_3:   0 (fixed)
#     D_1_3:   0 (fixed)
#     A_1_4:   1.73688499 +/- 0        (0.00%) (init= 1)
#     B_1_4:  -296.961282 +/- 0        (0.00%) (init=-1)
#     C_1_4:   0 (fixed)
#     D_1_4:   0 (fixed)
#     A_1_5:   378.775840 +/- 0        (0.00%) (init= 1)
#     B_1_5:  -7680.31887 +/- 0        (0.00%) (init=-1)
#     C_1_5:   0 (fixed)
#     D_1_5:   0 (fixed)
#     A_1_6:  -391.944552 +/- 0        (0.00%) (init= 1)
#     B_1_6:  -14520.2176 +/- 0        (0.00%) (init=-1)
#     C_1_6:   0 (fixed)
#     D_1_6:   0 (fixed)
#     A_1_7:   3.8841e+05 +/- 0        (0.00%) (init= 1)
#     B_1_7:   8.3859e+06 +/- 0        (0.00%) (init=-1)
#     C_1_7:   0 (fixed)
#     D_1_7:   0 (fixed)
#     A_1_8:  -6.0475e+06 +/- 0        (0.00%) (init= 1)
#     B_1_8:  -20.1295212 +/- 0        (0.00%) (init=-1)
#     C_1_8:   0 (fixed)
#     D_1_8:   0 (fixed)
#     A_1_9:   1          +/- 0        (0.00%) (init= 1)
#     B_1_9:  -1          +/- 0        (0.00%) (init=-1)
#     C_1_9:   0 (fixed)
#     D_1_9:   0 (fixed)
#     A_2_0:   0 (fixed)
#     B_2_0:   0 (fixed)
#     C_2_0:   0 (fixed)
#     D_2_0:   0 (fixed)
#     A_2_1:   0 (fixed)
#     B_2_1:   0 (fixed)
#     C_2_1:   0 (fixed)
#     D_2_1:   0 (fixed)
#     A_2_2:  -1365.37880 +/- 0        (0.00%) (init= 1)
#     B_2_2:  -1.4658e+05 +/- 0        (0.00%) (init=-1)
#     C_2_2:   0 (fixed)
#     D_2_2:   0 (fixed)
#     A_2_3:   0 (fixed)
#     B_2_3:   13.3870573 +/- 0        (0.00%) (init=-1)
#     C_2_3:   0 (fixed)
#     D_2_3:   0 (fixed)
#     A_2_4:  -31.8820315 +/- 0        (0.00%) (init= 1)
#     B_2_4:  -2.22474701 +/- 0        (0.00%) (init=-1)
#     C_2_4:   0 (fixed)
#     D_2_4:   0 (fixed)
#     A_2_5:   0.13156644 +/- 0        (0.00%) (init= 1)
#     B_2_5:   152.768917 +/- 0        (0.00%) (init=-1)
#     C_2_5:   0 (fixed)
#     D_2_5:   0 (fixed)
#     A_2_6:  -100.830977 +/- 0        (0.00%) (init= 1)
#     B_2_6:   1240.50529 +/- 0        (0.00%) (init=-1)
#     C_2_6:   0 (fixed)
#     D_2_6:   0 (fixed)
#     A_2_7:  -32.7328934 +/- 0        (0.00%) (init= 1)
#     B_2_7:   793.704799 +/- 0        (0.00%) (init=-1)
#     C_2_7:   0 (fixed)
#     D_2_7:   0 (fixed)
#     A_2_8:   820.640859 +/- 0        (0.00%) (init= 1)
#     B_2_8:  -2.4903e+05 +/- 0        (0.00%) (init=-1)
#     C_2_8:   0 (fixed)
#     D_2_8:   0 (fixed)
#     A_2_9:   40502.3246 +/- 0        (0.00%) (init= 1)
#     B_2_9:  -3148.03902 +/- 0        (0.00%) (init=-1)
#     C_2_9:   0 (fixed)
#     D_2_9:   0 (fixed)
#     A_3_0:   0 (fixed)
#     B_3_0:   0 (fixed)
#     C_3_0:   0 (fixed)
#     D_3_0:   0 (fixed)
#     A_3_1:   0 (fixed)
#     B_3_1:   0 (fixed)
#     C_3_1:   0 (fixed)
#     D_3_1:   0 (fixed)
#     A_3_2:   0 (fixed)
#     B_3_2:   0 (fixed)
#     C_3_2:   0 (fixed)
#     D_3_2:   0 (fixed)
#     A_3_3:   499.751084 +/- 0        (0.00%) (init= 1)
#     B_3_3:   1.3968e+05 +/- 0        (0.00%) (init=-1)
#     C_3_3:   0 (fixed)
#     D_3_3:   0 (fixed)
#     A_3_4:   0 (fixed)
#     B_3_4:  -21.5406534 +/- 0        (0.00%) (init=-1)
#     C_3_4:   0 (fixed)
#     D_3_4:   0 (fixed)
#     A_3_5:   31.5818813 +/- 0        (0.00%) (init= 1)
#     B_3_5:   2.24533177 +/- 0        (0.00%) (init=-1)
#     C_3_5:   0 (fixed)
#     D_3_5:   0 (fixed)
#     A_3_6:  -0.10587417 +/- 0        (0.00%) (init= 1)
#     B_3_6:  -79.0868545 +/- 0        (0.00%) (init=-1)
#     C_3_6:   0 (fixed)
#     D_3_6:   0 (fixed)
#     A_3_7:   21.6805060 +/- 0        (0.00%) (init= 1)
#     B_3_7:  -262.676656 +/- 0        (0.00%) (init=-1)
#     C_3_7:   0 (fixed)
#     D_3_7:   0 (fixed)
#     A_3_8:   6.39791506 +/- 0        (0.00%) (init= 1)
#     B_3_8:  -45.7027992 +/- 0        (0.00%) (init=-1)
#     C_3_8:   0 (fixed)
#     D_3_8:   0 (fixed)
#     A_3_9:  -313.574711 +/- 0        (0.00%) (init= 1)
#     B_3_9:   12251.6328 +/- 0        (0.00%) (init=-1)
#     C_3_9:   0 (fixed)
#     D_3_9:   0 (fixed)
#     A_4_0:   0 (fixed)
#     B_4_0:   0 (fixed)
#     C_4_0:   0 (fixed)
#     D_4_0:   0 (fixed)
#     A_4_1:   0 (fixed)
#     B_4_1:   0 (fixed)
#     C_4_1:   0 (fixed)
#     D_4_1:   0 (fixed)
#     A_4_2:   0 (fixed)
#     B_4_2:   0 (fixed)
#     C_4_2:   0 (fixed)
#     D_4_2:   0 (fixed)
#     A_4_3:   0 (fixed)
#     B_4_3:   0 (fixed)
#     C_4_3:   0 (fixed)
#     D_4_3:   0 (fixed)
#     A_4_4:  -5.68012926 +/- 0        (0.00%) (init= 1)
#     B_4_4:  -96531.4375 +/- 0        (0.00%) (init=-1)
#     C_4_4:   0 (fixed)
#     D_4_4:   0 (fixed)
#     A_4_5:   0 (fixed)
#     B_4_5:   22.5280799 +/- 0        (0.00%) (init=-1)
#     C_4_5:   0 (fixed)
#     D_4_5:   0 (fixed)
#     A_4_6:  -20.9625349 +/- 0        (0.00%) (init= 1)
#     B_4_6:  -1.64655807 +/- 0        (0.00%) (init=-1)
#     C_4_6:   0 (fixed)
#     D_4_6:   0 (fixed)
#     A_4_7:  -0.00300559 +/- 0        (0.00%) (init= 1)
#     B_4_7:   30.8982814 +/- 0        (0.00%) (init=-1)
#     C_4_7:   0 (fixed)
#     D_4_7:   0 (fixed)
#     A_4_8:  -3.21947873 +/- 0        (0.00%) (init= 1)
#     B_4_8:   46.3199020 +/- 0        (0.00%) (init=-1)
#     C_4_8:   0 (fixed)
#     D_4_8:   0 (fixed)
#     A_4_9:  -0.30479919 +/- 0        (0.00%) (init= 1)
#     B_4_9:  -2.25712311 +/- 0        (0.00%) (init=-1)
#     C_4_9:   0 (fixed)
#     D_4_9:   0 (fixed)
#     A_5_0:   0 (fixed)
#     B_5_0:   0 (fixed)
#     C_5_0:   0 (fixed)
#     D_5_0:   0 (fixed)
#     A_5_1:   0 (fixed)
#     B_5_1:   0 (fixed)
#     C_5_1:   0 (fixed)
#     D_5_1:   0 (fixed)
#     A_5_2:   0 (fixed)
#     B_5_2:   0 (fixed)
#     C_5_2:   0 (fixed)
#     D_5_2:   0 (fixed)
#     A_5_3:   0 (fixed)
#     B_5_3:   0 (fixed)
#     C_5_3:   0 (fixed)
#     D_5_3:   0 (fixed)
#     A_5_4:   0 (fixed)
#     B_5_4:   0 (fixed)
#     C_5_4:   0 (fixed)
#     D_5_4:   0 (fixed)
#     A_5_5:  -125.665838 +/- 0        (0.00%) (init= 1)
#     B_5_5:   49428.6732 +/- 0        (0.00%) (init=-1)
#     C_5_5:   0 (fixed)
#     D_5_5:   0 (fixed)
#     A_5_6:   0 (fixed)
#     B_5_6:  -15.8864025 +/- 0        (0.00%) (init=-1)
#     C_5_6:   0 (fixed)
#     D_5_6:   0 (fixed)
#     A_5_7:   9.05797804 +/- 0        (0.00%) (init= 1)
#     B_5_7:   0.82347887 +/- 0        (0.00%) (init=-1)
#     C_5_7:   0 (fixed)
#     D_5_7:   0 (fixed)
#     A_5_8:   0.01042765 +/- 0        (0.00%) (init= 1)
#     B_5_8:  -7.77339954 +/- 0        (0.00%) (init=-1)
#     C_5_8:   0 (fixed)
#     D_5_8:   0 (fixed)
#     A_5_9:   0.32165131 +/- 0        (0.00%) (init= 1)
#     B_5_9:  -5.84120960 +/- 0        (0.00%) (init=-1)
#     C_5_9:   0 (fixed)
#     D_5_9:   0 (fixed)
#     A_6_0:   0 (fixed)
#     B_6_0:   0 (fixed)
#     C_6_0:   0 (fixed)
#     D_6_0:   0 (fixed)
#     A_6_1:   0 (fixed)
#     B_6_1:   0 (fixed)
#     C_6_1:   0 (fixed)
#     D_6_1:   0 (fixed)
#     A_6_2:   0 (fixed)
#     B_6_2:   0 (fixed)
#     C_6_2:   0 (fixed)
#     D_6_2:   0 (fixed)
#     A_6_3:   0 (fixed)
#     B_6_3:   0 (fixed)
#     C_6_3:   0 (fixed)
#     D_6_3:   0 (fixed)
#     A_6_4:   0 (fixed)
#     B_6_4:   0 (fixed)
#     C_6_4:   0 (fixed)
#     D_6_4:   0 (fixed)
#     A_6_5:   0 (fixed)
#     B_6_5:   0 (fixed)
#     C_6_5:   0 (fixed)
#     D_6_5:   0 (fixed)
#     A_6_6:   87.5685330 +/- 0        (0.00%) (init= 1)
#     B_6_6:  -18471.0772 +/- 0        (0.00%) (init=-1)
#     C_6_6:   0 (fixed)
#     D_6_6:   0 (fixed)
#     A_6_7:   0 (fixed)
#     B_6_7:   7.36693905 +/- 0        (0.00%) (init=-1)
#     C_6_7:   0 (fixed)
#     D_6_7:   0 (fixed)
#     A_6_8:  -2.33996231 +/- 0        (0.00%) (init= 1)
#     B_6_8:  -0.25325997 +/- 0        (0.00%) (init=-1)
#     C_6_8:   0 (fixed)
#     D_6_8:   0 (fixed)
#     A_6_9:  -0.00192144 +/- 0        (0.00%) (init= 1)
#     B_6_9:   0.94883072 +/- 0        (0.00%) (init=-1)
#     C_6_9:   0 (fixed)
#     D_6_9:   0 (fixed)
#     A_7_0:   0 (fixed)
#     B_7_0:   0 (fixed)
#     C_7_0:   0 (fixed)
#     D_7_0:   0 (fixed)
#     A_7_1:   0 (fixed)
#     B_7_1:   0 (fixed)
#     C_7_1:   0 (fixed)
#     D_7_1:   0 (fixed)
#     A_7_2:   0 (fixed)
#     B_7_2:   0 (fixed)
#     C_7_2:   0 (fixed)
#     D_7_2:   0 (fixed)
#     A_7_3:   0 (fixed)
#     B_7_3:   0 (fixed)
#     C_7_3:   0 (fixed)
#     D_7_3:   0 (fixed)
#     A_7_4:   0 (fixed)
#     B_7_4:   0 (fixed)
#     C_7_4:   0 (fixed)
#     D_7_4:   0 (fixed)
#     A_7_5:   0 (fixed)
#     B_7_5:   0 (fixed)
#     C_7_5:   0 (fixed)
#     D_7_5:   0 (fixed)
#     A_7_6:   0 (fixed)
#     B_7_6:   0 (fixed)
#     C_7_6:   0 (fixed)
#     D_7_6:   0 (fixed)
#     A_7_7:  -32.7335124 +/- 0        (0.00%) (init= 1)
#     B_7_7:   4802.15575 +/- 0        (0.00%) (init=-1)
#     C_7_7:   0 (fixed)
#     D_7_7:   0 (fixed)
#     A_7_8:   0 (fixed)
#     B_7_8:  -2.05059312 +/- 0        (0.00%) (init=-1)
#     C_7_8:   0 (fixed)
#     D_7_8:   0 (fixed)
#     A_7_9:   0.27796906 +/- 0        (0.00%) (init= 1)
#     B_7_9:   0.04173220 +/- 0        (0.00%) (init=-1)
#     C_7_9:   0 (fixed)
#     D_7_9:   0 (fixed)
#     A_8_0:   0 (fixed)
#     B_8_0:   0 (fixed)
#     C_8_0:   0 (fixed)
#     D_8_0:   0 (fixed)
#     A_8_1:   0 (fixed)
#     B_8_1:   0 (fixed)
#     C_8_1:   0 (fixed)
#     D_8_1:   0 (fixed)
#     A_8_2:   0 (fixed)
#     B_8_2:   0 (fixed)
#     C_8_2:   0 (fixed)
#     D_8_2:   0 (fixed)
#     A_8_3:   0 (fixed)
#     B_8_3:   0 (fixed)
#     C_8_3:   0 (fixed)
#     D_8_3:   0 (fixed)
#     A_8_4:   0 (fixed)
#     B_8_4:   0 (fixed)
#     C_8_4:   0 (fixed)
#     D_8_4:   0 (fixed)
#     A_8_5:   0 (fixed)
#     B_8_5:   0 (fixed)
#     C_8_5:   0 (fixed)
#     D_8_5:   0 (fixed)
#     A_8_6:   0 (fixed)
#     B_8_6:   0 (fixed)
#     C_8_6:   0 (fixed)
#     D_8_6:   0 (fixed)
#     A_8_7:   0 (fixed)
#     B_8_7:   0 (fixed)
#     C_8_7:   0 (fixed)
#     D_8_7:   0 (fixed)
#     A_8_8:   7.01133435 +/- 0        (0.00%) (init= 1)
#     B_8_8:  -781.901734 +/- 0        (0.00%) (init=-1)
#     C_8_8:   0 (fixed)
#     D_8_8:   0 (fixed)
#     A_8_9:   0 (fixed)
#     B_8_9:   0.26240635 +/- 0        (0.00%) (init=-1)
#     C_8_9:   0 (fixed)
#     D_8_9:   0 (fixed)
#     A_9_0:   0 (fixed)
#     B_9_0:   0 (fixed)
#     C_9_0:   0 (fixed)
#     D_9_0:   0 (fixed)
#     A_9_1:   0 (fixed)
#     B_9_1:   0 (fixed)
#     C_9_1:   0 (fixed)
#     D_9_1:   0 (fixed)
#     A_9_2:   0 (fixed)
#     B_9_2:   0 (fixed)
#     C_9_2:   0 (fixed)
#     D_9_2:   0 (fixed)
#     A_9_3:   0 (fixed)
#     B_9_3:   0 (fixed)
#     C_9_3:   0 (fixed)
#     D_9_3:   0 (fixed)
#     A_9_4:   0 (fixed)
#     B_9_4:   0 (fixed)
#     C_9_4:   0 (fixed)
#     D_9_4:   0 (fixed)
#     A_9_5:   0 (fixed)
#     B_9_5:   0 (fixed)
#     C_9_5:   0 (fixed)
#     D_9_5:   0 (fixed)
#     A_9_6:   0 (fixed)
#     B_9_6:   0 (fixed)
#     C_9_6:   0 (fixed)
#     D_9_6:   0 (fixed)
#     A_9_7:   0 (fixed)
#     B_9_7:   0 (fixed)
#     C_9_7:   0 (fixed)
#     D_9_7:   0 (fixed)
#     A_9_8:   0 (fixed)
#     B_9_8:   0 (fixed)
#     C_9_8:   0 (fixed)
#     D_9_8:   0 (fixed)
#     A_9_9:  -0.68743586 +/- 0        (0.00%) (init= 1)
#     B_9_9:   60.4343498 +/- 0        (0.00%) (init=-1)
#     C_9_9:   0 (fixed)
#     D_9_9:   0 (fixed)

# %%
ff1 = deepcopy(ff)

# %%
run hallprobesim.py
# Out:
# 1.5707963267948966
# (140, 10)
# 375.0
# 1450.0
# 0.002531942
# 1732114    0.002532
# Name: Br, dtype: float64
# fitting with n=10, m=10, cn=0, cm=0
# Elapsed time was 6.36 seconds
# [[Fit Statistics]]
#     # function evals   = 836
#     # data points      = 4200
#     # variables        = 101
#     chi-square         = 0.000
#     reduced chi-square = 0.000
#     Akaike info crit   = -108979.589
#     Bayesian info crit = -108338.962
# [[Variables]]
#     R:       25000 (fixed)
#     ns:      10 (fixed)
#     ms:      10 (fixed)
#     A_0_0:   1          +/- 0        (0.00%) (init= 1)
#     B_0_0:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_0:   0 (fixed)
#     D_0_0:   0 (fixed)
#     A_0_1:   0 (fixed)
#     B_0_1:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_1:   0 (fixed)
#     D_0_1:   0 (fixed)
#     A_0_2:   1          +/- 0        (0.00%) (init= 1)
#     B_0_2:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_2:   0 (fixed)
#     D_0_2:   0 (fixed)
#     A_0_3:   1          +/- 0        (0.00%) (init= 1)
#     B_0_3:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_3:   0 (fixed)
#     D_0_3:   0 (fixed)
#     A_0_4:   1          +/- 0        (0.00%) (init= 1)
#     B_0_4:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_4:   0 (fixed)
#     D_0_4:   0 (fixed)
#     A_0_5:   1          +/- 0        (0.00%) (init= 1)
#     B_0_5:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_5:   0 (fixed)
#     D_0_5:   0 (fixed)
#     A_0_6:   1          +/- 0        (0.00%) (init= 1)
#     B_0_6:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_6:   0 (fixed)
#     D_0_6:   0 (fixed)
#     A_0_7:   1          +/- 0        (0.00%) (init= 1)
#     B_0_7:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_7:   0 (fixed)
#     D_0_7:   0 (fixed)
#     A_0_8:   1          +/- 0        (0.00%) (init= 1)
#     B_0_8:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_8:   0 (fixed)
#     D_0_8:   0 (fixed)
#     A_0_9:   1          +/- 0        (0.00%) (init= 1)
#     B_0_9:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_9:   0 (fixed)
#     D_0_9:   0 (fixed)
#     A_1_0:   0 (fixed)
#     B_1_0:   0 (fixed)
#     C_1_0:   0 (fixed)
#     D_1_0:   0 (fixed)
#     A_1_1:   1862.37703 +/- 0        (0.00%) (init= 1)
#     B_1_1:   1.0066e+05 +/- 0        (0.00%) (init=-1)
#     C_1_1:   0 (fixed)
#     D_1_1:   0 (fixed)
#     A_1_2:   0 (fixed)
#     B_1_2:  -5.67604972 +/- 0        (0.00%) (init=-1)
#     C_1_2:   0 (fixed)
#     D_1_2:   0 (fixed)
#     A_1_3:  -23.6273972 +/- 0        (0.00%) (init= 1)
#     B_1_3:  -8.31923410 +/- 0        (0.00%) (init=-1)
#     C_1_3:   0 (fixed)
#     D_1_3:   0 (fixed)
#     A_1_4:  -28.9668722 +/- 0        (0.00%) (init= 1)
#     B_1_4:   191.612025 +/- 0        (0.00%) (init=-1)
#     C_1_4:   0 (fixed)
#     D_1_4:   0 (fixed)
#     A_1_5:   280.596890 +/- 0        (0.00%) (init= 1)
#     B_1_5:  -5972.02838 +/- 0        (0.00%) (init=-1)
#     C_1_5:   0 (fixed)
#     D_1_5:   0 (fixed)
#     A_1_6:  -13542.2820 +/- 0        (0.00%) (init= 1)
#     B_1_6:   70784.4657 +/- 0        (0.00%) (init=-1)
#     C_1_6:   0 (fixed)
#     D_1_6:   0 (fixed)
#     A_1_7:  -2.3186e+05 +/- 0        (0.00%) (init= 1)
#     B_1_7:  -7.5477e+06 +/- 0        (0.00%) (init=-1)
#     C_1_7:   0 (fixed)
#     D_1_7:   0 (fixed)
#     A_1_8:  -3.6439e+07 +/- 0        (0.00%) (init= 1)
#     B_1_8:  -3.4455e+07 +/- 0        (0.00%) (init=-1)
#     C_1_8:   0 (fixed)
#     D_1_8:   0 (fixed)
#     A_1_9:   1          +/- 0        (0.00%) (init= 1)
#     B_1_9:  -1          +/- 0        (0.00%) (init=-1)
#     C_1_9:   0 (fixed)
#     D_1_9:   0 (fixed)
#     A_2_0:   0 (fixed)
#     B_2_0:   0 (fixed)
#     C_2_0:   0 (fixed)
#     D_2_0:   0 (fixed)
#     A_2_1:   0 (fixed)
#     B_2_1:   0 (fixed)
#     C_2_1:   0 (fixed)
#     D_2_1:   0 (fixed)
#     A_2_2:  -930.253679 +/- 0        (0.00%) (init= 1)
#     B_2_2:  -1.4759e+05 +/- 0        (0.00%) (init=-1)
#     C_2_2:   0 (fixed)
#     D_2_2:   0 (fixed)
#     A_2_3:   0 (fixed)
#     B_2_3:   16.7423357 +/- 0        (0.00%) (init=-1)
#     C_2_3:   0 (fixed)
#     D_2_3:   0 (fixed)
#     A_2_4:   32.8324095 +/- 0        (0.00%) (init= 1)
#     B_2_4:   9.11560834 +/- 0        (0.00%) (init=-1)
#     C_2_4:   0 (fixed)
#     D_2_4:   0 (fixed)
#     A_2_5:   14.0927916 +/- 0        (0.00%) (init= 1)
#     B_2_5:  -83.6465698 +/- 0        (0.00%) (init=-1)
#     C_2_5:   0 (fixed)
#     D_2_5:   0 (fixed)
#     A_2_6:  -12.4963554 +/- 0        (0.00%) (init= 1)
#     B_2_6:   923.126817 +/- 0        (0.00%) (init=-1)
#     C_2_6:   0 (fixed)
#     D_2_6:   0 (fixed)
#     A_2_7:   128.931439 +/- 0        (0.00%) (init= 1)
#     B_2_7:  -7590.34484 +/- 0        (0.00%) (init=-1)
#     C_2_7:   0 (fixed)
#     D_2_7:   0 (fixed)
#     A_2_8:   15467.9194 +/- 0        (0.00%) (init= 1)
#     B_2_8:   2.3160e+05 +/- 0        (0.00%) (init=-1)
#     C_2_8:   0 (fixed)
#     D_2_8:   0 (fixed)
#     A_2_9:   1.7087e+05 +/- 0        (0.00%) (init= 1)
#     B_2_9:   1.7291e+05 +/- 0        (0.00%) (init=-1)
#     C_2_9:   0 (fixed)
#     D_2_9:   0 (fixed)
#     A_3_0:   0 (fixed)
#     B_3_0:   0 (fixed)
#     C_3_0:   0 (fixed)
#     D_3_0:   0 (fixed)
#     A_3_1:   0 (fixed)
#     B_3_1:   0 (fixed)
#     C_3_1:   0 (fixed)
#     D_3_1:   0 (fixed)
#     A_3_2:   0 (fixed)
#     B_3_2:   0 (fixed)
#     C_3_2:   0 (fixed)
#     D_3_2:   0 (fixed)
#     A_3_3:   85.8704491 +/- 0        (0.00%) (init= 1)
#     B_3_3:   1.4062e+05 +/- 0        (0.00%) (init=-1)
#     C_3_3:   0 (fixed)
#     D_3_3:   0 (fixed)
#     A_3_4:   0 (fixed)
#     B_3_4:  -27.3174784 +/- 0        (0.00%) (init=-1)
#     C_3_4:   0 (fixed)
#     D_3_4:   0 (fixed)
#     A_3_5:  -32.3879917 +/- 0        (0.00%) (init= 1)
#     B_3_5:  -7.27110678 +/- 0        (0.00%) (init=-1)
#     C_3_5:   0 (fixed)
#     D_3_5:   0 (fixed)
#     A_3_6:  -7.68750054 +/- 0        (0.00%) (init= 1)
#     B_3_6:   35.8171605 +/- 0        (0.00%) (init=-1)
#     C_3_6:   0 (fixed)
#     D_3_6:   0 (fixed)
#     A_3_7:  -0.23214326 +/- 0        (0.00%) (init= 1)
#     B_3_7:  -183.446733 +/- 0        (0.00%) (init=-1)
#     C_3_7:   0 (fixed)
#     D_3_7:   0 (fixed)
#     A_3_8:   12.8704424 +/- 0        (0.00%) (init= 1)
#     B_3_8:   1132.32853 +/- 0        (0.00%) (init=-1)
#     C_3_8:   0 (fixed)
#     D_3_8:   0 (fixed)
#     A_3_9:  -1038.26335 +/- 0        (0.00%) (init= 1)
#     B_3_9:  -11447.8198 +/- 0        (0.00%) (init=-1)
#     C_3_9:   0 (fixed)
#     D_3_9:   0 (fixed)
#     A_4_0:   0 (fixed)
#     B_4_0:   0 (fixed)
#     C_4_0:   0 (fixed)
#     D_4_0:   0 (fixed)
#     A_4_1:   0 (fixed)
#     B_4_1:   0 (fixed)
#     C_4_1:   0 (fixed)
#     D_4_1:   0 (fixed)
#     A_4_2:   0 (fixed)
#     B_4_2:   0 (fixed)
#     C_4_2:   0 (fixed)
#     D_4_2:   0 (fixed)
#     A_4_3:   0 (fixed)
#     B_4_3:   0 (fixed)
#     C_4_3:   0 (fixed)
#     D_4_3:   0 (fixed)
#     A_4_4:   304.299275 +/- 0        (0.00%) (init= 1)
#     B_4_4:  -97165.5994 +/- 0        (0.00%) (init=-1)
#     C_4_4:   0 (fixed)
#     D_4_4:   0 (fixed)
#     A_4_5:   0 (fixed)
#     B_4_5:   29.0683792 +/- 0        (0.00%) (init=-1)
#     C_4_5:   0 (fixed)
#     D_4_5:   0 (fixed)
#     A_4_6:   21.4432567 +/- 0        (0.00%) (init= 1)
#     B_4_6:   4.17664713 +/- 0        (0.00%) (init=-1)
#     C_4_6:   0 (fixed)
#     D_4_6:   0 (fixed)
#     A_4_7:   3.22762001 +/- 0        (0.00%) (init= 1)
#     B_4_7:  -11.1437718 +/- 0        (0.00%) (init=-1)
#     C_4_7:   0 (fixed)
#     D_4_7:   0 (fixed)
#     A_4_8:   0.06648893 +/- 0        (0.00%) (init= 1)
#     B_4_8:   30.9852440 +/- 0        (0.00%) (init=-1)
#     C_4_8:   0 (fixed)
#     D_4_8:   0 (fixed)
#     A_4_9:   0.00782798 +/- 0        (0.00%) (init= 1)
#     B_4_9:  -109.932828 +/- 0        (0.00%) (init=-1)
#     C_4_9:   0 (fixed)
#     D_4_9:   0 (fixed)
#     A_5_0:   0 (fixed)
#     B_5_0:   0 (fixed)
#     C_5_0:   0 (fixed)
#     D_5_0:   0 (fixed)
#     A_5_1:   0 (fixed)
#     B_5_1:   0 (fixed)
#     C_5_1:   0 (fixed)
#     D_5_1:   0 (fixed)
#     A_5_2:   0 (fixed)
#     B_5_2:   0 (fixed)
#     C_5_2:   0 (fixed)
#     D_5_2:   0 (fixed)
#     A_5_3:   0 (fixed)
#     B_5_3:   0 (fixed)
#     C_5_3:   0 (fixed)
#     D_5_3:   0 (fixed)
#     A_5_4:   0 (fixed)
#     B_5_4:   0 (fixed)
#     C_5_4:   0 (fixed)
#     D_5_4:   0 (fixed)
#     A_5_5:  -301.959748 +/- 0        (0.00%) (init= 1)
#     B_5_5:   49747.4524 +/- 0        (0.00%) (init=-1)
#     C_5_5:   0 (fixed)
#     D_5_5:   0 (fixed)
#     A_5_6:   0 (fixed)
#     B_5_6:  -20.8672640 +/- 0        (0.00%) (init=-1)
#     C_5_6:   0 (fixed)
#     D_5_6:   0 (fixed)
#     A_5_7:  -9.25580347 +/- 0        (0.00%) (init= 1)
#     B_5_7:  -1.69143689 +/- 0        (0.00%) (init=-1)
#     C_5_7:   0 (fixed)
#     D_5_7:   0 (fixed)
#     A_5_8:  -0.87350841 +/- 0        (0.00%) (init= 1)
#     B_5_8:   2.12695844 +/- 0        (0.00%) (init=-1)
#     C_5_8:   0 (fixed)
#     D_5_8:   0 (fixed)
#     A_5_9:  -0.07964876 +/- 0        (0.00%) (init= 1)
#     B_5_9:  -4.20977144 +/- 0        (0.00%) (init=-1)
#     C_5_9:   0 (fixed)
#     D_5_9:   0 (fixed)
#     A_6_0:   0 (fixed)
#     B_6_0:   0 (fixed)
#     C_6_0:   0 (fixed)
#     D_6_0:   0 (fixed)
#     A_6_1:   0 (fixed)
#     B_6_1:   0 (fixed)
#     C_6_1:   0 (fixed)
#     D_6_1:   0 (fixed)
#     A_6_2:   0 (fixed)
#     B_6_2:   0 (fixed)
#     C_6_2:   0 (fixed)
#     D_6_2:   0 (fixed)
#     A_6_3:   0 (fixed)
#     B_6_3:   0 (fixed)
#     C_6_3:   0 (fixed)
#     D_6_3:   0 (fixed)
#     A_6_4:   0 (fixed)
#     B_6_4:   0 (fixed)
#     C_6_4:   0 (fixed)
#     D_6_4:   0 (fixed)
#     A_6_5:   0 (fixed)
#     B_6_5:   0 (fixed)
#     C_6_5:   0 (fixed)
#     D_6_5:   0 (fixed)
#     A_6_6:   161.317321 +/- 0        (0.00%) (init= 1)
#     B_6_6:  -18589.2023 +/- 0        (0.00%) (init=-1)
#     C_6_6:   0 (fixed)
#     D_6_6:   0 (fixed)
#     A_6_7:   0 (fixed)
#     B_6_7:   9.85912279 +/- 0        (0.00%) (init=-1)
#     C_6_7:   0 (fixed)
#     D_6_7:   0 (fixed)
#     A_6_8:   2.38966593 +/- 0        (0.00%) (init= 1)
#     B_6_8:   0.44195907 +/- 0        (0.00%) (init=-1)
#     C_6_8:   0 (fixed)
#     D_6_8:   0 (fixed)
#     A_6_9:   0.11526001 +/- 0        (0.00%) (init= 1)
#     B_6_9:  -0.20536780 +/- 0        (0.00%) (init=-1)
#     C_6_9:   0 (fixed)
#     D_6_9:   0 (fixed)
#     A_7_0:   0 (fixed)
#     B_7_0:   0 (fixed)
#     C_7_0:   0 (fixed)
#     D_7_0:   0 (fixed)
#     A_7_1:   0 (fixed)
#     B_7_1:   0 (fixed)
#     C_7_1:   0 (fixed)
#     D_7_1:   0 (fixed)
#     A_7_2:   0 (fixed)
#     B_7_2:   0 (fixed)
#     C_7_2:   0 (fixed)
#     D_7_2:   0 (fixed)
#     A_7_3:   0 (fixed)
#     B_7_3:   0 (fixed)
#     C_7_3:   0 (fixed)
#     D_7_3:   0 (fixed)
#     A_7_4:   0 (fixed)
#     B_7_4:   0 (fixed)
#     C_7_4:   0 (fixed)
#     D_7_4:   0 (fixed)
#     A_7_5:   0 (fixed)
#     B_7_5:   0 (fixed)
#     C_7_5:   0 (fixed)
#     D_7_5:   0 (fixed)
#     A_7_6:   0 (fixed)
#     B_7_6:   0 (fixed)
#     C_7_6:   0 (fixed)
#     D_7_6:   0 (fixed)
#     A_7_7:  -54.2673715 +/- 0        (0.00%) (init= 1)
#     B_7_7:   4832.96927 +/- 0        (0.00%) (init=-1)
#     C_7_7:   0 (fixed)
#     D_7_7:   0 (fixed)
#     A_7_8:   0 (fixed)
#     B_7_8:  -2.80114195 +/- 0        (0.00%) (init=-1)
#     C_7_8:   0 (fixed)
#     D_7_8:   0 (fixed)
#     A_7_9:  -0.28398696 +/- 0        (0.00%) (init= 1)
#     B_7_9:  -0.06136714 +/- 0        (0.00%) (init=-1)
#     C_7_9:   0 (fixed)
#     D_7_9:   0 (fixed)
#     A_8_0:   0 (fixed)
#     B_8_0:   0 (fixed)
#     C_8_0:   0 (fixed)
#     D_8_0:   0 (fixed)
#     A_8_1:   0 (fixed)
#     B_8_1:   0 (fixed)
#     C_8_1:   0 (fixed)
#     D_8_1:   0 (fixed)
#     A_8_2:   0 (fixed)
#     B_8_2:   0 (fixed)
#     C_8_2:   0 (fixed)
#     D_8_2:   0 (fixed)
#     A_8_3:   0 (fixed)
#     B_8_3:   0 (fixed)
#     C_8_3:   0 (fixed)
#     D_8_3:   0 (fixed)
#     A_8_4:   0 (fixed)
#     B_8_4:   0 (fixed)
#     C_8_4:   0 (fixed)
#     D_8_4:   0 (fixed)
#     A_8_5:   0 (fixed)
#     B_8_5:   0 (fixed)
#     C_8_5:   0 (fixed)
#     D_8_5:   0 (fixed)
#     A_8_6:   0 (fixed)
#     B_8_6:   0 (fixed)
#     C_8_6:   0 (fixed)
#     D_8_6:   0 (fixed)
#     A_8_7:   0 (fixed)
#     B_8_7:   0 (fixed)
#     C_8_7:   0 (fixed)
#     D_8_7:   0 (fixed)
#     A_8_8:   10.9579076 +/- 0        (0.00%) (init= 1)
#     B_8_8:  -786.999133 +/- 0        (0.00%) (init=-1)
#     C_8_8:   0 (fixed)
#     D_8_8:   0 (fixed)
#     A_8_9:   0 (fixed)
#     B_8_9:   0.36728487 +/- 0        (0.00%) (init=-1)
#     C_8_9:   0 (fixed)
#     D_8_9:   0 (fixed)
#     A_9_0:   0 (fixed)
#     B_9_0:   0 (fixed)
#     C_9_0:   0 (fixed)
#     D_9_0:   0 (fixed)
#     A_9_1:   0 (fixed)
#     B_9_1:   0 (fixed)
#     C_9_1:   0 (fixed)
#     D_9_1:   0 (fixed)
#     A_9_2:   0 (fixed)
#     B_9_2:   0 (fixed)
#     C_9_2:   0 (fixed)
#     D_9_2:   0 (fixed)
#     A_9_3:   0 (fixed)
#     B_9_3:   0 (fixed)
#     C_9_3:   0 (fixed)
#     D_9_3:   0 (fixed)
#     A_9_4:   0 (fixed)
#     B_9_4:   0 (fixed)
#     C_9_4:   0 (fixed)
#     D_9_4:   0 (fixed)
#     A_9_5:   0 (fixed)
#     B_9_5:   0 (fixed)
#     C_9_5:   0 (fixed)
#     D_9_5:   0 (fixed)
#     A_9_6:   0 (fixed)
#     B_9_6:   0 (fixed)
#     C_9_6:   0 (fixed)
#     D_9_6:   0 (fixed)
#     A_9_7:   0 (fixed)
#     B_9_7:   0 (fixed)
#     C_9_7:   0 (fixed)
#     D_9_7:   0 (fixed)
#     A_9_8:   0 (fixed)
#     B_9_8:   0 (fixed)
#     C_9_8:   0 (fixed)
#     D_9_8:   0 (fixed)
#     A_9_9:  -1.03147776 +/- 0        (0.00%) (init= 1)
#     B_9_9:   60.8398493 +/- 0        (0.00%) (init=-1)
#     C_9_9:   0 (fixed)
#     D_9_9:   0 (fixed)

# %%
ff2 = deepcopy(ff)

# %%
run hallprobesim.py
# Out:
# 0.463648
# (140, 10)
# 335.410196625
# 1450.0
# 0.002255389
# 2155999    0.002255
# Name: Br, dtype: float64
# fitting with n=10, m=10, cn=0, cm=0
# Elapsed time was 7.34936 seconds
# [[Fit Statistics]]
#     # function evals   = 1041
#     # data points      = 4200
#     # variables        = 101
#     chi-square         = 0.000
#     reduced chi-square = 0.000
#     Akaike info crit   = -93542.823
#     Bayesian info crit = -92902.197
# [[Variables]]
#     R:       25000 (fixed)
#     ns:      10 (fixed)
#     ms:      10 (fixed)
#     A_0_0:   1          +/- 0        (0.00%) (init= 1)
#     B_0_0:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_0:   0 (fixed)
#     D_0_0:   0 (fixed)
#     A_0_1:   0 (fixed)
#     B_0_1:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_1:   0 (fixed)
#     D_0_1:   0 (fixed)
#     A_0_2:   1          +/- 0        (0.00%) (init= 1)
#     B_0_2:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_2:   0 (fixed)
#     D_0_2:   0 (fixed)
#     A_0_3:   1          +/- 0        (0.00%) (init= 1)
#     B_0_3:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_3:   0 (fixed)
#     D_0_3:   0 (fixed)
#     A_0_4:   1          +/- 0        (0.00%) (init= 1)
#     B_0_4:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_4:   0 (fixed)
#     D_0_4:   0 (fixed)
#     A_0_5:   1          +/- 0        (0.00%) (init= 1)
#     B_0_5:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_5:   0 (fixed)
#     D_0_5:   0 (fixed)
#     A_0_6:   1          +/- 0        (0.00%) (init= 1)
#     B_0_6:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_6:   0 (fixed)
#     D_0_6:   0 (fixed)
#     A_0_7:   1          +/- 0        (0.00%) (init= 1)
#     B_0_7:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_7:   0 (fixed)
#     D_0_7:   0 (fixed)
#     A_0_8:   1          +/- 0        (0.00%) (init= 1)
#     B_0_8:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_8:   0 (fixed)
#     D_0_8:   0 (fixed)
#     A_0_9:   1          +/- 0        (0.00%) (init= 1)
#     B_0_9:  -1          +/- 0        (0.00%) (init=-1)
#     C_0_9:   0 (fixed)
#     D_0_9:   0 (fixed)
#     A_1_0:   0 (fixed)
#     B_1_0:   0 (fixed)
#     C_1_0:   0 (fixed)
#     D_1_0:   0 (fixed)
#     A_1_1:  -1430.26131 +/- 0        (0.00%) (init= 1)
#     B_1_1:   77140.6595 +/- 0        (0.00%) (init=-1)
#     C_1_1:   0 (fixed)
#     D_1_1:   0 (fixed)
#     A_1_2:   0 (fixed)
#     B_1_2:  -5.06862287 +/- 0        (0.00%) (init=-1)
#     C_1_2:   0 (fixed)
#     D_1_2:   0 (fixed)
#     A_1_3:   14.9303648 +/- 0        (0.00%) (init= 1)
#     B_1_3:  -3.35979614 +/- 0        (0.00%) (init=-1)
#     C_1_3:   0 (fixed)
#     D_1_3:   0 (fixed)
#     A_1_4:   300.342639 +/- 0        (0.00%) (init= 1)
#     B_1_4:  -199.700655 +/- 0        (0.00%) (init=-1)
#     C_1_4:   0 (fixed)
#     D_1_4:   0 (fixed)
#     A_1_5:  -338.633723 +/- 0        (0.00%) (init= 1)
#     B_1_5:   2292.11301 +/- 0        (0.00%) (init=-1)
#     C_1_5:   0 (fixed)
#     D_1_5:   0 (fixed)
#     A_1_6:  -1.1838e+05 +/- 0        (0.00%) (init= 1)
#     B_1_6:   82488.5286 +/- 0        (0.00%) (init=-1)
#     C_1_6:   0 (fixed)
#     D_1_6:   0 (fixed)
#     A_1_7:   1.9234e+06 +/- 0        (0.00%) (init= 1)
#     B_1_7:   1.1251e+06 +/- 0        (0.00%) (init=-1)
#     C_1_7:   0 (fixed)
#     D_1_7:   0 (fixed)
#     A_1_8:   1.7599e+08 +/- 0        (0.00%) (init= 1)
#     B_1_8:  -4507.37042 +/- 0        (0.00%) (init=-1)
#     C_1_8:   0 (fixed)
#     D_1_8:   0 (fixed)
#     A_1_9:   1          +/- 0        (0.00%) (init= 1)
#     B_1_9:  -1          +/- 0        (0.00%) (init=-1)
#     C_1_9:   0 (fixed)
#     D_1_9:   0 (fixed)
#     A_2_0:   0 (fixed)
#     B_2_0:   0 (fixed)
#     C_2_0:   0 (fixed)
#     D_2_0:   0 (fixed)
#     A_2_1:   0 (fixed)
#     B_2_1:   0 (fixed)
#     C_2_1:   0 (fixed)
#     D_2_1:   0 (fixed)
#     A_2_2:   982.573435 +/- 0        (0.00%) (init= 1)
#     B_2_2:  -1.1216e+05 +/- 0        (0.00%) (init=-1)
#     C_2_2:   0 (fixed)
#     D_2_2:   0 (fixed)
#     A_2_3:   0 (fixed)
#     B_2_3:   14.9997032 +/- 0        (0.00%) (init=-1)
#     C_2_3:   0 (fixed)
#     D_2_3:   0 (fixed)
#     A_2_4:  -20.0425403 +/- 0        (0.00%) (init= 1)
#     B_2_4:  -0.02153338 +/- 0        (0.00%) (init=-1)
#     C_2_4:   0 (fixed)
#     D_2_4:   0 (fixed)
#     A_2_5:  -153.800833 +/- 0        (0.00%) (init= 1)
#     B_2_5:   80.9986907 +/- 0        (0.00%) (init=-1)
#     C_2_5:   0 (fixed)
#     D_2_5:   0 (fixed)
#     A_2_6:   21.1123148 +/- 0        (0.00%) (init= 1)
#     B_2_6:  -348.726186 +/- 0        (0.00%) (init=-1)
#     C_2_6:   0 (fixed)
#     D_2_6:   0 (fixed)
#     A_2_7:   8736.53763 +/- 0        (0.00%) (init= 1)
#     B_2_7:  -2915.67572 +/- 0        (0.00%) (init=-1)
#     C_2_7:   0 (fixed)
#     D_2_7:   0 (fixed)
#     A_2_8:  -58312.6615 +/- 0        (0.00%) (init= 1)
#     B_2_8:  -46571.1477 +/- 0        (0.00%) (init=-1)
#     C_2_8:   0 (fixed)
#     D_2_8:   0 (fixed)
#     A_2_9:  -1.5182e+06 +/- 0        (0.00%) (init= 1)
#     B_2_9:  -6.2127e+05 +/- 0        (0.00%) (init=-1)
#     C_2_9:   0 (fixed)
#     D_2_9:   0 (fixed)
#     A_3_0:   0 (fixed)
#     B_3_0:   0 (fixed)
#     C_3_0:   0 (fixed)
#     D_3_0:   0 (fixed)
#     A_3_1:   0 (fixed)
#     B_3_1:   0 (fixed)
#     C_3_1:   0 (fixed)
#     D_3_1:   0 (fixed)
#     A_3_2:   0 (fixed)
#     B_3_2:   0 (fixed)
#     C_3_2:   0 (fixed)
#     D_3_2:   0 (fixed)
#     A_3_3:  -506.780973 +/- 0        (0.00%) (init= 1)
#     B_3_3:   1.0776e+05 +/- 0        (0.00%) (init=-1)
#     C_3_3:   0 (fixed)
#     D_3_3:   0 (fixed)
#     A_3_4:   0 (fixed)
#     B_3_4:  -24.2866518 +/- 0        (0.00%) (init=-1)
#     C_3_4:   0 (fixed)
#     D_3_4:   0 (fixed)
#     A_3_5:   19.3689413 +/- 0        (0.00%) (init= 1)
#     B_3_5:   1.21648719 +/- 0        (0.00%) (init=-1)
#     C_3_5:   0 (fixed)
#     D_3_5:   0 (fixed)
#     A_3_6:   78.8030691 +/- 0        (0.00%) (init= 1)
#     B_3_6:  -33.5137406 +/- 0        (0.00%) (init=-1)
#     C_3_6:   0 (fixed)
#     D_3_6:   0 (fixed)
#     A_3_7:   9.67430319 +/- 0        (0.00%) (init= 1)
#     B_3_7:   68.1445720 +/- 0        (0.00%) (init=-1)
#     C_3_7:   0 (fixed)
#     D_3_7:   0 (fixed)
#     A_3_8:  -863.719241 +/- 0        (0.00%) (init= 1)
#     B_3_8:   151.209837 +/- 0        (0.00%) (init=-1)
#     C_3_8:   0 (fixed)
#     D_3_8:   0 (fixed)
#     A_3_9:   3015.91543 +/- 0        (0.00%) (init= 1)
#     B_3_9:   3227.11979 +/- 0        (0.00%) (init=-1)
#     C_3_9:   0 (fixed)
#     D_3_9:   0 (fixed)
#     A_4_0:   0 (fixed)
#     B_4_0:   0 (fixed)
#     C_4_0:   0 (fixed)
#     D_4_0:   0 (fixed)
#     A_4_1:   0 (fixed)
#     B_4_1:   0 (fixed)
#     C_4_1:   0 (fixed)
#     D_4_1:   0 (fixed)
#     A_4_2:   0 (fixed)
#     B_4_2:   0 (fixed)
#     C_4_2:   0 (fixed)
#     D_4_2:   0 (fixed)
#     A_4_3:   0 (fixed)
#     B_4_3:   0 (fixed)
#     C_4_3:   0 (fixed)
#     D_4_3:   0 (fixed)
#     A_4_4:   180.596787 +/- 0        (0.00%) (init= 1)
#     B_4_4:  -75206.9753 +/- 0        (0.00%) (init=-1)
#     C_4_4:   0 (fixed)
#     D_4_4:   0 (fixed)
#     A_4_5:   0 (fixed)
#     B_4_5:   25.5848397 +/- 0        (0.00%) (init=-1)
#     C_4_5:   0 (fixed)
#     D_4_5:   0 (fixed)
#     A_4_6:  -12.3920370 +/- 0        (0.00%) (init= 1)
#     B_4_6:  -0.35079498 +/- 0        (0.00%) (init=-1)
#     C_4_6:   0 (fixed)
#     D_4_6:   0 (fixed)
#     A_4_7:  -30.8641657 +/- 0        (0.00%) (init= 1)
#     B_4_7:   10.6271087 +/- 0        (0.00%) (init=-1)
#     C_4_7:   0 (fixed)
#     D_4_7:   0 (fixed)
#     A_4_8:  -5.56003540 +/- 0        (0.00%) (init= 1)
#     B_4_8:  -10.6433510 +/- 0        (0.00%) (init=-1)
#     C_4_8:   0 (fixed)
#     D_4_8:   0 (fixed)
#     A_4_9:   84.7649875 +/- 0        (0.00%) (init= 1)
#     B_4_9:  -7.64067985 +/- 0        (0.00%) (init=-1)
#     C_4_9:   0 (fixed)
#     D_4_9:   0 (fixed)
#     A_5_0:   0 (fixed)
#     B_5_0:   0 (fixed)
#     C_5_0:   0 (fixed)
#     D_5_0:   0 (fixed)
#     A_5_1:   0 (fixed)
#     B_5_1:   0 (fixed)
#     C_5_1:   0 (fixed)
#     D_5_1:   0 (fixed)
#     A_5_2:   0 (fixed)
#     B_5_2:   0 (fixed)
#     C_5_2:   0 (fixed)
#     D_5_2:   0 (fixed)
#     A_5_3:   0 (fixed)
#     B_5_3:   0 (fixed)
#     C_5_3:   0 (fixed)
#     D_5_3:   0 (fixed)
#     A_5_4:   0 (fixed)
#     B_5_4:   0 (fixed)
#     C_5_4:   0 (fixed)
#     D_5_4:   0 (fixed)
#     A_5_5:  -33.1255556 +/- 0        (0.00%) (init= 1)
#     B_5_5:   38839.3989 +/- 0        (0.00%) (init=-1)
#     C_5_5:   0 (fixed)
#     D_5_5:   0 (fixed)
#     A_5_6:   0 (fixed)
#     B_5_6:  -18.1658776 +/- 0        (0.00%) (init=-1)
#     C_5_6:   0 (fixed)
#     D_5_6:   0 (fixed)
#     A_5_7:   5.07086015 +/- 0        (0.00%) (init= 1)
#     B_5_7:  -0.44651618 +/- 0        (0.00%) (init=-1)
#     C_5_7:   0 (fixed)
#     D_5_7:   0 (fixed)
#     A_5_8:   7.83555892 +/- 0        (0.00%) (init= 1)
#     B_5_8:  -2.12303584 +/- 0        (0.00%) (init=-1)
#     C_5_8:   0 (fixed)
#     D_5_8:   0 (fixed)
#     A_5_9:   0.46746102 +/- 0        (0.00%) (init= 1)
#     B_5_9:   0.87233890 +/- 0        (0.00%) (init=-1)
#     C_5_9:   0 (fixed)
#     D_5_9:   0 (fixed)
#     A_6_0:   0 (fixed)
#     B_6_0:   0 (fixed)
#     C_6_0:   0 (fixed)
#     D_6_0:   0 (fixed)
#     A_6_1:   0 (fixed)
#     B_6_1:   0 (fixed)
#     C_6_1:   0 (fixed)
#     D_6_1:   0 (fixed)
#     A_6_2:   0 (fixed)
#     B_6_2:   0 (fixed)
#     C_6_2:   0 (fixed)
#     D_6_2:   0 (fixed)
#     A_6_3:   0 (fixed)
#     B_6_3:   0 (fixed)
#     C_6_3:   0 (fixed)
#     D_6_3:   0 (fixed)
#     A_6_4:   0 (fixed)
#     B_6_4:   0 (fixed)
#     C_6_4:   0 (fixed)
#     D_6_4:   0 (fixed)
#     A_6_5:   0 (fixed)
#     B_6_5:   0 (fixed)
#     C_6_5:   0 (fixed)
#     D_6_5:   0 (fixed)
#     A_6_6:  -4.57804380 +/- 0        (0.00%) (init= 1)
#     B_6_6:  -14605.6548 +/- 0        (0.00%) (init=-1)
#     C_6_6:   0 (fixed)
#     D_6_6:   0 (fixed)
#     A_6_7:   0 (fixed)
#     B_6_7:   8.47891074 +/- 0        (0.00%) (init=-1)
#     C_6_7:   0 (fixed)
#     D_6_7:   0 (fixed)
#     A_6_8:  -1.20878166 +/- 0        (0.00%) (init= 1)
#     B_6_8:   0.36471938 +/- 0        (0.00%) (init=-1)
#     C_6_8:   0 (fixed)
#     D_6_8:   0 (fixed)
#     A_6_9:  -0.98087002 +/- 0        (0.00%) (init= 1)
#     B_6_9:   0.21548540 +/- 0        (0.00%) (init=-1)
#     C_6_9:   0 (fixed)
#     D_6_9:   0 (fixed)
#     A_7_0:   0 (fixed)
#     B_7_0:   0 (fixed)
#     C_7_0:   0 (fixed)
#     D_7_0:   0 (fixed)
#     A_7_1:   0 (fixed)
#     B_7_1:   0 (fixed)
#     C_7_1:   0 (fixed)
#     D_7_1:   0 (fixed)
#     A_7_2:   0 (fixed)
#     B_7_2:   0 (fixed)
#     C_7_2:   0 (fixed)
#     D_7_2:   0 (fixed)
#     A_7_3:   0 (fixed)
#     B_7_3:   0 (fixed)
#     C_7_3:   0 (fixed)
#     D_7_3:   0 (fixed)
#     A_7_4:   0 (fixed)
#     B_7_4:   0 (fixed)
#     C_7_4:   0 (fixed)
#     D_7_4:   0 (fixed)
#     A_7_5:   0 (fixed)
#     B_7_5:   0 (fixed)
#     C_7_5:   0 (fixed)
#     D_7_5:   0 (fixed)
#     A_7_6:   0 (fixed)
#     B_7_6:   0 (fixed)
#     C_7_6:   0 (fixed)
#     D_7_6:   0 (fixed)
#     A_7_7:   4.83863963 +/- 0        (0.00%) (init= 1)
#     B_7_7:   3811.91882 +/- 0        (0.00%) (init=-1)
#     C_7_7:   0 (fixed)
#     D_7_7:   0 (fixed)
#     A_7_8:   0 (fixed)
#     B_7_8:  -2.37560369 +/- 0        (0.00%) (init=-1)
#     C_7_8:   0 (fixed)
#     D_7_8:   0 (fixed)
#     A_7_9:   0.12827510 +/- 0        (0.00%) (init= 1)
#     B_7_9:  -0.08622072 +/- 0        (0.00%) (init=-1)
#     C_7_9:   0 (fixed)
#     D_7_9:   0 (fixed)
#     A_8_0:   0 (fixed)
#     B_8_0:   0 (fixed)
#     C_8_0:   0 (fixed)
#     D_8_0:   0 (fixed)
#     A_8_1:   0 (fixed)
#     B_8_1:   0 (fixed)
#     C_8_1:   0 (fixed)
#     D_8_1:   0 (fixed)
#     A_8_2:   0 (fixed)
#     B_8_2:   0 (fixed)
#     C_8_2:   0 (fixed)
#     D_8_2:   0 (fixed)
#     A_8_3:   0 (fixed)
#     B_8_3:   0 (fixed)
#     C_8_3:   0 (fixed)
#     D_8_3:   0 (fixed)
#     A_8_4:   0 (fixed)
#     B_8_4:   0 (fixed)
#     C_8_4:   0 (fixed)
#     D_8_4:   0 (fixed)
#     A_8_5:   0 (fixed)
#     B_8_5:   0 (fixed)
#     C_8_5:   0 (fixed)
#     D_8_5:   0 (fixed)
#     A_8_6:   0 (fixed)
#     B_8_6:   0 (fixed)
#     C_8_6:   0 (fixed)
#     D_8_6:   0 (fixed)
#     A_8_7:   0 (fixed)
#     B_8_7:   0 (fixed)
#     C_8_7:   0 (fixed)
#     D_8_7:   0 (fixed)
#     A_8_8:  -1.31118159 +/- 0        (0.00%) (init= 1)
#     B_8_8:  -621.599330 +/- 0        (0.00%) (init=-1)
#     C_8_8:   0 (fixed)
#     D_8_8:   0 (fixed)
#     A_8_9:   0 (fixed)
#     B_8_9:   0.30607233 +/- 0        (0.00%) (init=-1)
#     C_8_9:   0 (fixed)
#     D_8_9:   0 (fixed)
#     A_9_0:   0 (fixed)
#     B_9_0:   0 (fixed)
#     C_9_0:   0 (fixed)
#     D_9_0:   0 (fixed)
#     A_9_1:   0 (fixed)
#     B_9_1:   0 (fixed)
#     C_9_1:   0 (fixed)
#     D_9_1:   0 (fixed)
#     A_9_2:   0 (fixed)
#     B_9_2:   0 (fixed)
#     C_9_2:   0 (fixed)
#     D_9_2:   0 (fixed)
#     A_9_3:   0 (fixed)
#     B_9_3:   0 (fixed)
#     C_9_3:   0 (fixed)
#     D_9_3:   0 (fixed)
#     A_9_4:   0 (fixed)
#     B_9_4:   0 (fixed)
#     C_9_4:   0 (fixed)
#     D_9_4:   0 (fixed)
#     A_9_5:   0 (fixed)
#     B_9_5:   0 (fixed)
#     C_9_5:   0 (fixed)
#     D_9_5:   0 (fixed)
#     A_9_6:   0 (fixed)
#     B_9_6:   0 (fixed)
#     C_9_6:   0 (fixed)
#     D_9_6:   0 (fixed)
#     A_9_7:   0 (fixed)
#     B_9_7:   0 (fixed)
#     C_9_7:   0 (fixed)
#     D_9_7:   0 (fixed)
#     A_9_8:   0 (fixed)
#     B_9_8:   0 (fixed)
#     C_9_8:   0 (fixed)
#     D_9_8:   0 (fixed)
#     A_9_9:   0.13952393 +/- 0        (0.00%) (init= 1)
#     B_9_9:   48.0094660 +/- 0        (0.00%) (init=-1)
#     C_9_9:   0 (fixed)
#     D_9_9:   0 (fixed)

# %%
ff3 = deepcopy(ff)

# %%
labs=[i[2:] for i in ff1.params if ('A' in i and i.split('_')[1] != '0' and i.split('_')[1]<=i.split('_')[2])]

As_1=np.asarray([ff1.params[i].value for i in ff1.params if ('A' in i and i.split('_')[1] != '0' and i.split('_')[1]<=i.split('_')[2])])
As_2=np.asarray([ff2.params[i].value for i in ff2.params if ('A' in i and i.split('_')[1] != '0' and i.split('_')[1]<=i.split('_')[2])])
As_3=np.asarray([ff3.params[i].value for i in ff3.params if ('A' in i and i.split('_')[1] != '0' and i.split('_')[1]<=i.split('_')[2])])


Bs_1=np.asarray([ff1.params[i].value for i in ff1.params if ('B' in i and i.split('_')[1] != '0' and i.split('_')[1]<=i.split('_')[2])])
Bs_2=np.asarray([ff2.params[i].value for i in ff2.params if ('B' in i and i.split('_')[1] != '0' and i.split('_')[1]<=i.split('_')[2])])
Bs_3=np.asarray([ff3.params[i].value for i in ff3.params if ('B' in i and i.split('_')[1] != '0' and i.split('_')[1]<=i.split('_')[2])])

# %%
_ = plt.plot(range(len(As_1)),As_1, 'o-', label='As, phi=0')
_ = plt.plot(range(len(As_1)),As_2, 'o-', label='As, phi=pi/2')
_ = plt.plot(range(len(As_1)),As_3, 'o-', label='As, phi=pi/8')
_ = plt.axhline(0,0, 1, linestyle='--', color='k')

_ = plt.xticks(range(len(As_1)), labs, rotation='vertical')
plt.yscale('symlog')
plt.legend()
plt.title('Free param values for A')

# %%
_ = plt.plot(range(len(Bs_1)),Bs_1, 'o-', label='Bs, phi=0')
_ = plt.plot(range(len(Bs_1)),Bs_2, 'o-', label='Bs, phi=pi/2')
_ = plt.plot(range(len(Bs_1)),Bs_3, 'o-', label='Bs, phi=pi/8')
_ = plt.axhline(0,0, 1, linestyle='--', color='k')


_ = plt.xticks(range(len(Bs_1)), labs, rotation='vertical')
plt.yscale('symlog')
plt.legend()
plt.title('Free param values for B')

# %%
_ = plt.plot(As_1,As_2, 'o', label='As')
_ = plt.plot(Bs_1,Bs_2, 's', label='Bs')
plt.ylim(-10e7, 10e7)
plt.xlim(-10e7, 10e7)
_ =plt.plot(plt.gca().get_xlim(), plt.gca().get_ylim(), 'k--', zorder=0)
_ =plt.plot(plt.gca().get_xlim(), plt.gca().get_ylim()[::-1], 'k--', zorder=0)

#_ = plt.plot(range(len(Bs_1)),Bs_2, 'o-', label='Bs, 2 slices')
#_ = plt.xticks(range(len(Bs_1)), labs, rotation='vertical')
plt.xscale('symlog')
plt.yscale('symlog')
plt.legend()
plt.title('Free param values, phi=0 vs phi=pi/2')
plt.xlabel('1 slice phi=0')
plt.ylabel('1 slice phi=pi/2')

# %%
_ = plt.plot(As_1,As_3, 'o', color='C2', label='As')
_ = plt.plot(Bs_1,Bs_3, 's', color='C4', label='Bs')
plt.ylim(-10e7, 10e7)
plt.xlim(-10e7, 10e7)
_ =plt.plot(plt.gca().get_xlim(), plt.gca().get_ylim(), 'k--', zorder=0)
_ =plt.plot(plt.gca().get_xlim(), plt.gca().get_ylim()[::-1], 'k--', zorder=0)

#_ = plt.plot(range(len(Bs_1)),Bs_2, 'o-', label='Bs, 2 slices')
#_ = plt.xticks(range(len(Bs_1)), labs, rotation='vertical')
plt.xscale('symlog')
plt.yscale('symlog')
plt.legend()
plt.title('Free param values, phi=0 vs phi=pi/8')
plt.xlabel('1 slice phi=0')
plt.ylabel('1 slice phi=pi/8')

# %%
_ = plt.plot(range(len(Bs_1)),[Bs_1[i]/Bs_2[i] for i in range(len(Bs_2))], 'o-', label='B(phi 0)/B(phi pi/2)')
#_ = plt.plot(range(len(Bs_1)),Bs_1b, 'o-', label='Bs, 1 slice phi=pi/2')
_ = plt.xticks(range(len(Bs_1)), labs, rotation='vertical')
plt.yscale('symlog')
plt.legend()
plt.title('Ratio of B values')

# %%
arat = np.asarray([As_1[i]/As_2[i] for i in range(len(As_2))])
arat[np.isnan(arat)]=1
_ = plt.plot(range(len(As_1)),arat, 'o-', label='A(phi 0)/A(phi pi/2)')
#_ = plt.plot(range(len(Bs_1)),Bs_1b, 'o-', label='Bs, 1 slice phi=pi/2')
_ = plt.xticks(range(len(As_1)), labs, rotation='vertical')
plt.yscale('symlog')
plt.legend()
plt.title('Ratio of A values')

# %%
n,m = np.meshgrid(range(11),range(11))
Anm = np.asarray([ff1.params[i] for i in ff1.params if 'A' in i]).reshape(10,10)
Bnm = np.asarray([ff1.params[i] for i in ff1.params if 'B' in i]).reshape(10,10)
Anmb = np.asarray([ff2.params[i] for i in ff1.params if 'A' in i]).reshape(10,10)
Bnmb = np.asarray([ff2.params[i] for i in ff1.params if 'B' in i]).reshape(10,10)
Anm_rat = np.nan_to_num(Anm/Anmb)
Bnm_rat = np.nan_to_num(Bnm/Bnmb)
AB_comb = Anm**2+Bnm**2

# %%
import matplotlib.colors as colors
plt.pcolor(n,m, Anm,
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=Anm.min(), vmax=Anm.max()))
plt.colorbar()
plt.title('Amn for Phi=0')
plt.xlabel('m')
plt.ylabel('n')
plt.figure()
plt.pcolor(n,m, Bnm,
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=Bnm.min(), vmax=Bnm.max()))
plt.colorbar()
plt.title('Bmn for Phi=0')
plt.xlabel('m')
plt.ylabel('n')

# %%
import matplotlib.colors as colors
plt.pcolor(n,m, abs(Anm),
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=0, vmax=Anm.max()))
plt.colorbar()
plt.title('abs(Amn) for Phi=0')
plt.xlabel('m')
plt.ylabel('n')
plt.figure()
plt.pcolor(n,m, abs(Bnm),
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=0, vmax=Bnm.max()))
plt.colorbar()
plt.title('abs(Bmn) for Phi=0')
plt.xlabel('m')
plt.ylabel('n')

# %%
import matplotlib.colors as colors
plt.pcolor(n,m, Anm_rat,
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=Anm_rat.min(), vmax=Anm_rat.max()))
plt.colorbar()
plt.title('Amn (phi=0)/Amn (phi=pi/2)')
plt.xlabel('m')
plt.ylabel('n')
plt.figure()
plt.pcolor(n,m, Bnm_rat,
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=Bnm_rat.min(), vmax=Bnm_rat.max()))
plt.colorbar()
plt.title('Bmn (phi=0)/Bmn (phi=pi/2)')
plt.xlabel('m')
plt.ylabel('n')

# %%
import matplotlib.colors as colors
plt.pcolor(n,m, AB_comb,
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=AB_comb.min(), vmax=AB_comb.max()))
plt.colorbar()
plt.title('Anm^2+Bnm^2, phi=0')
plt.xlabel('m')
plt.ylabel('n')

# %%
import pickle as pkl
