# %%
import os
from mu2e import mu2e_ext_path
from mu2e.dataframeprod import DataFrameMaker
from mu2e.mu2eplots import mu2e_plot, mu2e_plot3d
import pandas as pd
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12,8)
from skhep.visual import MplPlotter as splt
from copy import deepcopy
from lmfit import Model, Parameters, report_fit
# Out:
# /usr/local/lib/python3.6/site-packages/IPython/html.py:14: ShimWarning:
#
# The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#
# /usr/local/lib/python3.6/site-packages/plotly/widgets/graph_widget.py:13: UserWarning:
#
# IPython.utils.traitlets has moved to a top-level traitlets package.

# %% [markdown]
# # 1 Slice v 1 Slice

# %%
run hallprobesim.py
# Out:
# 0
# (140, 10)
# 375.0
# 1450.0
# 0.002490821
# 2260594    0.002491
# Name: Br, dtype: float64
# fitting with n=20, m=20, cn=0, cm=0
# Elapsed time was 280.612 seconds
# [[Fit Statistics]]
#     # function evals   = 24
#     # data points      = 4200
#     # variables        = 362
#     chi-square         = 0.000
#     reduced chi-square = 0.000
#     Akaike info crit   = -136270.905
#     Bayesian info crit = -133974.797
# [[Variables]]
#     R:         25000 (fixed)
#     ns:        20 (fixed)
#     ms:        20 (fixed)
#     A_0_0:     0 (fixed)
#     B_0_0:     0 (fixed)
#     C_0_0:     0 (fixed)
#     D_0_0:     0 (fixed)
#     A_0_1:     0 (fixed)
#     B_0_1:     0 (fixed)
#     C_0_1:     0 (fixed)
#     D_0_1:     0 (fixed)
#     A_0_2:     0 (fixed)
#     B_0_2:     0 (fixed)
#     C_0_2:     0 (fixed)
#     D_0_2:     0 (fixed)
#     A_0_3:     0 (fixed)
#     B_0_3:     0 (fixed)
#     C_0_3:     0 (fixed)
#     D_0_3:     0 (fixed)
#     A_0_4:     0 (fixed)
#     B_0_4:     0 (fixed)
#     C_0_4:     0 (fixed)
#     D_0_4:     0 (fixed)
#     A_0_5:     0 (fixed)
#     B_0_5:     0 (fixed)
#     C_0_5:     0 (fixed)
#     D_0_5:     0 (fixed)
#     A_0_6:     0 (fixed)
#     B_0_6:     0 (fixed)
#     C_0_6:     0 (fixed)
#     D_0_6:     0 (fixed)
#     A_0_7:     0 (fixed)
#     B_0_7:     0 (fixed)
#     C_0_7:     0 (fixed)
#     D_0_7:     0 (fixed)
#     A_0_8:     0 (fixed)
#     B_0_8:     0 (fixed)
#     C_0_8:     0 (fixed)
#     D_0_8:     0 (fixed)
#     A_0_9:     0 (fixed)
#     B_0_9:     0 (fixed)
#     C_0_9:     0 (fixed)
#     D_0_9:     0 (fixed)
#     A_0_10:    0 (fixed)
#     B_0_10:    0 (fixed)
#     C_0_10:    0 (fixed)
#     D_0_10:    0 (fixed)
#     A_0_11:    0 (fixed)
#     B_0_11:    0 (fixed)
#     C_0_11:    0 (fixed)
#     D_0_11:    0 (fixed)
#     A_0_12:    0 (fixed)
#     B_0_12:    0 (fixed)
#     C_0_12:    0 (fixed)
#     D_0_12:    0 (fixed)
#     A_0_13:    0 (fixed)
#     B_0_13:    0 (fixed)
#     C_0_13:    0 (fixed)
#     D_0_13:    0 (fixed)
#     A_0_14:    0 (fixed)
#     B_0_14:    0 (fixed)
#     C_0_14:    0 (fixed)
#     D_0_14:    0 (fixed)
#     A_0_15:    0 (fixed)
#     B_0_15:    0 (fixed)
#     C_0_15:    0 (fixed)
#     D_0_15:    0 (fixed)
#     A_0_16:    0 (fixed)
#     B_0_16:    0 (fixed)
#     C_0_16:    0 (fixed)
#     D_0_16:    0 (fixed)
#     A_0_17:    0 (fixed)
#     B_0_17:    0 (fixed)
#     C_0_17:    0 (fixed)
#     D_0_17:    0 (fixed)
#     A_0_18:    0 (fixed)
#     B_0_18:    0 (fixed)
#     C_0_18:    0 (fixed)
#     D_0_18:    0 (fixed)
#     A_0_19:    0 (fixed)
#     B_0_19:    0 (fixed)
#     C_0_19:    0 (fixed)
#     D_0_19:    0 (fixed)
#     A_1_0:     0 (fixed)
#     B_1_0:     0 (fixed)
#     C_1_0:     0 (fixed)
#     D_1_0:     0 (fixed)
#     A_1_1:     3.94386565 (init= 1)
#     B_1_1:     7983.61028 (init=-1)
#     C_1_1:     0 (fixed)
#     D_1_1:     0 (fixed)
#     A_1_2:     0 (fixed)
#     B_1_2:     9.76479098 (init=-1)
#     C_1_2:     0 (fixed)
#     D_1_2:     0 (fixed)
#     A_1_3:    -7.87856376 (init= 1)
#     B_1_3:     7.39037480 (init=-1)
#     C_1_3:     0 (fixed)
#     D_1_3:     0 (fixed)
#     A_1_4:    -50.9762004 (init= 1)
#     B_1_4:     3.62996506 (init=-1)
#     C_1_4:     0 (fixed)
#     D_1_4:     0 (fixed)
#     A_1_5:     97.1062030 (init= 1)
#     B_1_5:     1.89318771 (init=-1)
#     C_1_5:     0 (fixed)
#     D_1_5:     0 (fixed)
#     A_1_6:    -12.1548298 (init= 1)
#     B_1_6:     2.86469143 (init=-1)
#     C_1_6:     0 (fixed)
#     D_1_6:     0 (fixed)
#     A_1_7:     36.2355686 (init= 1)
#     B_1_7:     114.840903 (init=-1)
#     C_1_7:     0 (fixed)
#     D_1_7:     0 (fixed)
#     A_1_8:    -11228.2142 (init= 1)
#     B_1_8:     26852.0923 (init=-1)
#     C_1_8:     0 (fixed)
#     D_1_8:     0 (fixed)
#     A_1_9:    -4721.01615 (init= 1)
#     B_1_9:     1295.44976 (init=-1)
#     C_1_9:     0 (fixed)
#     D_1_9:     0 (fixed)
#     A_1_10:   -525.942087 (init= 1)
#     B_1_10:   -715.548456 (init=-1)
#     C_1_10:    0 (fixed)
#     D_1_10:    0 (fixed)
#     A_1_11:    2354.81166 (init= 1)
#     B_1_11:   -360.338778 (init=-1)
#     C_1_11:    0 (fixed)
#     D_1_11:    0 (fixed)
#     A_1_12:    922.401034 (init= 1)
#     B_1_12:    771.737002 (init=-1)
#     C_1_12:    0 (fixed)
#     D_1_12:    0 (fixed)
#     A_1_13:    289.675582 (init= 1)
#     B_1_13:   -69.0543237 (init=-1)
#     C_1_13:    0 (fixed)
#     D_1_13:    0 (fixed)
#     A_1_14:    356.956115 (init= 1)
#     B_1_14:   -1310.84614 (init=-1)
#     C_1_14:    0 (fixed)
#     D_1_14:    0 (fixed)
#     A_1_15:    381.253336 (init= 1)
#     B_1_15:    441.163743 (init=-1)
#     C_1_15:    0 (fixed)
#     D_1_15:    0 (fixed)
#     A_1_16:    892.096734 (init= 1)
#     B_1_16:   -2872.86956 (init=-1)
#     C_1_16:    0 (fixed)
#     D_1_16:    0 (fixed)
#     A_1_17:   -172.183426 (init= 1)
#     B_1_17:    325.061924 (init=-1)
#     C_1_17:    0 (fixed)
#     D_1_17:    0 (fixed)
#     A_1_18:    1224.80792 (init= 1)
#     B_1_18:    1898.04229 (init=-1)
#     C_1_18:    0 (fixed)
#     D_1_18:    0 (fixed)
#     A_1_19:    911.091422 (init= 1)
#     B_1_19:   -989.370860 (init=-1)
#     C_1_19:    0 (fixed)
#     D_1_19:    0 (fixed)
#     A_2_0:     0 (fixed)
#     B_2_0:     0 (fixed)
#     C_2_0:     0 (fixed)
#     D_2_0:     0 (fixed)
#     A_2_1:     0 (fixed)
#     B_2_1:     0 (fixed)
#     C_2_1:     0 (fixed)
#     D_2_1:     0 (fixed)
#     A_2_2:    -1.85151563 (init= 1)
#     B_2_2:    -2592.49436 (init=-1)
#     C_2_2:     0 (fixed)
#     D_2_2:     0 (fixed)
#     A_2_3:     0 (fixed)
#     B_2_3:    -41.1752706 (init=-1)
#     C_2_3:     0 (fixed)
#     D_2_3:     0 (fixed)
#     A_2_4:     16.5005073 (init= 1)
#     B_2_4:    -2.61841398 (init=-1)
#     C_2_4:     0 (fixed)
#     D_2_4:     0 (fixed)
#     A_2_5:     41.9698774 (init= 1)
#     B_2_5:     4.23560405 (init=-1)
#     C_2_5:     0 (fixed)
#     D_2_5:     0 (fixed)
#     A_2_6:    -5.28409651 (init= 1)
#     B_2_6:     17.5749908 (init=-1)
#     C_2_6:     0 (fixed)
#     D_2_6:     0 (fixed)
#     A_2_7:    -22.0218736 (init= 1)
#     B_2_7:     238.076628 (init=-1)
#     C_2_7:     0 (fixed)
#     D_2_7:     0 (fixed)
#     A_2_8:     19.5066533 (init= 1)
#     B_2_8:     75.9588741 (init=-1)
#     C_2_8:     0 (fixed)
#     D_2_8:     0 (fixed)
#     A_2_9:     333.888832 (init= 1)
#     B_2_9:     668.547912 (init=-1)
#     C_2_9:     0 (fixed)
#     D_2_9:     0 (fixed)
#     A_2_10:    68286.3268 (init= 1)
#     B_2_10:   -1327.48512 (init=-1)
#     C_2_10:    0 (fixed)
#     D_2_10:    0 (fixed)
#     A_2_11:    12307.1221 (init= 1)
#     B_2_11:    23561.8477 (init=-1)
#     C_2_11:    0 (fixed)
#     D_2_11:    0 (fixed)
#     A_2_12:    124.994814 (init= 1)
#     B_2_12:    374.353567 (init=-1)
#     C_2_12:    0 (fixed)
#     D_2_12:    0 (fixed)
#     A_2_13:   -329.467345 (init= 1)
#     B_2_13:   -229.849232 (init=-1)
#     C_2_13:    0 (fixed)
#     D_2_13:    0 (fixed)
#     A_2_14:   -1060.74250 (init= 1)
#     B_2_14:    248.793809 (init=-1)
#     C_2_14:    0 (fixed)
#     D_2_14:    0 (fixed)
#     A_2_15:   -1498.86516 (init= 1)
#     B_2_15:   -1796.71065 (init=-1)
#     C_2_15:    0 (fixed)
#     D_2_15:    0 (fixed)
#     A_2_16:    1328.99155 (init= 1)
#     B_2_16:   -1408.38673 (init=-1)
#     C_2_16:    0 (fixed)
#     D_2_16:    0 (fixed)
#     A_2_17:    119.248442 (init= 1)
#     B_2_17:   -1416.48701 (init=-1)
#     C_2_17:    0 (fixed)
#     D_2_17:    0 (fixed)
#     A_2_18:   -663.185913 (init= 1)
#     B_2_18:   -566.975681 (init=-1)
#     C_2_18:    0 (fixed)
#     D_2_18:    0 (fixed)
#     A_2_19:    501.580237 (init= 1)
#     B_2_19:    9.83477814 (init=-1)
#     C_2_19:    0 (fixed)
#     D_2_19:    0 (fixed)
#     A_3_0:     0 (fixed)
#     B_3_0:     0 (fixed)
#     C_3_0:     0 (fixed)
#     D_3_0:     0 (fixed)
#     A_3_1:     0 (fixed)
#     B_3_1:     0 (fixed)
#     C_3_1:     0 (fixed)
#     D_3_1:     0 (fixed)
#     A_3_2:     0 (fixed)
#     B_3_2:     0 (fixed)
#     C_3_2:     0 (fixed)
#     D_3_2:     0 (fixed)
#     A_3_3:     5.55781592 (init= 1)
#     B_3_3:    -278.683696 (init=-1)
#     C_3_3:     0 (fixed)
#     D_3_3:     0 (fixed)
#     A_3_4:     0 (fixed)
#     B_3_4:     100.523611 (init=-1)
#     C_3_4:     0 (fixed)
#     D_3_4:     0 (fixed)
#     A_3_5:    -24.6688876 (init= 1)
#     B_3_5:    -21.7119562 (init=-1)
#     C_3_5:     0 (fixed)
#     D_3_5:     0 (fixed)
#     A_3_6:    -34.8669454 (init= 1)
#     B_3_6:    -9.61468304 (init=-1)
#     C_3_6:     0 (fixed)
#     D_3_6:     0 (fixed)
#     A_3_7:    -0.89525738 (init= 1)
#     B_3_7:     1.63671989 (init=-1)
#     C_3_7:     0 (fixed)
#     D_3_7:     0 (fixed)
#     A_3_8:    -31.2262721 (init= 1)
#     B_3_8:     8.60751130 (init=-1)
#     C_3_8:     0 (fixed)
#     D_3_8:     0 (fixed)
#     A_3_9:    -0.35221651 (init= 1)
#     B_3_9:    -0.48497556 (init=-1)
#     C_3_9:     0 (fixed)
#     D_3_9:     0 (fixed)
#     A_3_10:   -8.07725792 (init= 1)
#     B_3_10:    62.8088628 (init=-1)
#     C_3_10:    0 (fixed)
#     D_3_10:    0 (fixed)
#     A_3_11:    165.578046 (init= 1)
#     B_3_11:    423.933470 (init=-1)
#     C_3_11:    0 (fixed)
#     D_3_11:    0 (fixed)
#     A_3_12:    13187.0638 (init= 1)
#     B_3_12:    135.621946 (init=-1)
#     C_3_12:    0 (fixed)
#     D_3_12:    0 (fixed)
#     A_3_13:   -4654.02257 (init= 1)
#     B_3_13:    3117.93566 (init=-1)
#     C_3_13:    0 (fixed)
#     D_3_13:    0 (fixed)
#     A_3_14:   -351.267124 (init= 1)
#     B_3_14:   -11173.7185 (init=-1)
#     C_3_14:    0 (fixed)
#     D_3_14:    0 (fixed)
#     A_3_15:    298.209862 (init= 1)
#     B_3_15:   -373.292542 (init=-1)
#     C_3_15:    0 (fixed)
#     D_3_15:    0 (fixed)
#     A_3_16:    455.487113 (init= 1)
#     B_3_16:   -457.638105 (init=-1)
#     C_3_16:    0 (fixed)
#     D_3_16:    0 (fixed)
#     A_3_17:   -297.892624 (init= 1)
#     B_3_17:   -218.621165 (init=-1)
#     C_3_17:    0 (fixed)
#     D_3_17:    0 (fixed)
#     A_3_18:    741.043102 (init= 1)
#     B_3_18:   -1421.05028 (init=-1)
#     C_3_18:    0 (fixed)
#     D_3_18:    0 (fixed)
#     A_3_19:    562.566722 (init= 1)
#     B_3_19:   -139.838362 (init=-1)
#     C_3_19:    0 (fixed)
#     D_3_19:    0 (fixed)
#     A_4_0:     0 (fixed)
#     B_4_0:     0 (fixed)
#     C_4_0:     0 (fixed)
#     D_4_0:     0 (fixed)
#     A_4_1:     0 (fixed)
#     B_4_1:     0 (fixed)
#     C_4_1:     0 (fixed)
#     D_4_1:     0 (fixed)
#     A_4_2:     0 (fixed)
#     B_4_2:     0 (fixed)
#     C_4_2:     0 (fixed)
#     D_4_2:     0 (fixed)
#     A_4_3:     0 (fixed)
#     B_4_3:     0 (fixed)
#     C_4_3:     0 (fixed)
#     D_4_3:     0 (fixed)
#     A_4_4:    -7.76295350 (init= 1)
#     B_4_4:     90.7708413 (init=-1)
#     C_4_4:     0 (fixed)
#     D_4_4:     0 (fixed)
#     A_4_5:     0 (fixed)
#     B_4_5:    -145.321268 (init=-1)
#     C_4_5:     0 (fixed)
#     D_4_5:     0 (fixed)
#     A_4_6:     18.7866492 (init= 1)
#     B_4_6:     57.8878891 (init=-1)
#     C_4_6:     0 (fixed)
#     D_4_6:     0 (fixed)
#     A_4_7:     21.6780371 (init= 1)
#     B_4_7:     8.80487033 (init=-1)
#     C_4_7:     0 (fixed)
#     D_4_7:     0 (fixed)
#     A_4_8:    -0.89759729 (init= 1)
#     B_4_8:    -6.52779665 (init=-1)
#     C_4_8:     0 (fixed)
#     D_4_8:     0 (fixed)
#     A_4_9:     68.6500389 (init= 1)
#     B_4_9:    -96.7916233 (init=-1)
#     C_4_9:     0 (fixed)
#     D_4_9:     0 (fixed)
#     A_4_10:    124.276957 (init= 1)
#     B_4_10:    27.3700475 (init=-1)
#     C_4_10:    0 (fixed)
#     D_4_10:    0 (fixed)
#     A_4_11:   -2.34338218 (init= 1)
#     B_4_11:    16.6788077 (init=-1)
#     C_4_11:    0 (fixed)
#     D_4_11:    0 (fixed)
#     A_4_12:    3.67834310 (init= 1)
#     B_4_12:   -57.1834493 (init=-1)
#     C_4_12:    0 (fixed)
#     D_4_12:    0 (fixed)
#     A_4_13:   -502.026745 (init= 1)
#     B_4_13:   -2783.03356 (init=-1)
#     C_4_13:    0 (fixed)
#     D_4_13:    0 (fixed)
#     A_4_14:    5210.95762 (init= 1)
#     B_4_14:   -3278.51667 (init=-1)
#     C_4_14:    0 (fixed)
#     D_4_14:    0 (fixed)
#     A_4_15:   -10751.8700 (init= 1)
#     B_4_15:   -822.956297 (init=-1)
#     C_4_15:    0 (fixed)
#     D_4_15:    0 (fixed)
#     A_4_16:    278.152096 (init= 1)
#     B_4_16:   -713.108611 (init=-1)
#     C_4_16:    0 (fixed)
#     D_4_16:    0 (fixed)
#     A_4_17:   -815.687259 (init= 1)
#     B_4_17:    1318.58591 (init=-1)
#     C_4_17:    0 (fixed)
#     D_4_17:    0 (fixed)
#     A_4_18:   -1738.66250 (init= 1)
#     B_4_18:    11.5383204 (init=-1)
#     C_4_18:    0 (fixed)
#     D_4_18:    0 (fixed)
#     A_4_19:   -590.612007 (init= 1)
#     B_4_19:    238.466558 (init=-1)
#     C_4_19:    0 (fixed)
#     D_4_19:    0 (fixed)
#     A_5_0:     0 (fixed)
#     B_5_0:     0 (fixed)
#     C_5_0:     0 (fixed)
#     D_5_0:     0 (fixed)
#     A_5_1:     0 (fixed)
#     B_5_1:     0 (fixed)
#     C_5_1:     0 (fixed)
#     D_5_1:     0 (fixed)
#     A_5_2:     0 (fixed)
#     B_5_2:     0 (fixed)
#     C_5_2:     0 (fixed)
#     D_5_2:     0 (fixed)
#     A_5_3:     0 (fixed)
#     B_5_3:     0 (fixed)
#     C_5_3:     0 (fixed)
#     D_5_3:     0 (fixed)
#     A_5_4:     0 (fixed)
#     B_5_4:     0 (fixed)
#     C_5_4:     0 (fixed)
#     D_5_4:     0 (fixed)
#     A_5_5:    -0.09180494 (init= 1)
#     B_5_5:     1414.49952 (init=-1)
#     C_5_5:     0 (fixed)
#     D_5_5:     0 (fixed)
#     A_5_6:     0 (fixed)
#     B_5_6:     107.089039 (init=-1)
#     C_5_6:     0 (fixed)
#     D_5_6:     0 (fixed)
#     A_5_7:     0.80935414 (init= 1)
#     B_5_7:    -66.6827594 (init=-1)
#     C_5_7:     0 (fixed)
#     D_5_7:     0 (fixed)
#     A_5_8:    -7.69701347 (init= 1)
#     B_5_8:    -3.63328779 (init=-1)
#     C_5_8:     0 (fixed)
#     D_5_8:     0 (fixed)
#     A_5_9:    -0.93179264 (init= 1)
#     B_5_9:    -1.31722637 (init=-1)
#     C_5_9:     0 (fixed)
#     D_5_9:     0 (fixed)
#     A_5_10:   -93.7512257 (init= 1)
#     B_5_10:    56.0688242 (init=-1)
#     C_5_10:    0 (fixed)
#     D_5_10:    0 (fixed)
#     A_5_11:    0.32374364 (init= 1)
#     B_5_11:    59.4647694 (init=-1)
#     C_5_11:    0 (fixed)
#     D_5_11:    0 (fixed)
#     A_5_12:   -4.62316223 (init= 1)
#     B_5_12:   -0.19858866 (init=-1)
#     C_5_12:    0 (fixed)
#     D_5_12:    0 (fixed)
#     A_5_13:    21.5084797 (init= 1)
#     B_5_13:   -2.65402081 (init=-1)
#     C_5_13:    0 (fixed)
#     D_5_13:    0 (fixed)
#     A_5_14:    270.264333 (init= 1)
#     B_5_14:   -45.7029344 (init=-1)
#     C_5_14:    0 (fixed)
#     D_5_14:    0 (fixed)
#     A_5_15:    2332.67864 (init= 1)
#     B_5_15:   -6144.75162 (init=-1)
#     C_5_15:    0 (fixed)
#     D_5_15:    0 (fixed)
#     A_5_16:    36516.6356 (init= 1)
#     B_5_16:   -14815.1203 (init=-1)
#     C_5_16:    0 (fixed)
#     D_5_16:    0 (fixed)
#     A_5_17:    24216.3979 (init= 1)
#     B_5_17:   -61128.5083 (init=-1)
#     C_5_17:    0 (fixed)
#     D_5_17:    0 (fixed)
#     A_5_18:    181.380874 (init= 1)
#     B_5_18:   -980.840174 (init=-1)
#     C_5_18:    0 (fixed)
#     D_5_18:    0 (fixed)
#     A_5_19:   -1555.00911 (init= 1)
#     B_5_19:    425.303986 (init=-1)
#     C_5_19:    0 (fixed)
#     D_5_19:    0 (fixed)
#     A_6_0:     0 (fixed)
#     B_6_0:     0 (fixed)
#     C_6_0:     0 (fixed)
#     D_6_0:     0 (fixed)
#     A_6_1:     0 (fixed)
#     B_6_1:     0 (fixed)
#     C_6_1:     0 (fixed)
#     D_6_1:     0 (fixed)
#     A_6_2:     0 (fixed)
#     B_6_2:     0 (fixed)
#     C_6_2:     0 (fixed)
#     D_6_2:     0 (fixed)
#     A_6_3:     0 (fixed)
#     B_6_3:     0 (fixed)
#     C_6_3:     0 (fixed)
#     D_6_3:     0 (fixed)
#     A_6_4:     0 (fixed)
#     B_6_4:     0 (fixed)
#     C_6_4:     0 (fixed)
#     D_6_4:     0 (fixed)
#     A_6_5:     0 (fixed)
#     B_6_5:     0 (fixed)
#     C_6_5:     0 (fixed)
#     D_6_5:     0 (fixed)
#     A_6_6:     13.3305743 (init= 1)
#     B_6_6:    -348.966137 (init=-1)
#     C_6_6:     0 (fixed)
#     D_6_6:     0 (fixed)
#     A_6_7:     0 (fixed)
#     B_6_7:     19.0727174 (init=-1)
#     C_6_7:     0 (fixed)
#     D_6_7:     0 (fixed)
#     A_6_8:    -13.5448931 (init= 1)
#     B_6_8:     14.5558112 (init=-1)
#     C_6_8:     0 (fixed)
#     D_6_8:     0 (fixed)
#     A_6_9:     0.14915642 (init= 1)
#     B_6_9:     1.43856843 (init=-1)
#     C_6_9:     0 (fixed)
#     D_6_9:     0 (fixed)
#     A_6_10:    5.07440879 (init= 1)
#     B_6_10:    4.19701891 (init=-1)
#     C_6_10:    0 (fixed)
#     D_6_10:    0 (fixed)
#     A_6_11:    82.0365558 (init= 1)
#     B_6_11:    2.95941670 (init=-1)
#     C_6_11:    0 (fixed)
#     D_6_11:    0 (fixed)
#     A_6_12:   -89.5789013 (init= 1)
#     B_6_12:   -8.06472201 (init=-1)
#     C_6_12:    0 (fixed)
#     D_6_12:    0 (fixed)
#     A_6_13:   -16.7041397 (init= 1)
#     B_6_13:   -0.66714437 (init=-1)
#     C_6_13:    0 (fixed)
#     D_6_13:    0 (fixed)
#     A_6_14:    1.50170198 (init= 1)
#     B_6_14:    7.61357680 (init=-1)
#     C_6_14:    0 (fixed)
#     D_6_14:    0 (fixed)
#     A_6_15:   -27.2300452 (init= 1)
#     B_6_15:    32.8205995 (init=-1)
#     C_6_15:    0 (fixed)
#     D_6_15:    0 (fixed)
#     A_6_16:    832.858499 (init= 1)
#     B_6_16:   -592.581476 (init=-1)
#     C_6_16:    0 (fixed)
#     D_6_16:    0 (fixed)
#     A_6_17:   -3247.81206 (init= 1)
#     B_6_17:    4723.40988 (init=-1)
#     C_6_17:    0 (fixed)
#     D_6_17:    0 (fixed)
#     A_6_18:    46045.8154 (init= 1)
#     B_6_18:   -10416.0669 (init=-1)
#     C_6_18:    0 (fixed)
#     D_6_18:    0 (fixed)
#     A_6_19:   -3838.52707 (init= 1)
#     B_6_19:   -9968.40271 (init=-1)
#     C_6_19:    0 (fixed)
#     D_6_19:    0 (fixed)
#     A_7_0:     0 (fixed)
#     B_7_0:     0 (fixed)
#     C_7_0:     0 (fixed)
#     D_7_0:     0 (fixed)
#     A_7_1:     0 (fixed)
#     B_7_1:     0 (fixed)
#     C_7_1:     0 (fixed)
#     D_7_1:     0 (fixed)
#     A_7_2:     0 (fixed)
#     B_7_2:     0 (fixed)
#     C_7_2:     0 (fixed)
#     D_7_2:     0 (fixed)
#     A_7_3:     0 (fixed)
#     B_7_3:     0 (fixed)
#     C_7_3:     0 (fixed)
#     D_7_3:     0 (fixed)
#     A_7_4:     0 (fixed)
#     B_7_4:     0 (fixed)
#     C_7_4:     0 (fixed)
#     D_7_4:     0 (fixed)
#     A_7_5:     0 (fixed)
#     B_7_5:     0 (fixed)
#     C_7_5:     0 (fixed)
#     D_7_5:     0 (fixed)
#     A_7_6:     0 (fixed)
#     B_7_6:     0 (fixed)
#     C_7_6:     0 (fixed)
#     D_7_6:     0 (fixed)
#     A_7_7:    -19.6789566 (init= 1)
#     B_7_7:    -2708.17705 (init=-1)
#     C_7_7:     0 (fixed)
#     D_7_7:     0 (fixed)
#     A_7_8:     0 (fixed)
#     B_7_8:    -136.796926 (init=-1)
#     C_7_8:     0 (fixed)
#     D_7_8:     0 (fixed)
#     A_7_9:     5.90491485 (init= 1)
#     B_7_9:     73.1122912 (init=-1)
#     C_7_9:     0 (fixed)
#     D_7_9:     0 (fixed)
#     A_7_10:    0.40741898 (init= 1)
#     B_7_10:   -2.48873721 (init=-1)
#     C_7_10:    0 (fixed)
#     D_7_10:    0 (fixed)
#     A_7_11:   -7.20842458 (init= 1)
#     B_7_11:    6.48244741 (init=-1)
#     C_7_11:    0 (fixed)
#     D_7_11:    0 (fixed)
#     A_7_12:   -38.6871716 (init= 1)
#     B_7_12:   -18.4548083 (init=-1)
#     C_7_12:    0 (fixed)
#     D_7_12:    0 (fixed)
#     A_7_13:    68.1483159 (init= 1)
#     B_7_13:   -67.9654570 (init=-1)
#     C_7_13:    0 (fixed)
#     D_7_13:    0 (fixed)
#     A_7_14:   -46.2809287 (init= 1)
#     B_7_14:   -8.14082266 (init=-1)
#     C_7_14:    0 (fixed)
#     D_7_14:    0 (fixed)
#     A_7_15:    71.9090602 (init= 1)
#     B_7_15:   -15.7461313 (init=-1)
#     C_7_15:    0 (fixed)
#     D_7_15:    0 (fixed)
#     A_7_16:    3.90761069 (init= 1)
#     B_7_16:    2.85152304 (init=-1)
#     C_7_16:    0 (fixed)
#     D_7_16:    0 (fixed)
#     A_7_17:    192.593513 (init= 1)
#     B_7_17:   -5.16490852 (init=-1)
#     C_7_17:    0 (fixed)
#     D_7_17:    0 (fixed)
#     A_7_18:    104.077755 (init= 1)
#     B_7_18:    602.738882 (init=-1)
#     C_7_18:    0 (fixed)
#     D_7_18:    0 (fixed)
#     A_7_19:   -2504.42665 (init= 1)
#     B_7_19:    12385.6657 (init=-1)
#     C_7_19:    0 (fixed)
#     D_7_19:    0 (fixed)
#     A_8_0:     0 (fixed)
#     B_8_0:     0 (fixed)
#     C_8_0:     0 (fixed)
#     D_8_0:     0 (fixed)
#     A_8_1:     0 (fixed)
#     B_8_1:     0 (fixed)
#     C_8_1:     0 (fixed)
#     D_8_1:     0 (fixed)
#     A_8_2:     0 (fixed)
#     B_8_2:     0 (fixed)
#     C_8_2:     0 (fixed)
#     D_8_2:     0 (fixed)
#     A_8_3:     0 (fixed)
#     B_8_3:     0 (fixed)
#     C_8_3:     0 (fixed)
#     D_8_3:     0 (fixed)
#     A_8_4:     0 (fixed)
#     B_8_4:     0 (fixed)
#     C_8_4:     0 (fixed)
#     D_8_4:     0 (fixed)
#     A_8_5:     0 (fixed)
#     B_8_5:     0 (fixed)
#     C_8_5:     0 (fixed)
#     D_8_5:     0 (fixed)
#     A_8_6:     0 (fixed)
#     B_8_6:     0 (fixed)
#     C_8_6:     0 (fixed)
#     D_8_6:     0 (fixed)
#     A_8_7:     0 (fixed)
#     B_8_7:     0 (fixed)
#     C_8_7:     0 (fixed)
#     D_8_7:     0 (fixed)
#     A_8_8:     14.7888053 (init= 1)
#     B_8_8:     3264.92689 (init=-1)
#     C_8_8:     0 (fixed)
#     D_8_8:     0 (fixed)
#     A_8_9:     0 (fixed)
#     B_8_9:     146.947255 (init=-1)
#     C_8_9:     0 (fixed)
#     D_8_9:     0 (fixed)
#     A_8_10:    9.70009049 (init= 1)
#     B_8_10:   -122.889935 (init=-1)
#     C_8_10:    0 (fixed)
#     D_8_10:    0 (fixed)
#     A_8_11:    0.28608318 (init= 1)
#     B_8_11:   -2.82750240 (init=-1)
#     C_8_11:    0 (fixed)
#     D_8_11:    0 (fixed)
#     A_8_12:    5.47591611 (init= 1)
#     B_8_12:   -21.1029956 (init=-1)
#     C_8_12:    0 (fixed)
#     D_8_12:    0 (fixed)
#     A_8_13:   -0.83577545 (init= 1)
#     B_8_13:    7.30820078 (init=-1)
#     C_8_13:    0 (fixed)
#     D_8_13:    0 (fixed)
#     A_8_14:   -20.4210998 (init= 1)
#     B_8_14:    67.7953523 (init=-1)
#     C_8_14:    0 (fixed)
#     D_8_14:    0 (fixed)
#     A_8_15:    19.3343771 (init= 1)
#     B_8_15:    12.7977380 (init=-1)
#     C_8_15:    0 (fixed)
#     D_8_15:    0 (fixed)
#     A_8_16:   -54.6350227 (init= 1)
#     B_8_16:   -31.7455352 (init=-1)
#     C_8_16:    0 (fixed)
#     D_8_16:    0 (fixed)
#     A_8_17:    69.7922120 (init= 1)
#     B_8_17:    9.85902613 (init=-1)
#     C_8_17:    0 (fixed)
#     D_8_17:    0 (fixed)
#     A_8_18:   -205.022882 (init= 1)
#     B_8_18:   -1.69172627 (init=-1)
#     C_8_18:    0 (fixed)
#     D_8_18:    0 (fixed)
#     A_8_19:   -19.3381834 (init= 1)
#     B_8_19:   -211.030130 (init=-1)
#     C_8_19:    0 (fixed)
#     D_8_19:    0 (fixed)
#     A_9_0:     0 (fixed)
#     B_9_0:     0 (fixed)
#     C_9_0:     0 (fixed)
#     D_9_0:     0 (fixed)
#     A_9_1:     0 (fixed)
#     B_9_1:     0 (fixed)
#     C_9_1:     0 (fixed)
#     D_9_1:     0 (fixed)
#     A_9_2:     0 (fixed)
#     B_9_2:     0 (fixed)
#     C_9_2:     0 (fixed)
#     D_9_2:     0 (fixed)
#     A_9_3:     0 (fixed)
#     B_9_3:     0 (fixed)
#     C_9_3:     0 (fixed)
#     D_9_3:     0 (fixed)
#     A_9_4:     0 (fixed)
#     B_9_4:     0 (fixed)
#     C_9_4:     0 (fixed)
#     D_9_4:     0 (fixed)
#     A_9_5:     0 (fixed)
#     B_9_5:     0 (fixed)
#     C_9_5:     0 (fixed)
#     D_9_5:     0 (fixed)
#     A_9_6:     0 (fixed)
#     B_9_6:     0 (fixed)
#     C_9_6:     0 (fixed)
#     D_9_6:     0 (fixed)
#     A_9_7:     0 (fixed)
#     B_9_7:     0 (fixed)
#     C_9_7:     0 (fixed)
#     D_9_7:     0 (fixed)
#     A_9_8:     0 (fixed)
#     B_9_8:     0 (fixed)
#     C_9_8:     0 (fixed)
#     D_9_8:     0 (fixed)
#     A_9_9:    -5.02437748 (init= 1)
#     B_9_9:    -24.5464110 (init=-1)
#     C_9_9:     0 (fixed)
#     D_9_9:     0 (fixed)
#     A_9_10:    0 (fixed)
#     B_9_10:   -62.9749101 (init=-1)
#     C_9_10:    0 (fixed)
#     D_9_10:    0 (fixed)
#     A_9_11:   -14.1574799 (init= 1)
#     B_9_11:    90.7491050 (init=-1)
#     C_9_11:    0 (fixed)
#     D_9_11:    0 (fixed)
#     A_9_12:    1.82454758 (init= 1)
#     B_9_12:    18.7803013 (init=-1)
#     C_9_12:    0 (fixed)
#     D_9_12:    0 (fixed)
#     A_9_13:   -1.60026939 (init= 1)
#     B_9_13:    26.2823029 (init=-1)
#     C_9_13:    0 (fixed)
#     D_9_13:    0 (fixed)
#     A_9_14:    16.7564385 (init= 1)
#     B_9_14:   -2.93456330 (init=-1)
#     C_9_14:    0 (fixed)
#     D_9_14:    0 (fixed)
#     A_9_15:    0.89235385 (init= 1)
#     B_9_15:   -22.4933945 (init=-1)
#     C_9_15:    0 (fixed)
#     D_9_15:    0 (fixed)
#     A_9_16:    11.0759981 (init= 1)
#     B_9_16:    3.79664909 (init=-1)
#     C_9_16:    0 (fixed)
#     D_9_16:    0 (fixed)
#     A_9_17:    10.0235533 (init= 1)
#     B_9_17:    26.8450396 (init=-1)
#     C_9_17:    0 (fixed)
#     D_9_17:    0 (fixed)
#     A_9_18:   -5.21874042 (init= 1)
#     B_9_18:   -5.62559119 (init=-1)
#     C_9_18:    0 (fixed)
#     D_9_18:    0 (fixed)
#     A_9_19:    0.88109923 (init= 1)
#     B_9_19:   -8.71677072 (init=-1)
#     C_9_19:    0 (fixed)
#     D_9_19:    0 (fixed)
#     A_10_0:    0 (fixed)
#     B_10_0:    0 (fixed)
#     C_10_0:    0 (fixed)
#     D_10_0:    0 (fixed)
#     A_10_1:    0 (fixed)
#     B_10_1:    0 (fixed)
#     C_10_1:    0 (fixed)
#     D_10_1:    0 (fixed)
#     A_10_2:    0 (fixed)
#     B_10_2:    0 (fixed)
#     C_10_2:    0 (fixed)
#     D_10_2:    0 (fixed)
#     A_10_3:    0 (fixed)
#     B_10_3:    0 (fixed)
#     C_10_3:    0 (fixed)
#     D_10_3:    0 (fixed)
#     A_10_4:    0 (fixed)
#     B_10_4:    0 (fixed)
#     C_10_4:    0 (fixed)
#     D_10_4:    0 (fixed)
#     A_10_5:    0 (fixed)
#     B_10_5:    0 (fixed)
#     C_10_5:    0 (fixed)
#     D_10_5:    0 (fixed)
#     A_10_6:    0 (fixed)
#     B_10_6:    0 (fixed)
#     C_10_6:    0 (fixed)
#     D_10_6:    0 (fixed)
#     A_10_7:    0 (fixed)
#     B_10_7:    0 (fixed)
#     C_10_7:    0 (fixed)
#     D_10_7:    0 (fixed)
#     A_10_8:    0 (fixed)
#     B_10_8:    0 (fixed)
#     C_10_8:    0 (fixed)
#     D_10_8:    0 (fixed)
#     A_10_9:    0 (fixed)
#     B_10_9:    0 (fixed)
#     C_10_9:    0 (fixed)
#     D_10_9:    0 (fixed)
#     A_10_10:  -2.61960468 (init= 1)
#     B_10_10:  -3394.89942 (init=-1)
#     C_10_10:   0 (fixed)
#     D_10_10:   0 (fixed)
#     A_10_11:   0 (fixed)
#     B_10_11:  -16.4332380 (init=-1)
#     C_10_11:   0 (fixed)
#     D_10_11:   0 (fixed)
#     A_10_12:   6.27930832 (init= 1)
#     B_10_12:  -9.15677091 (init=-1)
#     C_10_12:   0 (fixed)
#     D_10_12:   0 (fixed)
#     A_10_13:  -5.10433255 (init= 1)
#     B_10_13:  -34.7823500 (init=-1)
#     C_10_13:   0 (fixed)
#     D_10_13:   0 (fixed)
#     A_10_14:  -1.46530910 (init= 1)
#     B_10_14:  -20.1063371 (init=-1)
#     C_10_14:   0 (fixed)
#     D_10_14:   0 (fixed)
#     A_10_15:  -14.3216280 (init= 1)
#     B_10_15:   7.78883453 (init=-1)
#     C_10_15:   0 (fixed)
#     D_10_15:   0 (fixed)
#     A_10_16:  -0.86057303 (init= 1)
#     B_10_16:  -7.04273980 (init=-1)
#     C_10_16:   0 (fixed)
#     D_10_16:   0 (fixed)
#     A_10_17:  -10.7748509 (init= 1)
#     B_10_17:  -12.2738115 (init=-1)
#     C_10_17:   0 (fixed)
#     D_10_17:   0 (fixed)
#     A_10_18:   6.16971171 (init= 1)
#     B_10_18:  -4.73896556 (init=-1)
#     C_10_18:   0 (fixed)
#     D_10_18:   0 (fixed)
#     A_10_19:   12.0566485 (init= 1)
#     B_10_19:  -79.0340951 (init=-1)
#     C_10_19:   0 (fixed)
#     D_10_19:   0 (fixed)
#     A_11_0:    0 (fixed)
#     B_11_0:    0 (fixed)
#     C_11_0:    0 (fixed)
#     D_11_0:    0 (fixed)
#     A_11_1:    0 (fixed)
#     B_11_1:    0 (fixed)
#     C_11_1:    0 (fixed)
#     D_11_1:    0 (fixed)
#     A_11_2:    0 (fixed)
#     B_11_2:    0 (fixed)
#     C_11_2:    0 (fixed)
#     D_11_2:    0 (fixed)
#     A_11_3:    0 (fixed)
#     B_11_3:    0 (fixed)
#     C_11_3:    0 (fixed)
#     D_11_3:    0 (fixed)
#     A_11_4:    0 (fixed)
#     B_11_4:    0 (fixed)
#     C_11_4:    0 (fixed)
#     D_11_4:    0 (fixed)
#     A_11_5:    0 (fixed)
#     B_11_5:    0 (fixed)
#     C_11_5:    0 (fixed)
#     D_11_5:    0 (fixed)
#     A_11_6:    0 (fixed)
#     B_11_6:    0 (fixed)
#     C_11_6:    0 (fixed)
#     D_11_6:    0 (fixed)
#     A_11_7:    0 (fixed)
#     B_11_7:    0 (fixed)
#     C_11_7:    0 (fixed)
#     D_11_7:    0 (fixed)
#     A_11_8:    0 (fixed)
#     B_11_8:    0 (fixed)
#     C_11_8:    0 (fixed)
#     D_11_8:    0 (fixed)
#     A_11_9:    0 (fixed)
#     B_11_9:    0 (fixed)
#     C_11_9:    0 (fixed)
#     D_11_9:    0 (fixed)
#     A_11_10:   0 (fixed)
#     B_11_10:   0 (fixed)
#     C_11_10:   0 (fixed)
#     D_11_10:   0 (fixed)
#     A_11_11:   6.80937348 (init= 1)
#     B_11_11:   3802.15759 (init=-1)
#     C_11_11:   0 (fixed)
#     D_11_11:   0 (fixed)
#     A_11_12:   0 (fixed)
#     B_11_12:   29.2218824 (init=-1)
#     C_11_12:   0 (fixed)
#     D_11_12:   0 (fixed)
#     A_11_13:   1.82800011 (init= 1)
#     B_11_13:  -54.4943237 (init=-1)
#     C_11_13:   0 (fixed)
#     D_11_13:   0 (fixed)
#     A_11_14:   6.19605658 (init= 1)
#     B_11_14:   37.6999875 (init=-1)
#     C_11_14:   0 (fixed)
#     D_11_14:   0 (fixed)
#     A_11_15:   2.31406464 (init= 1)
#     B_11_15:   10.2699927 (init=-1)
#     C_11_15:   0 (fixed)
#     D_11_15:   0 (fixed)
#     A_11_16:   6.91354036 (init= 1)
#     B_11_16:  -9.52968229 (init=-1)
#     C_11_16:   0 (fixed)
#     D_11_16:   0 (fixed)
#     A_11_17:   1.99702476 (init= 1)
#     B_11_17:   9.65204966 (init=-1)
#     C_11_17:   0 (fixed)
#     D_11_17:   0 (fixed)
#     A_11_18:   2.58015584 (init= 1)
#     B_11_18:   9.45562987 (init=-1)
#     C_11_18:   0 (fixed)
#     D_11_18:   0 (fixed)
#     A_11_19:  -3.01633826 (init= 1)
#     B_11_19:  -2.30655266 (init=-1)
#     C_11_19:   0 (fixed)
#     D_11_19:   0 (fixed)
#     A_12_0:    0 (fixed)
#     B_12_0:    0 (fixed)
#     C_12_0:    0 (fixed)
#     D_12_0:    0 (fixed)
#     A_12_1:    0 (fixed)
#     B_12_1:    0 (fixed)
#     C_12_1:    0 (fixed)
#     D_12_1:    0 (fixed)
#     A_12_2:    0 (fixed)
#     B_12_2:    0 (fixed)
#     C_12_2:    0 (fixed)
#     D_12_2:    0 (fixed)
#     A_12_3:    0 (fixed)
#     B_12_3:    0 (fixed)
#     C_12_3:    0 (fixed)
#     D_12_3:    0 (fixed)
#     A_12_4:    0 (fixed)
#     B_12_4:    0 (fixed)
#     C_12_4:    0 (fixed)
#     D_12_4:    0 (fixed)
#     A_12_5:    0 (fixed)
#     B_12_5:    0 (fixed)
#     C_12_5:    0 (fixed)
#     D_12_5:    0 (fixed)
#     A_12_6:    0 (fixed)
#     B_12_6:    0 (fixed)
#     C_12_6:    0 (fixed)
#     D_12_6:    0 (fixed)
#     A_12_7:    0 (fixed)
#     B_12_7:    0 (fixed)
#     C_12_7:    0 (fixed)
#     D_12_7:    0 (fixed)
#     A_12_8:    0 (fixed)
#     B_12_8:    0 (fixed)
#     C_12_8:    0 (fixed)
#     D_12_8:    0 (fixed)
#     A_12_9:    0 (fixed)
#     B_12_9:    0 (fixed)
#     C_12_9:    0 (fixed)
#     D_12_9:    0 (fixed)
#     A_12_10:   0 (fixed)
#     B_12_10:   0 (fixed)
#     C_12_10:   0 (fixed)
#     D_12_10:   0 (fixed)
#     A_12_11:   0 (fixed)
#     B_12_11:   0 (fixed)
#     C_12_11:   0 (fixed)
#     D_12_11:   0 (fixed)
#     A_12_12:  -8.80729107 (init= 1)
#     B_12_12:  -1866.60503 (init=-1)
#     C_12_12:   0 (fixed)
#     D_12_12:   0 (fixed)
#     A_12_13:   0 (fixed)
#     B_12_13:   1.36379589 (init=-1)
#     C_12_13:   0 (fixed)
#     D_12_13:   0 (fixed)
#     A_12_14:  -3.38008774 (init= 1)
#     B_12_14:   67.2391694 (init=-1)
#     C_12_14:   0 (fixed)
#     D_12_14:   0 (fixed)
#     A_12_15:  -4.60310662 (init= 1)
#     B_12_15:  -27.2358971 (init=-1)
#     C_12_15:   0 (fixed)
#     D_12_15:   0 (fixed)
#     A_12_16:  -1.61426607 (init= 1)
#     B_12_16:  -3.45115236 (init=-1)
#     C_12_16:   0 (fixed)
#     D_12_16:   0 (fixed)
#     A_12_17:  -2.06427971 (init= 1)
#     B_12_17:   5.75664890 (init=-1)
#     C_12_17:   0 (fixed)
#     D_12_17:   0 (fixed)
#     A_12_18:  -0.98477230 (init= 1)
#     B_12_18:  -3.69371445 (init=-1)
#     C_12_18:   0 (fixed)
#     D_12_18:   0 (fixed)
#     A_12_19:  -0.08295157 (init= 1)
#     B_12_19:  -2.20549874 (init=-1)
#     C_12_19:   0 (fixed)
#     D_12_19:   0 (fixed)
#     A_13_0:    0 (fixed)
#     B_13_0:    0 (fixed)
#     C_13_0:    0 (fixed)
#     D_13_0:    0 (fixed)
#     A_13_1:    0 (fixed)
#     B_13_1:    0 (fixed)
#     C_13_1:    0 (fixed)
#     D_13_1:    0 (fixed)
#     A_13_2:    0 (fixed)
#     B_13_2:    0 (fixed)
#     C_13_2:    0 (fixed)
#     D_13_2:    0 (fixed)
#     A_13_3:    0 (fixed)
#     B_13_3:    0 (fixed)
#     C_13_3:    0 (fixed)
#     D_13_3:    0 (fixed)
#     A_13_4:    0 (fixed)
#     B_13_4:    0 (fixed)
#     C_13_4:    0 (fixed)
#     D_13_4:    0 (fixed)
#     A_13_5:    0 (fixed)
#     B_13_5:    0 (fixed)
#     C_13_5:    0 (fixed)
#     D_13_5:    0 (fixed)
#     A_13_6:    0 (fixed)
#     B_13_6:    0 (fixed)
#     C_13_6:    0 (fixed)
#     D_13_6:    0 (fixed)
#     A_13_7:    0 (fixed)
#     B_13_7:    0 (fixed)
#     C_13_7:    0 (fixed)
#     D_13_7:    0 (fixed)
#     A_13_8:    0 (fixed)
#     B_13_8:    0 (fixed)
#     C_13_8:    0 (fixed)
#     D_13_8:    0 (fixed)
#     A_13_9:    0 (fixed)
#     B_13_9:    0 (fixed)
#     C_13_9:    0 (fixed)
#     D_13_9:    0 (fixed)
#     A_13_10:   0 (fixed)
#     B_13_10:   0 (fixed)
#     C_13_10:   0 (fixed)
#     D_13_10:   0 (fixed)
#     A_13_11:   0 (fixed)
#     B_13_11:   0 (fixed)
#     C_13_11:   0 (fixed)
#     D_13_11:   0 (fixed)
#     A_13_12:   0 (fixed)
#     B_13_12:   0 (fixed)
#     C_13_12:   0 (fixed)
#     D_13_12:   0 (fixed)
#     A_13_13:   8.82059073 (init= 1)
#     B_13_13:  -1.85826106 (init=-1)
#     C_13_13:   0 (fixed)
#     D_13_13:   0 (fixed)
#     A_13_14:   0 (fixed)
#     B_13_14:  -25.1850453 (init=-1)
#     C_13_14:   0 (fixed)
#     D_13_14:   0 (fixed)
#     A_13_15:   1.26144627 (init= 1)
#     B_13_15:  -45.6492783 (init=-1)
#     C_13_15:   0 (fixed)
#     D_13_15:   0 (fixed)
#     A_13_16:   2.26220814 (init= 1)
#     B_13_16:   13.5043207 (init=-1)
#     C_13_16:   0 (fixed)
#     D_13_16:   0 (fixed)
#     A_13_17:   0.67747801 (init= 1)
#     B_13_17:   0.67556700 (init=-1)
#     C_13_17:   0 (fixed)
#     D_13_17:   0 (fixed)
#     A_13_18:   0.35006855 (init= 1)
#     B_13_18:  -1.84306067 (init=-1)
#     C_13_18:   0 (fixed)
#     D_13_18:   0 (fixed)
#     A_13_19:   0.17718690 (init= 1)
#     B_13_19:   0.56351460 (init=-1)
#     C_13_19:   0 (fixed)
#     D_13_19:   0 (fixed)
#     A_14_0:    0 (fixed)
#     B_14_0:    0 (fixed)
#     C_14_0:    0 (fixed)
#     D_14_0:    0 (fixed)
#     A_14_1:    0 (fixed)
#     B_14_1:    0 (fixed)
#     C_14_1:    0 (fixed)
#     D_14_1:    0 (fixed)
#     A_14_2:    0 (fixed)
#     B_14_2:    0 (fixed)
#     C_14_2:    0 (fixed)
#     D_14_2:    0 (fixed)
#     A_14_3:    0 (fixed)
#     B_14_3:    0 (fixed)
#     C_14_3:    0 (fixed)
#     D_14_3:    0 (fixed)
#     A_14_4:    0 (fixed)
#     B_14_4:    0 (fixed)
#     C_14_4:    0 (fixed)
#     D_14_4:    0 (fixed)
#     A_14_5:    0 (fixed)
#     B_14_5:    0 (fixed)
#     C_14_5:    0 (fixed)
#     D_14_5:    0 (fixed)
#     A_14_6:    0 (fixed)
#     B_14_6:    0 (fixed)
#     C_14_6:    0 (fixed)
#     D_14_6:    0 (fixed)
#     A_14_7:    0 (fixed)
#     B_14_7:    0 (fixed)
#     C_14_7:    0 (fixed)
#     D_14_7:    0 (fixed)
#     A_14_8:    0 (fixed)
#     B_14_8:    0 (fixed)
#     C_14_8:    0 (fixed)
#     D_14_8:    0 (fixed)
#     A_14_9:    0 (fixed)
#     B_14_9:    0 (fixed)
#     C_14_9:    0 (fixed)
#     D_14_9:    0 (fixed)
#     A_14_10:   0 (fixed)
#     B_14_10:   0 (fixed)
#     C_14_10:   0 (fixed)
#     D_14_10:   0 (fixed)
#     A_14_11:   0 (fixed)
#     B_14_11:   0 (fixed)
#     C_14_11:   0 (fixed)
#     D_14_11:   0 (fixed)
#     A_14_12:   0 (fixed)
#     B_14_12:   0 (fixed)
#     C_14_12:   0 (fixed)
#     D_14_12:   0 (fixed)
#     A_14_13:   0 (fixed)
#     B_14_13:   0 (fixed)
#     C_14_13:   0 (fixed)
#     D_14_13:   0 (fixed)
#     A_14_14:  -6.81546219 (init= 1)
#     B_14_14:   659.358287 (init=-1)
#     C_14_14:   0 (fixed)
#     D_14_14:   0 (fixed)
#     A_14_15:   0 (fixed)
#     B_14_15:   24.8865143 (init=-1)
#     C_14_15:   0 (fixed)
#     D_14_15:   0 (fixed)
#     A_14_16:   0.25669029 (init= 1)
#     B_14_16:   20.3480884 (init=-1)
#     C_14_16:   0 (fixed)
#     D_14_16:   0 (fixed)
#     A_14_17:  -0.73023446 (init= 1)
#     B_14_17:  -4.49010171 (init=-1)
#     C_14_17:   0 (fixed)
#     D_14_17:   0 (fixed)
#     A_14_18:  -0.16575379 (init= 1)
#     B_14_18:  -0.04347346 (init=-1)
#     C_14_18:   0 (fixed)
#     D_14_18:   0 (fixed)
#     A_14_19:  -0.02644334 (init= 1)
#     B_14_19:   0.26172631 (init=-1)
#     C_14_19:   0 (fixed)
#     D_14_19:   0 (fixed)
#     A_15_0:    0 (fixed)
#     B_15_0:    0 (fixed)
#     C_15_0:    0 (fixed)
#     D_15_0:    0 (fixed)
#     A_15_1:    0 (fixed)
#     B_15_1:    0 (fixed)
#     C_15_1:    0 (fixed)
#     D_15_1:    0 (fixed)
#     A_15_2:    0 (fixed)
#     B_15_2:    0 (fixed)
#     C_15_2:    0 (fixed)
#     D_15_2:    0 (fixed)
#     A_15_3:    0 (fixed)
#     B_15_3:    0 (fixed)
#     C_15_3:    0 (fixed)
#     D_15_3:    0 (fixed)
#     A_15_4:    0 (fixed)
#     B_15_4:    0 (fixed)
#     C_15_4:    0 (fixed)
#     D_15_4:    0 (fixed)
#     A_15_5:    0 (fixed)
#     B_15_5:    0 (fixed)
#     C_15_5:    0 (fixed)
#     D_15_5:    0 (fixed)
#     A_15_6:    0 (fixed)
#     B_15_6:    0 (fixed)
#     C_15_6:    0 (fixed)
#     D_15_6:    0 (fixed)
#     A_15_7:    0 (fixed)
#     B_15_7:    0 (fixed)
#     C_15_7:    0 (fixed)
#     D_15_7:    0 (fixed)
#     A_15_8:    0 (fixed)
#     B_15_8:    0 (fixed)
#     C_15_8:    0 (fixed)
#     D_15_8:    0 (fixed)
#     A_15_9:    0 (fixed)
#     B_15_9:    0 (fixed)
#     C_15_9:    0 (fixed)
#     D_15_9:    0 (fixed)
#     A_15_10:   0 (fixed)
#     B_15_10:   0 (fixed)
#     C_15_10:   0 (fixed)
#     D_15_10:   0 (fixed)
#     A_15_11:   0 (fixed)
#     B_15_11:   0 (fixed)
#     C_15_11:   0 (fixed)
#     D_15_11:   0 (fixed)
#     A_15_12:   0 (fixed)
#     B_15_12:   0 (fixed)
#     C_15_12:   0 (fixed)
#     D_15_12:   0 (fixed)
#     A_15_13:   0 (fixed)
#     B_15_13:   0 (fixed)
#     C_15_13:   0 (fixed)
#     D_15_13:   0 (fixed)
#     A_15_14:   0 (fixed)
#     B_15_14:   0 (fixed)
#     C_15_14:   0 (fixed)
#     D_15_14:   0 (fixed)
#     A_15_15:   3.93818842 (init= 1)
#     B_15_15:  -502.191399 (init=-1)
#     C_15_15:   0 (fixed)
#     D_15_15:   0 (fixed)
#     A_15_16:   0 (fixed)
#     B_15_16:  -13.3722585 (init=-1)
#     C_15_16:   0 (fixed)
#     D_15_16:   0 (fixed)
#     A_15_17:  -0.39907327 (init= 1)
#     B_15_17:  -5.99497085 (init=-1)
#     C_15_17:   0 (fixed)
#     D_15_17:   0 (fixed)
#     A_15_18:   0.14259793 (init= 1)
#     B_15_18:   0.91700838 (init=-1)
#     C_15_18:   0 (fixed)
#     D_15_18:   0 (fixed)
#     A_15_19:   0.01817216 (init= 1)
#     B_15_19:  -0.00637182 (init=-1)
#     C_15_19:   0 (fixed)
#     D_15_19:   0 (fixed)
#     A_16_0:    0 (fixed)
#     B_16_0:    0 (fixed)
#     C_16_0:    0 (fixed)
#     D_16_0:    0 (fixed)
#     A_16_1:    0 (fixed)
#     B_16_1:    0 (fixed)
#     C_16_1:    0 (fixed)
#     D_16_1:    0 (fixed)
#     A_16_2:    0 (fixed)
#     B_16_2:    0 (fixed)
#     C_16_2:    0 (fixed)
#     D_16_2:    0 (fixed)
#     A_16_3:    0 (fixed)
#     B_16_3:    0 (fixed)
#     C_16_3:    0 (fixed)
#     D_16_3:    0 (fixed)
#     A_16_4:    0 (fixed)
#     B_16_4:    0 (fixed)
#     C_16_4:    0 (fixed)
#     D_16_4:    0 (fixed)
#     A_16_5:    0 (fixed)
#     B_16_5:    0 (fixed)
#     C_16_5:    0 (fixed)
#     D_16_5:    0 (fixed)
#     A_16_6:    0 (fixed)
#     B_16_6:    0 (fixed)
#     C_16_6:    0 (fixed)
#     D_16_6:    0 (fixed)
#     A_16_7:    0 (fixed)
#     B_16_7:    0 (fixed)
#     C_16_7:    0 (fixed)
#     D_16_7:    0 (fixed)
#     A_16_8:    0 (fixed)
#     B_16_8:    0 (fixed)
#     C_16_8:    0 (fixed)
#     D_16_8:    0 (fixed)
#     A_16_9:    0 (fixed)
#     B_16_9:    0 (fixed)
#     C_16_9:    0 (fixed)
#     D_16_9:    0 (fixed)
#     A_16_10:   0 (fixed)
#     B_16_10:   0 (fixed)
#     C_16_10:   0 (fixed)
#     D_16_10:   0 (fixed)
#     A_16_11:   0 (fixed)
#     B_16_11:   0 (fixed)
#     C_16_11:   0 (fixed)
#     D_16_11:   0 (fixed)
#     A_16_12:   0 (fixed)
#     B_16_12:   0 (fixed)
#     C_16_12:   0 (fixed)
#     D_16_12:   0 (fixed)
#     A_16_13:   0 (fixed)
#     B_16_13:   0 (fixed)
#     C_16_13:   0 (fixed)
#     D_16_13:   0 (fixed)
#     A_16_14:   0 (fixed)
#     B_16_14:   0 (fixed)
#     C_16_14:   0 (fixed)
#     D_16_14:   0 (fixed)
#     A_16_15:   0 (fixed)
#     B_16_15:   0 (fixed)
#     C_16_15:   0 (fixed)
#     D_16_15:   0 (fixed)
#     A_16_16:  -1.65310547 (init= 1)
#     B_16_16:   210.589190 (init=-1)
#     C_16_16:   0 (fixed)
#     D_16_16:   0 (fixed)
#     A_16_17:   0 (fixed)
#     B_16_17:   4.42774620 (init=-1)
#     C_16_17:   0 (fixed)
#     D_16_17:   0 (fixed)
#     A_16_18:   0.14380049 (init= 1)
#     B_16_18:   1.07477797 (init=-1)
#     C_16_18:   0 (fixed)
#     D_16_18:   0 (fixed)
#     A_16_19:  -0.01295614 (init= 1)
#     B_16_19:  -0.08874095 (init=-1)
#     C_16_19:   0 (fixed)
#     D_16_19:   0 (fixed)
#     A_17_0:    0 (fixed)
#     B_17_0:    0 (fixed)
#     C_17_0:    0 (fixed)
#     D_17_0:    0 (fixed)
#     A_17_1:    0 (fixed)
#     B_17_1:    0 (fixed)
#     C_17_1:    0 (fixed)
#     D_17_1:    0 (fixed)
#     A_17_2:    0 (fixed)
#     B_17_2:    0 (fixed)
#     C_17_2:    0 (fixed)
#     D_17_2:    0 (fixed)
#     A_17_3:    0 (fixed)
#     B_17_3:    0 (fixed)
#     C_17_3:    0 (fixed)
#     D_17_3:    0 (fixed)
#     A_17_4:    0 (fixed)
#     B_17_4:    0 (fixed)
#     C_17_4:    0 (fixed)
#     D_17_4:    0 (fixed)
#     A_17_5:    0 (fixed)
#     B_17_5:    0 (fixed)
#     C_17_5:    0 (fixed)
#     D_17_5:    0 (fixed)
#     A_17_6:    0 (fixed)
#     B_17_6:    0 (fixed)
#     C_17_6:    0 (fixed)
#     D_17_6:    0 (fixed)
#     A_17_7:    0 (fixed)
#     B_17_7:    0 (fixed)
#     C_17_7:    0 (fixed)
#     D_17_7:    0 (fixed)
#     A_17_8:    0 (fixed)
#     B_17_8:    0 (fixed)
#     C_17_8:    0 (fixed)
#     D_17_8:    0 (fixed)
#     A_17_9:    0 (fixed)
#     B_17_9:    0 (fixed)
#     C_17_9:    0 (fixed)
#     D_17_9:    0 (fixed)
#     A_17_10:   0 (fixed)
#     B_17_10:   0 (fixed)
#     C_17_10:   0 (fixed)
#     D_17_10:   0 (fixed)
#     A_17_11:   0 (fixed)
#     B_17_11:   0 (fixed)
#     C_17_11:   0 (fixed)
#     D_17_11:   0 (fixed)
#     A_17_12:   0 (fixed)
#     B_17_12:   0 (fixed)
#     C_17_12:   0 (fixed)
#     D_17_12:   0 (fixed)
#     A_17_13:   0 (fixed)
#     B_17_13:   0 (fixed)
#     C_17_13:   0 (fixed)
#     D_17_13:   0 (fixed)
#     A_17_14:   0 (fixed)
#     B_17_14:   0 (fixed)
#     C_17_14:   0 (fixed)
#     D_17_14:   0 (fixed)
#     A_17_15:   0 (fixed)
#     B_17_15:   0 (fixed)
#     C_17_15:   0 (fixed)
#     D_17_15:   0 (fixed)
#     A_17_16:   0 (fixed)
#     B_17_16:   0 (fixed)
#     C_17_16:   0 (fixed)
#     D_17_16:   0 (fixed)
#     A_17_17:   0.48209835 (init= 1)
#     B_17_17:  -54.8871682 (init=-1)
#     C_17_17:   0 (fixed)
#     D_17_17:   0 (fixed)
#     A_17_18:   0 (fixed)
#     B_17_18:  -0.86211935 (init=-1)
#     C_17_18:   0 (fixed)
#     D_17_18:   0 (fixed)
#     A_17_19:  -0.01937815 (init= 1)
#     B_17_19:  -0.08978671 (init=-1)
#     C_17_19:   0 (fixed)
#     D_17_19:   0 (fixed)
#     A_18_0:    0 (fixed)
#     B_18_0:    0 (fixed)
#     C_18_0:    0 (fixed)
#     D_18_0:    0 (fixed)
#     A_18_1:    0 (fixed)
#     B_18_1:    0 (fixed)
#     C_18_1:    0 (fixed)
#     D_18_1:    0 (fixed)
#     A_18_2:    0 (fixed)
#     B_18_2:    0 (fixed)
#     C_18_2:    0 (fixed)
#     D_18_2:    0 (fixed)
#     A_18_3:    0 (fixed)
#     B_18_3:    0 (fixed)
#     C_18_3:    0 (fixed)
#     D_18_3:    0 (fixed)
#     A_18_4:    0 (fixed)
#     B_18_4:    0 (fixed)
#     C_18_4:    0 (fixed)
#     D_18_4:    0 (fixed)
#     A_18_5:    0 (fixed)
#     B_18_5:    0 (fixed)
#     C_18_5:    0 (fixed)
#     D_18_5:    0 (fixed)
#     A_18_6:    0 (fixed)
#     B_18_6:    0 (fixed)
#     C_18_6:    0 (fixed)
#     D_18_6:    0 (fixed)
#     A_18_7:    0 (fixed)
#     B_18_7:    0 (fixed)
#     C_18_7:    0 (fixed)
#     D_18_7:    0 (fixed)
#     A_18_8:    0 (fixed)
#     B_18_8:    0 (fixed)
#     C_18_8:    0 (fixed)
#     D_18_8:    0 (fixed)
#     A_18_9:    0 (fixed)
#     B_18_9:    0 (fixed)
#     C_18_9:    0 (fixed)
#     D_18_9:    0 (fixed)
#     A_18_10:   0 (fixed)
#     B_18_10:   0 (fixed)
#     C_18_10:   0 (fixed)
#     D_18_10:   0 (fixed)
#     A_18_11:   0 (fixed)
#     B_18_11:   0 (fixed)
#     C_18_11:   0 (fixed)
#     D_18_11:   0 (fixed)
#     A_18_12:   0 (fixed)
#     B_18_12:   0 (fixed)
#     C_18_12:   0 (fixed)
#     D_18_12:   0 (fixed)
#     A_18_13:   0 (fixed)
#     B_18_13:   0 (fixed)
#     C_18_13:   0 (fixed)
#     D_18_13:   0 (fixed)
#     A_18_14:   0 (fixed)
#     B_18_14:   0 (fixed)
#     C_18_14:   0 (fixed)
#     D_18_14:   0 (fixed)
#     A_18_15:   0 (fixed)
#     B_18_15:   0 (fixed)
#     C_18_15:   0 (fixed)
#     D_18_15:   0 (fixed)
#     A_18_16:   0 (fixed)
#     B_18_16:   0 (fixed)
#     C_18_16:   0 (fixed)
#     D_18_16:   0 (fixed)
#     A_18_17:   0 (fixed)
#     B_18_17:   0 (fixed)
#     C_18_17:   0 (fixed)
#     D_18_17:   0 (fixed)
#     A_18_18:  -0.08883987 (init= 1)
#     B_18_18:   8.43690302 (init=-1)
#     C_18_18:   0 (fixed)
#     D_18_18:   0 (fixed)
#     A_18_19:   0 (fixed)
#     B_18_19:   0.07694520 (init=-1)
#     C_18_19:   0 (fixed)
#     D_18_19:   0 (fixed)
#     A_19_0:    0 (fixed)
#     B_19_0:    0 (fixed)
#     C_19_0:    0 (fixed)
#     D_19_0:    0 (fixed)
#     A_19_1:    0 (fixed)
#     B_19_1:    0 (fixed)
#     C_19_1:    0 (fixed)
#     D_19_1:    0 (fixed)
#     A_19_2:    0 (fixed)
#     B_19_2:    0 (fixed)
#     C_19_2:    0 (fixed)
#     D_19_2:    0 (fixed)
#     A_19_3:    0 (fixed)
#     B_19_3:    0 (fixed)
#     C_19_3:    0 (fixed)
#     D_19_3:    0 (fixed)
#     A_19_4:    0 (fixed)
#     B_19_4:    0 (fixed)
#     C_19_4:    0 (fixed)
#     D_19_4:    0 (fixed)
#     A_19_5:    0 (fixed)
#     B_19_5:    0 (fixed)
#     C_19_5:    0 (fixed)
#     D_19_5:    0 (fixed)
#     A_19_6:    0 (fixed)
#     B_19_6:    0 (fixed)
#     C_19_6:    0 (fixed)
#     D_19_6:    0 (fixed)
#     A_19_7:    0 (fixed)
#     B_19_7:    0 (fixed)
#     C_19_7:    0 (fixed)
#     D_19_7:    0 (fixed)
#     A_19_8:    0 (fixed)
#     B_19_8:    0 (fixed)
#     C_19_8:    0 (fixed)
#     D_19_8:    0 (fixed)
#     A_19_9:    0 (fixed)
#     B_19_9:    0 (fixed)
#     C_19_9:    0 (fixed)
#     D_19_9:    0 (fixed)
#     A_19_10:   0 (fixed)
#     B_19_10:   0 (fixed)
#     C_19_10:   0 (fixed)
#     D_19_10:   0 (fixed)
#     A_19_11:   0 (fixed)
#     B_19_11:   0 (fixed)
#     C_19_11:   0 (fixed)
#     D_19_11:   0 (fixed)
#     A_19_12:   0 (fixed)
#     B_19_12:   0 (fixed)
#     C_19_12:   0 (fixed)
#     D_19_12:   0 (fixed)
#     A_19_13:   0 (fixed)
#     B_19_13:   0 (fixed)
#     C_19_13:   0 (fixed)
#     D_19_13:   0 (fixed)
#     A_19_14:   0 (fixed)
#     B_19_14:   0 (fixed)
#     C_19_14:   0 (fixed)
#     D_19_14:   0 (fixed)
#     A_19_15:   0 (fixed)
#     B_19_15:   0 (fixed)
#     C_19_15:   0 (fixed)
#     D_19_15:   0 (fixed)
#     A_19_16:   0 (fixed)
#     B_19_16:   0 (fixed)
#     C_19_16:   0 (fixed)
#     D_19_16:   0 (fixed)
#     A_19_17:   0 (fixed)
#     B_19_17:   0 (fixed)
#     C_19_17:   0 (fixed)
#     D_19_17:   0 (fixed)
#     A_19_18:   0 (fixed)
#     B_19_18:   0 (fixed)
#     C_19_18:   0 (fixed)
#     D_19_18:   0 (fixed)
#     A_19_19:   0.00794721 (init= 1)
#     B_19_19:  -0.59305412 (init=-1)
#     C_19_19:   0 (fixed)
#     D_19_19:   0 (fixed)

# %%
ff1 = deepcopy(ff)

# %%
run hallprobesim.py
# Out:
# 1.5707963267948966
# (140, 10)
# 375.0
# 1450.0
# 0.002531942
# 1732114    0.002532
# Name: Br, dtype: float64
# fitting with n=20, m=20, cn=0, cm=0
# Elapsed time was 258.325 seconds
# [[Fit Statistics]]
#     # function evals   = 24
#     # data points      = 4200
#     # variables        = 362
#     chi-square         = 0.000
#     reduced chi-square = 0.000
#     Akaike info crit   = -126666.959
#     Bayesian info crit = -124370.851
# [[Variables]]
#     R:         25000 (fixed)
#     ns:        20 (fixed)
#     ms:        20 (fixed)
#     A_0_0:     0 (fixed)
#     B_0_0:     0 (fixed)
#     C_0_0:     0 (fixed)
#     D_0_0:     0 (fixed)
#     A_0_1:     0 (fixed)
#     B_0_1:     0 (fixed)
#     C_0_1:     0 (fixed)
#     D_0_1:     0 (fixed)
#     A_0_2:     0 (fixed)
#     B_0_2:     0 (fixed)
#     C_0_2:     0 (fixed)
#     D_0_2:     0 (fixed)
#     A_0_3:     0 (fixed)
#     B_0_3:     0 (fixed)
#     C_0_3:     0 (fixed)
#     D_0_3:     0 (fixed)
#     A_0_4:     0 (fixed)
#     B_0_4:     0 (fixed)
#     C_0_4:     0 (fixed)
#     D_0_4:     0 (fixed)
#     A_0_5:     0 (fixed)
#     B_0_5:     0 (fixed)
#     C_0_5:     0 (fixed)
#     D_0_5:     0 (fixed)
#     A_0_6:     0 (fixed)
#     B_0_6:     0 (fixed)
#     C_0_6:     0 (fixed)
#     D_0_6:     0 (fixed)
#     A_0_7:     0 (fixed)
#     B_0_7:     0 (fixed)
#     C_0_7:     0 (fixed)
#     D_0_7:     0 (fixed)
#     A_0_8:     0 (fixed)
#     B_0_8:     0 (fixed)
#     C_0_8:     0 (fixed)
#     D_0_8:     0 (fixed)
#     A_0_9:     0 (fixed)
#     B_0_9:     0 (fixed)
#     C_0_9:     0 (fixed)
#     D_0_9:     0 (fixed)
#     A_0_10:    0 (fixed)
#     B_0_10:    0 (fixed)
#     C_0_10:    0 (fixed)
#     D_0_10:    0 (fixed)
#     A_0_11:    0 (fixed)
#     B_0_11:    0 (fixed)
#     C_0_11:    0 (fixed)
#     D_0_11:    0 (fixed)
#     A_0_12:    0 (fixed)
#     B_0_12:    0 (fixed)
#     C_0_12:    0 (fixed)
#     D_0_12:    0 (fixed)
#     A_0_13:    0 (fixed)
#     B_0_13:    0 (fixed)
#     C_0_13:    0 (fixed)
#     D_0_13:    0 (fixed)
#     A_0_14:    0 (fixed)
#     B_0_14:    0 (fixed)
#     C_0_14:    0 (fixed)
#     D_0_14:    0 (fixed)
#     A_0_15:    0 (fixed)
#     B_0_15:    0 (fixed)
#     C_0_15:    0 (fixed)
#     D_0_15:    0 (fixed)
#     A_0_16:    0 (fixed)
#     B_0_16:    0 (fixed)
#     C_0_16:    0 (fixed)
#     D_0_16:    0 (fixed)
#     A_0_17:    0 (fixed)
#     B_0_17:    0 (fixed)
#     C_0_17:    0 (fixed)
#     D_0_17:    0 (fixed)
#     A_0_18:    0 (fixed)
#     B_0_18:    0 (fixed)
#     C_0_18:    0 (fixed)
#     D_0_18:    0 (fixed)
#     A_0_19:    0 (fixed)
#     B_0_19:    0 (fixed)
#     C_0_19:    0 (fixed)
#     D_0_19:    0 (fixed)
#     A_1_0:     0 (fixed)
#     B_1_0:     0 (fixed)
#     C_1_0:     0 (fixed)
#     D_1_0:     0 (fixed)
#     A_1_1:     1.84606645 (init= 1)
#     B_1_1:     5509.79412 (init=-1)
#     C_1_1:     0 (fixed)
#     D_1_1:     0 (fixed)
#     A_1_2:     0 (fixed)
#     B_1_2:     3.66588611 (init=-1)
#     C_1_2:     0 (fixed)
#     D_1_2:     0 (fixed)
#     A_1_3:     26.5880691 (init= 1)
#     B_1_3:     34.6048876 (init=-1)
#     C_1_3:     0 (fixed)
#     D_1_3:     0 (fixed)
#     A_1_4:     49.2248048 (init= 1)
#     B_1_4:    -157.789020 (init=-1)
#     C_1_4:     0 (fixed)
#     D_1_4:     0 (fixed)
#     A_1_5:     295.272816 (init= 1)
#     B_1_5:     1.28726655 (init=-1)
#     C_1_5:     0 (fixed)
#     D_1_5:     0 (fixed)
#     A_1_6:     59.0314164 (init= 1)
#     B_1_6:    -29.3124012 (init=-1)
#     C_1_6:     0 (fixed)
#     D_1_6:     0 (fixed)
#     A_1_7:     2228.51822 (init= 1)
#     B_1_7:     1404.90125 (init=-1)
#     C_1_7:     0 (fixed)
#     D_1_7:     0 (fixed)
#     A_1_8:     7128.91123 (init= 1)
#     B_1_8:    -3084.44500 (init=-1)
#     C_1_8:     0 (fixed)
#     D_1_8:     0 (fixed)
#     A_1_9:    -66.6480268 (init= 1)
#     B_1_9:    -6820.02936 (init=-1)
#     C_1_9:     0 (fixed)
#     D_1_9:     0 (fixed)
#     A_1_10:   -748.932696 (init= 1)
#     B_1_10:   -1523.34832 (init=-1)
#     C_1_10:    0 (fixed)
#     D_1_10:    0 (fixed)
#     A_1_11:    4345.57327 (init= 1)
#     B_1_11:    403.057354 (init=-1)
#     C_1_11:    0 (fixed)
#     D_1_11:    0 (fixed)
#     A_1_12:    2652.56717 (init= 1)
#     B_1_12:   -2292.39372 (init=-1)
#     C_1_12:    0 (fixed)
#     D_1_12:    0 (fixed)
#     A_1_13:   -2414.26897 (init= 1)
#     B_1_13:   -326.715932 (init=-1)
#     C_1_13:    0 (fixed)
#     D_1_13:    0 (fixed)
#     A_1_14:    343.375050 (init= 1)
#     B_1_14:    417.090588 (init=-1)
#     C_1_14:    0 (fixed)
#     D_1_14:    0 (fixed)
#     A_1_15:    1918.88123 (init= 1)
#     B_1_15:   -1600.65658 (init=-1)
#     C_1_15:    0 (fixed)
#     D_1_15:    0 (fixed)
#     A_1_16:    1855.17876 (init= 1)
#     B_1_16:   -814.254461 (init=-1)
#     C_1_16:    0 (fixed)
#     D_1_16:    0 (fixed)
#     A_1_17:    1607.90257 (init= 1)
#     B_1_17:   -277.407274 (init=-1)
#     C_1_17:    0 (fixed)
#     D_1_17:    0 (fixed)
#     A_1_18:    1118.05260 (init= 1)
#     B_1_18:    106.455216 (init=-1)
#     C_1_18:    0 (fixed)
#     D_1_18:    0 (fixed)
#     A_1_19:   -433.600640 (init= 1)
#     B_1_19:    502.982714 (init=-1)
#     C_1_19:    0 (fixed)
#     D_1_19:    0 (fixed)
#     A_2_0:     0 (fixed)
#     B_2_0:     0 (fixed)
#     C_2_0:     0 (fixed)
#     D_2_0:     0 (fixed)
#     A_2_1:     0 (fixed)
#     B_2_1:     0 (fixed)
#     C_2_1:     0 (fixed)
#     D_2_1:     0 (fixed)
#     A_2_2:     2.43306890 (init= 1)
#     B_2_2:    -1.50571620 (init=-1)
#     C_2_2:     0 (fixed)
#     D_2_2:     0 (fixed)
#     A_2_3:     0 (fixed)
#     B_2_3:    -15.9829017 (init=-1)
#     C_2_3:     0 (fixed)
#     D_2_3:     0 (fixed)
#     A_2_4:    -51.4262317 (init= 1)
#     B_2_4:    -61.3929395 (init=-1)
#     C_2_4:     0 (fixed)
#     D_2_4:     0 (fixed)
#     A_2_5:    -25.2580167 (init= 1)
#     B_2_5:     89.4953619 (init=-1)
#     C_2_5:     0 (fixed)
#     D_2_5:     0 (fixed)
#     A_2_6:    -69.7709791 (init= 1)
#     B_2_6:    -0.48660768 (init=-1)
#     C_2_6:     0 (fixed)
#     D_2_6:     0 (fixed)
#     A_2_7:     16.3108921 (init= 1)
#     B_2_7:     0.76990314 (init=-1)
#     C_2_7:     0 (fixed)
#     D_2_7:     0 (fixed)
#     A_2_8:    -82.2110916 (init= 1)
#     B_2_8:    -125.433372 (init=-1)
#     C_2_8:     0 (fixed)
#     D_2_8:     0 (fixed)
#     A_2_9:    -45.1368371 (init= 1)
#     B_2_9:     18.7279084 (init=-1)
#     C_2_9:     0 (fixed)
#     D_2_9:     0 (fixed)
#     A_2_10:    10910.0134 (init= 1)
#     B_2_10:   -2624.58278 (init=-1)
#     C_2_10:    0 (fixed)
#     D_2_10:    0 (fixed)
#     A_2_11:   -14823.5383 (init= 1)
#     B_2_11:   -578.857712 (init=-1)
#     C_2_11:    0 (fixed)
#     D_2_11:    0 (fixed)
#     A_2_12:    949.521451 (init= 1)
#     B_2_12:    1185.74029 (init=-1)
#     C_2_12:    0 (fixed)
#     D_2_12:    0 (fixed)
#     A_2_13:   -157.232226 (init= 1)
#     B_2_13:   -650.595575 (init=-1)
#     C_2_13:    0 (fixed)
#     D_2_13:    0 (fixed)
#     A_2_14:    11.3483617 (init= 1)
#     B_2_14:   -101.566911 (init=-1)
#     C_2_14:    0 (fixed)
#     D_2_14:    0 (fixed)
#     A_2_15:    198.713728 (init= 1)
#     B_2_15:   -263.005120 (init=-1)
#     C_2_15:    0 (fixed)
#     D_2_15:    0 (fixed)
#     A_2_16:   -1171.00528 (init= 1)
#     B_2_16:   -2.04862648 (init=-1)
#     C_2_16:    0 (fixed)
#     D_2_16:    0 (fixed)
#     A_2_17:    598.843000 (init= 1)
#     B_2_17:    458.613867 (init=-1)
#     C_2_17:    0 (fixed)
#     D_2_17:    0 (fixed)
#     A_2_18:    1109.12589 (init= 1)
#     B_2_18:   -618.498235 (init=-1)
#     C_2_18:    0 (fixed)
#     D_2_18:    0 (fixed)
#     A_2_19:   -843.287783 (init= 1)
#     B_2_19:   -544.517077 (init=-1)
#     C_2_19:    0 (fixed)
#     D_2_19:    0 (fixed)
#     A_3_0:     0 (fixed)
#     B_3_0:     0 (fixed)
#     C_3_0:     0 (fixed)
#     D_3_0:     0 (fixed)
#     A_3_1:     0 (fixed)
#     B_3_1:     0 (fixed)
#     C_3_1:     0 (fixed)
#     D_3_1:     0 (fixed)
#     A_3_2:     0 (fixed)
#     B_3_2:     0 (fixed)
#     C_3_2:     0 (fixed)
#     D_3_2:     0 (fixed)
#     A_3_3:    -3.76697065 (init= 1)
#     B_3_3:    -1080.28360 (init=-1)
#     C_3_3:     0 (fixed)
#     D_3_3:     0 (fixed)
#     A_3_4:     0 (fixed)
#     B_3_4:     37.2501343 (init=-1)
#     C_3_4:     0 (fixed)
#     D_3_4:     0 (fixed)
#     A_3_5:     72.3797424 (init= 1)
#     B_3_5:     84.6139519 (init=-1)
#     C_3_5:     0 (fixed)
#     D_3_5:     0 (fixed)
#     A_3_6:    -1.13461457 (init= 1)
#     B_3_6:    -35.7295705 (init=-1)
#     C_3_6:     0 (fixed)
#     D_3_6:     0 (fixed)
#     A_3_7:    -37.2979826 (init= 1)
#     B_3_7:    -10.1392999 (init=-1)
#     C_3_7:     0 (fixed)
#     D_3_7:     0 (fixed)
#     A_3_8:    -45.4824638 (init= 1)
#     B_3_8:     0.73096108 (init=-1)
#     C_3_8:     0 (fixed)
#     D_3_8:     0 (fixed)
#     A_3_9:     82.9366864 (init= 1)
#     B_3_9:    -1.43088247 (init=-1)
#     C_3_9:     0 (fixed)
#     D_3_9:     0 (fixed)
#     A_3_10:    45.3191746 (init= 1)
#     B_3_10:   -16.7286563 (init=-1)
#     C_3_10:    0 (fixed)
#     D_3_10:    0 (fixed)
#     A_3_11:   -91.2495467 (init= 1)
#     B_3_11:   -0.32414785 (init=-1)
#     C_3_11:    0 (fixed)
#     D_3_11:    0 (fixed)
#     A_3_12:   -416.586748 (init= 1)
#     B_3_12:    10832.9861 (init=-1)
#     C_3_12:    0 (fixed)
#     D_3_12:    0 (fixed)
#     A_3_13:    116.892799 (init= 1)
#     B_3_13:    17281.6340 (init=-1)
#     C_3_13:    0 (fixed)
#     D_3_13:    0 (fixed)
#     A_3_14:    113.539865 (init= 1)
#     B_3_14:    603.301192 (init=-1)
#     C_3_14:    0 (fixed)
#     D_3_14:    0 (fixed)
#     A_3_15:    990.514146 (init= 1)
#     B_3_15:    1038.50913 (init=-1)
#     C_3_15:    0 (fixed)
#     D_3_15:    0 (fixed)
#     A_3_16:    316.610952 (init= 1)
#     B_3_16:    160.708898 (init=-1)
#     C_3_16:    0 (fixed)
#     D_3_16:    0 (fixed)
#     A_3_17:    482.643801 (init= 1)
#     B_3_17:   -395.617506 (init=-1)
#     C_3_17:    0 (fixed)
#     D_3_17:    0 (fixed)
#     A_3_18:    1052.95161 (init= 1)
#     B_3_18:   -419.669021 (init=-1)
#     C_3_18:    0 (fixed)
#     D_3_18:    0 (fixed)
#     A_3_19:    140.059837 (init= 1)
#     B_3_19:    265.084677 (init=-1)
#     C_3_19:    0 (fixed)
#     D_3_19:    0 (fixed)
#     A_4_0:     0 (fixed)
#     B_4_0:     0 (fixed)
#     C_4_0:     0 (fixed)
#     D_4_0:     0 (fixed)
#     A_4_1:     0 (fixed)
#     B_4_1:     0 (fixed)
#     C_4_1:     0 (fixed)
#     D_4_1:     0 (fixed)
#     A_4_2:     0 (fixed)
#     B_4_2:     0 (fixed)
#     C_4_2:     0 (fixed)
#     D_4_2:     0 (fixed)
#     A_4_3:     0 (fixed)
#     B_4_3:     0 (fixed)
#     C_4_3:     0 (fixed)
#     D_4_3:     0 (fixed)
#     A_4_4:     1.46188814 (init= 1)
#     B_4_4:    -509.945753 (init=-1)
#     C_4_4:     0 (fixed)
#     D_4_4:     0 (fixed)
#     A_4_5:     0 (fixed)
#     B_4_5:    -41.4093116 (init=-1)
#     C_4_5:     0 (fixed)
#     D_4_5:     0 (fixed)
#     A_4_6:    -55.5623803 (init= 1)
#     B_4_6:    -77.1597315 (init=-1)
#     C_4_6:     0 (fixed)
#     D_4_6:     0 (fixed)
#     A_4_7:     30.4776381 (init= 1)
#     B_4_7:    -10.6396764 (init=-1)
#     C_4_7:     0 (fixed)
#     D_4_7:     0 (fixed)
#     A_4_8:     100.457591 (init= 1)
#     B_4_8:     5.09045631 (init=-1)
#     C_4_8:     0 (fixed)
#     D_4_8:     0 (fixed)
#     A_4_9:     0.41058131 (init= 1)
#     B_4_9:    -0.02561363 (init=-1)
#     C_4_9:     0 (fixed)
#     D_4_9:     0 (fixed)
#     A_4_10:    51.7983152 (init= 1)
#     B_4_10:   -23.0341006 (init=-1)
#     C_4_10:    0 (fixed)
#     D_4_10:    0 (fixed)
#     A_4_11:    38.5327408 (init= 1)
#     B_4_11:    14.3470454 (init=-1)
#     C_4_11:    0 (fixed)
#     D_4_11:    0 (fixed)
#     A_4_12:   -59.5599518 (init= 1)
#     B_4_12:   -355.443562 (init=-1)
#     C_4_12:    0 (fixed)
#     D_4_12:    0 (fixed)
#     A_4_13:    314.656805 (init= 1)
#     B_4_13:   -841.502838 (init=-1)
#     C_4_13:    0 (fixed)
#     D_4_13:    0 (fixed)
#     A_4_14:   -4024.29493 (init= 1)
#     B_4_14:   -5415.76522 (init=-1)
#     C_4_14:    0 (fixed)
#     D_4_14:    0 (fixed)
#     A_4_15:    26.1593247 (init= 1)
#     B_4_15:   -14155.5653 (init=-1)
#     C_4_15:    0 (fixed)
#     D_4_15:    0 (fixed)
#     A_4_16:    91.0649621 (init= 1)
#     B_4_16:    311.131708 (init=-1)
#     C_4_16:    0 (fixed)
#     D_4_16:    0 (fixed)
#     A_4_17:    342.643492 (init= 1)
#     B_4_17:   -642.343396 (init=-1)
#     C_4_17:    0 (fixed)
#     D_4_17:    0 (fixed)
#     A_4_18:    20.0437994 (init= 1)
#     B_4_18:    463.939841 (init=-1)
#     C_4_18:    0 (fixed)
#     D_4_18:    0 (fixed)
#     A_4_19:    464.482913 (init= 1)
#     B_4_19:    30.3638410 (init=-1)
#     C_4_19:    0 (fixed)
#     D_4_19:    0 (fixed)
#     A_5_0:     0 (fixed)
#     B_5_0:     0 (fixed)
#     C_5_0:     0 (fixed)
#     D_5_0:     0 (fixed)
#     A_5_1:     0 (fixed)
#     B_5_1:     0 (fixed)
#     C_5_1:     0 (fixed)
#     D_5_1:     0 (fixed)
#     A_5_2:     0 (fixed)
#     B_5_2:     0 (fixed)
#     C_5_2:     0 (fixed)
#     D_5_2:     0 (fixed)
#     A_5_3:     0 (fixed)
#     B_5_3:     0 (fixed)
#     C_5_3:     0 (fixed)
#     D_5_3:     0 (fixed)
#     A_5_4:     0 (fixed)
#     B_5_4:     0 (fixed)
#     C_5_4:     0 (fixed)
#     D_5_4:     0 (fixed)
#     A_5_5:     2.12309516 (init= 1)
#     B_5_5:     1885.27149 (init=-1)
#     C_5_5:     0 (fixed)
#     D_5_5:     0 (fixed)
#     A_5_6:     0 (fixed)
#     B_5_6:    -0.54799486 (init=-1)
#     C_5_6:     0 (fixed)
#     D_5_6:     0 (fixed)
#     A_5_7:    -5.59281291 (init= 1)
#     B_5_7:     33.0015394 (init=-1)
#     C_5_7:     0 (fixed)
#     D_5_7:     0 (fixed)
#     A_5_8:    -47.2847482 (init= 1)
#     B_5_8:     24.9360010 (init=-1)
#     C_5_8:     0 (fixed)
#     D_5_8:     0 (fixed)
#     A_5_9:    -96.0674094 (init= 1)
#     B_5_9:     3.47547163 (init=-1)
#     C_5_9:     0 (fixed)
#     D_5_9:     0 (fixed)
#     A_5_10:    13.9224460 (init= 1)
#     B_5_10:   -2.11847840 (init=-1)
#     C_5_10:    0 (fixed)
#     D_5_10:    0 (fixed)
#     A_5_11:    49.1329019 (init= 1)
#     B_5_11:    75.6475225 (init=-1)
#     C_5_11:    0 (fixed)
#     D_5_11:    0 (fixed)
#     A_5_12:   -41.7453077 (init= 1)
#     B_5_12:   -29.0242826 (init=-1)
#     C_5_12:    0 (fixed)
#     D_5_12:    0 (fixed)
#     A_5_13:    83.6898934 (init= 1)
#     B_5_13:    343.254140 (init=-1)
#     C_5_13:    0 (fixed)
#     D_5_13:    0 (fixed)
#     A_5_14:   -103.088891 (init= 1)
#     B_5_14:    148.238818 (init=-1)
#     C_5_14:    0 (fixed)
#     D_5_14:    0 (fixed)
#     A_5_15:   -2356.62305 (init= 1)
#     B_5_15:    214.881403 (init=-1)
#     C_5_15:    0 (fixed)
#     D_5_15:    0 (fixed)
#     A_5_16:    163.178197 (init= 1)
#     B_5_16:   -21785.5632 (init=-1)
#     C_5_16:    0 (fixed)
#     D_5_16:    0 (fixed)
#     A_5_17:   -207.713635 (init= 1)
#     B_5_17:   -3434.85670 (init=-1)
#     C_5_17:    0 (fixed)
#     D_5_17:    0 (fixed)
#     A_5_18:   -583.867996 (init= 1)
#     B_5_18:   -165.932000 (init=-1)
#     C_5_18:    0 (fixed)
#     D_5_18:    0 (fixed)
#     A_5_19:    323.650655 (init= 1)
#     B_5_19:   -151.112511 (init=-1)
#     C_5_19:    0 (fixed)
#     D_5_19:    0 (fixed)
#     A_6_0:     0 (fixed)
#     B_6_0:     0 (fixed)
#     C_6_0:     0 (fixed)
#     D_6_0:     0 (fixed)
#     A_6_1:     0 (fixed)
#     B_6_1:     0 (fixed)
#     C_6_1:     0 (fixed)
#     D_6_1:     0 (fixed)
#     A_6_2:     0 (fixed)
#     B_6_2:     0 (fixed)
#     C_6_2:     0 (fixed)
#     D_6_2:     0 (fixed)
#     A_6_3:     0 (fixed)
#     B_6_3:     0 (fixed)
#     C_6_3:     0 (fixed)
#     D_6_3:     0 (fixed)
#     A_6_4:     0 (fixed)
#     B_6_4:     0 (fixed)
#     C_6_4:     0 (fixed)
#     D_6_4:     0 (fixed)
#     A_6_5:     0 (fixed)
#     B_6_5:     0 (fixed)
#     C_6_5:     0 (fixed)
#     D_6_5:     0 (fixed)
#     A_6_6:    -3.64499093 (init= 1)
#     B_6_6:    -0.68370314 (init=-1)
#     C_6_6:     0 (fixed)
#     D_6_6:     0 (fixed)
#     A_6_7:     0 (fixed)
#     B_6_7:     67.9835723 (init=-1)
#     C_6_7:     0 (fixed)
#     D_6_7:     0 (fixed)
#     A_6_8:     66.8919677 (init= 1)
#     B_6_8:     20.3089329 (init=-1)
#     C_6_8:     0 (fixed)
#     D_6_8:     0 (fixed)
#     A_6_9:     41.6137746 (init= 1)
#     B_6_9:    -7.46003867 (init=-1)
#     C_6_9:     0 (fixed)
#     D_6_9:     0 (fixed)
#     A_6_10:    45.4276031 (init= 1)
#     B_6_10:   -10.3529383 (init=-1)
#     C_6_10:    0 (fixed)
#     D_6_10:    0 (fixed)
#     A_6_11:   -0.57385595 (init= 1)
#     B_6_11:   -1.22158516 (init=-1)
#     C_6_11:    0 (fixed)
#     D_6_11:    0 (fixed)
#     A_6_12:   -72.8254036 (init= 1)
#     B_6_12:   -21.3705218 (init=-1)
#     C_6_12:    0 (fixed)
#     D_6_12:    0 (fixed)
#     A_6_13:    16.5152855 (init= 1)
#     B_6_13:    0.95397289 (init=-1)
#     C_6_13:    0 (fixed)
#     D_6_13:    0 (fixed)
#     A_6_14:   -0.13670060 (init= 1)
#     B_6_14:    31.2819224 (init=-1)
#     C_6_14:    0 (fixed)
#     D_6_14:    0 (fixed)
#     A_6_15:    51.9440800 (init= 1)
#     B_6_15:   -73.0093410 (init=-1)
#     C_6_15:    0 (fixed)
#     D_6_15:    0 (fixed)
#     A_6_16:    1771.24622 (init= 1)
#     B_6_16:    333.038468 (init=-1)
#     C_6_16:    0 (fixed)
#     D_6_16:    0 (fixed)
#     A_6_17:   -3619.37930 (init= 1)
#     B_6_17:    377.015684 (init=-1)
#     C_6_17:    0 (fixed)
#     D_6_17:    0 (fixed)
#     A_6_18:    156.349677 (init= 1)
#     B_6_18:    6902.39877 (init=-1)
#     C_6_18:    0 (fixed)
#     D_6_18:    0 (fixed)
#     A_6_19:    21.2576811 (init= 1)
#     B_6_19:    425.488828 (init=-1)
#     C_6_19:    0 (fixed)
#     D_6_19:    0 (fixed)
#     A_7_0:     0 (fixed)
#     B_7_0:     0 (fixed)
#     C_7_0:     0 (fixed)
#     D_7_0:     0 (fixed)
#     A_7_1:     0 (fixed)
#     B_7_1:     0 (fixed)
#     C_7_1:     0 (fixed)
#     D_7_1:     0 (fixed)
#     A_7_2:     0 (fixed)
#     B_7_2:     0 (fixed)
#     C_7_2:     0 (fixed)
#     D_7_2:     0 (fixed)
#     A_7_3:     0 (fixed)
#     B_7_3:     0 (fixed)
#     C_7_3:     0 (fixed)
#     D_7_3:     0 (fixed)
#     A_7_4:     0 (fixed)
#     B_7_4:     0 (fixed)
#     C_7_4:     0 (fixed)
#     D_7_4:     0 (fixed)
#     A_7_5:     0 (fixed)
#     B_7_5:     0 (fixed)
#     C_7_5:     0 (fixed)
#     D_7_5:     0 (fixed)
#     A_7_6:     0 (fixed)
#     B_7_6:     0 (fixed)
#     C_7_6:     0 (fixed)
#     D_7_6:     0 (fixed)
#     A_7_7:     0.56029278 (init= 1)
#     B_7_7:    -3483.94105 (init=-1)
#     C_7_7:     0 (fixed)
#     D_7_7:     0 (fixed)
#     A_7_8:     0 (fixed)
#     B_7_8:    -94.8884254 (init=-1)
#     C_7_8:     0 (fixed)
#     D_7_8:     0 (fixed)
#     A_7_9:    -77.9646417 (init= 1)
#     B_7_9:    -46.3472845 (init=-1)
#     C_7_9:     0 (fixed)
#     D_7_9:     0 (fixed)
#     A_7_10:   -20.7037122 (init= 1)
#     B_7_10:   -12.8046724 (init=-1)
#     C_7_10:    0 (fixed)
#     D_7_10:    0 (fixed)
#     A_7_11:    0.39139300 (init= 1)
#     B_7_11:    25.8434099 (init=-1)
#     C_7_11:    0 (fixed)
#     D_7_11:    0 (fixed)
#     A_7_12:   -3.27068043 (init= 1)
#     B_7_12:    5.21416632 (init=-1)
#     C_7_12:    0 (fixed)
#     D_7_12:    0 (fixed)
#     A_7_13:    19.2008455 (init= 1)
#     B_7_13:    0.06998869 (init=-1)
#     C_7_13:    0 (fixed)
#     D_7_13:    0 (fixed)
#     A_7_14:   -0.39944054 (init= 1)
#     B_7_14:    5.76256501 (init=-1)
#     C_7_14:    0 (fixed)
#     D_7_14:    0 (fixed)
#     A_7_15:    0.26275295 (init= 1)
#     B_7_15:    427.745829 (init=-1)
#     C_7_15:    0 (fixed)
#     D_7_15:    0 (fixed)
#     A_7_16:   -0.12700025 (init= 1)
#     B_7_16:    63.4391402 (init=-1)
#     C_7_16:    0 (fixed)
#     D_7_16:    0 (fixed)
#     A_7_17:   -451.626746 (init= 1)
#     B_7_17:    16.2461563 (init=-1)
#     C_7_17:    0 (fixed)
#     D_7_17:    0 (fixed)
#     A_7_18:   -267.236662 (init= 1)
#     B_7_18:    1231.39180 (init=-1)
#     C_7_18:    0 (fixed)
#     D_7_18:    0 (fixed)
#     A_7_19:    1955.08260 (init= 1)
#     B_7_19:   -7115.65273 (init=-1)
#     C_7_19:    0 (fixed)
#     D_7_19:    0 (fixed)
#     A_8_0:     0 (fixed)
#     B_8_0:     0 (fixed)
#     C_8_0:     0 (fixed)
#     D_8_0:     0 (fixed)
#     A_8_1:     0 (fixed)
#     B_8_1:     0 (fixed)
#     C_8_1:     0 (fixed)
#     D_8_1:     0 (fixed)
#     A_8_2:     0 (fixed)
#     B_8_2:     0 (fixed)
#     C_8_2:     0 (fixed)
#     D_8_2:     0 (fixed)
#     A_8_3:     0 (fixed)
#     B_8_3:     0 (fixed)
#     C_8_3:     0 (fixed)
#     D_8_3:     0 (fixed)
#     A_8_4:     0 (fixed)
#     B_8_4:     0 (fixed)
#     C_8_4:     0 (fixed)
#     D_8_4:     0 (fixed)
#     A_8_5:     0 (fixed)
#     B_8_5:     0 (fixed)
#     C_8_5:     0 (fixed)
#     D_8_5:     0 (fixed)
#     A_8_6:     0 (fixed)
#     B_8_6:     0 (fixed)
#     C_8_6:     0 (fixed)
#     D_8_6:     0 (fixed)
#     A_8_7:     0 (fixed)
#     B_8_7:     0 (fixed)
#     C_8_7:     0 (fixed)
#     D_8_7:     0 (fixed)
#     A_8_8:     5.70256804 (init= 1)
#     B_8_8:     4081.97231 (init=-1)
#     C_8_8:     0 (fixed)
#     D_8_8:     0 (fixed)
#     A_8_9:     0 (fixed)
#     B_8_9:     53.2203279 (init=-1)
#     C_8_9:     0 (fixed)
#     D_8_9:     0 (fixed)
#     A_8_10:    40.1033449 (init= 1)
#     B_8_10:    34.8082763 (init=-1)
#     C_8_10:    0 (fixed)
#     D_8_10:    0 (fixed)
#     A_8_11:    1.79459005 (init= 1)
#     B_8_11:    13.2723504 (init=-1)
#     C_8_11:    0 (fixed)
#     D_8_11:    0 (fixed)
#     A_8_12:   -13.2036834 (init= 1)
#     B_8_12:   -53.1331608 (init=-1)
#     C_8_12:    0 (fixed)
#     D_8_12:    0 (fixed)
#     A_8_13:   -12.5210105 (init= 1)
#     B_8_13:   -1.00959169 (init=-1)
#     C_8_13:    0 (fixed)
#     D_8_13:    0 (fixed)
#     A_8_14:    17.8718839 (init= 1)
#     B_8_14:   -27.7357102 (init=-1)
#     C_8_14:    0 (fixed)
#     D_8_14:    0 (fixed)
#     A_8_15:   -4.20275694 (init= 1)
#     B_8_15:    1.25342793 (init=-1)
#     C_8_15:    0 (fixed)
#     D_8_15:    0 (fixed)
#     A_8_16:   -1.59203509 (init= 1)
#     B_8_16:   -76.0988063 (init=-1)
#     C_8_16:    0 (fixed)
#     D_8_16:    0 (fixed)
#     A_8_17:    3.65677345 (init= 1)
#     B_8_17:    69.7178769 (init=-1)
#     C_8_17:    0 (fixed)
#     D_8_17:    0 (fixed)
#     A_8_18:    41.3817278 (init= 1)
#     B_8_18:   -18.9192014 (init=-1)
#     C_8_18:    0 (fixed)
#     D_8_18:    0 (fixed)
#     A_8_19:    960.237759 (init= 1)
#     B_8_19:    71.3104083 (init=-1)
#     C_8_19:    0 (fixed)
#     D_8_19:    0 (fixed)
#     A_9_0:     0 (fixed)
#     B_9_0:     0 (fixed)
#     C_9_0:     0 (fixed)
#     D_9_0:     0 (fixed)
#     A_9_1:     0 (fixed)
#     B_9_1:     0 (fixed)
#     C_9_1:     0 (fixed)
#     D_9_1:     0 (fixed)
#     A_9_2:     0 (fixed)
#     B_9_2:     0 (fixed)
#     C_9_2:     0 (fixed)
#     D_9_2:     0 (fixed)
#     A_9_3:     0 (fixed)
#     B_9_3:     0 (fixed)
#     C_9_3:     0 (fixed)
#     D_9_3:     0 (fixed)
#     A_9_4:     0 (fixed)
#     B_9_4:     0 (fixed)
#     C_9_4:     0 (fixed)
#     D_9_4:     0 (fixed)
#     A_9_5:     0 (fixed)
#     B_9_5:     0 (fixed)
#     C_9_5:     0 (fixed)
#     D_9_5:     0 (fixed)
#     A_9_6:     0 (fixed)
#     B_9_6:     0 (fixed)
#     C_9_6:     0 (fixed)
#     D_9_6:     0 (fixed)
#     A_9_7:     0 (fixed)
#     B_9_7:     0 (fixed)
#     C_9_7:     0 (fixed)
#     D_9_7:     0 (fixed)
#     A_9_8:     0 (fixed)
#     B_9_8:     0 (fixed)
#     C_9_8:     0 (fixed)
#     D_9_8:     0 (fixed)
#     A_9_9:    -8.71848103 (init= 1)
#     B_9_9:    -1005.83004 (init=-1)
#     C_9_9:     0 (fixed)
#     D_9_9:     0 (fixed)
#     A_9_10:    0 (fixed)
#     B_9_10:    1.40111474 (init=-1)
#     C_9_10:    0 (fixed)
#     D_9_10:    0 (fixed)
#     A_9_11:    1.56988863 (init= 1)
#     B_9_11:   -5.72102183 (init=-1)
#     C_9_11:    0 (fixed)
#     D_9_11:    0 (fixed)
#     A_9_12:    4.68145783 (init= 1)
#     B_9_12:   -0.07286933 (init=-1)
#     C_9_12:    0 (fixed)
#     D_9_12:    0 (fixed)
#     A_9_13:    3.74974539 (init= 1)
#     B_9_13:    75.3244841 (init=-1)
#     C_9_13:    0 (fixed)
#     D_9_13:    0 (fixed)
#     A_9_14:    28.7158831 (init= 1)
#     B_9_14:   -8.88623591 (init=-1)
#     C_9_14:    0 (fixed)
#     D_9_14:    0 (fixed)
#     A_9_15:   -14.0094175 (init= 1)
#     B_9_15:    58.4809456 (init=-1)
#     C_9_15:    0 (fixed)
#     D_9_15:    0 (fixed)
#     A_9_16:    15.1077120 (init= 1)
#     B_9_16:    15.3528927 (init=-1)
#     C_9_16:    0 (fixed)
#     D_9_16:    0 (fixed)
#     A_9_17:   -1.01151455 (init= 1)
#     B_9_17:   -62.6736586 (init=-1)
#     C_9_17:    0 (fixed)
#     D_9_17:    0 (fixed)
#     A_9_18:    3.54743159 (init= 1)
#     B_9_18:   -50.9378201 (init=-1)
#     C_9_18:    0 (fixed)
#     D_9_18:    0 (fixed)
#     A_9_19:    92.1005490 (init= 1)
#     B_9_19:    230.793576 (init=-1)
#     C_9_19:    0 (fixed)
#     D_9_19:    0 (fixed)
#     A_10_0:    0 (fixed)
#     B_10_0:    0 (fixed)
#     C_10_0:    0 (fixed)
#     D_10_0:    0 (fixed)
#     A_10_1:    0 (fixed)
#     B_10_1:    0 (fixed)
#     C_10_1:    0 (fixed)
#     D_10_1:    0 (fixed)
#     A_10_2:    0 (fixed)
#     B_10_2:    0 (fixed)
#     C_10_2:    0 (fixed)
#     D_10_2:    0 (fixed)
#     A_10_3:    0 (fixed)
#     B_10_3:    0 (fixed)
#     C_10_3:    0 (fixed)
#     D_10_3:    0 (fixed)
#     A_10_4:    0 (fixed)
#     B_10_4:    0 (fixed)
#     C_10_4:    0 (fixed)
#     D_10_4:    0 (fixed)
#     A_10_5:    0 (fixed)
#     B_10_5:    0 (fixed)
#     C_10_5:    0 (fixed)
#     D_10_5:    0 (fixed)
#     A_10_6:    0 (fixed)
#     B_10_6:    0 (fixed)
#     C_10_6:    0 (fixed)
#     D_10_6:    0 (fixed)
#     A_10_7:    0 (fixed)
#     B_10_7:    0 (fixed)
#     C_10_7:    0 (fixed)
#     D_10_7:    0 (fixed)
#     A_10_8:    0 (fixed)
#     B_10_8:    0 (fixed)
#     C_10_8:    0 (fixed)
#     D_10_8:    0 (fixed)
#     A_10_9:    0 (fixed)
#     B_10_9:    0 (fixed)
#     C_10_9:    0 (fixed)
#     D_10_9:    0 (fixed)
#     A_10_10:   2.42128001 (init= 1)
#     B_10_10:  -2093.09626 (init=-1)
#     C_10_10:   0 (fixed)
#     D_10_10:   0 (fixed)
#     A_10_11:   0 (fixed)
#     B_10_11:   0.02792812 (init=-1)
#     C_10_11:   0 (fixed)
#     D_10_11:   0 (fixed)
#     A_10_12:  -13.9940620 (init= 1)
#     B_10_12:  -15.9661504 (init=-1)
#     C_10_12:   0 (fixed)
#     D_10_12:   0 (fixed)
#     A_10_13:  -1.67832154 (init= 1)
#     B_10_13:  -8.67480074 (init=-1)
#     C_10_13:   0 (fixed)
#     D_10_13:   0 (fixed)
#     A_10_14:   5.86804546 (init= 1)
#     B_10_14:  -74.0055535 (init=-1)
#     C_10_14:   0 (fixed)
#     D_10_14:   0 (fixed)
#     A_10_15:  -29.1978640 (init= 1)
#     B_10_15:   14.5999407 (init=-1)
#     C_10_15:   0 (fixed)
#     D_10_15:   0 (fixed)
#     A_10_16:  -0.59415481 (init= 1)
#     B_10_16:  -53.7226319 (init=-1)
#     C_10_16:   0 (fixed)
#     D_10_16:   0 (fixed)
#     A_10_17:  -16.7287402 (init= 1)
#     B_10_17:  -33.4671449 (init=-1)
#     C_10_17:   0 (fixed)
#     D_10_17:   0 (fixed)
#     A_10_18:  -8.69288489 (init= 1)
#     B_10_18:   41.5261615 (init=-1)
#     C_10_18:   0 (fixed)
#     D_10_18:   0 (fixed)
#     A_10_19:   101.534238 (init= 1)
#     B_10_19:  -201.963727 (init=-1)
#     C_10_19:   0 (fixed)
#     D_10_19:   0 (fixed)
#     A_11_0:    0 (fixed)
#     B_11_0:    0 (fixed)
#     C_11_0:    0 (fixed)
#     D_11_0:    0 (fixed)
#     A_11_1:    0 (fixed)
#     B_11_1:    0 (fixed)
#     C_11_1:    0 (fixed)
#     D_11_1:    0 (fixed)
#     A_11_2:    0 (fixed)
#     B_11_2:    0 (fixed)
#     C_11_2:    0 (fixed)
#     D_11_2:    0 (fixed)
#     A_11_3:    0 (fixed)
#     B_11_3:    0 (fixed)
#     C_11_3:    0 (fixed)
#     D_11_3:    0 (fixed)
#     A_11_4:    0 (fixed)
#     B_11_4:    0 (fixed)
#     C_11_4:    0 (fixed)
#     D_11_4:    0 (fixed)
#     A_11_5:    0 (fixed)
#     B_11_5:    0 (fixed)
#     C_11_5:    0 (fixed)
#     D_11_5:    0 (fixed)
#     A_11_6:    0 (fixed)
#     B_11_6:    0 (fixed)
#     C_11_6:    0 (fixed)
#     D_11_6:    0 (fixed)
#     A_11_7:    0 (fixed)
#     B_11_7:    0 (fixed)
#     C_11_7:    0 (fixed)
#     D_11_7:    0 (fixed)
#     A_11_8:    0 (fixed)
#     B_11_8:    0 (fixed)
#     C_11_8:    0 (fixed)
#     D_11_8:    0 (fixed)
#     A_11_9:    0 (fixed)
#     B_11_9:    0 (fixed)
#     C_11_9:    0 (fixed)
#     D_11_9:    0 (fixed)
#     A_11_10:   0 (fixed)
#     B_11_10:   0 (fixed)
#     C_11_10:   0 (fixed)
#     D_11_10:   0 (fixed)
#     A_11_11:   11.5078977 (init= 1)
#     B_11_11:   2401.46333 (init=-1)
#     C_11_11:   0 (fixed)
#     D_11_11:   0 (fixed)
#     A_11_12:   0 (fixed)
#     B_11_12:  -53.2457775 (init=-1)
#     C_11_12:   0 (fixed)
#     D_11_12:   0 (fixed)
#     A_11_13:   3.27674494 (init= 1)
#     B_11_13:   21.3043695 (init=-1)
#     C_11_13:   0 (fixed)
#     D_11_13:   0 (fixed)
#     A_11_14:  -2.42882825 (init= 1)
#     B_11_14:   7.09173475 (init=-1)
#     C_11_14:   0 (fixed)
#     D_11_14:   0 (fixed)
#     A_11_15:  -7.14580774 (init= 1)
#     B_11_15:   51.4180125 (init=-1)
#     C_11_15:   0 (fixed)
#     D_11_15:   0 (fixed)
#     A_11_16:   17.9135414 (init= 1)
#     B_11_16:  -12.5161821 (init=-1)
#     C_11_16:   0 (fixed)
#     D_11_16:   0 (fixed)
#     A_11_17:   4.82495446 (init= 1)
#     B_11_17:   28.0813377 (init=-1)
#     C_11_17:   0 (fixed)
#     D_11_17:   0 (fixed)
#     A_11_18:   10.8068474 (init= 1)
#     B_11_18:   15.8751027 (init=-1)
#     C_11_18:   0 (fixed)
#     D_11_18:   0 (fixed)
#     A_11_19:   5.28383467 (init= 1)
#     B_11_19:  -9.26511781 (init=-1)
#     C_11_19:   0 (fixed)
#     D_11_19:   0 (fixed)
#     A_12_0:    0 (fixed)
#     B_12_0:    0 (fixed)
#     C_12_0:    0 (fixed)
#     D_12_0:    0 (fixed)
#     A_12_1:    0 (fixed)
#     B_12_1:    0 (fixed)
#     C_12_1:    0 (fixed)
#     D_12_1:    0 (fixed)
#     A_12_2:    0 (fixed)
#     B_12_2:    0 (fixed)
#     C_12_2:    0 (fixed)
#     D_12_2:    0 (fixed)
#     A_12_3:    0 (fixed)
#     B_12_3:    0 (fixed)
#     C_12_3:    0 (fixed)
#     D_12_3:    0 (fixed)
#     A_12_4:    0 (fixed)
#     B_12_4:    0 (fixed)
#     C_12_4:    0 (fixed)
#     D_12_4:    0 (fixed)
#     A_12_5:    0 (fixed)
#     B_12_5:    0 (fixed)
#     C_12_5:    0 (fixed)
#     D_12_5:    0 (fixed)
#     A_12_6:    0 (fixed)
#     B_12_6:    0 (fixed)
#     C_12_6:    0 (fixed)
#     D_12_6:    0 (fixed)
#     A_12_7:    0 (fixed)
#     B_12_7:    0 (fixed)
#     C_12_7:    0 (fixed)
#     D_12_7:    0 (fixed)
#     A_12_8:    0 (fixed)
#     B_12_8:    0 (fixed)
#     C_12_8:    0 (fixed)
#     D_12_8:    0 (fixed)
#     A_12_9:    0 (fixed)
#     B_12_9:    0 (fixed)
#     C_12_9:    0 (fixed)
#     D_12_9:    0 (fixed)
#     A_12_10:   0 (fixed)
#     B_12_10:   0 (fixed)
#     C_12_10:   0 (fixed)
#     D_12_10:   0 (fixed)
#     A_12_11:   0 (fixed)
#     B_12_11:   0 (fixed)
#     C_12_11:   0 (fixed)
#     D_12_11:   0 (fixed)
#     A_12_12:  -23.8175931 (init= 1)
#     B_12_12:  -756.425072 (init=-1)
#     C_12_12:   0 (fixed)
#     D_12_12:   0 (fixed)
#     A_12_13:   0 (fixed)
#     B_12_13:   97.4668229 (init=-1)
#     C_12_13:   0 (fixed)
#     D_12_13:   0 (fixed)
#     A_12_14:   8.10126193 (init= 1)
#     B_12_14:  -16.0039680 (init=-1)
#     C_12_14:   0 (fixed)
#     D_12_14:   0 (fixed)
#     A_12_15:   3.35452573 (init= 1)
#     B_12_15:  -1.93610287 (init=-1)
#     C_12_15:   0 (fixed)
#     D_12_15:   0 (fixed)
#     A_12_16:   4.00467761 (init= 1)
#     B_12_16:  -25.2075021 (init=-1)
#     C_12_16:   0 (fixed)
#     D_12_16:   0 (fixed)
#     A_12_17:  -6.88614127 (init= 1)
#     B_12_17:   6.47998723 (init=-1)
#     C_12_17:   0 (fixed)
#     D_12_17:   0 (fixed)
#     A_12_18:  -2.35056714 (init= 1)
#     B_12_18:  -8.39167499 (init=-1)
#     C_12_18:   0 (fixed)
#     D_12_18:   0 (fixed)
#     A_12_19:  -2.35724982 (init= 1)
#     B_12_19:  -3.46361352 (init=-1)
#     C_12_19:   0 (fixed)
#     D_12_19:   0 (fixed)
#     A_13_0:    0 (fixed)
#     B_13_0:    0 (fixed)
#     C_13_0:    0 (fixed)
#     D_13_0:    0 (fixed)
#     A_13_1:    0 (fixed)
#     B_13_1:    0 (fixed)
#     C_13_1:    0 (fixed)
#     D_13_1:    0 (fixed)
#     A_13_2:    0 (fixed)
#     B_13_2:    0 (fixed)
#     C_13_2:    0 (fixed)
#     D_13_2:    0 (fixed)
#     A_13_3:    0 (fixed)
#     B_13_3:    0 (fixed)
#     C_13_3:    0 (fixed)
#     D_13_3:    0 (fixed)
#     A_13_4:    0 (fixed)
#     B_13_4:    0 (fixed)
#     C_13_4:    0 (fixed)
#     D_13_4:    0 (fixed)
#     A_13_5:    0 (fixed)
#     B_13_5:    0 (fixed)
#     C_13_5:    0 (fixed)
#     D_13_5:    0 (fixed)
#     A_13_6:    0 (fixed)
#     B_13_6:    0 (fixed)
#     C_13_6:    0 (fixed)
#     D_13_6:    0 (fixed)
#     A_13_7:    0 (fixed)
#     B_13_7:    0 (fixed)
#     C_13_7:    0 (fixed)
#     D_13_7:    0 (fixed)
#     A_13_8:    0 (fixed)
#     B_13_8:    0 (fixed)
#     C_13_8:    0 (fixed)
#     D_13_8:    0 (fixed)
#     A_13_9:    0 (fixed)
#     B_13_9:    0 (fixed)
#     C_13_9:    0 (fixed)
#     D_13_9:    0 (fixed)
#     A_13_10:   0 (fixed)
#     B_13_10:   0 (fixed)
#     C_13_10:   0 (fixed)
#     D_13_10:   0 (fixed)
#     A_13_11:   0 (fixed)
#     B_13_11:   0 (fixed)
#     C_13_11:   0 (fixed)
#     D_13_11:   0 (fixed)
#     A_13_12:   0 (fixed)
#     B_13_12:   0 (fixed)
#     C_13_12:   0 (fixed)
#     D_13_12:   0 (fixed)
#     A_13_13:   26.5419245 (init= 1)
#     B_13_13:  -642.467680 (init=-1)
#     C_13_13:   0 (fixed)
#     D_13_13:   0 (fixed)
#     A_13_14:   0 (fixed)
#     B_13_14:  -94.7987624 (init=-1)
#     C_13_14:   0 (fixed)
#     D_13_14:   0 (fixed)
#     A_13_15:  -9.76594819 (init= 1)
#     B_13_15:   8.59271727 (init=-1)
#     C_13_15:   0 (fixed)
#     D_13_15:   0 (fixed)
#     A_13_16:  -2.07859876 (init= 1)
#     B_13_16:  -0.72994323 (init=-1)
#     C_13_16:   0 (fixed)
#     D_13_16:   0 (fixed)
#     A_13_17:  -1.31730402 (init= 1)
#     B_13_17:   8.41984597 (init=-1)
#     C_13_17:   0 (fixed)
#     D_13_17:   0 (fixed)
#     A_13_18:   1.56300080 (init= 1)
#     B_13_18:  -1.94199801 (init=-1)
#     C_13_18:   0 (fixed)
#     D_13_18:   0 (fixed)
#     A_13_19:   0.43109870 (init= 1)
#     B_13_19:   1.13028794 (init=-1)
#     C_13_19:   0 (fixed)
#     D_13_19:   0 (fixed)
#     A_14_0:    0 (fixed)
#     B_14_0:    0 (fixed)
#     C_14_0:    0 (fixed)
#     D_14_0:    0 (fixed)
#     A_14_1:    0 (fixed)
#     B_14_1:    0 (fixed)
#     C_14_1:    0 (fixed)
#     D_14_1:    0 (fixed)
#     A_14_2:    0 (fixed)
#     B_14_2:    0 (fixed)
#     C_14_2:    0 (fixed)
#     D_14_2:    0 (fixed)
#     A_14_3:    0 (fixed)
#     B_14_3:    0 (fixed)
#     C_14_3:    0 (fixed)
#     D_14_3:    0 (fixed)
#     A_14_4:    0 (fixed)
#     B_14_4:    0 (fixed)
#     C_14_4:    0 (fixed)
#     D_14_4:    0 (fixed)
#     A_14_5:    0 (fixed)
#     B_14_5:    0 (fixed)
#     C_14_5:    0 (fixed)
#     D_14_5:    0 (fixed)
#     A_14_6:    0 (fixed)
#     B_14_6:    0 (fixed)
#     C_14_6:    0 (fixed)
#     D_14_6:    0 (fixed)
#     A_14_7:    0 (fixed)
#     B_14_7:    0 (fixed)
#     C_14_7:    0 (fixed)
#     D_14_7:    0 (fixed)
#     A_14_8:    0 (fixed)
#     B_14_8:    0 (fixed)
#     C_14_8:    0 (fixed)
#     D_14_8:    0 (fixed)
#     A_14_9:    0 (fixed)
#     B_14_9:    0 (fixed)
#     C_14_9:    0 (fixed)
#     D_14_9:    0 (fixed)
#     A_14_10:   0 (fixed)
#     B_14_10:   0 (fixed)
#     C_14_10:   0 (fixed)
#     D_14_10:   0 (fixed)
#     A_14_11:   0 (fixed)
#     B_14_11:   0 (fixed)
#     C_14_11:   0 (fixed)
#     D_14_11:   0 (fixed)
#     A_14_12:   0 (fixed)
#     B_14_12:   0 (fixed)
#     C_14_12:   0 (fixed)
#     D_14_12:   0 (fixed)
#     A_14_13:   0 (fixed)
#     B_14_13:   0 (fixed)
#     C_14_13:   0 (fixed)
#     D_14_13:   0 (fixed)
#     A_14_14:  -20.0879836 (init= 1)
#     B_14_14:   924.766229 (init=-1)
#     C_14_14:   0 (fixed)
#     D_14_14:   0 (fixed)
#     A_14_15:   0 (fixed)
#     B_14_15:   60.1548591 (init=-1)
#     C_14_15:   0 (fixed)
#     D_14_15:   0 (fixed)
#     A_14_16:   5.70291801 (init= 1)
#     B_14_16:  -3.45677677 (init=-1)
#     C_14_16:   0 (fixed)
#     D_14_16:   0 (fixed)
#     A_14_17:   0.75781621 (init= 1)
#     B_14_17:   0.79893065 (init=-1)
#     C_14_17:   0 (fixed)
#     D_14_17:   0 (fixed)
#     A_14_18:   0.24271115 (init= 1)
#     B_14_18:  -1.74775192 (init=-1)
#     C_14_18:   0 (fixed)
#     D_14_18:   0 (fixed)
#     A_14_19:  -0.16800475 (init= 1)
#     B_14_19:   0.25568685 (init=-1)
#     C_14_19:   0 (fixed)
#     D_14_19:   0 (fixed)
#     A_15_0:    0 (fixed)
#     B_15_0:    0 (fixed)
#     C_15_0:    0 (fixed)
#     D_15_0:    0 (fixed)
#     A_15_1:    0 (fixed)
#     B_15_1:    0 (fixed)
#     C_15_1:    0 (fixed)
#     D_15_1:    0 (fixed)
#     A_15_2:    0 (fixed)
#     B_15_2:    0 (fixed)
#     C_15_2:    0 (fixed)
#     D_15_2:    0 (fixed)
#     A_15_3:    0 (fixed)
#     B_15_3:    0 (fixed)
#     C_15_3:    0 (fixed)
#     D_15_3:    0 (fixed)
#     A_15_4:    0 (fixed)
#     B_15_4:    0 (fixed)
#     C_15_4:    0 (fixed)
#     D_15_4:    0 (fixed)
#     A_15_5:    0 (fixed)
#     B_15_5:    0 (fixed)
#     C_15_5:    0 (fixed)
#     D_15_5:    0 (fixed)
#     A_15_6:    0 (fixed)
#     B_15_6:    0 (fixed)
#     C_15_6:    0 (fixed)
#     D_15_6:    0 (fixed)
#     A_15_7:    0 (fixed)
#     B_15_7:    0 (fixed)
#     C_15_7:    0 (fixed)
#     D_15_7:    0 (fixed)
#     A_15_8:    0 (fixed)
#     B_15_8:    0 (fixed)
#     C_15_8:    0 (fixed)
#     D_15_8:    0 (fixed)
#     A_15_9:    0 (fixed)
#     B_15_9:    0 (fixed)
#     C_15_9:    0 (fixed)
#     D_15_9:    0 (fixed)
#     A_15_10:   0 (fixed)
#     B_15_10:   0 (fixed)
#     C_15_10:   0 (fixed)
#     D_15_10:   0 (fixed)
#     A_15_11:   0 (fixed)
#     B_15_11:   0 (fixed)
#     C_15_11:   0 (fixed)
#     D_15_11:   0 (fixed)
#     A_15_12:   0 (fixed)
#     B_15_12:   0 (fixed)
#     C_15_12:   0 (fixed)
#     D_15_12:   0 (fixed)
#     A_15_13:   0 (fixed)
#     B_15_13:   0 (fixed)
#     C_15_13:   0 (fixed)
#     D_15_13:   0 (fixed)
#     A_15_14:   0 (fixed)
#     B_15_14:   0 (fixed)
#     C_15_14:   0 (fixed)
#     D_15_14:   0 (fixed)
#     A_15_15:   10.8536356 (init= 1)
#     B_15_15:  -577.443801 (init=-1)
#     C_15_15:   0 (fixed)
#     D_15_15:   0 (fixed)
#     A_15_16:   0 (fixed)
#     B_15_16:  -26.0680963 (init=-1)
#     C_15_16:   0 (fixed)
#     D_15_16:   0 (fixed)
#     A_15_17:  -1.99632144 (init= 1)
#     B_15_17:   1.01739602 (init=-1)
#     C_15_17:   0 (fixed)
#     D_15_17:   0 (fixed)
#     A_15_18:  -0.15851629 (init= 1)
#     B_15_18:  -0.27662150 (init=-1)
#     C_15_18:   0 (fixed)
#     D_15_18:   0 (fixed)
#     A_15_19:  -0.01783977 (init= 1)
#     B_15_19:   0.17398147 (init=-1)
#     C_15_19:   0 (fixed)
#     D_15_19:   0 (fixed)
#     A_16_0:    0 (fixed)
#     B_16_0:    0 (fixed)
#     C_16_0:    0 (fixed)
#     D_16_0:    0 (fixed)
#     A_16_1:    0 (fixed)
#     B_16_1:    0 (fixed)
#     C_16_1:    0 (fixed)
#     D_16_1:    0 (fixed)
#     A_16_2:    0 (fixed)
#     B_16_2:    0 (fixed)
#     C_16_2:    0 (fixed)
#     D_16_2:    0 (fixed)
#     A_16_3:    0 (fixed)
#     B_16_3:    0 (fixed)
#     C_16_3:    0 (fixed)
#     D_16_3:    0 (fixed)
#     A_16_4:    0 (fixed)
#     B_16_4:    0 (fixed)
#     C_16_4:    0 (fixed)
#     D_16_4:    0 (fixed)
#     A_16_5:    0 (fixed)
#     B_16_5:    0 (fixed)
#     C_16_5:    0 (fixed)
#     D_16_5:    0 (fixed)
#     A_16_6:    0 (fixed)
#     B_16_6:    0 (fixed)
#     C_16_6:    0 (fixed)
#     D_16_6:    0 (fixed)
#     A_16_7:    0 (fixed)
#     B_16_7:    0 (fixed)
#     C_16_7:    0 (fixed)
#     D_16_7:    0 (fixed)
#     A_16_8:    0 (fixed)
#     B_16_8:    0 (fixed)
#     C_16_8:    0 (fixed)
#     D_16_8:    0 (fixed)
#     A_16_9:    0 (fixed)
#     B_16_9:    0 (fixed)
#     C_16_9:    0 (fixed)
#     D_16_9:    0 (fixed)
#     A_16_10:   0 (fixed)
#     B_16_10:   0 (fixed)
#     C_16_10:   0 (fixed)
#     D_16_10:   0 (fixed)
#     A_16_11:   0 (fixed)
#     B_16_11:   0 (fixed)
#     C_16_11:   0 (fixed)
#     D_16_11:   0 (fixed)
#     A_16_12:   0 (fixed)
#     B_16_12:   0 (fixed)
#     C_16_12:   0 (fixed)
#     D_16_12:   0 (fixed)
#     A_16_13:   0 (fixed)
#     B_16_13:   0 (fixed)
#     C_16_13:   0 (fixed)
#     D_16_13:   0 (fixed)
#     A_16_14:   0 (fixed)
#     B_16_14:   0 (fixed)
#     C_16_14:   0 (fixed)
#     D_16_14:   0 (fixed)
#     A_16_15:   0 (fixed)
#     B_16_15:   0 (fixed)
#     C_16_15:   0 (fixed)
#     D_16_15:   0 (fixed)
#     A_16_16:  -4.17109216 (init= 1)
#     B_16_16:   223.234261 (init=-1)
#     C_16_16:   0 (fixed)
#     D_16_16:   0 (fixed)
#     A_16_17:   0 (fixed)
#     B_16_17:   7.56570459 (init=-1)
#     C_16_17:   0 (fixed)
#     D_16_17:   0 (fixed)
#     A_16_18:   0.40600668 (init= 1)
#     B_16_18:  -0.19843728 (init=-1)
#     C_16_18:   0 (fixed)
#     D_16_18:   0 (fixed)
#     A_16_19:   0.01480216 (init= 1)
#     B_16_19:   0.03807554 (init=-1)
#     C_16_19:   0 (fixed)
#     D_16_19:   0 (fixed)
#     A_17_0:    0 (fixed)
#     B_17_0:    0 (fixed)
#     C_17_0:    0 (fixed)
#     D_17_0:    0 (fixed)
#     A_17_1:    0 (fixed)
#     B_17_1:    0 (fixed)
#     C_17_1:    0 (fixed)
#     D_17_1:    0 (fixed)
#     A_17_2:    0 (fixed)
#     B_17_2:    0 (fixed)
#     C_17_2:    0 (fixed)
#     D_17_2:    0 (fixed)
#     A_17_3:    0 (fixed)
#     B_17_3:    0 (fixed)
#     C_17_3:    0 (fixed)
#     D_17_3:    0 (fixed)
#     A_17_4:    0 (fixed)
#     B_17_4:    0 (fixed)
#     C_17_4:    0 (fixed)
#     D_17_4:    0 (fixed)
#     A_17_5:    0 (fixed)
#     B_17_5:    0 (fixed)
#     C_17_5:    0 (fixed)
#     D_17_5:    0 (fixed)
#     A_17_6:    0 (fixed)
#     B_17_6:    0 (fixed)
#     C_17_6:    0 (fixed)
#     D_17_6:    0 (fixed)
#     A_17_7:    0 (fixed)
#     B_17_7:    0 (fixed)
#     C_17_7:    0 (fixed)
#     D_17_7:    0 (fixed)
#     A_17_8:    0 (fixed)
#     B_17_8:    0 (fixed)
#     C_17_8:    0 (fixed)
#     D_17_8:    0 (fixed)
#     A_17_9:    0 (fixed)
#     B_17_9:    0 (fixed)
#     C_17_9:    0 (fixed)
#     D_17_9:    0 (fixed)
#     A_17_10:   0 (fixed)
#     B_17_10:   0 (fixed)
#     C_17_10:   0 (fixed)
#     D_17_10:   0 (fixed)
#     A_17_11:   0 (fixed)
#     B_17_11:   0 (fixed)
#     C_17_11:   0 (fixed)
#     D_17_11:   0 (fixed)
#     A_17_12:   0 (fixed)
#     B_17_12:   0 (fixed)
#     C_17_12:   0 (fixed)
#     D_17_12:   0 (fixed)
#     A_17_13:   0 (fixed)
#     B_17_13:   0 (fixed)
#     C_17_13:   0 (fixed)
#     D_17_13:   0 (fixed)
#     A_17_14:   0 (fixed)
#     B_17_14:   0 (fixed)
#     C_17_14:   0 (fixed)
#     D_17_14:   0 (fixed)
#     A_17_15:   0 (fixed)
#     B_17_15:   0 (fixed)
#     C_17_15:   0 (fixed)
#     D_17_15:   0 (fixed)
#     A_17_16:   0 (fixed)
#     B_17_16:   0 (fixed)
#     C_17_16:   0 (fixed)
#     D_17_16:   0 (fixed)
#     A_17_17:   1.09209330 (init= 1)
#     B_17_17:  -55.4229385 (init=-1)
#     C_17_17:   0 (fixed)
#     D_17_17:   0 (fixed)
#     A_17_18:   0 (fixed)
#     B_17_18:  -1.34488253 (init=-1)
#     C_17_18:   0 (fixed)
#     D_17_18:   0 (fixed)
#     A_17_19:  -0.03748568 (init= 1)
#     B_17_19:   0.01943829 (init=-1)
#     C_17_19:   0 (fixed)
#     D_17_19:   0 (fixed)
#     A_18_0:    0 (fixed)
#     B_18_0:    0 (fixed)
#     C_18_0:    0 (fixed)
#     D_18_0:    0 (fixed)
#     A_18_1:    0 (fixed)
#     B_18_1:    0 (fixed)
#     C_18_1:    0 (fixed)
#     D_18_1:    0 (fixed)
#     A_18_2:    0 (fixed)
#     B_18_2:    0 (fixed)
#     C_18_2:    0 (fixed)
#     D_18_2:    0 (fixed)
#     A_18_3:    0 (fixed)
#     B_18_3:    0 (fixed)
#     C_18_3:    0 (fixed)
#     D_18_3:    0 (fixed)
#     A_18_4:    0 (fixed)
#     B_18_4:    0 (fixed)
#     C_18_4:    0 (fixed)
#     D_18_4:    0 (fixed)
#     A_18_5:    0 (fixed)
#     B_18_5:    0 (fixed)
#     C_18_5:    0 (fixed)
#     D_18_5:    0 (fixed)
#     A_18_6:    0 (fixed)
#     B_18_6:    0 (fixed)
#     C_18_6:    0 (fixed)
#     D_18_6:    0 (fixed)
#     A_18_7:    0 (fixed)
#     B_18_7:    0 (fixed)
#     C_18_7:    0 (fixed)
#     D_18_7:    0 (fixed)
#     A_18_8:    0 (fixed)
#     B_18_8:    0 (fixed)
#     C_18_8:    0 (fixed)
#     D_18_8:    0 (fixed)
#     A_18_9:    0 (fixed)
#     B_18_9:    0 (fixed)
#     C_18_9:    0 (fixed)
#     D_18_9:    0 (fixed)
#     A_18_10:   0 (fixed)
#     B_18_10:   0 (fixed)
#     C_18_10:   0 (fixed)
#     D_18_10:   0 (fixed)
#     A_18_11:   0 (fixed)
#     B_18_11:   0 (fixed)
#     C_18_11:   0 (fixed)
#     D_18_11:   0 (fixed)
#     A_18_12:   0 (fixed)
#     B_18_12:   0 (fixed)
#     C_18_12:   0 (fixed)
#     D_18_12:   0 (fixed)
#     A_18_13:   0 (fixed)
#     B_18_13:   0 (fixed)
#     C_18_13:   0 (fixed)
#     D_18_13:   0 (fixed)
#     A_18_14:   0 (fixed)
#     B_18_14:   0 (fixed)
#     C_18_14:   0 (fixed)
#     D_18_14:   0 (fixed)
#     A_18_15:   0 (fixed)
#     B_18_15:   0 (fixed)
#     C_18_15:   0 (fixed)
#     D_18_15:   0 (fixed)
#     A_18_16:   0 (fixed)
#     B_18_16:   0 (fixed)
#     C_18_16:   0 (fixed)
#     D_18_16:   0 (fixed)
#     A_18_17:   0 (fixed)
#     B_18_17:   0 (fixed)
#     C_18_17:   0 (fixed)
#     D_18_17:   0 (fixed)
#     A_18_18:  -0.17551181 (init= 1)
#     B_18_18:   8.22042178 (init=-1)
#     C_18_18:   0 (fixed)
#     D_18_18:   0 (fixed)
#     A_18_19:   0 (fixed)
#     B_18_19:   0.11214159 (init=-1)
#     C_18_19:   0 (fixed)
#     D_18_19:   0 (fixed)
#     A_19_0:    0 (fixed)
#     B_19_0:    0 (fixed)
#     C_19_0:    0 (fixed)
#     D_19_0:    0 (fixed)
#     A_19_1:    0 (fixed)
#     B_19_1:    0 (fixed)
#     C_19_1:    0 (fixed)
#     D_19_1:    0 (fixed)
#     A_19_2:    0 (fixed)
#     B_19_2:    0 (fixed)
#     C_19_2:    0 (fixed)
#     D_19_2:    0 (fixed)
#     A_19_3:    0 (fixed)
#     B_19_3:    0 (fixed)
#     C_19_3:    0 (fixed)
#     D_19_3:    0 (fixed)
#     A_19_4:    0 (fixed)
#     B_19_4:    0 (fixed)
#     C_19_4:    0 (fixed)
#     D_19_4:    0 (fixed)
#     A_19_5:    0 (fixed)
#     B_19_5:    0 (fixed)
#     C_19_5:    0 (fixed)
#     D_19_5:    0 (fixed)
#     A_19_6:    0 (fixed)
#     B_19_6:    0 (fixed)
#     C_19_6:    0 (fixed)
#     D_19_6:    0 (fixed)
#     A_19_7:    0 (fixed)
#     B_19_7:    0 (fixed)
#     C_19_7:    0 (fixed)
#     D_19_7:    0 (fixed)
#     A_19_8:    0 (fixed)
#     B_19_8:    0 (fixed)
#     C_19_8:    0 (fixed)
#     D_19_8:    0 (fixed)
#     A_19_9:    0 (fixed)
#     B_19_9:    0 (fixed)
#     C_19_9:    0 (fixed)
#     D_19_9:    0 (fixed)
#     A_19_10:   0 (fixed)
#     B_19_10:   0 (fixed)
#     C_19_10:   0 (fixed)
#     D_19_10:   0 (fixed)
#     A_19_11:   0 (fixed)
#     B_19_11:   0 (fixed)
#     C_19_11:   0 (fixed)
#     D_19_11:   0 (fixed)
#     A_19_12:   0 (fixed)
#     B_19_12:   0 (fixed)
#     C_19_12:   0 (fixed)
#     D_19_12:   0 (fixed)
#     A_19_13:   0 (fixed)
#     B_19_13:   0 (fixed)
#     C_19_13:   0 (fixed)
#     D_19_13:   0 (fixed)
#     A_19_14:   0 (fixed)
#     B_19_14:   0 (fixed)
#     C_19_14:   0 (fixed)
#     D_19_14:   0 (fixed)
#     A_19_15:   0 (fixed)
#     B_19_15:   0 (fixed)
#     C_19_15:   0 (fixed)
#     D_19_15:   0 (fixed)
#     A_19_16:   0 (fixed)
#     B_19_16:   0 (fixed)
#     C_19_16:   0 (fixed)
#     D_19_16:   0 (fixed)
#     A_19_17:   0 (fixed)
#     B_19_17:   0 (fixed)
#     C_19_17:   0 (fixed)
#     D_19_17:   0 (fixed)
#     A_19_18:   0 (fixed)
#     B_19_18:   0 (fixed)
#     C_19_18:   0 (fixed)
#     D_19_18:   0 (fixed)
#     A_19_19:   0.01309209 (init= 1)
#     B_19_19:  -0.56070033 (init=-1)
#     C_19_19:   0 (fixed)
#     D_19_19:   0 (fixed)

# %%
ff2 = deepcopy(ff)

# %%
labs=[i[2:] for i in ff1.params if ('A' in i and ff1.params[i].vary==True and i.split('_')[1] != '0')]

As_1=[ff1.params[i].value for i in ff1.params if ('A' in i and ff1.params[i].vary==True and i.split('_')[1] != '0')]
As_2=[ff2.params[i].value for i in ff2.params if ('A' in i and ff2.params[i].vary==True and i.split('_')[1] != '0')]
#As_3=[ff3.params[i].value for i in ff3.params if ('A' in i and ff3.params[i].vary==True and i.split('_')[1] != '0')]


Bs_1=[ff1.params[i].value for i in ff1.params if ('B' in i and ff1.params[i].vary==True and i.split('_')[1] != '0')]
Bs_2=[ff2.params[i].value for i in ff2.params if ('B' in i and ff2.params[i].vary==True and i.split('_')[1] != '0')]
#Bs_3=[ff3.params[i].value for i in ff3.params if ('B' in i and ff3.params[i].vary==True and i.split('_')[1] != '0')]

# %%
_ = plt.plot(range(len(As_1)),As_1, 'o-', label='As, phi=0')
_ = plt.plot(range(len(As_1)),As_2, 'o-', label='As, phi=pi/2')
#_ = plt.plot(range(len(As_1)),As_3, 'o-', label='As, phi=pi/8')
_ = plt.axhline(0,0, 1, linestyle='--', color='k')

_ = plt.xticks(range(len(As_1)), labs, rotation='vertical')
plt.yscale('symlog')
plt.legend()
plt.title('Free param values for A')

# %%
_ = plt.plot(range(len(Bs_1)),Bs_1, 'o-', label='Bs, phi=0')
_ = plt.plot(range(len(Bs_1)),Bs_2, 'o-', label='Bs, phi=pi/2')
#_ = plt.plot(range(len(Bs_1)),Bs_3, 'o-', label='Bs, phi=pi/8')
_ = plt.axhline(0,0, 1, linestyle='--', color='k')


_ = plt.xticks(range(len(Bs_1)), labs, rotation='vertical')
plt.yscale('symlog')
plt.legend()
plt.title('Free param values for B')

# %%
_ = plt.plot(As_1,As_2, 'o', label='As')
_ = plt.plot(Bs_1,Bs_2, 's', label='Bs')
plt.ylim(-10e7, 10e7)
plt.xlim(-10e7, 10e7)
_ =plt.plot(plt.gca().get_xlim(), plt.gca().get_ylim(), 'k--', zorder=0)
_ =plt.plot(plt.gca().get_xlim(), plt.gca().get_ylim()[::-1], 'k--', zorder=0)

#_ = plt.plot(range(len(Bs_1)),Bs_2, 'o-', label='Bs, 2 slices')
#_ = plt.xticks(range(len(Bs_1)), labs, rotation='vertical')
plt.xscale('symlog')
plt.yscale('symlog')
plt.legend()
plt.title('Free param values, phi=0 vs phi=pi/2')
plt.xlabel('1 slice phi=0')
plt.ylabel('1 slice phi=pi/2')

# %%
_ = plt.plot(As_1,As_3, 'o', color='C2', label='As')
_ = plt.plot(Bs_1,Bs_3, 's', color='C4', label='Bs')
plt.ylim(-10e7, 10e7)
plt.xlim(-10e7, 10e7)
_ =plt.plot(plt.gca().get_xlim(), plt.gca().get_ylim(), 'k--', zorder=0)
_ =plt.plot(plt.gca().get_xlim(), plt.gca().get_ylim()[::-1], 'k--', zorder=0)

#_ = plt.plot(range(len(Bs_1)),Bs_2, 'o-', label='Bs, 2 slices')
#_ = plt.xticks(range(len(Bs_1)), labs, rotation='vertical')
plt.xscale('symlog')
plt.yscale('symlog')
plt.legend()
plt.title('Free param values, phi=0 vs phi=pi/8')
plt.xlabel('1 slice phi=0')
plt.ylabel('1 slice phi=pi/8')

# %%
_ = plt.plot(range(len(Bs_1)),[Bs_1[i]/Bs_2[i] for i in range(len(Bs_2))], 'o-', label='B(phi 0)/B(phi pi/2)')
#_ = plt.plot(range(len(Bs_1)),Bs_1b, 'o-', label='Bs, 1 slice phi=pi/2')
_ = plt.xticks(range(len(Bs_1)), labs, rotation='vertical')
plt.yscale('symlog')
plt.legend()
plt.title('Ratio of B values')

# %%
_ = plt.plot(range(len(As_1)),[As_1[i]/As_2[i] for i in range(len(As_2))], 'o-', label='A(phi 0)/A(phi pi/2)')
#_ = plt.plot(range(len(Bs_1)),Bs_1b, 'o-', label='Bs, 1 slice phi=pi/2')
_ = plt.xticks(range(len(As_1)), labs, rotation='vertical')
plt.yscale('symlog')
plt.legend()
plt.title('Ratio of A values')

# %%
n,m = np.meshgrid(range(21),range(21))
Anm1 = np.asarray([ff1.params[i] for i in ff1.params if 'A' in i]).reshape(20,20)
Bnm1 = np.asarray([ff1.params[i] for i in ff1.params if 'B' in i]).reshape(20,20)
Anm2 = np.asarray([ff2.params[i] for i in ff1.params if 'A' in i]).reshape(20,20)
Bnm2 = np.asarray([ff2.params[i] for i in ff1.params if 'B' in i]).reshape(20,20)
Anm_rat = np.nan_to_num(Anm1/Anm2)
Bnm_rat = np.nan_to_num(Bnm1/Bnm2)
AB_comb1 = Anm1**2+Bnm1**2
AB_comb2 = Anm2**2+Bnm2**2

# %%
import matplotlib.colors as colors
plt.pcolor(n,m, Anm,
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=Anm.min(), vmax=Anm.max()))
plt.colorbar()
plt.title('Amn for Phi=0')
plt.xlabel('m')
plt.ylabel('n')
plt.figure()
plt.pcolor(n,m, Bnm,
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=Bnm.min(), vmax=Bnm.max()))
plt.colorbar()
plt.title('Bmn for Phi=0')
plt.xlabel('m')
plt.ylabel('n')

# %%
import matplotlib.colors as colors
plt.pcolor(n,m, abs(Anm),
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=0, vmax=Anm.max()))
plt.colorbar()
plt.title('abs(Amn) for Phi=0')
plt.xlabel('m')
plt.ylabel('n')
plt.figure()
plt.pcolor(n,m, abs(Bnm),
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=0, vmax=Bnm.max()))
plt.colorbar()
plt.title('abs(Bmn) for Phi=0')
plt.xlabel('m')
plt.ylabel('n')

# %%
import matplotlib.colors as colors
plt.pcolor(n,m, abs(Anm_rat),
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=0, vmax=Anm_rat.max()))
plt.colorbar()
plt.title('abs(Amn (phi=0)/Amn (phi=pi/2))')
plt.xlabel('m')
plt.ylabel('n')
plt.figure()
plt.pcolor(n,m, abs(Bnm_rat),
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=0, vmax=Bnm_rat.max()))
plt.colorbar()
plt.title('abs(Bmn (phi=0)/Bmn (phi=pi/2))')
plt.xlabel('m')
plt.ylabel('n')

# %%
import matplotlib.colors as colors
plt.pcolor(n,m, AB_comb1,
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=AB_comb1.min(), vmax=AB_comb1.max()))
plt.colorbar()
plt.title('Anm^2+Bnm^2, phi=0')
plt.xlabel('m')
plt.ylabel('n')
plt.figure()

plt.pcolor(n,m, AB_comb2,
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=AB_comb2.min(), vmax=AB_comb2.max()))
plt.colorbar()
plt.title('Anm^2+Bnm^2, phi=pi/2')
plt.xlabel('m')
plt.ylabel('n')
