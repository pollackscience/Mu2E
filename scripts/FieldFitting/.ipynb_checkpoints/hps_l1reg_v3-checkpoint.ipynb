# %%
import os
from mu2e import mu2e_ext_path
from mu2e.dataframeprod import DataFrameMaker
from mu2e.mu2eplots import mu2e_plot, mu2e_plot3d
import pandas as pd
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12,8)
from skhep.visual import MplPlotter as splt
from copy import deepcopy
from lmfit import Model, Parameters, report_fit

# %% [markdown]
# # 1 Slice v 1 Slice

# %%
run hallprobesim.py
# Out:
# 0
# (140, 10)
# 375.0
# 1450.0
# 0.002490821
# 2260594    0.002491
# Name: Br, dtype: float64
# fitting with n=20, m=20, cn=0, cm=0
# Elapsed time was 370.584 seconds
# [[Fit Statistics]]
#     # function evals   = 40
#     # data points      = 4200
#     # variables        = 362
#     chi-square         = 0.000
#     reduced chi-square = 0.000
#     Akaike info crit   = -118088.051
#     Bayesian info crit = -115791.943
# [[Variables]]
#     R:         12500 (fixed)
#     ns:        20 (fixed)
#     ms:        20 (fixed)
#     A_0_0:     0 (fixed)
#     B_0_0:     0 (fixed)
#     C_0_0:     0 (fixed)
#     D_0_0:     0 (fixed)
#     A_0_1:     0 (fixed)
#     B_0_1:     0 (fixed)
#     C_0_1:     0 (fixed)
#     D_0_1:     0 (fixed)
#     A_0_2:     0 (fixed)
#     B_0_2:     0 (fixed)
#     C_0_2:     0 (fixed)
#     D_0_2:     0 (fixed)
#     A_0_3:     0 (fixed)
#     B_0_3:     0 (fixed)
#     C_0_3:     0 (fixed)
#     D_0_3:     0 (fixed)
#     A_0_4:     0 (fixed)
#     B_0_4:     0 (fixed)
#     C_0_4:     0 (fixed)
#     D_0_4:     0 (fixed)
#     A_0_5:     0 (fixed)
#     B_0_5:     0 (fixed)
#     C_0_5:     0 (fixed)
#     D_0_5:     0 (fixed)
#     A_0_6:     0 (fixed)
#     B_0_6:     0 (fixed)
#     C_0_6:     0 (fixed)
#     D_0_6:     0 (fixed)
#     A_0_7:     0 (fixed)
#     B_0_7:     0 (fixed)
#     C_0_7:     0 (fixed)
#     D_0_7:     0 (fixed)
#     A_0_8:     0 (fixed)
#     B_0_8:     0 (fixed)
#     C_0_8:     0 (fixed)
#     D_0_8:     0 (fixed)
#     A_0_9:     0 (fixed)
#     B_0_9:     0 (fixed)
#     C_0_9:     0 (fixed)
#     D_0_9:     0 (fixed)
#     A_0_10:    0 (fixed)
#     B_0_10:    0 (fixed)
#     C_0_10:    0 (fixed)
#     D_0_10:    0 (fixed)
#     A_0_11:    0 (fixed)
#     B_0_11:    0 (fixed)
#     C_0_11:    0 (fixed)
#     D_0_11:    0 (fixed)
#     A_0_12:    0 (fixed)
#     B_0_12:    0 (fixed)
#     C_0_12:    0 (fixed)
#     D_0_12:    0 (fixed)
#     A_0_13:    0 (fixed)
#     B_0_13:    0 (fixed)
#     C_0_13:    0 (fixed)
#     D_0_13:    0 (fixed)
#     A_0_14:    0 (fixed)
#     B_0_14:    0 (fixed)
#     C_0_14:    0 (fixed)
#     D_0_14:    0 (fixed)
#     A_0_15:    0 (fixed)
#     B_0_15:    0 (fixed)
#     C_0_15:    0 (fixed)
#     D_0_15:    0 (fixed)
#     A_0_16:    0 (fixed)
#     B_0_16:    0 (fixed)
#     C_0_16:    0 (fixed)
#     D_0_16:    0 (fixed)
#     A_0_17:    0 (fixed)
#     B_0_17:    0 (fixed)
#     C_0_17:    0 (fixed)
#     D_0_17:    0 (fixed)
#     A_0_18:    0 (fixed)
#     B_0_18:    0 (fixed)
#     C_0_18:    0 (fixed)
#     D_0_18:    0 (fixed)
#     A_0_19:    0 (fixed)
#     B_0_19:    0 (fixed)
#     C_0_19:    0 (fixed)
#     D_0_19:    0 (fixed)
#     A_1_0:     0 (fixed)
#     B_1_0:     0 (fixed)
#     C_1_0:     0 (fixed)
#     D_1_0:     0 (fixed)
#     A_1_1:    -21.9437114 (init= 1)
#     B_1_1:     3631.81230 (init=-1)
#     C_1_1:     0 (fixed)
#     D_1_1:     0 (fixed)
#     A_1_2:     0 (fixed)
#     B_1_2:     0.55071047 (init=-1)
#     C_1_2:     0 (fixed)
#     D_1_2:     0 (fixed)
#     A_1_3:    -0.81271424 (init= 1)
#     B_1_3:    -0.88971840 (init=-1)
#     C_1_3:     0 (fixed)
#     D_1_3:     0 (fixed)
#     A_1_4:     2.83862793 (init= 1)
#     B_1_4:    -19.6668026 (init=-1)
#     C_1_4:     0 (fixed)
#     D_1_4:     0 (fixed)
#     A_1_5:     35.2394219 (init= 1)
#     B_1_5:    -0.03386092 (init=-1)
#     C_1_5:     0 (fixed)
#     D_1_5:     0 (fixed)
#     A_1_6:    -911.664978 (init= 1)
#     B_1_6:     878.289040 (init=-1)
#     C_1_6:     0 (fixed)
#     D_1_6:     0 (fixed)
#     A_1_7:     6970.96695 (init= 1)
#     B_1_7:     2209.86677 (init=-1)
#     C_1_7:     0 (fixed)
#     D_1_7:     0 (fixed)
#     A_1_8:     31017.0478 (init= 1)
#     B_1_8:     35416.1032 (init=-1)
#     C_1_8:     0 (fixed)
#     D_1_8:     0 (fixed)
#     A_1_9:     11782.4079 (init= 1)
#     B_1_9:    -8003.73468 (init=-1)
#     C_1_9:     0 (fixed)
#     D_1_9:     0 (fixed)
#     A_1_10:    3899.32307 (init= 1)
#     B_1_10:    540.427664 (init=-1)
#     C_1_10:    0 (fixed)
#     D_1_10:    0 (fixed)
#     A_1_11:   -1570.42028 (init= 1)
#     B_1_11:   -76.3389439 (init=-1)
#     C_1_11:    0 (fixed)
#     D_1_11:    0 (fixed)
#     A_1_12:   -297.804299 (init= 1)
#     B_1_12:    258.100859 (init=-1)
#     C_1_12:    0 (fixed)
#     D_1_12:    0 (fixed)
#     A_1_13:    272.931082 (init= 1)
#     B_1_13:    677.548727 (init=-1)
#     C_1_13:    0 (fixed)
#     D_1_13:    0 (fixed)
#     A_1_14:   -49.3600954 (init= 1)
#     B_1_14:   -505.037762 (init=-1)
#     C_1_14:    0 (fixed)
#     D_1_14:    0 (fixed)
#     A_1_15:   -238.343363 (init= 1)
#     B_1_15:   -503.421848 (init=-1)
#     C_1_15:    0 (fixed)
#     D_1_15:    0 (fixed)
#     A_1_16:   -54.2393146 (init= 1)
#     B_1_16:    84.8518877 (init=-1)
#     C_1_16:    0 (fixed)
#     D_1_16:    0 (fixed)
#     A_1_17:    387.969318 (init= 1)
#     B_1_17:    33.9016219 (init=-1)
#     C_1_17:    0 (fixed)
#     D_1_17:    0 (fixed)
#     A_1_18:   -109.037353 (init= 1)
#     B_1_18:   -56.3211349 (init=-1)
#     C_1_18:    0 (fixed)
#     D_1_18:    0 (fixed)
#     A_1_19:   -128.077756 (init= 1)
#     B_1_19:   -42.1153338 (init=-1)
#     C_1_19:    0 (fixed)
#     D_1_19:    0 (fixed)
#     A_2_0:     0 (fixed)
#     B_2_0:     0 (fixed)
#     C_2_0:     0 (fixed)
#     D_2_0:     0 (fixed)
#     A_2_1:     0 (fixed)
#     B_2_1:     0 (fixed)
#     C_2_1:     0 (fixed)
#     D_2_1:     0 (fixed)
#     A_2_2:     20.3050500 (init= 1)
#     B_2_2:    -1466.05295 (init=-1)
#     C_2_2:     0 (fixed)
#     D_2_2:     0 (fixed)
#     A_2_3:     0 (fixed)
#     B_2_3:    -0.44399873 (init=-1)
#     C_2_3:     0 (fixed)
#     D_2_3:     0 (fixed)
#     A_2_4:     0.43149089 (init= 1)
#     B_2_4:     0.96058586 (init=-1)
#     C_2_4:     0 (fixed)
#     D_2_4:     0 (fixed)
#     A_2_5:    -1.63374827 (init= 1)
#     B_2_5:     11.8809702 (init=-1)
#     C_2_5:     0 (fixed)
#     D_2_5:     0 (fixed)
#     A_2_6:    -13.4791523 (init= 1)
#     B_2_6:     0.33704964 (init=-1)
#     C_2_6:     0 (fixed)
#     D_2_6:     0 (fixed)
#     A_2_7:     124.301277 (init= 1)
#     B_2_7:     16.3537168 (init=-1)
#     C_2_7:     0 (fixed)
#     D_2_7:     0 (fixed)
#     A_2_8:    -592.331042 (init= 1)
#     B_2_8:    -31.2129434 (init=-1)
#     C_2_8:     0 (fixed)
#     D_2_8:     0 (fixed)
#     A_2_9:     1058.31201 (init= 1)
#     B_2_9:    -710.129962 (init=-1)
#     C_2_9:     0 (fixed)
#     D_2_9:     0 (fixed)
#     A_2_10:    8529.21369 (init= 1)
#     B_2_10:    2969.52764 (init=-1)
#     C_2_10:    0 (fixed)
#     D_2_10:    0 (fixed)
#     A_2_11:    23737.1356 (init= 1)
#     B_2_11:   -12227.6630 (init=-1)
#     C_2_11:    0 (fixed)
#     D_2_11:    0 (fixed)
#     A_2_12:    7206.09007 (init= 1)
#     B_2_12:    11537.5230 (init=-1)
#     C_2_12:    0 (fixed)
#     D_2_12:    0 (fixed)
#     A_2_13:   -3478.23172 (init= 1)
#     B_2_13:   -6475.16703 (init=-1)
#     C_2_13:    0 (fixed)
#     D_2_13:    0 (fixed)
#     A_2_14:   -67.5487959 (init= 1)
#     B_2_14:   -118.163477 (init=-1)
#     C_2_14:    0 (fixed)
#     D_2_14:    0 (fixed)
#     A_2_15:    314.148479 (init= 1)
#     B_2_15:    387.462854 (init=-1)
#     C_2_15:    0 (fixed)
#     D_2_15:    0 (fixed)
#     A_2_16:    53.5782913 (init= 1)
#     B_2_16:   -176.844565 (init=-1)
#     C_2_16:    0 (fixed)
#     D_2_16:    0 (fixed)
#     A_2_17:    13.9451195 (init= 1)
#     B_2_17:   -65.0050740 (init=-1)
#     C_2_17:    0 (fixed)
#     D_2_17:    0 (fixed)
#     A_2_18:   -93.4802598 (init= 1)
#     B_2_18:    216.713513 (init=-1)
#     C_2_18:    0 (fixed)
#     D_2_18:    0 (fixed)
#     A_2_19:    376.134459 (init= 1)
#     B_2_19:    46.2715026 (init=-1)
#     C_2_19:    0 (fixed)
#     D_2_19:    0 (fixed)
#     A_3_0:     0 (fixed)
#     B_3_0:     0 (fixed)
#     C_3_0:     0 (fixed)
#     D_3_0:     0 (fixed)
#     A_3_1:     0 (fixed)
#     B_3_1:     0 (fixed)
#     C_3_1:     0 (fixed)
#     D_3_1:     0 (fixed)
#     A_3_2:     0 (fixed)
#     B_3_2:     0 (fixed)
#     C_3_2:     0 (fixed)
#     D_3_2:     0 (fixed)
#     A_3_3:    -17.7122649 (init= 1)
#     B_3_3:     754.182290 (init=-1)
#     C_3_3:     0 (fixed)
#     D_3_3:     0 (fixed)
#     A_3_4:     0 (fixed)
#     B_3_4:     0.20243197 (init=-1)
#     C_3_4:     0 (fixed)
#     D_3_4:     0 (fixed)
#     A_3_5:     0.07765773 (init= 1)
#     B_3_5:    -1.15800688 (init=-1)
#     C_3_5:     0 (fixed)
#     D_3_5:     0 (fixed)
#     A_3_6:     1.25310857 (init= 1)
#     B_3_6:    -9.52249936 (init=-1)
#     C_3_6:     0 (fixed)
#     D_3_6:     0 (fixed)
#     A_3_7:     8.34616575 (init= 1)
#     B_3_7:    -0.26431200 (init=-1)
#     C_3_7:     0 (fixed)
#     D_3_7:     0 (fixed)
#     A_3_8:    -34.2824280 (init= 1)
#     B_3_8:    -55.4155911 (init=-1)
#     C_3_8:     0 (fixed)
#     D_3_8:     0 (fixed)
#     A_3_9:     188.640625 (init= 1)
#     B_3_9:    -0.89833596 (init=-1)
#     C_3_9:     0 (fixed)
#     D_3_9:     0 (fixed)
#     A_3_10:   -1033.72164 (init= 1)
#     B_3_10:   -3.31980219 (init=-1)
#     C_3_10:    0 (fixed)
#     D_3_10:    0 (fixed)
#     A_3_11:   -1884.67365 (init= 1)
#     B_3_11:   -325.356516 (init=-1)
#     C_3_11:    0 (fixed)
#     D_3_11:    0 (fixed)
#     A_3_12:    4813.08960 (init= 1)
#     B_3_12:   -61190.0753 (init=-1)
#     C_3_12:    0 (fixed)
#     D_3_12:    0 (fixed)
#     A_3_13:   -12849.3418 (init= 1)
#     B_3_13:   -21959.6942 (init=-1)
#     C_3_13:    0 (fixed)
#     D_3_13:    0 (fixed)
#     A_3_14:    15112.0479 (init= 1)
#     B_3_14:    5712.97922 (init=-1)
#     C_3_14:    0 (fixed)
#     D_3_14:    0 (fixed)
#     A_3_15:    3354.88243 (init= 1)
#     B_3_15:   -11164.9884 (init=-1)
#     C_3_15:    0 (fixed)
#     D_3_15:    0 (fixed)
#     A_3_16:    566.643071 (init= 1)
#     B_3_16:   -52.3541865 (init=-1)
#     C_3_16:    0 (fixed)
#     D_3_16:    0 (fixed)
#     A_3_17:    338.237790 (init= 1)
#     B_3_17:   -219.059228 (init=-1)
#     C_3_17:    0 (fixed)
#     D_3_17:    0 (fixed)
#     A_3_18:    117.239822 (init= 1)
#     B_3_18:    243.986768 (init=-1)
#     C_3_18:    0 (fixed)
#     D_3_18:    0 (fixed)
#     A_3_19:   -41.5260492 (init= 1)
#     B_3_19:   -92.6671653 (init=-1)
#     C_3_19:    0 (fixed)
#     D_3_19:    0 (fixed)
#     A_4_0:     0 (fixed)
#     B_4_0:     0 (fixed)
#     C_4_0:     0 (fixed)
#     D_4_0:     0 (fixed)
#     A_4_1:     0 (fixed)
#     B_4_1:     0 (fixed)
#     C_4_1:     0 (fixed)
#     D_4_1:     0 (fixed)
#     A_4_2:     0 (fixed)
#     B_4_2:     0 (fixed)
#     C_4_2:     0 (fixed)
#     D_4_2:     0 (fixed)
#     A_4_3:     0 (fixed)
#     B_4_3:     0 (fixed)
#     C_4_3:     0 (fixed)
#     D_4_3:     0 (fixed)
#     A_4_4:     14.5365487 (init= 1)
#     B_4_4:    -424.530495 (init=-1)
#     C_4_4:     0 (fixed)
#     D_4_4:     0 (fixed)
#     A_4_5:     0 (fixed)
#     B_4_5:     0.17555102 (init=-1)
#     C_4_5:     0 (fixed)
#     D_4_5:     0 (fixed)
#     A_4_6:    -0.56984459 (init= 1)
#     B_4_6:     1.30595877 (init=-1)
#     C_4_6:     0 (fixed)
#     D_4_6:     0 (fixed)
#     A_4_7:    -0.99870826 (init= 1)
#     B_4_7:     7.70273285 (init=-1)
#     C_4_7:     0 (fixed)
#     D_4_7:     0 (fixed)
#     A_4_8:    -5.90493043 (init= 1)
#     B_4_8:     0.10392026 (init=-1)
#     C_4_8:     0 (fixed)
#     D_4_8:     0 (fixed)
#     A_4_9:     12.3292230 (init= 1)
#     B_4_9:     48.2374739 (init=-1)
#     C_4_9:     0 (fixed)
#     D_4_9:     0 (fixed)
#     A_4_10:   -77.7144322 (init= 1)
#     B_4_10:    2.22832041 (init=-1)
#     C_4_10:    0 (fixed)
#     D_4_10:    0 (fixed)
#     A_4_11:    447.165660 (init= 1)
#     B_4_11:    336.383839 (init=-1)
#     C_4_11:    0 (fixed)
#     D_4_11:    0 (fixed)
#     A_4_12:    65.0187195 (init= 1)
#     B_4_12:    150.304163 (init=-1)
#     C_4_12:    0 (fixed)
#     D_4_12:    0 (fixed)
#     A_4_13:   -231.866070 (init= 1)
#     B_4_13:   -303.168571 (init=-1)
#     C_4_13:    0 (fixed)
#     D_4_13:    0 (fixed)
#     A_4_14:    16379.7276 (init= 1)
#     B_4_14:   -2805.54277 (init=-1)
#     C_4_14:    0 (fixed)
#     D_4_14:    0 (fixed)
#     A_4_15:   -12517.4863 (init= 1)
#     B_4_15:    236.607369 (init=-1)
#     C_4_15:    0 (fixed)
#     D_4_15:    0 (fixed)
#     A_4_16:    13790.6784 (init= 1)
#     B_4_16:   -15722.0087 (init=-1)
#     C_4_16:    0 (fixed)
#     D_4_16:    0 (fixed)
#     A_4_17:    5240.20731 (init= 1)
#     B_4_17:    3364.77178 (init=-1)
#     C_4_17:    0 (fixed)
#     D_4_17:    0 (fixed)
#     A_4_18:   -2.99792443 (init= 1)
#     B_4_18:   -637.636977 (init=-1)
#     C_4_18:    0 (fixed)
#     D_4_18:    0 (fixed)
#     A_4_19:    139.153404 (init= 1)
#     B_4_19:    131.828475 (init=-1)
#     C_4_19:    0 (fixed)
#     D_4_19:    0 (fixed)
#     A_5_0:     0 (fixed)
#     B_5_0:     0 (fixed)
#     C_5_0:     0 (fixed)
#     D_5_0:     0 (fixed)
#     A_5_1:     0 (fixed)
#     B_5_1:     0 (fixed)
#     C_5_1:     0 (fixed)
#     D_5_1:     0 (fixed)
#     A_5_2:     0 (fixed)
#     B_5_2:     0 (fixed)
#     C_5_2:     0 (fixed)
#     D_5_2:     0 (fixed)
#     A_5_3:     0 (fixed)
#     B_5_3:     0 (fixed)
#     C_5_3:     0 (fixed)
#     D_5_3:     0 (fixed)
#     A_5_4:     0 (fixed)
#     B_5_4:     0 (fixed)
#     C_5_4:     0 (fixed)
#     D_5_4:     0 (fixed)
#     A_5_5:    -11.2042338 (init= 1)
#     B_5_5:     247.144844 (init=-1)
#     C_5_5:     0 (fixed)
#     D_5_5:     0 (fixed)
#     A_5_6:     0 (fixed)
#     B_5_6:    -0.61960405 (init=-1)
#     C_5_6:     0 (fixed)
#     D_5_6:     0 (fixed)
#     A_5_7:     0.92029422 (init= 1)
#     B_5_7:    -1.34010294 (init=-1)
#     C_5_7:     0 (fixed)
#     D_5_7:     0 (fixed)
#     A_5_8:     0.76155280 (init= 1)
#     B_5_8:    -5.83576609 (init=-1)
#     C_5_8:     0 (fixed)
#     D_5_8:     0 (fixed)
#     A_5_9:     4.21378062 (init= 1)
#     B_5_9:     0.03936779 (init=-1)
#     C_5_9:     0 (fixed)
#     D_5_9:     0 (fixed)
#     A_5_10:   -4.93200638 (init= 1)
#     B_5_10:   -38.7504227 (init=-1)
#     C_5_10:    0 (fixed)
#     D_5_10:    0 (fixed)
#     A_5_11:    36.0288931 (init= 1)
#     B_5_11:   -2.21245341 (init=-1)
#     C_5_11:    0 (fixed)
#     D_5_11:    0 (fixed)
#     A_5_12:   -184.886236 (init= 1)
#     B_5_12:   -90.8840151 (init=-1)
#     C_5_12:    0 (fixed)
#     D_5_12:    0 (fixed)
#     A_5_13:    14.4975011 (init= 1)
#     B_5_13:   -28.9255097 (init=-1)
#     C_5_13:    0 (fixed)
#     D_5_13:    0 (fixed)
#     A_5_14:   -66.1768092 (init= 1)
#     B_5_14:   -1236.21738 (init=-1)
#     C_5_14:    0 (fixed)
#     D_5_14:    0 (fixed)
#     A_5_15:   -1032.94611 (init= 1)
#     B_5_15:    152.028011 (init=-1)
#     C_5_15:    0 (fixed)
#     D_5_15:    0 (fixed)
#     A_5_16:   -17214.7229 (init= 1)
#     B_5_16:   -15107.9339 (init=-1)
#     C_5_16:    0 (fixed)
#     D_5_16:    0 (fixed)
#     A_5_17:   -2352.37720 (init= 1)
#     B_5_17:    1512.21242 (init=-1)
#     C_5_17:    0 (fixed)
#     D_5_17:    0 (fixed)
#     A_5_18:   -18834.5451 (init= 1)
#     B_5_18:   -16594.2153 (init=-1)
#     C_5_18:    0 (fixed)
#     D_5_18:    0 (fixed)
#     A_5_19:    5453.81798 (init= 1)
#     B_5_19:   -13467.0605 (init=-1)
#     C_5_19:    0 (fixed)
#     D_5_19:    0 (fixed)
#     A_6_0:     0 (fixed)
#     B_6_0:     0 (fixed)
#     C_6_0:     0 (fixed)
#     D_6_0:     0 (fixed)
#     A_6_1:     0 (fixed)
#     B_6_1:     0 (fixed)
#     C_6_1:     0 (fixed)
#     D_6_1:     0 (fixed)
#     A_6_2:     0 (fixed)
#     B_6_2:     0 (fixed)
#     C_6_2:     0 (fixed)
#     D_6_2:     0 (fixed)
#     A_6_3:     0 (fixed)
#     B_6_3:     0 (fixed)
#     C_6_3:     0 (fixed)
#     D_6_3:     0 (fixed)
#     A_6_4:     0 (fixed)
#     B_6_4:     0 (fixed)
#     C_6_4:     0 (fixed)
#     D_6_4:     0 (fixed)
#     A_6_5:     0 (fixed)
#     B_6_5:     0 (fixed)
#     C_6_5:     0 (fixed)
#     D_6_5:     0 (fixed)
#     A_6_6:     8.09022909 (init= 1)
#     B_6_6:    -143.361011 (init=-1)
#     C_6_6:     0 (fixed)
#     D_6_6:     0 (fixed)
#     A_6_7:     0 (fixed)
#     B_6_7:     0.99947147 (init=-1)
#     C_6_7:     0 (fixed)
#     D_6_7:     0 (fixed)
#     A_6_8:    -1.06615767 (init= 1)
#     B_6_8:     1.24140754 (init=-1)
#     C_6_8:     0 (fixed)
#     D_6_8:     0 (fixed)
#     A_6_9:    -0.53592130 (init= 1)
#     B_6_9:     4.04755467 (init=-1)
#     C_6_9:     0 (fixed)
#     D_6_9:     0 (fixed)
#     A_6_10:   -2.87411091 (init= 1)
#     B_6_10:   -0.13099189 (init=-1)
#     C_6_10:    0 (fixed)
#     D_6_10:    0 (fixed)
#     A_6_11:    1.98378544 (init= 1)
#     B_6_11:    27.7031850 (init=-1)
#     C_6_11:    0 (fixed)
#     D_6_11:    0 (fixed)
#     A_6_12:   -16.9622898 (init= 1)
#     B_6_12:    1.78125864 (init=-1)
#     C_6_12:    0 (fixed)
#     D_6_12:    0 (fixed)
#     A_6_13:    77.6426510 (init= 1)
#     B_6_13:    10.5431327 (init=-1)
#     C_6_13:    0 (fixed)
#     D_6_13:    0 (fixed)
#     A_6_14:   -16.6047413 (init= 1)
#     B_6_14:    0.10204741 (init=-1)
#     C_6_14:    0 (fixed)
#     D_6_14:    0 (fixed)
#     A_6_15:    93.7908919 (init= 1)
#     B_6_15:    893.706347 (init=-1)
#     C_6_15:    0 (fixed)
#     D_6_15:    0 (fixed)
#     A_6_16:   -138.288962 (init= 1)
#     B_6_16:    34.0606648 (init=-1)
#     C_6_16:    0 (fixed)
#     D_6_16:    0 (fixed)
#     A_6_17:    1690.76992 (init= 1)
#     B_6_17:   -4390.12876 (init=-1)
#     C_6_17:    0 (fixed)
#     D_6_17:    0 (fixed)
#     A_6_18:   -63.8310408 (init= 1)
#     B_6_18:    3247.51839 (init=-1)
#     C_6_18:    0 (fixed)
#     D_6_18:    0 (fixed)
#     A_6_19:   -13003.0937 (init= 1)
#     B_6_19:    13260.6386 (init=-1)
#     C_6_19:    0 (fixed)
#     D_6_19:    0 (fixed)
#     A_7_0:     0 (fixed)
#     B_7_0:     0 (fixed)
#     C_7_0:     0 (fixed)
#     D_7_0:     0 (fixed)
#     A_7_1:     0 (fixed)
#     B_7_1:     0 (fixed)
#     C_7_1:     0 (fixed)
#     D_7_1:     0 (fixed)
#     A_7_2:     0 (fixed)
#     B_7_2:     0 (fixed)
#     C_7_2:     0 (fixed)
#     D_7_2:     0 (fixed)
#     A_7_3:     0 (fixed)
#     B_7_3:     0 (fixed)
#     C_7_3:     0 (fixed)
#     D_7_3:     0 (fixed)
#     A_7_4:     0 (fixed)
#     B_7_4:     0 (fixed)
#     C_7_4:     0 (fixed)
#     D_7_4:     0 (fixed)
#     A_7_5:     0 (fixed)
#     B_7_5:     0 (fixed)
#     C_7_5:     0 (fixed)
#     D_7_5:     0 (fixed)
#     A_7_6:     0 (fixed)
#     B_7_6:     0 (fixed)
#     C_7_6:     0 (fixed)
#     D_7_6:     0 (fixed)
#     A_7_7:    -5.45296258 (init= 1)
#     B_7_7:     80.5877370 (init=-1)
#     C_7_7:     0 (fixed)
#     D_7_7:     0 (fixed)
#     A_7_8:     0 (fixed)
#     B_7_8:    -1.19710969 (init=-1)
#     C_7_8:     0 (fixed)
#     D_7_8:     0 (fixed)
#     A_7_9:     1.01528605 (init= 1)
#     B_7_9:    -1.03319831 (init=-1)
#     C_7_9:     0 (fixed)
#     D_7_9:     0 (fixed)
#     A_7_10:    0.34229379 (init= 1)
#     B_7_10:   -2.54963953 (init=-1)
#     C_7_10:    0 (fixed)
#     D_7_10:    0 (fixed)
#     A_7_11:    1.81951806 (init= 1)
#     B_7_11:    0.15633104 (init=-1)
#     C_7_11:    0 (fixed)
#     D_7_11:    0 (fixed)
#     A_7_12:   -0.77036258 (init= 1)
#     B_7_12:   -17.4586865 (init=-1)
#     C_7_12:    0 (fixed)
#     D_7_12:    0 (fixed)
#     A_7_13:    7.85189719 (init= 1)
#     B_7_13:   -1.04919819 (init=-1)
#     C_7_13:    0 (fixed)
#     D_7_13:    0 (fixed)
#     A_7_14:   -33.9312565 (init= 1)
#     B_7_14:   -0.06473958 (init=-1)
#     C_7_14:    0 (fixed)
#     D_7_14:    0 (fixed)
#     A_7_15:    5.58064259 (init= 1)
#     B_7_15:   -0.38103363 (init=-1)
#     C_7_15:    0 (fixed)
#     D_7_15:    0 (fixed)
#     A_7_16:    63.6123590 (init= 1)
#     B_7_16:   -244.137256 (init=-1)
#     C_7_16:    0 (fixed)
#     D_7_16:    0 (fixed)
#     A_7_17:    116.785484 (init= 1)
#     B_7_17:    42.6363871 (init=-1)
#     C_7_17:    0 (fixed)
#     D_7_17:    0 (fixed)
#     A_7_18:   -1988.13641 (init= 1)
#     B_7_18:    1839.74049 (init=-1)
#     C_7_18:    0 (fixed)
#     D_7_18:    0 (fixed)
#     A_7_19:    1522.92881 (init= 1)
#     B_7_19:   -1172.25535 (init=-1)
#     C_7_19:    0 (fixed)
#     D_7_19:    0 (fixed)
#     A_8_0:     0 (fixed)
#     B_8_0:     0 (fixed)
#     C_8_0:     0 (fixed)
#     D_8_0:     0 (fixed)
#     A_8_1:     0 (fixed)
#     B_8_1:     0 (fixed)
#     C_8_1:     0 (fixed)
#     D_8_1:     0 (fixed)
#     A_8_2:     0 (fixed)
#     B_8_2:     0 (fixed)
#     C_8_2:     0 (fixed)
#     D_8_2:     0 (fixed)
#     A_8_3:     0 (fixed)
#     B_8_3:     0 (fixed)
#     C_8_3:     0 (fixed)
#     D_8_3:     0 (fixed)
#     A_8_4:     0 (fixed)
#     B_8_4:     0 (fixed)
#     C_8_4:     0 (fixed)
#     D_8_4:     0 (fixed)
#     A_8_5:     0 (fixed)
#     B_8_5:     0 (fixed)
#     C_8_5:     0 (fixed)
#     D_8_5:     0 (fixed)
#     A_8_6:     0 (fixed)
#     B_8_6:     0 (fixed)
#     C_8_6:     0 (fixed)
#     D_8_6:     0 (fixed)
#     A_8_7:     0 (fixed)
#     B_8_7:     0 (fixed)
#     C_8_7:     0 (fixed)
#     D_8_7:     0 (fixed)
#     A_8_8:     3.41378983 (init= 1)
#     B_8_8:    -43.0196722 (init=-1)
#     C_8_8:     0 (fixed)
#     D_8_8:     0 (fixed)
#     A_8_9:     0 (fixed)
#     B_8_9:     1.17087301 (init=-1)
#     C_8_9:     0 (fixed)
#     D_8_9:     0 (fixed)
#     A_8_10:   -0.82906548 (init= 1)
#     B_8_10:    0.76924917 (init=-1)
#     C_8_10:    0 (fixed)
#     D_8_10:    0 (fixed)
#     A_8_11:   -0.19660388 (init= 1)
#     B_8_11:    1.45497305 (init=-1)
#     C_8_11:    0 (fixed)
#     D_8_11:    0 (fixed)
#     A_8_12:   -1.05341228 (init= 1)
#     B_8_12:   -0.13851211 (init=-1)
#     C_8_12:    0 (fixed)
#     D_8_12:    0 (fixed)
#     A_8_13:    0.32089438 (init= 1)
#     B_8_13:    9.75811561 (init=-1)
#     C_8_13:    0 (fixed)
#     D_8_13:    0 (fixed)
#     A_8_14:   -3.35277838 (init= 1)
#     B_8_14:    0.61305035 (init=-1)
#     C_8_14:    0 (fixed)
#     D_8_14:    0 (fixed)
#     A_8_15:    13.5460691 (init= 1)
#     B_8_15:   -1.49642196 (init=-1)
#     C_8_15:    0 (fixed)
#     D_8_15:    0 (fixed)
#     A_8_16:   -2.35008620 (init= 1)
#     B_8_16:   -1.83057132 (init=-1)
#     C_8_16:    0 (fixed)
#     D_8_16:    0 (fixed)
#     A_8_17:   -48.2604818 (init= 1)
#     B_8_17:    54.2452138 (init=-1)
#     C_8_17:    0 (fixed)
#     D_8_17:    0 (fixed)
#     A_8_18:   -45.1489619 (init= 1)
#     B_8_18:    16.0034626 (init=-1)
#     C_8_18:    0 (fixed)
#     D_8_18:    0 (fixed)
#     A_8_19:    847.059103 (init= 1)
#     B_8_19:   -576.867904 (init=-1)
#     C_8_19:    0 (fixed)
#     D_8_19:    0 (fixed)
#     A_9_0:     0 (fixed)
#     B_9_0:     0 (fixed)
#     C_9_0:     0 (fixed)
#     D_9_0:     0 (fixed)
#     A_9_1:     0 (fixed)
#     B_9_1:     0 (fixed)
#     C_9_1:     0 (fixed)
#     D_9_1:     0 (fixed)
#     A_9_2:     0 (fixed)
#     B_9_2:     0 (fixed)
#     C_9_2:     0 (fixed)
#     D_9_2:     0 (fixed)
#     A_9_3:     0 (fixed)
#     B_9_3:     0 (fixed)
#     C_9_3:     0 (fixed)
#     D_9_3:     0 (fixed)
#     A_9_4:     0 (fixed)
#     B_9_4:     0 (fixed)
#     C_9_4:     0 (fixed)
#     D_9_4:     0 (fixed)
#     A_9_5:     0 (fixed)
#     B_9_5:     0 (fixed)
#     C_9_5:     0 (fixed)
#     D_9_5:     0 (fixed)
#     A_9_6:     0 (fixed)
#     B_9_6:     0 (fixed)
#     C_9_6:     0 (fixed)
#     D_9_6:     0 (fixed)
#     A_9_7:     0 (fixed)
#     B_9_7:     0 (fixed)
#     C_9_7:     0 (fixed)
#     D_9_7:     0 (fixed)
#     A_9_8:     0 (fixed)
#     B_9_8:     0 (fixed)
#     C_9_8:     0 (fixed)
#     D_9_8:     0 (fixed)
#     A_9_9:    -1.97219166 (init= 1)
#     B_9_9:     21.4891612 (init=-1)
#     C_9_9:     0 (fixed)
#     D_9_9:     0 (fixed)
#     A_9_10:    0 (fixed)
#     B_9_10:   -0.96793819 (init=-1)
#     C_9_10:    0 (fixed)
#     D_9_10:    0 (fixed)
#     A_9_11:    0.58954616 (init= 1)
#     B_9_11:   -0.50955683 (init=-1)
#     C_9_11:    0 (fixed)
#     D_9_11:    0 (fixed)
#     A_9_12:    0.10118120 (init= 1)
#     B_9_12:   -0.75590111 (init=-1)
#     C_9_12:    0 (fixed)
#     D_9_12:    0 (fixed)
#     A_9_13:    0.54903210 (init= 1)
#     B_9_13:    0.09730972 (init=-1)
#     C_9_13:    0 (fixed)
#     D_9_13:    0 (fixed)
#     A_9_14:   -0.18613874 (init= 1)
#     B_9_14:   -4.76628025 (init=-1)
#     C_9_14:    0 (fixed)
#     D_9_14:    0 (fixed)
#     A_9_15:    1.28269603 (init= 1)
#     B_9_15:   -0.27319266 (init=-1)
#     C_9_15:    0 (fixed)
#     D_9_15:    0 (fixed)
#     A_9_16:   -3.71430411 (init= 1)
#     B_9_16:    0.92783949 (init=-1)
#     C_9_16:    0 (fixed)
#     D_9_16:    0 (fixed)
#     A_9_17:    1.13860747 (init= 1)
#     B_9_17:    0.67822654 (init=-1)
#     C_9_17:    0 (fixed)
#     D_9_17:    0 (fixed)
#     A_9_18:   -1.26315673 (init= 1)
#     B_9_18:   -1.31321849 (init=-1)
#     C_9_18:    0 (fixed)
#     D_9_18:    0 (fixed)
#     A_9_19:    5.31127889 (init= 1)
#     B_9_19:   -3.52132421 (init=-1)
#     C_9_19:    0 (fixed)
#     D_9_19:    0 (fixed)
#     A_10_0:    0 (fixed)
#     B_10_0:    0 (fixed)
#     C_10_0:    0 (fixed)
#     D_10_0:    0 (fixed)
#     A_10_1:    0 (fixed)
#     B_10_1:    0 (fixed)
#     C_10_1:    0 (fixed)
#     D_10_1:    0 (fixed)
#     A_10_2:    0 (fixed)
#     B_10_2:    0 (fixed)
#     C_10_2:    0 (fixed)
#     D_10_2:    0 (fixed)
#     A_10_3:    0 (fixed)
#     B_10_3:    0 (fixed)
#     C_10_3:    0 (fixed)
#     D_10_3:    0 (fixed)
#     A_10_4:    0 (fixed)
#     B_10_4:    0 (fixed)
#     C_10_4:    0 (fixed)
#     D_10_4:    0 (fixed)
#     A_10_5:    0 (fixed)
#     B_10_5:    0 (fixed)
#     C_10_5:    0 (fixed)
#     D_10_5:    0 (fixed)
#     A_10_6:    0 (fixed)
#     B_10_6:    0 (fixed)
#     C_10_6:    0 (fixed)
#     D_10_6:    0 (fixed)
#     A_10_7:    0 (fixed)
#     B_10_7:    0 (fixed)
#     C_10_7:    0 (fixed)
#     D_10_7:    0 (fixed)
#     A_10_8:    0 (fixed)
#     B_10_8:    0 (fixed)
#     C_10_8:    0 (fixed)
#     D_10_8:    0 (fixed)
#     A_10_9:    0 (fixed)
#     B_10_9:    0 (fixed)
#     C_10_9:    0 (fixed)
#     D_10_9:    0 (fixed)
#     A_10_10:   1.04278316 (init= 1)
#     B_10_10:  -9.92894953 (init=-1)
#     C_10_10:   0 (fixed)
#     D_10_10:   0 (fixed)
#     A_10_11:   0 (fixed)
#     B_10_11:   0.68623801 (init=-1)
#     C_10_11:   0 (fixed)
#     D_10_11:   0 (fixed)
#     A_10_12:  -0.36635378 (init= 1)
#     B_10_12:   0.29813465 (init=-1)
#     C_10_12:   0 (fixed)
#     D_10_12:   0 (fixed)
#     A_10_13:  -0.04522510 (init= 1)
#     B_10_13:   0.36071343 (init=-1)
#     C_10_13:   0 (fixed)
#     D_10_13:   0 (fixed)
#     A_10_14:  -0.25315944 (init= 1)
#     B_10_14:  -0.05616190 (init=-1)
#     C_10_14:   0 (fixed)
#     D_10_14:   0 (fixed)
#     A_10_15:   0.09394990 (init= 1)
#     B_10_15:   1.99396283 (init=-1)
#     C_10_15:   0 (fixed)
#     D_10_15:   0 (fixed)
#     A_10_16:  -0.43153541 (init= 1)
#     B_10_16:   0.09292829 (init=-1)
#     C_10_16:   0 (fixed)
#     D_10_16:   0 (fixed)
#     A_10_17:   0.97437312 (init= 1)
#     B_10_17:  -0.60264283 (init=-1)
#     C_10_17:   0 (fixed)
#     D_10_17:   0 (fixed)
#     A_10_18:  -0.32596320 (init= 1)
#     B_10_18:  -0.10738862 (init=-1)
#     C_10_18:   0 (fixed)
#     D_10_18:   0 (fixed)
#     A_10_19:   0.17260398 (init= 1)
#     B_10_19:   0.42328523 (init=-1)
#     C_10_19:   0 (fixed)
#     D_10_19:   0 (fixed)
#     A_11_0:    0 (fixed)
#     B_11_0:    0 (fixed)
#     C_11_0:    0 (fixed)
#     D_11_0:    0 (fixed)
#     A_11_1:    0 (fixed)
#     B_11_1:    0 (fixed)
#     C_11_1:    0 (fixed)
#     D_11_1:    0 (fixed)
#     A_11_2:    0 (fixed)
#     B_11_2:    0 (fixed)
#     C_11_2:    0 (fixed)
#     D_11_2:    0 (fixed)
#     A_11_3:    0 (fixed)
#     B_11_3:    0 (fixed)
#     C_11_3:    0 (fixed)
#     D_11_3:    0 (fixed)
#     A_11_4:    0 (fixed)
#     B_11_4:    0 (fixed)
#     C_11_4:    0 (fixed)
#     D_11_4:    0 (fixed)
#     A_11_5:    0 (fixed)
#     B_11_5:    0 (fixed)
#     C_11_5:    0 (fixed)
#     D_11_5:    0 (fixed)
#     A_11_6:    0 (fixed)
#     B_11_6:    0 (fixed)
#     C_11_6:    0 (fixed)
#     D_11_6:    0 (fixed)
#     A_11_7:    0 (fixed)
#     B_11_7:    0 (fixed)
#     C_11_7:    0 (fixed)
#     D_11_7:    0 (fixed)
#     A_11_8:    0 (fixed)
#     B_11_8:    0 (fixed)
#     C_11_8:    0 (fixed)
#     D_11_8:    0 (fixed)
#     A_11_9:    0 (fixed)
#     B_11_9:    0 (fixed)
#     C_11_9:    0 (fixed)
#     D_11_9:    0 (fixed)
#     A_11_10:   0 (fixed)
#     B_11_10:   0 (fixed)
#     C_11_10:   0 (fixed)
#     D_11_10:   0 (fixed)
#     A_11_11:  -0.49946987 (init= 1)
#     B_11_11:   4.19937351 (init=-1)
#     C_11_11:   0 (fixed)
#     D_11_11:   0 (fixed)
#     A_11_12:   0 (fixed)
#     B_11_12:  -0.41937261 (init=-1)
#     C_11_12:   0 (fixed)
#     D_11_12:   0 (fixed)
#     A_11_13:   0.19816951 (init= 1)
#     B_11_13:  -0.15253026 (init=-1)
#     C_11_13:   0 (fixed)
#     D_11_13:   0 (fixed)
#     A_11_14:   0.01705716 (init= 1)
#     B_11_14:  -0.15913100 (init=-1)
#     C_11_14:   0 (fixed)
#     D_11_14:   0 (fixed)
#     A_11_15:   0.10114783 (init= 1)
#     B_11_15:   0.02701896 (init=-1)
#     C_11_15:   0 (fixed)
#     D_11_15:   0 (fixed)
#     A_11_16:  -0.04141339 (init= 1)
#     B_11_16:  -0.68208705 (init=-1)
#     C_11_16:   0 (fixed)
#     D_11_16:   0 (fixed)
#     A_11_17:   0.12170766 (init= 1)
#     B_11_17:  -0.02570166 (init=-1)
#     C_11_17:   0 (fixed)
#     D_11_17:   0 (fixed)
#     A_11_18:  -0.19188952 (init= 1)
#     B_11_18:   0.18048711 (init=-1)
#     C_11_18:   0 (fixed)
#     D_11_18:   0 (fixed)
#     A_11_19:   0.03567602 (init= 1)
#     B_11_19:   0.01937622 (init=-1)
#     C_11_19:   0 (fixed)
#     D_11_19:   0 (fixed)
#     A_12_0:    0 (fixed)
#     B_12_0:    0 (fixed)
#     C_12_0:    0 (fixed)
#     D_12_0:    0 (fixed)
#     A_12_1:    0 (fixed)
#     B_12_1:    0 (fixed)
#     C_12_1:    0 (fixed)
#     D_12_1:    0 (fixed)
#     A_12_2:    0 (fixed)
#     B_12_2:    0 (fixed)
#     C_12_2:    0 (fixed)
#     D_12_2:    0 (fixed)
#     A_12_3:    0 (fixed)
#     B_12_3:    0 (fixed)
#     C_12_3:    0 (fixed)
#     D_12_3:    0 (fixed)
#     A_12_4:    0 (fixed)
#     B_12_4:    0 (fixed)
#     C_12_4:    0 (fixed)
#     D_12_4:    0 (fixed)
#     A_12_5:    0 (fixed)
#     B_12_5:    0 (fixed)
#     C_12_5:    0 (fixed)
#     D_12_5:    0 (fixed)
#     A_12_6:    0 (fixed)
#     B_12_6:    0 (fixed)
#     C_12_6:    0 (fixed)
#     D_12_6:    0 (fixed)
#     A_12_7:    0 (fixed)
#     B_12_7:    0 (fixed)
#     C_12_7:    0 (fixed)
#     D_12_7:    0 (fixed)
#     A_12_8:    0 (fixed)
#     B_12_8:    0 (fixed)
#     C_12_8:    0 (fixed)
#     D_12_8:    0 (fixed)
#     A_12_9:    0 (fixed)
#     B_12_9:    0 (fixed)
#     C_12_9:    0 (fixed)
#     D_12_9:    0 (fixed)
#     A_12_10:   0 (fixed)
#     B_12_10:   0 (fixed)
#     C_12_10:   0 (fixed)
#     D_12_10:   0 (fixed)
#     A_12_11:   0 (fixed)
#     B_12_11:   0 (fixed)
#     C_12_11:   0 (fixed)
#     D_12_11:   0 (fixed)
#     A_12_12:   0.21394137 (init= 1)
#     B_12_12:  -1.60795782 (init=-1)
#     C_12_12:   0 (fixed)
#     D_12_12:   0 (fixed)
#     A_12_13:   0 (fixed)
#     B_12_13:   0.22068646 (init=-1)
#     C_12_13:   0 (fixed)
#     D_12_13:   0 (fixed)
#     A_12_14:  -0.09233105 (init= 1)
#     B_12_14:   0.06724593 (init=-1)
#     C_12_14:   0 (fixed)
#     D_12_14:   0 (fixed)
#     A_12_15:  -0.00511884 (init= 1)
#     B_12_15:   0.06361323 (init=-1)
#     C_12_15:   0 (fixed)
#     D_12_15:   0 (fixed)
#     A_12_16:  -0.03401778 (init= 1)
#     B_12_16:  -0.01059956 (init=-1)
#     C_12_16:   0 (fixed)
#     D_12_16:   0 (fixed)
#     A_12_17:   0.01436194 (init= 1)
#     B_12_17:   0.18134785 (init=-1)
#     C_12_17:   0 (fixed)
#     D_12_17:   0 (fixed)
#     A_12_18:  -0.02509647 (init= 1)
#     B_12_18:   0.00470268 (init=-1)
#     C_12_18:   0 (fixed)
#     D_12_18:   0 (fixed)
#     A_12_19:   0.02156045 (init= 1)
#     B_12_19:  -0.03053541 (init=-1)
#     C_12_19:   0 (fixed)
#     D_12_19:   0 (fixed)
#     A_13_0:    0 (fixed)
#     B_13_0:    0 (fixed)
#     C_13_0:    0 (fixed)
#     D_13_0:    0 (fixed)
#     A_13_1:    0 (fixed)
#     B_13_1:    0 (fixed)
#     C_13_1:    0 (fixed)
#     D_13_1:    0 (fixed)
#     A_13_2:    0 (fixed)
#     B_13_2:    0 (fixed)
#     C_13_2:    0 (fixed)
#     D_13_2:    0 (fixed)
#     A_13_3:    0 (fixed)
#     B_13_3:    0 (fixed)
#     C_13_3:    0 (fixed)
#     D_13_3:    0 (fixed)
#     A_13_4:    0 (fixed)
#     B_13_4:    0 (fixed)
#     C_13_4:    0 (fixed)
#     D_13_4:    0 (fixed)
#     A_13_5:    0 (fixed)
#     B_13_5:    0 (fixed)
#     C_13_5:    0 (fixed)
#     D_13_5:    0 (fixed)
#     A_13_6:    0 (fixed)
#     B_13_6:    0 (fixed)
#     C_13_6:    0 (fixed)
#     D_13_6:    0 (fixed)
#     A_13_7:    0 (fixed)
#     B_13_7:    0 (fixed)
#     C_13_7:    0 (fixed)
#     D_13_7:    0 (fixed)
#     A_13_8:    0 (fixed)
#     B_13_8:    0 (fixed)
#     C_13_8:    0 (fixed)
#     D_13_8:    0 (fixed)
#     A_13_9:    0 (fixed)
#     B_13_9:    0 (fixed)
#     C_13_9:    0 (fixed)
#     D_13_9:    0 (fixed)
#     A_13_10:   0 (fixed)
#     B_13_10:   0 (fixed)
#     C_13_10:   0 (fixed)
#     D_13_10:   0 (fixed)
#     A_13_11:   0 (fixed)
#     B_13_11:   0 (fixed)
#     C_13_11:   0 (fixed)
#     D_13_11:   0 (fixed)
#     A_13_12:   0 (fixed)
#     B_13_12:   0 (fixed)
#     C_13_12:   0 (fixed)
#     D_13_12:   0 (fixed)
#     A_13_13:  -0.08061025 (init= 1)
#     B_13_13:   0.55010589 (init=-1)
#     C_13_13:   0 (fixed)
#     D_13_13:   0 (fixed)
#     A_13_14:   0 (fixed)
#     B_13_14:  -0.09929178 (init=-1)
#     C_13_14:   0 (fixed)
#     D_13_14:   0 (fixed)
#     A_13_15:   0.03637856 (init= 1)
#     B_13_15:  -0.02500895 (init=-1)
#     C_13_15:   0 (fixed)
#     D_13_15:   0 (fixed)
#     A_13_16:   0.00107730 (init= 1)
#     B_13_16:  -0.02186910 (init=-1)
#     C_13_16:   0 (fixed)
#     D_13_16:   0 (fixed)
#     A_13_17:   0.00909872 (init= 1)
#     B_13_17:   0.00330664 (init=-1)
#     C_13_17:   0 (fixed)
#     D_13_17:   0 (fixed)
#     A_13_18:  -0.00336993 (init= 1)
#     B_13_18:  -0.03378883 (init=-1)
#     C_13_18:   0 (fixed)
#     D_13_18:   0 (fixed)
#     A_13_19:   0.00281772 (init= 1)
#     B_13_19:  -0.00057651 (init=-1)
#     C_13_19:   0 (fixed)
#     D_13_19:   0 (fixed)
#     A_14_0:    0 (fixed)
#     B_14_0:    0 (fixed)
#     C_14_0:    0 (fixed)
#     D_14_0:    0 (fixed)
#     A_14_1:    0 (fixed)
#     B_14_1:    0 (fixed)
#     C_14_1:    0 (fixed)
#     D_14_1:    0 (fixed)
#     A_14_2:    0 (fixed)
#     B_14_2:    0 (fixed)
#     C_14_2:    0 (fixed)
#     D_14_2:    0 (fixed)
#     A_14_3:    0 (fixed)
#     B_14_3:    0 (fixed)
#     C_14_3:    0 (fixed)
#     D_14_3:    0 (fixed)
#     A_14_4:    0 (fixed)
#     B_14_4:    0 (fixed)
#     C_14_4:    0 (fixed)
#     D_14_4:    0 (fixed)
#     A_14_5:    0 (fixed)
#     B_14_5:    0 (fixed)
#     C_14_5:    0 (fixed)
#     D_14_5:    0 (fixed)
#     A_14_6:    0 (fixed)
#     B_14_6:    0 (fixed)
#     C_14_6:    0 (fixed)
#     D_14_6:    0 (fixed)
#     A_14_7:    0 (fixed)
#     B_14_7:    0 (fixed)
#     C_14_7:    0 (fixed)
#     D_14_7:    0 (fixed)
#     A_14_8:    0 (fixed)
#     B_14_8:    0 (fixed)
#     C_14_8:    0 (fixed)
#     D_14_8:    0 (fixed)
#     A_14_9:    0 (fixed)
#     B_14_9:    0 (fixed)
#     C_14_9:    0 (fixed)
#     D_14_9:    0 (fixed)
#     A_14_10:   0 (fixed)
#     B_14_10:   0 (fixed)
#     C_14_10:   0 (fixed)
#     D_14_10:   0 (fixed)
#     A_14_11:   0 (fixed)
#     B_14_11:   0 (fixed)
#     C_14_11:   0 (fixed)
#     D_14_11:   0 (fixed)
#     A_14_12:   0 (fixed)
#     B_14_12:   0 (fixed)
#     C_14_12:   0 (fixed)
#     D_14_12:   0 (fixed)
#     A_14_13:   0 (fixed)
#     B_14_13:   0 (fixed)
#     C_14_13:   0 (fixed)
#     D_14_13:   0 (fixed)
#     A_14_14:   0.02614372 (init= 1)
#     B_14_14:  -0.16529162 (init=-1)
#     C_14_14:   0 (fixed)
#     D_14_14:   0 (fixed)
#     A_14_15:   0 (fixed)
#     B_14_15:   0.03763192 (init=-1)
#     C_14_15:   0 (fixed)
#     D_14_15:   0 (fixed)
#     A_14_16:  -0.01175436 (init= 1)
#     B_14_16:   0.00759084 (init=-1)
#     C_14_16:   0 (fixed)
#     D_14_16:   0 (fixed)
#     A_14_17:  -9.9479e-05 (init= 1)
#     B_14_17:   0.00582980 (init=-1)
#     C_14_17:   0 (fixed)
#     D_14_17:   0 (fixed)
#     A_14_18:  -0.00170424 (init= 1)
#     B_14_18:  -0.00074391 (init=-1)
#     C_14_18:   0 (fixed)
#     D_14_18:   0 (fixed)
#     A_14_19:   0.00032782 (init= 1)
#     B_14_19:   0.00369913 (init=-1)
#     C_14_19:   0 (fixed)
#     D_14_19:   0 (fixed)
#     A_15_0:    0 (fixed)
#     B_15_0:    0 (fixed)
#     C_15_0:    0 (fixed)
#     D_15_0:    0 (fixed)
#     A_15_1:    0 (fixed)
#     B_15_1:    0 (fixed)
#     C_15_1:    0 (fixed)
#     D_15_1:    0 (fixed)
#     A_15_2:    0 (fixed)
#     B_15_2:    0 (fixed)
#     C_15_2:    0 (fixed)
#     D_15_2:    0 (fixed)
#     A_15_3:    0 (fixed)
#     B_15_3:    0 (fixed)
#     C_15_3:    0 (fixed)
#     D_15_3:    0 (fixed)
#     A_15_4:    0 (fixed)
#     B_15_4:    0 (fixed)
#     C_15_4:    0 (fixed)
#     D_15_4:    0 (fixed)
#     A_15_5:    0 (fixed)
#     B_15_5:    0 (fixed)
#     C_15_5:    0 (fixed)
#     D_15_5:    0 (fixed)
#     A_15_6:    0 (fixed)
#     B_15_6:    0 (fixed)
#     C_15_6:    0 (fixed)
#     D_15_6:    0 (fixed)
#     A_15_7:    0 (fixed)
#     B_15_7:    0 (fixed)
#     C_15_7:    0 (fixed)
#     D_15_7:    0 (fixed)
#     A_15_8:    0 (fixed)
#     B_15_8:    0 (fixed)
#     C_15_8:    0 (fixed)
#     D_15_8:    0 (fixed)
#     A_15_9:    0 (fixed)
#     B_15_9:    0 (fixed)
#     C_15_9:    0 (fixed)
#     D_15_9:    0 (fixed)
#     A_15_10:   0 (fixed)
#     B_15_10:   0 (fixed)
#     C_15_10:   0 (fixed)
#     D_15_10:   0 (fixed)
#     A_15_11:   0 (fixed)
#     B_15_11:   0 (fixed)
#     C_15_11:   0 (fixed)
#     D_15_11:   0 (fixed)
#     A_15_12:   0 (fixed)
#     B_15_12:   0 (fixed)
#     C_15_12:   0 (fixed)
#     D_15_12:   0 (fixed)
#     A_15_13:   0 (fixed)
#     B_15_13:   0 (fixed)
#     C_15_13:   0 (fixed)
#     D_15_13:   0 (fixed)
#     A_15_14:   0 (fixed)
#     B_15_14:   0 (fixed)
#     C_15_14:   0 (fixed)
#     D_15_14:   0 (fixed)
#     A_15_15:  -0.00708555 (init= 1)
#     B_15_15:   0.04259826 (init=-1)
#     C_15_15:   0 (fixed)
#     D_15_15:   0 (fixed)
#     A_15_16:   0 (fixed)
#     B_15_16:  -0.01167908 (init=-1)
#     C_15_16:   0 (fixed)
#     D_15_16:   0 (fixed)
#     A_15_17:   0.00295033 (init= 1)
#     B_15_17:  -0.00178322 (init=-1)
#     C_15_17:   0 (fixed)
#     D_15_17:   0 (fixed)
#     A_15_18:  -9.5402e-06 (init= 1)
#     B_15_18:  -0.00103966 (init=-1)
#     C_15_18:   0 (fixed)
#     D_15_18:   0 (fixed)
#     A_15_19:   0.00015036 (init= 1)
#     B_15_19:   9.9302e-05 (init=-1)
#     C_15_19:   0 (fixed)
#     D_15_19:   0 (fixed)
#     A_16_0:    0 (fixed)
#     B_16_0:    0 (fixed)
#     C_16_0:    0 (fixed)
#     D_16_0:    0 (fixed)
#     A_16_1:    0 (fixed)
#     B_16_1:    0 (fixed)
#     C_16_1:    0 (fixed)
#     D_16_1:    0 (fixed)
#     A_16_2:    0 (fixed)
#     B_16_2:    0 (fixed)
#     C_16_2:    0 (fixed)
#     D_16_2:    0 (fixed)
#     A_16_3:    0 (fixed)
#     B_16_3:    0 (fixed)
#     C_16_3:    0 (fixed)
#     D_16_3:    0 (fixed)
#     A_16_4:    0 (fixed)
#     B_16_4:    0 (fixed)
#     C_16_4:    0 (fixed)
#     D_16_4:    0 (fixed)
#     A_16_5:    0 (fixed)
#     B_16_5:    0 (fixed)
#     C_16_5:    0 (fixed)
#     D_16_5:    0 (fixed)
#     A_16_6:    0 (fixed)
#     B_16_6:    0 (fixed)
#     C_16_6:    0 (fixed)
#     D_16_6:    0 (fixed)
#     A_16_7:    0 (fixed)
#     B_16_7:    0 (fixed)
#     C_16_7:    0 (fixed)
#     D_16_7:    0 (fixed)
#     A_16_8:    0 (fixed)
#     B_16_8:    0 (fixed)
#     C_16_8:    0 (fixed)
#     D_16_8:    0 (fixed)
#     A_16_9:    0 (fixed)
#     B_16_9:    0 (fixed)
#     C_16_9:    0 (fixed)
#     D_16_9:    0 (fixed)
#     A_16_10:   0 (fixed)
#     B_16_10:   0 (fixed)
#     C_16_10:   0 (fixed)
#     D_16_10:   0 (fixed)
#     A_16_11:   0 (fixed)
#     B_16_11:   0 (fixed)
#     C_16_11:   0 (fixed)
#     D_16_11:   0 (fixed)
#     A_16_12:   0 (fixed)
#     B_16_12:   0 (fixed)
#     C_16_12:   0 (fixed)
#     D_16_12:   0 (fixed)
#     A_16_13:   0 (fixed)
#     B_16_13:   0 (fixed)
#     C_16_13:   0 (fixed)
#     D_16_13:   0 (fixed)
#     A_16_14:   0 (fixed)
#     B_16_14:   0 (fixed)
#     C_16_14:   0 (fixed)
#     D_16_14:   0 (fixed)
#     A_16_15:   0 (fixed)
#     B_16_15:   0 (fixed)
#     C_16_15:   0 (fixed)
#     D_16_15:   0 (fixed)
#     A_16_16:   0.00153885 (init= 1)
#     B_16_16:  -0.00909342 (init=-1)
#     C_16_16:   0 (fixed)
#     D_16_16:   0 (fixed)
#     A_16_17:   0 (fixed)
#     B_16_17:   0.00282039 (init=-1)
#     C_16_17:   0 (fixed)
#     D_16_17:   0 (fixed)
#     A_16_18:  -0.00051243 (init= 1)
#     B_16_18:   0.00029356 (init=-1)
#     C_16_18:   0 (fixed)
#     D_16_18:   0 (fixed)
#     A_16_19:   2.5929e-06 (init= 1)
#     B_16_19:   6.4029e-05 (init=-1)
#     C_16_19:   0 (fixed)
#     D_16_19:   0 (fixed)
#     A_17_0:    0 (fixed)
#     B_17_0:    0 (fixed)
#     C_17_0:    0 (fixed)
#     D_17_0:    0 (fixed)
#     A_17_1:    0 (fixed)
#     B_17_1:    0 (fixed)
#     C_17_1:    0 (fixed)
#     D_17_1:    0 (fixed)
#     A_17_2:    0 (fixed)
#     B_17_2:    0 (fixed)
#     C_17_2:    0 (fixed)
#     D_17_2:    0 (fixed)
#     A_17_3:    0 (fixed)
#     B_17_3:    0 (fixed)
#     C_17_3:    0 (fixed)
#     D_17_3:    0 (fixed)
#     A_17_4:    0 (fixed)
#     B_17_4:    0 (fixed)
#     C_17_4:    0 (fixed)
#     D_17_4:    0 (fixed)
#     A_17_5:    0 (fixed)
#     B_17_5:    0 (fixed)
#     C_17_5:    0 (fixed)
#     D_17_5:    0 (fixed)
#     A_17_6:    0 (fixed)
#     B_17_6:    0 (fixed)
#     C_17_6:    0 (fixed)
#     D_17_6:    0 (fixed)
#     A_17_7:    0 (fixed)
#     B_17_7:    0 (fixed)
#     C_17_7:    0 (fixed)
#     D_17_7:    0 (fixed)
#     A_17_8:    0 (fixed)
#     B_17_8:    0 (fixed)
#     C_17_8:    0 (fixed)
#     D_17_8:    0 (fixed)
#     A_17_9:    0 (fixed)
#     B_17_9:    0 (fixed)
#     C_17_9:    0 (fixed)
#     D_17_9:    0 (fixed)
#     A_17_10:   0 (fixed)
#     B_17_10:   0 (fixed)
#     C_17_10:   0 (fixed)
#     D_17_10:   0 (fixed)
#     A_17_11:   0 (fixed)
#     B_17_11:   0 (fixed)
#     C_17_11:   0 (fixed)
#     D_17_11:   0 (fixed)
#     A_17_12:   0 (fixed)
#     B_17_12:   0 (fixed)
#     C_17_12:   0 (fixed)
#     D_17_12:   0 (fixed)
#     A_17_13:   0 (fixed)
#     B_17_13:   0 (fixed)
#     C_17_13:   0 (fixed)
#     D_17_13:   0 (fixed)
#     A_17_14:   0 (fixed)
#     B_17_14:   0 (fixed)
#     C_17_14:   0 (fixed)
#     D_17_14:   0 (fixed)
#     A_17_15:   0 (fixed)
#     B_17_15:   0 (fixed)
#     C_17_15:   0 (fixed)
#     D_17_15:   0 (fixed)
#     A_17_16:   0 (fixed)
#     B_17_16:   0 (fixed)
#     C_17_16:   0 (fixed)
#     D_17_16:   0 (fixed)
#     A_17_17:  -0.00025301 (init= 1)
#     B_17_17:   0.00152086 (init=-1)
#     C_17_17:   0 (fixed)
#     D_17_17:   0 (fixed)
#     A_17_18:   0 (fixed)
#     B_17_18:  -0.00047423 (init=-1)
#     C_17_18:   0 (fixed)
#     D_17_18:   0 (fixed)
#     A_17_19:   4.6713e-05 (init= 1)
#     B_17_19:  -2.7656e-05 (init=-1)
#     C_17_19:   0 (fixed)
#     D_17_19:   0 (fixed)
#     A_18_0:    0 (fixed)
#     B_18_0:    0 (fixed)
#     C_18_0:    0 (fixed)
#     D_18_0:    0 (fixed)
#     A_18_1:    0 (fixed)
#     B_18_1:    0 (fixed)
#     C_18_1:    0 (fixed)
#     D_18_1:    0 (fixed)
#     A_18_2:    0 (fixed)
#     B_18_2:    0 (fixed)
#     C_18_2:    0 (fixed)
#     D_18_2:    0 (fixed)
#     A_18_3:    0 (fixed)
#     B_18_3:    0 (fixed)
#     C_18_3:    0 (fixed)
#     D_18_3:    0 (fixed)
#     A_18_4:    0 (fixed)
#     B_18_4:    0 (fixed)
#     C_18_4:    0 (fixed)
#     D_18_4:    0 (fixed)
#     A_18_5:    0 (fixed)
#     B_18_5:    0 (fixed)
#     C_18_5:    0 (fixed)
#     D_18_5:    0 (fixed)
#     A_18_6:    0 (fixed)
#     B_18_6:    0 (fixed)
#     C_18_6:    0 (fixed)
#     D_18_6:    0 (fixed)
#     A_18_7:    0 (fixed)
#     B_18_7:    0 (fixed)
#     C_18_7:    0 (fixed)
#     D_18_7:    0 (fixed)
#     A_18_8:    0 (fixed)
#     B_18_8:    0 (fixed)
#     C_18_8:    0 (fixed)
#     D_18_8:    0 (fixed)
#     A_18_9:    0 (fixed)
#     B_18_9:    0 (fixed)
#     C_18_9:    0 (fixed)
#     D_18_9:    0 (fixed)
#     A_18_10:   0 (fixed)
#     B_18_10:   0 (fixed)
#     C_18_10:   0 (fixed)
#     D_18_10:   0 (fixed)
#     A_18_11:   0 (fixed)
#     B_18_11:   0 (fixed)
#     C_18_11:   0 (fixed)
#     D_18_11:   0 (fixed)
#     A_18_12:   0 (fixed)
#     B_18_12:   0 (fixed)
#     C_18_12:   0 (fixed)
#     D_18_12:   0 (fixed)
#     A_18_13:   0 (fixed)
#     B_18_13:   0 (fixed)
#     C_18_13:   0 (fixed)
#     D_18_13:   0 (fixed)
#     A_18_14:   0 (fixed)
#     B_18_14:   0 (fixed)
#     C_18_14:   0 (fixed)
#     D_18_14:   0 (fixed)
#     A_18_15:   0 (fixed)
#     B_18_15:   0 (fixed)
#     C_18_15:   0 (fixed)
#     D_18_15:   0 (fixed)
#     A_18_16:   0 (fixed)
#     B_18_16:   0 (fixed)
#     C_18_16:   0 (fixed)
#     D_18_16:   0 (fixed)
#     A_18_17:   0 (fixed)
#     B_18_17:   0 (fixed)
#     C_18_17:   0 (fixed)
#     D_18_17:   0 (fixed)
#     A_18_18:   2.9273e-05 (init= 1)
#     B_18_18:  -0.00017949 (init=-1)
#     C_18_18:   0 (fixed)
#     D_18_18:   0 (fixed)
#     A_18_19:   0 (fixed)
#     B_18_19:   4.3249e-05 (init=-1)
#     C_18_19:   0 (fixed)
#     D_18_19:   0 (fixed)
#     A_19_0:    0 (fixed)
#     B_19_0:    0 (fixed)
#     C_19_0:    0 (fixed)
#     D_19_0:    0 (fixed)
#     A_19_1:    0 (fixed)
#     B_19_1:    0 (fixed)
#     C_19_1:    0 (fixed)
#     D_19_1:    0 (fixed)
#     A_19_2:    0 (fixed)
#     B_19_2:    0 (fixed)
#     C_19_2:    0 (fixed)
#     D_19_2:    0 (fixed)
#     A_19_3:    0 (fixed)
#     B_19_3:    0 (fixed)
#     C_19_3:    0 (fixed)
#     D_19_3:    0 (fixed)
#     A_19_4:    0 (fixed)
#     B_19_4:    0 (fixed)
#     C_19_4:    0 (fixed)
#     D_19_4:    0 (fixed)
#     A_19_5:    0 (fixed)
#     B_19_5:    0 (fixed)
#     C_19_5:    0 (fixed)
#     D_19_5:    0 (fixed)
#     A_19_6:    0 (fixed)
#     B_19_6:    0 (fixed)
#     C_19_6:    0 (fixed)
#     D_19_6:    0 (fixed)
#     A_19_7:    0 (fixed)
#     B_19_7:    0 (fixed)
#     C_19_7:    0 (fixed)
#     D_19_7:    0 (fixed)
#     A_19_8:    0 (fixed)
#     B_19_8:    0 (fixed)
#     C_19_8:    0 (fixed)
#     D_19_8:    0 (fixed)
#     A_19_9:    0 (fixed)
#     B_19_9:    0 (fixed)
#     C_19_9:    0 (fixed)
#     D_19_9:    0 (fixed)
#     A_19_10:   0 (fixed)
#     B_19_10:   0 (fixed)
#     C_19_10:   0 (fixed)
#     D_19_10:   0 (fixed)
#     A_19_11:   0 (fixed)
#     B_19_11:   0 (fixed)
#     C_19_11:   0 (fixed)
#     D_19_11:   0 (fixed)
#     A_19_12:   0 (fixed)
#     B_19_12:   0 (fixed)
#     C_19_12:   0 (fixed)
#     D_19_12:   0 (fixed)
#     A_19_13:   0 (fixed)
#     B_19_13:   0 (fixed)
#     C_19_13:   0 (fixed)
#     D_19_13:   0 (fixed)
#     A_19_14:   0 (fixed)
#     B_19_14:   0 (fixed)
#     C_19_14:   0 (fixed)
#     D_19_14:   0 (fixed)
#     A_19_15:   0 (fixed)
#     B_19_15:   0 (fixed)
#     C_19_15:   0 (fixed)
#     D_19_15:   0 (fixed)
#     A_19_16:   0 (fixed)
#     B_19_16:   0 (fixed)
#     C_19_16:   0 (fixed)
#     D_19_16:   0 (fixed)
#     A_19_17:   0 (fixed)
#     B_19_17:   0 (fixed)
#     C_19_17:   0 (fixed)
#     D_19_17:   0 (fixed)
#     A_19_18:   0 (fixed)
#     B_19_18:   0 (fixed)
#     C_19_18:   0 (fixed)
#     D_19_18:   0 (fixed)
#     A_19_19:  -2.1620e-06 (init= 1)
#     B_19_19:   1.1624e-05 (init=-1)
#     C_19_19:   0 (fixed)
#     D_19_19:   0 (fixed)

# %%
ff1 = deepcopy(ff)

# %%
run hallprobesim.py
# Out:
# 1.5707963267948966
# (140, 10)
# 375.0
# 1450.0
# 0.002531942
# 1732114    0.002532
# Name: Br, dtype: float64
# fitting with n=20, m=20, cn=0, cm=0
# Elapsed time was 360.039 seconds
# [[Fit Statistics]]
#     # function evals   = 40
#     # data points      = 4200
#     # variables        = 362
#     chi-square         = 0.000
#     reduced chi-square = 0.000
#     Akaike info crit   = -117715.943
#     Bayesian info crit = -115419.835
# [[Variables]]
#     R:         12500 (fixed)
#     ns:        20 (fixed)
#     ms:        20 (fixed)
#     A_0_0:     0 (fixed)
#     B_0_0:     0 (fixed)
#     C_0_0:     0 (fixed)
#     D_0_0:     0 (fixed)
#     A_0_1:     0 (fixed)
#     B_0_1:     0 (fixed)
#     C_0_1:     0 (fixed)
#     D_0_1:     0 (fixed)
#     A_0_2:     0 (fixed)
#     B_0_2:     0 (fixed)
#     C_0_2:     0 (fixed)
#     D_0_2:     0 (fixed)
#     A_0_3:     0 (fixed)
#     B_0_3:     0 (fixed)
#     C_0_3:     0 (fixed)
#     D_0_3:     0 (fixed)
#     A_0_4:     0 (fixed)
#     B_0_4:     0 (fixed)
#     C_0_4:     0 (fixed)
#     D_0_4:     0 (fixed)
#     A_0_5:     0 (fixed)
#     B_0_5:     0 (fixed)
#     C_0_5:     0 (fixed)
#     D_0_5:     0 (fixed)
#     A_0_6:     0 (fixed)
#     B_0_6:     0 (fixed)
#     C_0_6:     0 (fixed)
#     D_0_6:     0 (fixed)
#     A_0_7:     0 (fixed)
#     B_0_7:     0 (fixed)
#     C_0_7:     0 (fixed)
#     D_0_7:     0 (fixed)
#     A_0_8:     0 (fixed)
#     B_0_8:     0 (fixed)
#     C_0_8:     0 (fixed)
#     D_0_8:     0 (fixed)
#     A_0_9:     0 (fixed)
#     B_0_9:     0 (fixed)
#     C_0_9:     0 (fixed)
#     D_0_9:     0 (fixed)
#     A_0_10:    0 (fixed)
#     B_0_10:    0 (fixed)
#     C_0_10:    0 (fixed)
#     D_0_10:    0 (fixed)
#     A_0_11:    0 (fixed)
#     B_0_11:    0 (fixed)
#     C_0_11:    0 (fixed)
#     D_0_11:    0 (fixed)
#     A_0_12:    0 (fixed)
#     B_0_12:    0 (fixed)
#     C_0_12:    0 (fixed)
#     D_0_12:    0 (fixed)
#     A_0_13:    0 (fixed)
#     B_0_13:    0 (fixed)
#     C_0_13:    0 (fixed)
#     D_0_13:    0 (fixed)
#     A_0_14:    0 (fixed)
#     B_0_14:    0 (fixed)
#     C_0_14:    0 (fixed)
#     D_0_14:    0 (fixed)
#     A_0_15:    0 (fixed)
#     B_0_15:    0 (fixed)
#     C_0_15:    0 (fixed)
#     D_0_15:    0 (fixed)
#     A_0_16:    0 (fixed)
#     B_0_16:    0 (fixed)
#     C_0_16:    0 (fixed)
#     D_0_16:    0 (fixed)
#     A_0_17:    0 (fixed)
#     B_0_17:    0 (fixed)
#     C_0_17:    0 (fixed)
#     D_0_17:    0 (fixed)
#     A_0_18:    0 (fixed)
#     B_0_18:    0 (fixed)
#     C_0_18:    0 (fixed)
#     D_0_18:    0 (fixed)
#     A_0_19:    0 (fixed)
#     B_0_19:    0 (fixed)
#     C_0_19:    0 (fixed)
#     D_0_19:    0 (fixed)
#     A_1_0:     0 (fixed)
#     B_1_0:     0 (fixed)
#     C_1_0:     0 (fixed)
#     D_1_0:     0 (fixed)
#     A_1_1:    -3.35453347 (init= 1)
#     B_1_1:     3630.50506 (init=-1)
#     C_1_1:     0 (fixed)
#     D_1_1:     0 (fixed)
#     A_1_2:     0 (fixed)
#     B_1_2:     0.56893397 (init=-1)
#     C_1_2:     0 (fixed)
#     D_1_2:     0 (fixed)
#     A_1_3:     0.78830039 (init= 1)
#     B_1_3:     0.22126312 (init=-1)
#     C_1_3:     0 (fixed)
#     D_1_3:     0 (fixed)
#     A_1_4:    -1.71382330 (init= 1)
#     B_1_4:     26.3827340 (init=-1)
#     C_1_4:     0 (fixed)
#     D_1_4:     0 (fixed)
#     A_1_5:     35.4404134 (init= 1)
#     B_1_5:    -22.3120360 (init=-1)
#     C_1_5:     0 (fixed)
#     D_1_5:     0 (fixed)
#     A_1_6:    -189.083472 (init= 1)
#     B_1_6:     4462.98696 (init=-1)
#     C_1_6:     0 (fixed)
#     D_1_6:     0 (fixed)
#     A_1_7:    -959.579192 (init= 1)
#     B_1_7:     3228.11843 (init=-1)
#     C_1_7:     0 (fixed)
#     D_1_7:     0 (fixed)
#     A_1_8:     833.383488 (init= 1)
#     B_1_8:     52454.4807 (init=-1)
#     C_1_8:     0 (fixed)
#     D_1_8:     0 (fixed)
#     A_1_9:     16130.6607 (init= 1)
#     B_1_9:    -17043.8436 (init=-1)
#     C_1_9:     0 (fixed)
#     D_1_9:     0 (fixed)
#     A_1_10:    1854.44862 (init= 1)
#     B_1_10:   -1345.48853 (init=-1)
#     C_1_10:    0 (fixed)
#     D_1_10:    0 (fixed)
#     A_1_11:   -189.167321 (init= 1)
#     B_1_11:   -27.7485535 (init=-1)
#     C_1_11:    0 (fixed)
#     D_1_11:    0 (fixed)
#     A_1_12:   -390.731392 (init= 1)
#     B_1_12:   -198.374030 (init=-1)
#     C_1_12:    0 (fixed)
#     D_1_12:    0 (fixed)
#     A_1_13:   -804.114986 (init= 1)
#     B_1_13:   -427.431404 (init=-1)
#     C_1_13:    0 (fixed)
#     D_1_13:    0 (fixed)
#     A_1_14:   -1091.76656 (init= 1)
#     B_1_14:   -593.364156 (init=-1)
#     C_1_14:    0 (fixed)
#     D_1_14:    0 (fixed)
#     A_1_15:    263.062744 (init= 1)
#     B_1_15:   -877.076378 (init=-1)
#     C_1_15:    0 (fixed)
#     D_1_15:    0 (fixed)
#     A_1_16:   -153.676482 (init= 1)
#     B_1_16:   -945.469359 (init=-1)
#     C_1_16:    0 (fixed)
#     D_1_16:    0 (fixed)
#     A_1_17:    611.701902 (init= 1)
#     B_1_17:    79.5297974 (init=-1)
#     C_1_17:    0 (fixed)
#     D_1_17:    0 (fixed)
#     A_1_18:   -265.252454 (init= 1)
#     B_1_18:    216.798229 (init=-1)
#     C_1_18:    0 (fixed)
#     D_1_18:    0 (fixed)
#     A_1_19:    193.615746 (init= 1)
#     B_1_19:   -110.742219 (init=-1)
#     C_1_19:    0 (fixed)
#     D_1_19:    0 (fixed)
#     A_2_0:     0 (fixed)
#     B_2_0:     0 (fixed)
#     C_2_0:     0 (fixed)
#     D_2_0:     0 (fixed)
#     A_2_1:     0 (fixed)
#     B_2_1:     0 (fixed)
#     C_2_1:     0 (fixed)
#     D_2_1:     0 (fixed)
#     A_2_2:     3.47687090 (init= 1)
#     B_2_2:    -1463.65493 (init=-1)
#     C_2_2:     0 (fixed)
#     D_2_2:     0 (fixed)
#     A_2_3:     0 (fixed)
#     B_2_3:    -0.49518214 (init=-1)
#     C_2_3:     0 (fixed)
#     D_2_3:     0 (fixed)
#     A_2_4:    -0.39207222 (init= 1)
#     B_2_4:     0.12128147 (init=-1)
#     C_2_4:     0 (fixed)
#     D_2_4:     0 (fixed)
#     A_2_5:     0.91124951 (init= 1)
#     B_2_5:    -16.4952311 (init=-1)
#     C_2_5:     0 (fixed)
#     D_2_5:     0 (fixed)
#     A_2_6:    -13.1714988 (init= 1)
#     B_2_6:     8.79247599 (init=-1)
#     C_2_6:     0 (fixed)
#     D_2_6:     0 (fixed)
#     A_2_7:     14.3133436 (init= 1)
#     B_2_7:    -384.045603 (init=-1)
#     C_2_7:     0 (fixed)
#     D_2_7:     0 (fixed)
#     A_2_8:    -2.94156234 (init= 1)
#     B_2_8:    -32.9882136 (init=-1)
#     C_2_8:     0 (fixed)
#     D_2_8:     0 (fixed)
#     A_2_9:     780.108910 (init= 1)
#     B_2_9:     46561.0235 (init=-1)
#     C_2_9:     0 (fixed)
#     D_2_9:     0 (fixed)
#     A_2_10:   -15156.0557 (init= 1)
#     B_2_10:    17605.8533 (init=-1)
#     C_2_10:    0 (fixed)
#     D_2_10:    0 (fixed)
#     A_2_11:    21044.5753 (init= 1)
#     B_2_11:   -19660.7550 (init=-1)
#     C_2_11:    0 (fixed)
#     D_2_11:    0 (fixed)
#     A_2_12:   -6185.41282 (init= 1)
#     B_2_12:    21386.3390 (init=-1)
#     C_2_12:    0 (fixed)
#     D_2_12:    0 (fixed)
#     A_2_13:    2318.61685 (init= 1)
#     B_2_13:    1278.41239 (init=-1)
#     C_2_13:    0 (fixed)
#     D_2_13:    0 (fixed)
#     A_2_14:    85.8780444 (init= 1)
#     B_2_14:    165.065721 (init=-1)
#     C_2_14:    0 (fixed)
#     D_2_14:    0 (fixed)
#     A_2_15:   -216.987787 (init= 1)
#     B_2_15:   -56.5378069 (init=-1)
#     C_2_15:    0 (fixed)
#     D_2_15:    0 (fixed)
#     A_2_16:    420.900604 (init= 1)
#     B_2_16:    65.8142030 (init=-1)
#     C_2_16:    0 (fixed)
#     D_2_16:    0 (fixed)
#     A_2_17:    67.0471567 (init= 1)
#     B_2_17:    50.3759434 (init=-1)
#     C_2_17:    0 (fixed)
#     D_2_17:    0 (fixed)
#     A_2_18:    462.215231 (init= 1)
#     B_2_18:   -94.6273346 (init=-1)
#     C_2_18:    0 (fixed)
#     D_2_18:    0 (fixed)
#     A_2_19:    170.276206 (init= 1)
#     B_2_19:    130.434088 (init=-1)
#     C_2_19:    0 (fixed)
#     D_2_19:    0 (fixed)
#     A_3_0:     0 (fixed)
#     B_3_0:     0 (fixed)
#     C_3_0:     0 (fixed)
#     D_3_0:     0 (fixed)
#     A_3_1:     0 (fixed)
#     B_3_1:     0 (fixed)
#     C_3_1:     0 (fixed)
#     D_3_1:     0 (fixed)
#     A_3_2:     0 (fixed)
#     B_3_2:     0 (fixed)
#     C_3_2:     0 (fixed)
#     D_3_2:     0 (fixed)
#     A_3_3:    -3.46555784 (init= 1)
#     B_3_3:     751.073936 (init=-1)
#     C_3_3:     0 (fixed)
#     D_3_3:     0 (fixed)
#     A_3_4:     0 (fixed)
#     B_3_4:     0.30971945 (init=-1)
#     C_3_4:     0 (fixed)
#     D_3_4:     0 (fixed)
#     A_3_5:    -0.13455246 (init= 1)
#     B_3_5:    -0.30207424 (init=-1)
#     C_3_5:     0 (fixed)
#     D_3_5:     0 (fixed)
#     A_3_6:    -0.69448461 (init= 1)
#     B_3_6:     13.9207523 (init=-1)
#     C_3_6:     0 (fixed)
#     D_3_6:     0 (fixed)
#     A_3_7:     8.07192707 (init= 1)
#     B_3_7:    -5.63885138 (init=-1)
#     C_3_7:     0 (fixed)
#     D_3_7:     0 (fixed)
#     A_3_8:    -0.80136401 (init= 1)
#     B_3_8:     60.7866273 (init=-1)
#     C_3_8:     0 (fixed)
#     D_3_8:     0 (fixed)
#     A_3_9:    -13.6819313 (init= 1)
#     B_3_9:     18.2563506 (init=-1)
#     C_3_9:     0 (fixed)
#     D_3_9:     0 (fixed)
#     A_3_10:   -12.2287481 (init= 1)
#     B_3_10:   -13967.0611 (init=-1)
#     C_3_10:    0 (fixed)
#     D_3_10:    0 (fixed)
#     A_3_11:    1093.26834 (init= 1)
#     B_3_11:   -1851.26455 (init=-1)
#     C_3_11:    0 (fixed)
#     D_3_11:    0 (fixed)
#     A_3_12:    21757.7640 (init= 1)
#     B_3_12:   -49342.0662 (init=-1)
#     C_3_12:    0 (fixed)
#     D_3_12:    0 (fixed)
#     A_3_13:   -1517.37567 (init= 1)
#     B_3_13:   -26937.7883 (init=-1)
#     C_3_13:    0 (fixed)
#     D_3_13:    0 (fixed)
#     A_3_14:   -555.875493 (init= 1)
#     B_3_14:   -6604.09587 (init=-1)
#     C_3_14:    0 (fixed)
#     D_3_14:    0 (fixed)
#     A_3_15:   -14467.4111 (init= 1)
#     B_3_15:    549.521823 (init=-1)
#     C_3_15:    0 (fixed)
#     D_3_15:    0 (fixed)
#     A_3_16:    5.86792618 (init= 1)
#     B_3_16:   -643.866074 (init=-1)
#     C_3_16:    0 (fixed)
#     D_3_16:    0 (fixed)
#     A_3_17:    233.948811 (init= 1)
#     B_3_17:    539.110903 (init=-1)
#     C_3_17:    0 (fixed)
#     D_3_17:    0 (fixed)
#     A_3_18:    221.894874 (init= 1)
#     B_3_18:   -153.253557 (init=-1)
#     C_3_18:    0 (fixed)
#     D_3_18:    0 (fixed)
#     A_3_19:   -356.014787 (init= 1)
#     B_3_19:   -70.2168936 (init=-1)
#     C_3_19:    0 (fixed)
#     D_3_19:    0 (fixed)
#     A_4_0:     0 (fixed)
#     B_4_0:     0 (fixed)
#     C_4_0:     0 (fixed)
#     D_4_0:     0 (fixed)
#     A_4_1:     0 (fixed)
#     B_4_1:     0 (fixed)
#     C_4_1:     0 (fixed)
#     D_4_1:     0 (fixed)
#     A_4_2:     0 (fixed)
#     B_4_2:     0 (fixed)
#     C_4_2:     0 (fixed)
#     D_4_2:     0 (fixed)
#     A_4_3:     0 (fixed)
#     B_4_3:     0 (fixed)
#     C_4_3:     0 (fixed)
#     D_4_3:     0 (fixed)
#     A_4_4:     3.26820350 (init= 1)
#     B_4_4:    -421.165743 (init=-1)
#     C_4_4:     0 (fixed)
#     D_4_4:     0 (fixed)
#     A_4_5:     0 (fixed)
#     B_4_5:    -0.00620659 (init=-1)
#     C_4_5:     0 (fixed)
#     D_4_5:     0 (fixed)
#     A_4_6:     0.64358769 (init= 1)
#     B_4_6:     0.39789052 (init=-1)
#     C_4_6:     0 (fixed)
#     D_4_6:     0 (fixed)
#     A_4_7:     0.54564273 (init= 1)
#     B_4_7:    -12.0462457 (init=-1)
#     C_4_7:     0 (fixed)
#     D_4_7:     0 (fixed)
#     A_4_8:    -5.50945900 (init= 1)
#     B_4_8:     4.07108553 (init=-1)
#     C_4_8:     0 (fixed)
#     D_4_8:     0 (fixed)
#     A_4_9:    -1.45262269 (init= 1)
#     B_4_9:    -2.76684763 (init=-1)
#     C_4_9:     0 (fixed)
#     D_4_9:     0 (fixed)
#     A_4_10:    14.6760186 (init= 1)
#     B_4_10:   -19.6977717 (init=-1)
#     C_4_10:    0 (fixed)
#     D_4_10:    0 (fixed)
#     A_4_11:    20.7615847 (init= 1)
#     B_4_11:    4851.58220 (init=-1)
#     C_4_11:    0 (fixed)
#     D_4_11:    0 (fixed)
#     A_4_12:    43.6886479 (init= 1)
#     B_4_12:   -141.215576 (init=-1)
#     C_4_12:    0 (fixed)
#     D_4_12:    0 (fixed)
#     A_4_13:   -2411.93540 (init= 1)
#     B_4_13:    35.3985841 (init=-1)
#     C_4_13:    0 (fixed)
#     D_4_13:    0 (fixed)
#     A_4_14:    3197.56743 (init= 1)
#     B_4_14:   -15812.1522 (init=-1)
#     C_4_14:    0 (fixed)
#     D_4_14:    0 (fixed)
#     A_4_15:    15167.8319 (init= 1)
#     B_4_15:   -19860.3905 (init=-1)
#     C_4_15:    0 (fixed)
#     D_4_15:    0 (fixed)
#     A_4_16:    34435.0032 (init= 1)
#     B_4_16:   -10138.4885 (init=-1)
#     C_4_16:    0 (fixed)
#     D_4_16:    0 (fixed)
#     A_4_17:   -2696.76518 (init= 1)
#     B_4_17:    24615.5771 (init=-1)
#     C_4_17:    0 (fixed)
#     D_4_17:    0 (fixed)
#     A_4_18:    234.813440 (init= 1)
#     B_4_18:   -2.04310728 (init=-1)
#     C_4_18:    0 (fixed)
#     D_4_18:    0 (fixed)
#     A_4_19:   -5.83453436 (init= 1)
#     B_4_19:   -36.5132098 (init=-1)
#     C_4_19:    0 (fixed)
#     D_4_19:    0 (fixed)
#     A_5_0:     0 (fixed)
#     B_5_0:     0 (fixed)
#     C_5_0:     0 (fixed)
#     D_5_0:     0 (fixed)
#     A_5_1:     0 (fixed)
#     B_5_1:     0 (fixed)
#     C_5_1:     0 (fixed)
#     D_5_1:     0 (fixed)
#     A_5_2:     0 (fixed)
#     B_5_2:     0 (fixed)
#     C_5_2:     0 (fixed)
#     D_5_2:     0 (fixed)
#     A_5_3:     0 (fixed)
#     B_5_3:     0 (fixed)
#     C_5_3:     0 (fixed)
#     D_5_3:     0 (fixed)
#     A_5_4:     0 (fixed)
#     B_5_4:     0 (fixed)
#     C_5_4:     0 (fixed)
#     D_5_4:     0 (fixed)
#     A_5_5:    -2.88935917 (init= 1)
#     B_5_5:     243.948800 (init=-1)
#     C_5_5:     0 (fixed)
#     D_5_5:     0 (fixed)
#     A_5_6:     0 (fixed)
#     B_5_6:    -0.36348041 (init=-1)
#     C_5_6:     0 (fixed)
#     D_5_6:     0 (fixed)
#     A_5_7:    -1.00400068 (init= 1)
#     B_5_7:    -0.41640292 (init=-1)
#     C_5_7:     0 (fixed)
#     D_5_7:     0 (fixed)
#     A_5_8:    -0.40739908 (init= 1)
#     B_5_8:     9.97906365 (init=-1)
#     C_5_8:     0 (fixed)
#     D_5_8:     0 (fixed)
#     A_5_9:     3.78625703 (init= 1)
#     B_5_9:    -3.04907947 (init=-1)
#     C_5_9:     0 (fixed)
#     D_5_9:     0 (fixed)
#     A_5_10:    1.69130235 (init= 1)
#     B_5_10:   -3.50868491 (init=-1)
#     C_5_10:    0 (fixed)
#     D_5_10:    0 (fixed)
#     A_5_11:   -8.34997071 (init= 1)
#     B_5_11:    10.2195344 (init=-1)
#     C_5_11:    0 (fixed)
#     D_5_11:    0 (fixed)
#     A_5_12:   -10.6709895 (init= 1)
#     B_5_12:   -1623.05881 (init=-1)
#     C_5_12:    0 (fixed)
#     D_5_12:    0 (fixed)
#     A_5_13:   -32.8475680 (init= 1)
#     B_5_13:   -3.86918804 (init=-1)
#     C_5_13:    0 (fixed)
#     D_5_13:    0 (fixed)
#     A_5_14:    277.395018 (init= 1)
#     B_5_14:    10012.7781 (init=-1)
#     C_5_14:    0 (fixed)
#     D_5_14:    0 (fixed)
#     A_5_15:   -1166.63928 (init= 1)
#     B_5_15:    1290.50274 (init=-1)
#     C_5_15:    0 (fixed)
#     D_5_15:    0 (fixed)
#     A_5_16:   -794.209692 (init= 1)
#     B_5_16:    17243.7192 (init=-1)
#     C_5_16:    0 (fixed)
#     D_5_16:    0 (fixed)
#     A_5_17:   -361.929650 (init= 1)
#     B_5_17:    24409.3043 (init=-1)
#     C_5_17:    0 (fixed)
#     D_5_17:    0 (fixed)
#     A_5_18:   -36946.1508 (init= 1)
#     B_5_18:    34314.4729 (init=-1)
#     C_5_18:    0 (fixed)
#     D_5_18:    0 (fixed)
#     A_5_19:    6193.58516 (init= 1)
#     B_5_19:   -22555.4578 (init=-1)
#     C_5_19:    0 (fixed)
#     D_5_19:    0 (fixed)
#     A_6_0:     0 (fixed)
#     B_6_0:     0 (fixed)
#     C_6_0:     0 (fixed)
#     D_6_0:     0 (fixed)
#     A_6_1:     0 (fixed)
#     B_6_1:     0 (fixed)
#     C_6_1:     0 (fixed)
#     D_6_1:     0 (fixed)
#     A_6_2:     0 (fixed)
#     B_6_2:     0 (fixed)
#     C_6_2:     0 (fixed)
#     D_6_2:     0 (fixed)
#     A_6_3:     0 (fixed)
#     B_6_3:     0 (fixed)
#     C_6_3:     0 (fixed)
#     D_6_3:     0 (fixed)
#     A_6_4:     0 (fixed)
#     B_6_4:     0 (fixed)
#     C_6_4:     0 (fixed)
#     D_6_4:     0 (fixed)
#     A_6_5:     0 (fixed)
#     B_6_5:     0 (fixed)
#     C_6_5:     0 (fixed)
#     D_6_5:     0 (fixed)
#     A_6_6:     2.37701786 (init= 1)
#     B_6_6:    -140.645621 (init=-1)
#     C_6_6:     0 (fixed)
#     D_6_6:     0 (fixed)
#     A_6_7:     0 (fixed)
#     B_6_7:     0.69375115 (init=-1)
#     C_6_7:     0 (fixed)
#     D_6_7:     0 (fixed)
#     A_6_8:     1.14940122 (init= 1)
#     B_6_8:     0.36808764 (init=-1)
#     C_6_8:     0 (fixed)
#     D_6_8:     0 (fixed)
#     A_6_9:     0.28006324 (init= 1)
#     B_6_9:    -7.64822657 (init=-1)
#     C_6_9:     0 (fixed)
#     D_6_9:     0 (fixed)
#     A_6_10:   -2.47272051 (init= 1)
#     B_6_10:    2.19250808 (init=-1)
#     C_6_10:    0 (fixed)
#     D_6_10:    0 (fixed)
#     A_6_11:   -1.39527920 (init= 1)
#     B_6_11:    2.55556095 (init=-1)
#     C_6_11:    0 (fixed)
#     D_6_11:    0 (fixed)
#     A_6_12:    3.82957562 (init= 1)
#     B_6_12:   -5.65982209 (init=-1)
#     C_6_12:    0 (fixed)
#     D_6_12:    0 (fixed)
#     A_6_13:    1.84404777 (init= 1)
#     B_6_13:    588.800926 (init=-1)
#     C_6_13:    0 (fixed)
#     D_6_13:    0 (fixed)
#     A_6_14:   -7.31973130 (init= 1)
#     B_6_14:   -21.4941082 (init=-1)
#     C_6_14:    0 (fixed)
#     D_6_14:    0 (fixed)
#     A_6_15:   -102.761529 (init= 1)
#     B_6_15:   -4114.02030 (init=-1)
#     C_6_15:    0 (fixed)
#     D_6_15:    0 (fixed)
#     A_6_16:   -7.58040982 (init= 1)
#     B_6_16:   -1627.78602 (init=-1)
#     C_6_16:    0 (fixed)
#     D_6_16:    0 (fixed)
#     A_6_17:   -2286.58832 (init= 1)
#     B_6_17:   -528.447822 (init=-1)
#     C_6_17:    0 (fixed)
#     D_6_17:    0 (fixed)
#     A_6_18:    5431.15214 (init= 1)
#     B_6_18:   -42655.2488 (init=-1)
#     C_6_18:    0 (fixed)
#     D_6_18:    0 (fixed)
#     A_6_19:    18817.5651 (init= 1)
#     B_6_19:   -15403.3088 (init=-1)
#     C_6_19:    0 (fixed)
#     D_6_19:    0 (fixed)
#     A_7_0:     0 (fixed)
#     B_7_0:     0 (fixed)
#     C_7_0:     0 (fixed)
#     D_7_0:     0 (fixed)
#     A_7_1:     0 (fixed)
#     B_7_1:     0 (fixed)
#     C_7_1:     0 (fixed)
#     D_7_1:     0 (fixed)
#     A_7_2:     0 (fixed)
#     B_7_2:     0 (fixed)
#     C_7_2:     0 (fixed)
#     D_7_2:     0 (fixed)
#     A_7_3:     0 (fixed)
#     B_7_3:     0 (fixed)
#     C_7_3:     0 (fixed)
#     D_7_3:     0 (fixed)
#     A_7_4:     0 (fixed)
#     B_7_4:     0 (fixed)
#     C_7_4:     0 (fixed)
#     D_7_4:     0 (fixed)
#     A_7_5:     0 (fixed)
#     B_7_5:     0 (fixed)
#     C_7_5:     0 (fixed)
#     D_7_5:     0 (fixed)
#     A_7_6:     0 (fixed)
#     B_7_6:     0 (fixed)
#     C_7_6:     0 (fixed)
#     D_7_6:     0 (fixed)
#     A_7_7:    -1.80638920 (init= 1)
#     B_7_7:     78.5090177 (init=-1)
#     C_7_7:     0 (fixed)
#     D_7_7:     0 (fixed)
#     A_7_8:     0 (fixed)
#     B_7_8:    -0.88427827 (init=-1)
#     C_7_8:     0 (fixed)
#     D_7_8:     0 (fixed)
#     A_7_9:    -1.08777055 (init= 1)
#     B_7_9:    -0.27799774 (init=-1)
#     C_7_9:     0 (fixed)
#     D_7_9:     0 (fixed)
#     A_7_10:   -0.17590165 (init= 1)
#     B_7_10:    5.33638040 (init=-1)
#     C_7_10:    0 (fixed)
#     D_7_10:    0 (fixed)
#     A_7_11:    1.47863977 (init= 1)
#     B_7_11:   -1.48090640 (init=-1)
#     C_7_11:    0 (fixed)
#     D_7_11:    0 (fixed)
#     A_7_12:    0.91116459 (init= 1)
#     B_7_12:   -0.90049234 (init=-1)
#     C_7_12:    0 (fixed)
#     D_7_12:    0 (fixed)
#     A_7_13:   -1.79153679 (init= 1)
#     B_7_13:    2.28995464 (init=-1)
#     C_7_13:    0 (fixed)
#     D_7_13:    0 (fixed)
#     A_7_14:   -0.87369642 (init= 1)
#     B_7_14:   -221.655702 (init=-1)
#     C_7_14:    0 (fixed)
#     D_7_14:    0 (fixed)
#     A_7_15:    3.14615209 (init= 1)
#     B_7_15:   -17.0455649 (init=-1)
#     C_7_15:    0 (fixed)
#     D_7_15:    0 (fixed)
#     A_7_16:   -12.6647750 (init= 1)
#     B_7_16:    1261.01188 (init=-1)
#     C_7_16:    0 (fixed)
#     D_7_16:    0 (fixed)
#     A_7_17:    15.4826063 (init= 1)
#     B_7_17:   -589.959657 (init=-1)
#     C_7_17:    0 (fixed)
#     D_7_17:    0 (fixed)
#     A_7_18:   -72.9609229 (init= 1)
#     B_7_18:    943.394960 (init=-1)
#     C_7_18:    0 (fixed)
#     D_7_18:    0 (fixed)
#     A_7_19:   -166.890929 (init= 1)
#     B_7_19:   -15224.8069 (init=-1)
#     C_7_19:    0 (fixed)
#     D_7_19:    0 (fixed)
#     A_8_0:     0 (fixed)
#     B_8_0:     0 (fixed)
#     C_8_0:     0 (fixed)
#     D_8_0:     0 (fixed)
#     A_8_1:     0 (fixed)
#     B_8_1:     0 (fixed)
#     C_8_1:     0 (fixed)
#     D_8_1:     0 (fixed)
#     A_8_2:     0 (fixed)
#     B_8_2:     0 (fixed)
#     C_8_2:     0 (fixed)
#     D_8_2:     0 (fixed)
#     A_8_3:     0 (fixed)
#     B_8_3:     0 (fixed)
#     C_8_3:     0 (fixed)
#     D_8_3:     0 (fixed)
#     A_8_4:     0 (fixed)
#     B_8_4:     0 (fixed)
#     C_8_4:     0 (fixed)
#     D_8_4:     0 (fixed)
#     A_8_5:     0 (fixed)
#     B_8_5:     0 (fixed)
#     C_8_5:     0 (fixed)
#     D_8_5:     0 (fixed)
#     A_8_6:     0 (fixed)
#     B_8_6:     0 (fixed)
#     C_8_6:     0 (fixed)
#     D_8_6:     0 (fixed)
#     A_8_7:     0 (fixed)
#     B_8_7:     0 (fixed)
#     C_8_7:     0 (fixed)
#     D_8_7:     0 (fixed)
#     A_8_8:     1.25828020 (init= 1)
#     B_8_8:    -41.5837194 (init=-1)
#     C_8_8:     0 (fixed)
#     D_8_8:     0 (fixed)
#     A_8_9:     0 (fixed)
#     B_8_9:     0.89541702 (init=-1)
#     C_8_9:     0 (fixed)
#     D_8_9:     0 (fixed)
#     A_8_10:    0.88393086 (init= 1)
#     B_8_10:    0.17765063 (init=-1)
#     C_8_10:    0 (fixed)
#     D_8_10:    0 (fixed)
#     A_8_11:    0.09975662 (init= 1)
#     B_8_11:   -3.35175872 (init=-1)
#     C_8_11:    0 (fixed)
#     D_8_11:    0 (fixed)
#     A_8_12:   -0.79550508 (init= 1)
#     B_8_12:    0.90887659 (init=-1)
#     C_8_12:    0 (fixed)
#     D_8_12:    0 (fixed)
#     A_8_13:   -0.53185870 (init= 1)
#     B_8_13:   -0.17745600 (init=-1)
#     C_8_13:    0 (fixed)
#     D_8_13:    0 (fixed)
#     A_8_14:    0.70325020 (init= 1)
#     B_8_14:   -1.07273805 (init=-1)
#     C_8_14:    0 (fixed)
#     D_8_14:    0 (fixed)
#     A_8_15:   -0.49558300 (init= 1)
#     B_8_15:    81.5344774 (init=-1)
#     C_8_15:    0 (fixed)
#     D_8_15:    0 (fixed)
#     A_8_16:   -2.40140437 (init= 1)
#     B_8_16:    0.72991525 (init=-1)
#     C_8_16:    0 (fixed)
#     D_8_16:    0 (fixed)
#     A_8_17:   -5.54684113 (init= 1)
#     B_8_17:   -302.888737 (init=-1)
#     C_8_17:    0 (fixed)
#     D_8_17:    0 (fixed)
#     A_8_18:   -22.4040569 (init= 1)
#     B_8_18:   -24.8367734 (init=-1)
#     C_8_18:    0 (fixed)
#     D_8_18:    0 (fixed)
#     A_8_19:   -121.444216 (init= 1)
#     B_8_19:   -248.346299 (init=-1)
#     C_8_19:    0 (fixed)
#     D_8_19:    0 (fixed)
#     A_9_0:     0 (fixed)
#     B_9_0:     0 (fixed)
#     C_9_0:     0 (fixed)
#     D_9_0:     0 (fixed)
#     A_9_1:     0 (fixed)
#     B_9_1:     0 (fixed)
#     C_9_1:     0 (fixed)
#     D_9_1:     0 (fixed)
#     A_9_2:     0 (fixed)
#     B_9_2:     0 (fixed)
#     C_9_2:     0 (fixed)
#     D_9_2:     0 (fixed)
#     A_9_3:     0 (fixed)
#     B_9_3:     0 (fixed)
#     C_9_3:     0 (fixed)
#     D_9_3:     0 (fixed)
#     A_9_4:     0 (fixed)
#     B_9_4:     0 (fixed)
#     C_9_4:     0 (fixed)
#     D_9_4:     0 (fixed)
#     A_9_5:     0 (fixed)
#     B_9_5:     0 (fixed)
#     C_9_5:     0 (fixed)
#     D_9_5:     0 (fixed)
#     A_9_6:     0 (fixed)
#     B_9_6:     0 (fixed)
#     C_9_6:     0 (fixed)
#     D_9_6:     0 (fixed)
#     A_9_7:     0 (fixed)
#     B_9_7:     0 (fixed)
#     C_9_7:     0 (fixed)
#     D_9_7:     0 (fixed)
#     A_9_8:     0 (fixed)
#     B_9_8:     0 (fixed)
#     C_9_8:     0 (fixed)
#     D_9_8:     0 (fixed)
#     A_9_9:    -0.79668894 (init= 1)
#     B_9_9:     20.5959197 (init=-1)
#     C_9_9:     0 (fixed)
#     D_9_9:     0 (fixed)
#     A_9_10:    0 (fixed)
#     B_9_10:   -0.75962815 (init=-1)
#     C_9_10:    0 (fixed)
#     D_9_10:    0 (fixed)
#     A_9_11:   -0.62520274 (init= 1)
#     B_9_11:   -0.09337172 (init=-1)
#     C_9_11:    0 (fixed)
#     D_9_11:    0 (fixed)
#     A_9_12:   -0.05124573 (init= 1)
#     B_9_12:    1.87292872 (init=-1)
#     C_9_12:    0 (fixed)
#     D_9_12:    0 (fixed)
#     A_9_13:    0.37555445 (init= 1)
#     B_9_13:   -0.50110282 (init=-1)
#     C_9_13:    0 (fixed)
#     D_9_13:    0 (fixed)
#     A_9_14:    0.25653073 (init= 1)
#     B_9_14:    0.56086740 (init=-1)
#     C_9_14:    0 (fixed)
#     D_9_14:    0 (fixed)
#     A_9_15:   -0.25491472 (init= 1)
#     B_9_15:    0.38765496 (init=-1)
#     C_9_15:    0 (fixed)
#     D_9_15:    0 (fixed)
#     A_9_16:    0.26752471 (init= 1)
#     B_9_16:   -27.4250836 (init=-1)
#     C_9_16:    0 (fixed)
#     D_9_16:    0 (fixed)
#     A_9_17:    0.84309099 (init= 1)
#     B_9_17:   -0.41382578 (init=-1)
#     C_9_17:    0 (fixed)
#     D_9_17:    0 (fixed)
#     A_9_18:   -0.20418278 (init= 1)
#     B_9_18:    51.8685967 (init=-1)
#     C_9_18:    0 (fixed)
#     D_9_18:    0 (fixed)
#     A_9_19:    7.48741402 (init= 1)
#     B_9_19:    5.41178624 (init=-1)
#     C_9_19:    0 (fixed)
#     D_9_19:    0 (fixed)
#     A_10_0:    0 (fixed)
#     B_10_0:    0 (fixed)
#     C_10_0:    0 (fixed)
#     D_10_0:    0 (fixed)
#     A_10_1:    0 (fixed)
#     B_10_1:    0 (fixed)
#     C_10_1:    0 (fixed)
#     D_10_1:    0 (fixed)
#     A_10_2:    0 (fixed)
#     B_10_2:    0 (fixed)
#     C_10_2:    0 (fixed)
#     D_10_2:    0 (fixed)
#     A_10_3:    0 (fixed)
#     B_10_3:    0 (fixed)
#     C_10_3:    0 (fixed)
#     D_10_3:    0 (fixed)
#     A_10_4:    0 (fixed)
#     B_10_4:    0 (fixed)
#     C_10_4:    0 (fixed)
#     D_10_4:    0 (fixed)
#     A_10_5:    0 (fixed)
#     B_10_5:    0 (fixed)
#     C_10_5:    0 (fixed)
#     D_10_5:    0 (fixed)
#     A_10_6:    0 (fixed)
#     B_10_6:    0 (fixed)
#     C_10_6:    0 (fixed)
#     D_10_6:    0 (fixed)
#     A_10_7:    0 (fixed)
#     B_10_7:    0 (fixed)
#     C_10_7:    0 (fixed)
#     D_10_7:    0 (fixed)
#     A_10_8:    0 (fixed)
#     B_10_8:    0 (fixed)
#     C_10_8:    0 (fixed)
#     D_10_8:    0 (fixed)
#     A_10_9:    0 (fixed)
#     B_10_9:    0 (fixed)
#     C_10_9:    0 (fixed)
#     D_10_9:    0 (fixed)
#     A_10_10:   0.45419042 (init= 1)
#     B_10_10:  -9.43091886 (init=-1)
#     C_10_10:   0 (fixed)
#     D_10_10:   0 (fixed)
#     A_10_11:   0 (fixed)
#     B_10_11:   0.55148558 (init=-1)
#     C_10_11:   0 (fixed)
#     D_10_11:   0 (fixed)
#     A_10_12:   0.38575962 (init= 1)
#     B_10_12:   0.03756125 (init=-1)
#     C_10_12:   0 (fixed)
#     D_10_12:   0 (fixed)
#     A_10_13:   0.02371487 (init= 1)
#     B_10_13:  -0.91682978 (init=-1)
#     C_10_13:   0 (fixed)
#     D_10_13:   0 (fixed)
#     A_10_14:  -0.15110599 (init= 1)
#     B_10_14:   0.24265095 (init=-1)
#     C_10_14:   0 (fixed)
#     D_10_14:   0 (fixed)
#     A_10_15:  -0.10349758 (init= 1)
#     B_10_15:  -0.50590856 (init=-1)
#     C_10_15:   0 (fixed)
#     D_10_15:   0 (fixed)
#     A_10_16:   0.09344703 (init= 1)
#     B_10_16:  -0.11328177 (init=-1)
#     C_10_16:   0 (fixed)
#     D_10_16:   0 (fixed)
#     A_10_17:  -0.12318780 (init= 1)
#     B_10_17:   7.72918556 (init=-1)
#     C_10_17:   0 (fixed)
#     D_10_17:   0 (fixed)
#     A_10_18:  -0.00142574 (init= 1)
#     B_10_18:   0.24643520 (init=-1)
#     C_10_18:   0 (fixed)
#     D_10_18:   0 (fixed)
#     A_10_19:  -0.01618756 (init= 1)
#     B_10_19:  -5.67158324 (init=-1)
#     C_10_19:   0 (fixed)
#     D_10_19:   0 (fixed)
#     A_11_0:    0 (fixed)
#     B_11_0:    0 (fixed)
#     C_11_0:    0 (fixed)
#     D_11_0:    0 (fixed)
#     A_11_1:    0 (fixed)
#     B_11_1:    0 (fixed)
#     C_11_1:    0 (fixed)
#     D_11_1:    0 (fixed)
#     A_11_2:    0 (fixed)
#     B_11_2:    0 (fixed)
#     C_11_2:    0 (fixed)
#     D_11_2:    0 (fixed)
#     A_11_3:    0 (fixed)
#     B_11_3:    0 (fixed)
#     C_11_3:    0 (fixed)
#     D_11_3:    0 (fixed)
#     A_11_4:    0 (fixed)
#     B_11_4:    0 (fixed)
#     C_11_4:    0 (fixed)
#     D_11_4:    0 (fixed)
#     A_11_5:    0 (fixed)
#     B_11_5:    0 (fixed)
#     C_11_5:    0 (fixed)
#     D_11_5:    0 (fixed)
#     A_11_6:    0 (fixed)
#     B_11_6:    0 (fixed)
#     C_11_6:    0 (fixed)
#     D_11_6:    0 (fixed)
#     A_11_7:    0 (fixed)
#     B_11_7:    0 (fixed)
#     C_11_7:    0 (fixed)
#     D_11_7:    0 (fixed)
#     A_11_8:    0 (fixed)
#     B_11_8:    0 (fixed)
#     C_11_8:    0 (fixed)
#     D_11_8:    0 (fixed)
#     A_11_9:    0 (fixed)
#     B_11_9:    0 (fixed)
#     C_11_9:    0 (fixed)
#     D_11_9:    0 (fixed)
#     A_11_10:   0 (fixed)
#     B_11_10:   0 (fixed)
#     C_11_10:   0 (fixed)
#     D_11_10:   0 (fixed)
#     A_11_11:  -0.23053885 (init= 1)
#     B_11_11:   3.95223116 (init=-1)
#     C_11_11:   0 (fixed)
#     D_11_11:   0 (fixed)
#     A_11_12:   0 (fixed)
#     B_11_12:  -0.34513784 (init=-1)
#     C_11_12:   0 (fixed)
#     D_11_12:   0 (fixed)
#     A_11_13:  -0.20653074 (init= 1)
#     B_11_13:  -0.00893005 (init=-1)
#     C_11_13:   0 (fixed)
#     D_11_13:   0 (fixed)
#     A_11_14:  -0.00980320 (init= 1)
#     B_11_14:   0.38422924 (init=-1)
#     C_11_14:   0 (fixed)
#     D_11_14:   0 (fixed)
#     A_11_15:   0.05042933 (init= 1)
#     B_11_15:  -0.10025197 (init=-1)
#     C_11_15:   0 (fixed)
#     D_11_15:   0 (fixed)
#     A_11_16:   0.03311805 (init= 1)
#     B_11_16:   0.29949924 (init=-1)
#     C_11_16:   0 (fixed)
#     D_11_16:   0 (fixed)
#     A_11_17:  -0.02320227 (init= 1)
#     B_11_17:   0.03007912 (init=-1)
#     C_11_17:   0 (fixed)
#     D_11_17:   0 (fixed)
#     A_11_18:   0.03443496 (init= 1)
#     B_11_18:  -1.63344454 (init=-1)
#     C_11_18:   0 (fixed)
#     D_11_18:   0 (fixed)
#     A_11_19:  -0.00449322 (init= 1)
#     B_11_19:  -0.04063525 (init=-1)
#     C_11_19:   0 (fixed)
#     D_11_19:   0 (fixed)
#     A_12_0:    0 (fixed)
#     B_12_0:    0 (fixed)
#     C_12_0:    0 (fixed)
#     D_12_0:    0 (fixed)
#     A_12_1:    0 (fixed)
#     B_12_1:    0 (fixed)
#     C_12_1:    0 (fixed)
#     D_12_1:    0 (fixed)
#     A_12_2:    0 (fixed)
#     B_12_2:    0 (fixed)
#     C_12_2:    0 (fixed)
#     D_12_2:    0 (fixed)
#     A_12_3:    0 (fixed)
#     B_12_3:    0 (fixed)
#     C_12_3:    0 (fixed)
#     D_12_3:    0 (fixed)
#     A_12_4:    0 (fixed)
#     B_12_4:    0 (fixed)
#     C_12_4:    0 (fixed)
#     D_12_4:    0 (fixed)
#     A_12_5:    0 (fixed)
#     B_12_5:    0 (fixed)
#     C_12_5:    0 (fixed)
#     D_12_5:    0 (fixed)
#     A_12_6:    0 (fixed)
#     B_12_6:    0 (fixed)
#     C_12_6:    0 (fixed)
#     D_12_6:    0 (fixed)
#     A_12_7:    0 (fixed)
#     B_12_7:    0 (fixed)
#     C_12_7:    0 (fixed)
#     D_12_7:    0 (fixed)
#     A_12_8:    0 (fixed)
#     B_12_8:    0 (fixed)
#     C_12_8:    0 (fixed)
#     D_12_8:    0 (fixed)
#     A_12_9:    0 (fixed)
#     B_12_9:    0 (fixed)
#     C_12_9:    0 (fixed)
#     D_12_9:    0 (fixed)
#     A_12_10:   0 (fixed)
#     B_12_10:   0 (fixed)
#     C_12_10:   0 (fixed)
#     D_12_10:   0 (fixed)
#     A_12_11:   0 (fixed)
#     B_12_11:   0 (fixed)
#     C_12_11:   0 (fixed)
#     D_12_11:   0 (fixed)
#     A_12_12:   0.10273036 (init= 1)
#     B_12_12:  -1.49983411 (init=-1)
#     C_12_12:   0 (fixed)
#     D_12_12:   0 (fixed)
#     A_12_13:   0 (fixed)
#     B_12_13:   0.18593343 (init=-1)
#     C_12_13:   0 (fixed)
#     D_12_13:   0 (fixed)
#     A_12_14:   0.09481772 (init= 1)
#     B_12_14:  -0.00132929 (init=-1)
#     C_12_14:   0 (fixed)
#     D_12_14:   0 (fixed)
#     A_12_15:   0.00352437 (init= 1)
#     B_12_15:  -0.13291107 (init=-1)
#     C_12_15:   0 (fixed)
#     D_12_15:   0 (fixed)
#     A_12_16:  -0.01306110 (init= 1)
#     B_12_16:   0.03416973 (init=-1)
#     C_12_16:   0 (fixed)
#     D_12_16:   0 (fixed)
#     A_12_17:  -0.00787699 (init= 1)
#     B_12_17:  -0.12567942 (init=-1)
#     C_12_17:   0 (fixed)
#     D_12_17:   0 (fixed)
#     A_12_18:   0.00385201 (init= 1)
#     B_12_18:  -0.00654444 (init=-1)
#     C_12_18:   0 (fixed)
#     D_12_18:   0 (fixed)
#     A_12_19:  -0.00565396 (init= 1)
#     B_12_19:   0.18344649 (init=-1)
#     C_12_19:   0 (fixed)
#     D_12_19:   0 (fixed)
#     A_13_0:    0 (fixed)
#     B_13_0:    0 (fixed)
#     C_13_0:    0 (fixed)
#     D_13_0:    0 (fixed)
#     A_13_1:    0 (fixed)
#     B_13_1:    0 (fixed)
#     C_13_1:    0 (fixed)
#     D_13_1:    0 (fixed)
#     A_13_2:    0 (fixed)
#     B_13_2:    0 (fixed)
#     C_13_2:    0 (fixed)
#     D_13_2:    0 (fixed)
#     A_13_3:    0 (fixed)
#     B_13_3:    0 (fixed)
#     C_13_3:    0 (fixed)
#     D_13_3:    0 (fixed)
#     A_13_4:    0 (fixed)
#     B_13_4:    0 (fixed)
#     C_13_4:    0 (fixed)
#     D_13_4:    0 (fixed)
#     A_13_5:    0 (fixed)
#     B_13_5:    0 (fixed)
#     C_13_5:    0 (fixed)
#     D_13_5:    0 (fixed)
#     A_13_6:    0 (fixed)
#     B_13_6:    0 (fixed)
#     C_13_6:    0 (fixed)
#     D_13_6:    0 (fixed)
#     A_13_7:    0 (fixed)
#     B_13_7:    0 (fixed)
#     C_13_7:    0 (fixed)
#     D_13_7:    0 (fixed)
#     A_13_8:    0 (fixed)
#     B_13_8:    0 (fixed)
#     C_13_8:    0 (fixed)
#     D_13_8:    0 (fixed)
#     A_13_9:    0 (fixed)
#     B_13_9:    0 (fixed)
#     C_13_9:    0 (fixed)
#     D_13_9:    0 (fixed)
#     A_13_10:   0 (fixed)
#     B_13_10:   0 (fixed)
#     C_13_10:   0 (fixed)
#     D_13_10:   0 (fixed)
#     A_13_11:   0 (fixed)
#     B_13_11:   0 (fixed)
#     C_13_11:   0 (fixed)
#     D_13_11:   0 (fixed)
#     A_13_12:   0 (fixed)
#     B_13_12:   0 (fixed)
#     C_13_12:   0 (fixed)
#     D_13_12:   0 (fixed)
#     A_13_13:  -0.03945272 (init= 1)
#     B_13_13:   0.50891052 (init=-1)
#     C_13_13:   0 (fixed)
#     D_13_13:   0 (fixed)
#     A_13_14:   0 (fixed)
#     B_13_14:  -0.08545192 (init=-1)
#     C_13_14:   0 (fixed)
#     D_13_14:   0 (fixed)
#     A_13_15:  -0.03658324 (init= 1)
#     B_13_15:   0.00273052 (init=-1)
#     C_13_15:   0 (fixed)
#     D_13_15:   0 (fixed)
#     A_13_16:  -0.00104736 (init= 1)
#     B_13_16:   0.03544725 (init=-1)
#     C_13_16:   0 (fixed)
#     D_13_16:   0 (fixed)
#     A_13_17:   0.00228411 (init= 1)
#     B_13_17:  -0.00914481 (init=-1)
#     C_13_17:   0 (fixed)
#     D_13_17:   0 (fixed)
#     A_13_18:   0.00118468 (init= 1)
#     B_13_18:   0.03294513 (init=-1)
#     C_13_18:   0 (fixed)
#     D_13_18:   0 (fixed)
#     A_13_19:  -0.00038392 (init= 1)
#     B_13_19:   0.00059639 (init=-1)
#     C_13_19:   0 (fixed)
#     D_13_19:   0 (fixed)
#     A_14_0:    0 (fixed)
#     B_14_0:    0 (fixed)
#     C_14_0:    0 (fixed)
#     D_14_0:    0 (fixed)
#     A_14_1:    0 (fixed)
#     B_14_1:    0 (fixed)
#     C_14_1:    0 (fixed)
#     D_14_1:    0 (fixed)
#     A_14_2:    0 (fixed)
#     B_14_2:    0 (fixed)
#     C_14_2:    0 (fixed)
#     D_14_2:    0 (fixed)
#     A_14_3:    0 (fixed)
#     B_14_3:    0 (fixed)
#     C_14_3:    0 (fixed)
#     D_14_3:    0 (fixed)
#     A_14_4:    0 (fixed)
#     B_14_4:    0 (fixed)
#     C_14_4:    0 (fixed)
#     D_14_4:    0 (fixed)
#     A_14_5:    0 (fixed)
#     B_14_5:    0 (fixed)
#     C_14_5:    0 (fixed)
#     D_14_5:    0 (fixed)
#     A_14_6:    0 (fixed)
#     B_14_6:    0 (fixed)
#     C_14_6:    0 (fixed)
#     D_14_6:    0 (fixed)
#     A_14_7:    0 (fixed)
#     B_14_7:    0 (fixed)
#     C_14_7:    0 (fixed)
#     D_14_7:    0 (fixed)
#     A_14_8:    0 (fixed)
#     B_14_8:    0 (fixed)
#     C_14_8:    0 (fixed)
#     D_14_8:    0 (fixed)
#     A_14_9:    0 (fixed)
#     B_14_9:    0 (fixed)
#     C_14_9:    0 (fixed)
#     D_14_9:    0 (fixed)
#     A_14_10:   0 (fixed)
#     B_14_10:   0 (fixed)
#     C_14_10:   0 (fixed)
#     D_14_10:   0 (fixed)
#     A_14_11:   0 (fixed)
#     B_14_11:   0 (fixed)
#     C_14_11:   0 (fixed)
#     D_14_11:   0 (fixed)
#     A_14_12:   0 (fixed)
#     B_14_12:   0 (fixed)
#     C_14_12:   0 (fixed)
#     D_14_12:   0 (fixed)
#     A_14_13:   0 (fixed)
#     B_14_13:   0 (fixed)
#     C_14_13:   0 (fixed)
#     D_14_13:   0 (fixed)
#     A_14_14:   0.01273115 (init= 1)
#     B_14_14:  -0.15183516 (init=-1)
#     C_14_14:   0 (fixed)
#     D_14_14:   0 (fixed)
#     A_14_15:   0 (fixed)
#     B_14_15:   0.03288558 (init=-1)
#     C_14_15:   0 (fixed)
#     D_14_15:   0 (fixed)
#     A_14_16:   0.01147977 (init= 1)
#     B_14_16:  -0.00159105 (init=-1)
#     C_14_16:   0 (fixed)
#     D_14_16:   0 (fixed)
#     A_14_17:   0.00022707 (init= 1)
#     B_14_17:  -0.00644068 (init=-1)
#     C_14_17:   0 (fixed)
#     D_14_17:   0 (fixed)
#     A_14_18:  -0.00017238 (init= 1)
#     B_14_18:   0.00170452 (init=-1)
#     C_14_18:   0 (fixed)
#     D_14_18:   0 (fixed)
#     A_14_19:  -0.00011925 (init= 1)
#     B_14_19:  -0.00351068 (init=-1)
#     C_14_19:   0 (fixed)
#     D_14_19:   0 (fixed)
#     A_15_0:    0 (fixed)
#     B_15_0:    0 (fixed)
#     C_15_0:    0 (fixed)
#     D_15_0:    0 (fixed)
#     A_15_1:    0 (fixed)
#     B_15_1:    0 (fixed)
#     C_15_1:    0 (fixed)
#     D_15_1:    0 (fixed)
#     A_15_2:    0 (fixed)
#     B_15_2:    0 (fixed)
#     C_15_2:    0 (fixed)
#     D_15_2:    0 (fixed)
#     A_15_3:    0 (fixed)
#     B_15_3:    0 (fixed)
#     C_15_3:    0 (fixed)
#     D_15_3:    0 (fixed)
#     A_15_4:    0 (fixed)
#     B_15_4:    0 (fixed)
#     C_15_4:    0 (fixed)
#     D_15_4:    0 (fixed)
#     A_15_5:    0 (fixed)
#     B_15_5:    0 (fixed)
#     C_15_5:    0 (fixed)
#     D_15_5:    0 (fixed)
#     A_15_6:    0 (fixed)
#     B_15_6:    0 (fixed)
#     C_15_6:    0 (fixed)
#     D_15_6:    0 (fixed)
#     A_15_7:    0 (fixed)
#     B_15_7:    0 (fixed)
#     C_15_7:    0 (fixed)
#     D_15_7:    0 (fixed)
#     A_15_8:    0 (fixed)
#     B_15_8:    0 (fixed)
#     C_15_8:    0 (fixed)
#     D_15_8:    0 (fixed)
#     A_15_9:    0 (fixed)
#     B_15_9:    0 (fixed)
#     C_15_9:    0 (fixed)
#     D_15_9:    0 (fixed)
#     A_15_10:   0 (fixed)
#     B_15_10:   0 (fixed)
#     C_15_10:   0 (fixed)
#     D_15_10:   0 (fixed)
#     A_15_11:   0 (fixed)
#     B_15_11:   0 (fixed)
#     C_15_11:   0 (fixed)
#     D_15_11:   0 (fixed)
#     A_15_12:   0 (fixed)
#     B_15_12:   0 (fixed)
#     C_15_12:   0 (fixed)
#     D_15_12:   0 (fixed)
#     A_15_13:   0 (fixed)
#     B_15_13:   0 (fixed)
#     C_15_13:   0 (fixed)
#     D_15_13:   0 (fixed)
#     A_15_14:   0 (fixed)
#     B_15_14:   0 (fixed)
#     C_15_14:   0 (fixed)
#     D_15_14:   0 (fixed)
#     A_15_15:  -0.00332968 (init= 1)
#     B_15_15:   0.03890342 (init=-1)
#     C_15_15:   0 (fixed)
#     D_15_15:   0 (fixed)
#     A_15_16:   0 (fixed)
#     B_15_16:  -0.01024832 (init=-1)
#     C_15_16:   0 (fixed)
#     D_15_16:   0 (fixed)
#     A_15_17:  -0.00277435 (init= 1)
#     B_15_17:   0.00056308 (init=-1)
#     C_15_17:   0 (fixed)
#     D_15_17:   0 (fixed)
#     A_15_18:  -3.1498e-05 (init= 1)
#     B_15_18:   0.00073512 (init=-1)
#     C_15_18:   0 (fixed)
#     D_15_18:   0 (fixed)
#     A_15_19:  -1.7127e-05 (init= 1)
#     B_15_19:  -0.00016775 (init=-1)
#     C_15_19:   0 (fixed)
#     D_15_19:   0 (fixed)
#     A_16_0:    0 (fixed)
#     B_16_0:    0 (fixed)
#     C_16_0:    0 (fixed)
#     D_16_0:    0 (fixed)
#     A_16_1:    0 (fixed)
#     B_16_1:    0 (fixed)
#     C_16_1:    0 (fixed)
#     D_16_1:    0 (fixed)
#     A_16_2:    0 (fixed)
#     B_16_2:    0 (fixed)
#     C_16_2:    0 (fixed)
#     D_16_2:    0 (fixed)
#     A_16_3:    0 (fixed)
#     B_16_3:    0 (fixed)
#     C_16_3:    0 (fixed)
#     D_16_3:    0 (fixed)
#     A_16_4:    0 (fixed)
#     B_16_4:    0 (fixed)
#     C_16_4:    0 (fixed)
#     D_16_4:    0 (fixed)
#     A_16_5:    0 (fixed)
#     B_16_5:    0 (fixed)
#     C_16_5:    0 (fixed)
#     D_16_5:    0 (fixed)
#     A_16_6:    0 (fixed)
#     B_16_6:    0 (fixed)
#     C_16_6:    0 (fixed)
#     D_16_6:    0 (fixed)
#     A_16_7:    0 (fixed)
#     B_16_7:    0 (fixed)
#     C_16_7:    0 (fixed)
#     D_16_7:    0 (fixed)
#     A_16_8:    0 (fixed)
#     B_16_8:    0 (fixed)
#     C_16_8:    0 (fixed)
#     D_16_8:    0 (fixed)
#     A_16_9:    0 (fixed)
#     B_16_9:    0 (fixed)
#     C_16_9:    0 (fixed)
#     D_16_9:    0 (fixed)
#     A_16_10:   0 (fixed)
#     B_16_10:   0 (fixed)
#     C_16_10:   0 (fixed)
#     D_16_10:   0 (fixed)
#     A_16_11:   0 (fixed)
#     B_16_11:   0 (fixed)
#     C_16_11:   0 (fixed)
#     D_16_11:   0 (fixed)
#     A_16_12:   0 (fixed)
#     B_16_12:   0 (fixed)
#     C_16_12:   0 (fixed)
#     D_16_12:   0 (fixed)
#     A_16_13:   0 (fixed)
#     B_16_13:   0 (fixed)
#     C_16_13:   0 (fixed)
#     D_16_13:   0 (fixed)
#     A_16_14:   0 (fixed)
#     B_16_14:   0 (fixed)
#     C_16_14:   0 (fixed)
#     D_16_14:   0 (fixed)
#     A_16_15:   0 (fixed)
#     B_16_15:   0 (fixed)
#     C_16_15:   0 (fixed)
#     D_16_15:   0 (fixed)
#     A_16_16:   0.00066940 (init= 1)
#     B_16_16:  -0.00826290 (init=-1)
#     C_16_16:   0 (fixed)
#     D_16_16:   0 (fixed)
#     A_16_17:   0 (fixed)
#     B_16_17:   0.00245717 (init=-1)
#     C_16_17:   0 (fixed)
#     D_16_17:   0 (fixed)
#     A_16_18:   0.00046589 (init= 1)
#     B_16_18:  -0.00012029 (init=-1)
#     C_16_18:   0 (fixed)
#     D_16_18:   0 (fixed)
#     A_16_19:   1.4000e-06 (init= 1)
#     B_16_19:  -5.8003e-05 (init=-1)
#     C_16_19:   0 (fixed)
#     D_16_19:   0 (fixed)
#     A_17_0:    0 (fixed)
#     B_17_0:    0 (fixed)
#     C_17_0:    0 (fixed)
#     D_17_0:    0 (fixed)
#     A_17_1:    0 (fixed)
#     B_17_1:    0 (fixed)
#     C_17_1:    0 (fixed)
#     D_17_1:    0 (fixed)
#     A_17_2:    0 (fixed)
#     B_17_2:    0 (fixed)
#     C_17_2:    0 (fixed)
#     D_17_2:    0 (fixed)
#     A_17_3:    0 (fixed)
#     B_17_3:    0 (fixed)
#     C_17_3:    0 (fixed)
#     D_17_3:    0 (fixed)
#     A_17_4:    0 (fixed)
#     B_17_4:    0 (fixed)
#     C_17_4:    0 (fixed)
#     D_17_4:    0 (fixed)
#     A_17_5:    0 (fixed)
#     B_17_5:    0 (fixed)
#     C_17_5:    0 (fixed)
#     D_17_5:    0 (fixed)
#     A_17_6:    0 (fixed)
#     B_17_6:    0 (fixed)
#     C_17_6:    0 (fixed)
#     D_17_6:    0 (fixed)
#     A_17_7:    0 (fixed)
#     B_17_7:    0 (fixed)
#     C_17_7:    0 (fixed)
#     D_17_7:    0 (fixed)
#     A_17_8:    0 (fixed)
#     B_17_8:    0 (fixed)
#     C_17_8:    0 (fixed)
#     D_17_8:    0 (fixed)
#     A_17_9:    0 (fixed)
#     B_17_9:    0 (fixed)
#     C_17_9:    0 (fixed)
#     D_17_9:    0 (fixed)
#     A_17_10:   0 (fixed)
#     B_17_10:   0 (fixed)
#     C_17_10:   0 (fixed)
#     D_17_10:   0 (fixed)
#     A_17_11:   0 (fixed)
#     B_17_11:   0 (fixed)
#     C_17_11:   0 (fixed)
#     D_17_11:   0 (fixed)
#     A_17_12:   0 (fixed)
#     B_17_12:   0 (fixed)
#     C_17_12:   0 (fixed)
#     D_17_12:   0 (fixed)
#     A_17_13:   0 (fixed)
#     B_17_13:   0 (fixed)
#     C_17_13:   0 (fixed)
#     D_17_13:   0 (fixed)
#     A_17_14:   0 (fixed)
#     B_17_14:   0 (fixed)
#     C_17_14:   0 (fixed)
#     D_17_14:   0 (fixed)
#     A_17_15:   0 (fixed)
#     B_17_15:   0 (fixed)
#     C_17_15:   0 (fixed)
#     D_17_15:   0 (fixed)
#     A_17_16:   0 (fixed)
#     B_17_16:   0 (fixed)
#     C_17_16:   0 (fixed)
#     D_17_16:   0 (fixed)
#     A_17_17:  -9.6113e-05 (init= 1)
#     B_17_17:   0.00137408 (init=-1)
#     C_17_17:   0 (fixed)
#     D_17_17:   0 (fixed)
#     A_17_18:   0 (fixed)
#     B_17_18:  -0.00041431 (init=-1)
#     C_17_18:   0 (fixed)
#     D_17_18:   0 (fixed)
#     A_17_19:  -4.2939e-05 (init= 1)
#     B_17_19:   1.1484e-05 (init=-1)
#     C_17_19:   0 (fixed)
#     D_17_19:   0 (fixed)
#     A_18_0:    0 (fixed)
#     B_18_0:    0 (fixed)
#     C_18_0:    0 (fixed)
#     D_18_0:    0 (fixed)
#     A_18_1:    0 (fixed)
#     B_18_1:    0 (fixed)
#     C_18_1:    0 (fixed)
#     D_18_1:    0 (fixed)
#     A_18_2:    0 (fixed)
#     B_18_2:    0 (fixed)
#     C_18_2:    0 (fixed)
#     D_18_2:    0 (fixed)
#     A_18_3:    0 (fixed)
#     B_18_3:    0 (fixed)
#     C_18_3:    0 (fixed)
#     D_18_3:    0 (fixed)
#     A_18_4:    0 (fixed)
#     B_18_4:    0 (fixed)
#     C_18_4:    0 (fixed)
#     D_18_4:    0 (fixed)
#     A_18_5:    0 (fixed)
#     B_18_5:    0 (fixed)
#     C_18_5:    0 (fixed)
#     D_18_5:    0 (fixed)
#     A_18_6:    0 (fixed)
#     B_18_6:    0 (fixed)
#     C_18_6:    0 (fixed)
#     D_18_6:    0 (fixed)
#     A_18_7:    0 (fixed)
#     B_18_7:    0 (fixed)
#     C_18_7:    0 (fixed)
#     D_18_7:    0 (fixed)
#     A_18_8:    0 (fixed)
#     B_18_8:    0 (fixed)
#     C_18_8:    0 (fixed)
#     D_18_8:    0 (fixed)
#     A_18_9:    0 (fixed)
#     B_18_9:    0 (fixed)
#     C_18_9:    0 (fixed)
#     D_18_9:    0 (fixed)
#     A_18_10:   0 (fixed)
#     B_18_10:   0 (fixed)
#     C_18_10:   0 (fixed)
#     D_18_10:   0 (fixed)
#     A_18_11:   0 (fixed)
#     B_18_11:   0 (fixed)
#     C_18_11:   0 (fixed)
#     D_18_11:   0 (fixed)
#     A_18_12:   0 (fixed)
#     B_18_12:   0 (fixed)
#     C_18_12:   0 (fixed)
#     D_18_12:   0 (fixed)
#     A_18_13:   0 (fixed)
#     B_18_13:   0 (fixed)
#     C_18_13:   0 (fixed)
#     D_18_13:   0 (fixed)
#     A_18_14:   0 (fixed)
#     B_18_14:   0 (fixed)
#     C_18_14:   0 (fixed)
#     D_18_14:   0 (fixed)
#     A_18_15:   0 (fixed)
#     B_18_15:   0 (fixed)
#     C_18_15:   0 (fixed)
#     D_18_15:   0 (fixed)
#     A_18_16:   0 (fixed)
#     B_18_16:   0 (fixed)
#     C_18_16:   0 (fixed)
#     D_18_16:   0 (fixed)
#     A_18_17:   0 (fixed)
#     B_18_17:   0 (fixed)
#     C_18_17:   0 (fixed)
#     D_18_17:   0 (fixed)
#     A_18_18:   9.0233e-06 (init= 1)
#     B_18_18:  -0.00016115 (init=-1)
#     C_18_18:   0 (fixed)
#     D_18_18:   0 (fixed)
#     A_18_19:   0 (fixed)
#     B_18_19:   3.7920e-05 (init=-1)
#     C_18_19:   0 (fixed)
#     D_18_19:   0 (fixed)
#     A_19_0:    0 (fixed)
#     B_19_0:    0 (fixed)
#     C_19_0:    0 (fixed)
#     D_19_0:    0 (fixed)
#     A_19_1:    0 (fixed)
#     B_19_1:    0 (fixed)
#     C_19_1:    0 (fixed)
#     D_19_1:    0 (fixed)
#     A_19_2:    0 (fixed)
#     B_19_2:    0 (fixed)
#     C_19_2:    0 (fixed)
#     D_19_2:    0 (fixed)
#     A_19_3:    0 (fixed)
#     B_19_3:    0 (fixed)
#     C_19_3:    0 (fixed)
#     D_19_3:    0 (fixed)
#     A_19_4:    0 (fixed)
#     B_19_4:    0 (fixed)
#     C_19_4:    0 (fixed)
#     D_19_4:    0 (fixed)
#     A_19_5:    0 (fixed)
#     B_19_5:    0 (fixed)
#     C_19_5:    0 (fixed)
#     D_19_5:    0 (fixed)
#     A_19_6:    0 (fixed)
#     B_19_6:    0 (fixed)
#     C_19_6:    0 (fixed)
#     D_19_6:    0 (fixed)
#     A_19_7:    0 (fixed)
#     B_19_7:    0 (fixed)
#     C_19_7:    0 (fixed)
#     D_19_7:    0 (fixed)
#     A_19_8:    0 (fixed)
#     B_19_8:    0 (fixed)
#     C_19_8:    0 (fixed)
#     D_19_8:    0 (fixed)
#     A_19_9:    0 (fixed)
#     B_19_9:    0 (fixed)
#     C_19_9:    0 (fixed)
#     D_19_9:    0 (fixed)
#     A_19_10:   0 (fixed)
#     B_19_10:   0 (fixed)
#     C_19_10:   0 (fixed)
#     D_19_10:   0 (fixed)
#     A_19_11:   0 (fixed)
#     B_19_11:   0 (fixed)
#     C_19_11:   0 (fixed)
#     D_19_11:   0 (fixed)
#     A_19_12:   0 (fixed)
#     B_19_12:   0 (fixed)
#     C_19_12:   0 (fixed)
#     D_19_12:   0 (fixed)
#     A_19_13:   0 (fixed)
#     B_19_13:   0 (fixed)
#     C_19_13:   0 (fixed)
#     D_19_13:   0 (fixed)
#     A_19_14:   0 (fixed)
#     B_19_14:   0 (fixed)
#     C_19_14:   0 (fixed)
#     D_19_14:   0 (fixed)
#     A_19_15:   0 (fixed)
#     B_19_15:   0 (fixed)
#     C_19_15:   0 (fixed)
#     D_19_15:   0 (fixed)
#     A_19_16:   0 (fixed)
#     B_19_16:   0 (fixed)
#     C_19_16:   0 (fixed)
#     D_19_16:   0 (fixed)
#     A_19_17:   0 (fixed)
#     B_19_17:   0 (fixed)
#     C_19_17:   0 (fixed)
#     D_19_17:   0 (fixed)
#     A_19_18:   0 (fixed)
#     B_19_18:   0 (fixed)
#     C_19_18:   0 (fixed)
#     D_19_18:   0 (fixed)
#     A_19_19:  -7.0172e-07 (init= 1)
#     B_19_19:   1.0243e-05 (init=-1)
#     C_19_19:   0 (fixed)
#     D_19_19:   0 (fixed)

# %%
ff2 = deepcopy(ff)

# %%
labs=[i[2:] for i in ff1.params if ('A' in i and ff1.params[i].vary==True and i.split('_')[1] != '0')]

As_1=[ff1.params[i].value for i in ff1.params if ('A' in i and ff1.params[i].vary==True and i.split('_')[1] != '0')]
As_2=[ff2.params[i].value for i in ff2.params if ('A' in i and ff2.params[i].vary==True and i.split('_')[1] != '0')]
#As_3=[ff3.params[i].value for i in ff3.params if ('A' in i and ff3.params[i].vary==True and i.split('_')[1] != '0')]


Bs_1=[ff1.params[i].value for i in ff1.params if ('B' in i and ff1.params[i].vary==True and i.split('_')[1] != '0')]
Bs_2=[ff2.params[i].value for i in ff2.params if ('B' in i and ff2.params[i].vary==True and i.split('_')[1] != '0')]
#Bs_3=[ff3.params[i].value for i in ff3.params if ('B' in i and ff3.params[i].vary==True and i.split('_')[1] != '0')]

# %%
_ = plt.plot(range(len(As_1)),As_1, 'o-', label='As, phi=0')
_ = plt.plot(range(len(As_1)),As_2, 'o-', label='As, phi=pi/2')
#_ = plt.plot(range(len(As_1)),As_3, 'o-', label='As, phi=pi/8')
_ = plt.axhline(0,0, 1, linestyle='--', color='k')

_ = plt.xticks(range(len(As_1)), labs, rotation='vertical')
plt.yscale('symlog')
plt.legend()
plt.title('Free param values for A')

# %%
_ = plt.plot(range(len(Bs_1)),Bs_1, 'o-', label='Bs, phi=0')
_ = plt.plot(range(len(Bs_1)),Bs_2, 'o-', label='Bs, phi=pi/2')
#_ = plt.plot(range(len(Bs_1)),Bs_3, 'o-', label='Bs, phi=pi/8')
_ = plt.axhline(0,0, 1, linestyle='--', color='k')


_ = plt.xticks(range(len(Bs_1)), labs, rotation='vertical')
plt.yscale('symlog')
plt.legend()
plt.title('Free param values for B')

# %%
_ = plt.plot(As_1,As_2, 'o', label='As')
_ = plt.plot(Bs_1,Bs_2, 's', label='Bs')
plt.ylim(-10e7, 10e7)
plt.xlim(-10e7, 10e7)
_ =plt.plot(plt.gca().get_xlim(), plt.gca().get_ylim(), 'k--', zorder=0)
_ =plt.plot(plt.gca().get_xlim(), plt.gca().get_ylim()[::-1], 'k--', zorder=0)

#_ = plt.plot(range(len(Bs_1)),Bs_2, 'o-', label='Bs, 2 slices')
#_ = plt.xticks(range(len(Bs_1)), labs, rotation='vertical')
plt.xscale('symlog')
plt.yscale('symlog')
plt.legend()
plt.title('Free param values, phi=0 vs phi=pi/2')
plt.xlabel('1 slice phi=0')
plt.ylabel('1 slice phi=pi/2')

# %%
_ = plt.plot(range(len(Bs_1)),[Bs_1[i]/Bs_2[i] for i in range(len(Bs_2))], 'o-', label='B(phi 0)/B(phi pi/2)')
#_ = plt.plot(range(len(Bs_1)),Bs_1b, 'o-', label='Bs, 1 slice phi=pi/2')
_ = plt.xticks(range(len(Bs_1)), labs, rotation='vertical')
plt.yscale('symlog')
plt.legend()
plt.title('Ratio of B values')

# %%
_ = plt.plot(range(len(As_1)),[As_1[i]/As_2[i] for i in range(len(As_2))], 'o-', label='A(phi 0)/A(phi pi/2)')
#_ = plt.plot(range(len(Bs_1)),Bs_1b, 'o-', label='Bs, 1 slice phi=pi/2')
_ = plt.xticks(range(len(As_1)), labs, rotation='vertical')
plt.yscale('symlog')
plt.legend()
plt.title('Ratio of A values')

# %%
n,m = np.meshgrid(range(21),range(21))
Anm1 = np.asarray([ff1.params[i] for i in ff1.params if 'A' in i]).reshape(20,20)
Bnm1 = np.asarray([ff1.params[i] for i in ff1.params if 'B' in i]).reshape(20,20)
Anm2 = np.asarray([ff2.params[i] for i in ff1.params if 'A' in i]).reshape(20,20)
Bnm2 = np.asarray([ff2.params[i] for i in ff1.params if 'B' in i]).reshape(20,20)
Anm_rat = np.nan_to_num(Anm1/Anm2)
Bnm_rat = np.nan_to_num(Bnm1/Bnm2)
AB_comb1 = Anm1**2+Bnm1**2
AB_comb2 = Anm2**2+Bnm2**2

# %%
import matplotlib.colors as colors
plt.pcolor(n,m, Anm1,
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=Anm.min(), vmax=Anm.max()))
plt.colorbar()
plt.title('Amn for Phi=0')
plt.xlabel('m')
plt.ylabel('n')
plt.figure()
plt.pcolor(n,m, Bnm1,
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=Bnm.min(), vmax=Bnm.max()))
plt.colorbar()
plt.title('Bmn for Phi=0')
plt.xlabel('m')
plt.ylabel('n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-4e4abc4bb7a9> in <module>()
#       1 import matplotlib.colors as colors
#       2 plt.pcolor(n,m, Anm1,
# ----> 3           norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=Anm.min(), vmax=Anm.max()))
#       4 plt.colorbar()
#       5 plt.title('Amn for Phi=0')
#
# NameError: name 'Anm' is not defined

# %%
import matplotlib.colors as colors
plt.pcolor(n,m, abs(Anm),
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=0, vmax=Anm.max()))
plt.colorbar()
plt.title('abs(Amn) for Phi=0')
plt.xlabel('m')
plt.ylabel('n')
plt.figure()
plt.pcolor(n,m, abs(Bnm),
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=0, vmax=Bnm.max()))
plt.colorbar()
plt.title('abs(Bmn) for Phi=0')
plt.xlabel('m')
plt.ylabel('n')

# %%
import matplotlib.colors as colors
plt.pcolor(n,m, abs(Anm_rat),
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=0, vmax=Anm_rat.max()))
plt.colorbar()
plt.title('abs(Amn (phi=0)/Amn (phi=pi/2))')
plt.xlabel('m')
plt.ylabel('n')
plt.figure()
plt.pcolor(n,m, abs(Bnm_rat),
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=0, vmax=Bnm_rat.max()))
plt.colorbar()
plt.title('abs(Bmn (phi=0)/Bmn (phi=pi/2))')
plt.xlabel('m')
plt.ylabel('n')

# %%
import matplotlib.colors as colors
plt.pcolor(n,m, AB_comb1,
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=AB_comb1.min(), vmax=AB_comb1.max()))
plt.colorbar()
plt.title('Anm^2+Bnm^2, phi=0')
plt.xlabel('m')
plt.ylabel('n')
plt.figure()

plt.pcolor(n,m, AB_comb2,
          norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03, vmin=AB_comb2.min(), vmax=AB_comb2.max()))
plt.colorbar()
plt.title('Anm^2+Bnm^2, phi=pi/2')
plt.xlabel('m')
plt.ylabel('n')
